# %% [markdown]
# # Modules

# %%
%%toMeta("m")
@module("m").
@non_omitable("iRel1"). @non_extensible_predicate("iRel1","bind"). @non_shrinkable("oRelA").
@input("iRel1"). @bind("iRel1","...").
iRel1("l1"). iRel1("l2").
f1("l1").
oRelA(X) :- iRel1(X), f1(X).
@label("M-R2") oRelB(X) :- iRel1(X), f2(X).
@output("oRelA"). @post("oRelA","orderby(1)").
@output("oRelB").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %%
%%toMeta("m1A").
@module("m1A"). @inherits("m").
@non_growable("oRelC").
@non_omitable("iRel1"). @non_extensible_predicate("iRel1","bind"). @non_shrinkable("oRelA").
@input("iRel1"). @bind("iRel1","...").
@input("iRel2"). @bind("iRel2","...").
iRel2("l1").
f1("l2").
iRel1("l1"). iRel1("l2").
f1("l1").
@label("F1") f2("l1").
@label("R3") oRelC(X) :- oRelA(X), oRelB(X), temp(X).
@label("R4") temp(T) :- iRel2(T), f1(T).
oRelA(X) :- iRel1(X), f1(X).
@output("oRelA"). @post("oRelA","orderby(1)").
@output("oRelB").
@output("oRelC").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %%
%%toMeta("m1B").
@module("m1B").
@input("iRel4"). @bind("iRel4","...").
iRel4("l1"). iRel4("l3").
f3("l2"). f3("l3").
@label("F1") f3("l1").
@label("R3") oRelD(X) :- oRelA(X), oRelB(X), f3(X), iRel4(X).
@output("oRelD"). %@delete("oRelD",{0}).
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %%
%%toMeta("m1C").
@module("m1C").  @inherits("m").
@non_omitable("iRel1"). @non_extensible_predicate("iRel1","bind"). @non_shrinkable("oRelA").
@input("iRel1"). @bind("iRel1","...").
@non_extensible_input.
@input("iRel3"). @bind("iRel3","...").
iRel3("l1","l1"). iRel3("l2","l3").
@label("R3") oRelC(X,Y) :- iRel3(X,Y), f1(Y).
iRel1("l1"). iRel1("l2").
f1("l1").
oRelA(X) :- iRel1(X), f1(X).
@label("M-R2") oRelB(X) :- iRel1(X), f2(X).
@output("oRelA"). @post("oRelA","orderby(1)").
@output("oRelB").
@output("oRelC").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %%
%%toMeta("m2").
@module("m2"). @inherits("m1A"). @inherits("m1B"). @inherits("m1C").

@non_growable("oRelC").
@non_extensible_input.
@non_extensible_output.
@non_omitable("iRel1"). @non_extensible_predicate("iRel1","bind"). @non_shrinkable("oRelA").
@non_omitable("iRel1"). @non_extensible_predicate("iRel1","bind"). @non_shrinkable("oRelA").
@input("iRel1"). @bind("iRel1","...").
@input("iRel1"). @bind("iRel1","...").
@input("iRel2"). @bind("iRel2","...").
@input("iRel3"). @bind("iRel3","...").
@input("iRel4"). @bind("iRel4","...").

f1("l2"). f1("l1").
@label("F1") f2("l1").
iRel1("l1"). iRel1("l2").
iRel2("l1").
iRel3("l1","l1"). iRel3("l2","l3").
iRel4("l1"). iRel4("l3").
f3("l2"). f3("l3").
@label("F1") f3("l1").
f1("l3"). f2("l3"). f2("f1").

@label("M-R2") oRelB(X) :- iRel1(X), f2(X).
@label("R3") oRelC(X) :- oRelA(X), oRelB(X), temp(X).
@label("R3") oRelC(X,Y) :- iRel3(X,Y), f1(Y).
@label("R3") oRelD(X) :- oRelA(X), oRelB(X), f3(X), iRel4(X).
@label("R4") temp(T) :- iRel2(T), f1(T).
@label("R5") oRelE(X) :- f1(X), f2(A), f3(X), iRel1(X), iRel3(A,X).
oRelA(X) :- iRel1(X), f1(X).

@output("oRelA"). @post("oRelA","orderby(1)").
@output("oRelB").
@output("oRelC").
@output("oRelC").
@output("oRelD"). %@delete("oRelD",{0}).
@output("oRelE").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %%
%%toMeta("m3").
@module("m3"). @inherits("m2").
@label("R6") oRelF(X,Y) :- iRel1(X), iRel2(X), iRel3(X,Y), iRel4(Y).
@removeQ("F1","m1C").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %% [markdown]
# **Restrictions:**
# * M: `non_omitable("iRel1").` `non_extensible_predicate("iRel1","bind")` `non_shrinkable("oRelA")`
# * M1A: `non_growable("oRelC")`
# * M1B: -
# * M1C: `non_extensible_input`
# * M2: `non_extensible_output`
# * M3: -

# %% [markdown]
# # Tests
# ## Module m

# %%
program("m").
hasRule("m","m:0").
rule("m:0").
hasPositiveHeadAtom("m:0","m:1").
relationalAtom("m:1").
hasName("m:1","oRelA").
hasArgument("m:1","m:2",0).
term("m:2").
hasSerialization("m:2","X").
hasPositiveBodyAtom("m:0","m:3").
relationalAtom("m:3").
hasName("m:3","iRel1").
hasArgument("m:3","m:4",0).
term("m:4").
hasSerialization("m:4","X").
hasPositiveBodyAtom("m:0","m:5").
relationalAtom("m:5").
hasName("m:5","f1").
hasArgument("m:5","m:6",0).
term("m:6").
hasSerialization("m:6","X").
hasRule("m","m:7").
rule("m:7").
hasPositiveHeadAtom("m:7","m:8").
relationalAtom("m:8").
hasName("m:8","oRelB").
hasArgument("m:8","m:9",0).
term("m:9").
hasSerialization("m:9","X").
hasPositiveBodyAtom("m:7","m:10").
relationalAtom("m:10").
hasName("m:10","iRel1").
hasArgument("m:10","m:11",0).
term("m:11").
hasSerialization("m:11","X").
hasPositiveBodyAtom("m:7","m:12").
relationalAtom("m:12").
hasName("m:12","f2").
hasArgument("m:12","m:13",0).
term("m:13").
hasSerialization("m:13","X").
hasAnnotation("m:7","m:14").
annotation("m:14").
hasName("m:14","label").
hasArgument("m:14","m:15",0).
term("m:15").
hasSerialization("m:15","""M-R2""").
hasFact("m","m:16").
relationalAtom("m:16").
hasName("m:16","iRel1").
hasArgument("m:16","m:17",0).
term("m:17").
hasSerialization("m:17","""l1""").
hasFact("m","m:18").
relationalAtom("m:18").
hasName("m:18","iRel1").
hasArgument("m:18","m:19",0).
term("m:19").
hasSerialization("m:19","""l2""").
hasFact("m","m:20").
relationalAtom("m:20").
hasName("m:20","f1").
hasArgument("m:20","m:21",0).
term("m:21").
hasSerialization("m:21","""l1""").
hasAnnotation("m","m:22").
annotation("m:22").
hasName("m:22","module").
hasArgument("m:22","m:23",0).
term("m:23").
hasSerialization("m:23","""m""").
hasAnnotation("m","m:24").
annotation("m:24").
hasName("m:24","non_omitable").
hasArgument("m:24","m:25",0).
term("m:25").
hasSerialization("m:25","""iRel1""").
hasAnnotation("m","m:26").
annotation("m:26").
hasName("m:26","non_extensible_predicate").
hasArgument("m:26","m:27",0).
term("m:27").
hasSerialization("m:27","""iRel1""").
hasArgument("m:26","m:28",1).
term("m:28").
hasSerialization("m:28","""bind""").
hasAnnotation("m","m:29").
annotation("m:29").
hasName("m:29","non_shrinkable").
hasArgument("m:29","m:30",0).
term("m:30").
hasSerialization("m:30","""oRelA""").
hasAnnotation("m","m:31").
annotation("m:31").
hasName("m:31","input").
hasArgument("m:31","m:32",0).
term("m:32").
hasSerialization("m:32","""iRel1""").
hasAnnotation("m","m:33").
annotation("m:33").
hasName("m:33","bind").
hasArgument("m:33","m:34",0).
term("m:34").
hasSerialization("m:34","""iRel1""").
hasArgument("m:33","m:35",1).
term("m:35").
hasSerialization("m:35","""...""").
hasAnnotation("m","m:36").
annotation("m:36").
hasName("m:36","output").
hasArgument("m:36","m:37",0).
term("m:37").
hasSerialization("m:37","""oRelA""").
hasAnnotation("m","m:38").
annotation("m:38").
hasName("m:38","post").
hasArgument("m:38","m:39",0).
term("m:39").
hasSerialization("m:39","""oRelA""").
hasArgument("m:38","m:40",1).
term("m:40").
hasSerialization("m:40","""orderby(1)""").
hasAnnotation("m","m:41").
annotation("m:41").
hasName("m:41","output").
hasArgument("m:41","m:42",0).
term("m:42").
hasSerialization("m:42","""oRelB""").

%-------------------------------------------------------------------------
% Abstract Modules
% Resolved module as input
%-------------------------------------------------------------------------
% Predicates in a module
inputPredicate(M,P) :- program(M), hasAnnotation(M,A), hasName(A,"input"), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- program(M), hasAnnotation(M,A), hasName(A,"output"), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

predicate(M,P) :- inputPredicate(M,P).
predicate(M,P) :- outputPredicate(M,P).
predicate(M,P) :- hasFact(M,F), relationalAtom(F), hasName(F,P).
predicate(M,P) :- hasRule(M,R), ruleHeadPredicate(R,P).
predicate(M,P) :- hasRule(M,R), ruleBodyPredicate(R,P).

ruleBodyPredicate(R,P):- hasRule(M,R), hasNegativeBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleBodyPredicate(R,P):- hasRule(M,R), hasPositiveBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- hasRule(M,R), hasNegativeHeadAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- hasRule(M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P).

% Derving abstract and concrete predicates
predicateDependency(M,P,P2) :- hasRule(M,R), ruleHeadPredicate(R,P), ruleBodyPredicate(R,P2).
concretePredicate(M,P) :- hasFact(M,F), relationalAtom(F), hasName(F,P).
concretePredicate(M,P) :- inputPredicate(M,P).
concretePredicate(M,P) :- hasConcreteDependency(M,P), not hasAbstractDependency(M,P).
hasConcreteDependency(M,X) :- predicateDependency(M,X,Y), concretePredicate(M,Y).
hasAbstractDependency(M,X) :- predicateDependency(M,X,Y), abstractPredicate(M,Y).

abstractPredicate(M,P) :- predicate(M,P), predicate(M,P2), not concretePredicate(M,P2), P2 = P. % P2 necessary as otherwise not warded
abstractModule(M) :- abstractPredicate(M,_).

@output("abstractPredicate").
@output("abstractModule").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %% [markdown]
# **Expected:** m is abstract due to `f2`

# %% [markdown]
# ## Module m1A

# %%
program("m1A").
hasRule("m1A","m1A:0").
rule("m1A:0").
hasPositiveHeadAtom("m1A:0","m1A:1").
relationalAtom("m1A:1").
hasName("m1A:1","oRelC").
hasArgument("m1A:1","m1A:2",0).
term("m1A:2").
hasSerialization("m1A:2","X").
hasPositiveBodyAtom("m1A:0","m1A:3").
relationalAtom("m1A:3").
hasName("m1A:3","oRelA").
hasArgument("m1A:3","m1A:4",0).
term("m1A:4").
hasSerialization("m1A:4","X").
hasPositiveBodyAtom("m1A:0","m1A:5").
relationalAtom("m1A:5").
hasName("m1A:5","oRelB").
hasArgument("m1A:5","m1A:6",0).
term("m1A:6").
hasSerialization("m1A:6","X").
hasPositiveBodyAtom("m1A:0","m1A:7").
relationalAtom("m1A:7").
hasName("m1A:7","temp").
hasArgument("m1A:7","m1A:8",0).
term("m1A:8").
hasSerialization("m1A:8","X").
hasAnnotation("m1A:0","m1A:9").
annotation("m1A:9").
hasName("m1A:9","label").
hasArgument("m1A:9","m1A:10",0).
term("m1A:10").
hasSerialization("m1A:10","""R3""").
hasRule("m1A","m1A:11").
rule("m1A:11").
hasPositiveHeadAtom("m1A:11","m1A:12").
relationalAtom("m1A:12").
hasName("m1A:12","temp").
hasArgument("m1A:12","m1A:13",0).
term("m1A:13").
hasSerialization("m1A:13","T").
hasPositiveBodyAtom("m1A:11","m1A:14").
relationalAtom("m1A:14").
hasName("m1A:14","iRel2").
hasArgument("m1A:14","m1A:15",0).
term("m1A:15").
hasSerialization("m1A:15","T").
hasPositiveBodyAtom("m1A:11","m1A:16").
relationalAtom("m1A:16").
hasName("m1A:16","f1").
hasArgument("m1A:16","m1A:17",0).
term("m1A:17").
hasSerialization("m1A:17","T").
hasAnnotation("m1A:11","m1A:18").
annotation("m1A:18").
hasName("m1A:18","label").
hasArgument("m1A:18","m1A:19",0).
term("m1A:19").
hasSerialization("m1A:19","""R4""").
hasRule("m1A","m1A:20").
rule("m1A:20").
hasPositiveHeadAtom("m1A:20","m1A:21").
relationalAtom("m1A:21").
hasName("m1A:21","oRelA").
hasArgument("m1A:21","m1A:22",0).
term("m1A:22").
hasSerialization("m1A:22","X").
hasPositiveBodyAtom("m1A:20","m1A:23").
relationalAtom("m1A:23").
hasName("m1A:23","iRel1").
hasArgument("m1A:23","m1A:24",0).
term("m1A:24").
hasSerialization("m1A:24","X").
hasPositiveBodyAtom("m1A:20","m1A:25").
relationalAtom("m1A:25").
hasName("m1A:25","f1").
hasArgument("m1A:25","m1A:26",0).
term("m1A:26").
hasSerialization("m1A:26","X").
hasFact("m1A","m1A:27").
relationalAtom("m1A:27").
hasName("m1A:27","iRel2").
hasArgument("m1A:27","m1A:28",0).
term("m1A:28").
hasSerialization("m1A:28","""l1""").
hasFact("m1A","m1A:29").
relationalAtom("m1A:29").
hasName("m1A:29","f1").
hasArgument("m1A:29","m1A:30",0).
term("m1A:30").
hasSerialization("m1A:30","""l2""").
hasFact("m1A","m1A:31").
relationalAtom("m1A:31").
hasName("m1A:31","iRel1").
hasArgument("m1A:31","m1A:32",0).
term("m1A:32").
hasSerialization("m1A:32","""l1""").
hasFact("m1A","m1A:33").
relationalAtom("m1A:33").
hasName("m1A:33","iRel1").
hasArgument("m1A:33","m1A:34",0).
term("m1A:34").
hasSerialization("m1A:34","""l2""").
hasFact("m1A","m1A:35").
relationalAtom("m1A:35").
hasName("m1A:35","f1").
hasArgument("m1A:35","m1A:36",0).
term("m1A:36").
hasSerialization("m1A:36","""l1""").
hasFact("m1A","m1A:37").
relationalAtom("m1A:37").
hasName("m1A:37","f2").
hasArgument("m1A:37","m1A:38",0).
term("m1A:38").
hasSerialization("m1A:38","""l1""").
hasAnnotation("m1A:37","m1A:39").
annotation("m1A:39").
hasName("m1A:39","label").
hasArgument("m1A:39","m1A:40",0).
term("m1A:40").
hasSerialization("m1A:40","""F1""").
hasAnnotation("m1A","m1A:41").
annotation("m1A:41").
hasName("m1A:41","module").
hasArgument("m1A:41","m1A:42",0).
term("m1A:42").
hasSerialization("m1A:42","""m1A""").
hasAnnotation("m1A","m1A:43").
annotation("m1A:43").
hasName("m1A:43","inherits").
hasArgument("m1A:43","m1A:44",0).
term("m1A:44").
hasSerialization("m1A:44","""m""").
hasAnnotation("m1A","m1A:45").
annotation("m1A:45").
hasName("m1A:45","non_growable").
hasArgument("m1A:45","m1A:46",0).
term("m1A:46").
hasSerialization("m1A:46","""oRelC""").
hasAnnotation("m1A","m1A:47").
annotation("m1A:47").
hasName("m1A:47","non_omitable").
hasArgument("m1A:47","m1A:48",0).
term("m1A:48").
hasSerialization("m1A:48","""iRel1""").
hasAnnotation("m1A","m1A:49").
annotation("m1A:49").
hasName("m1A:49","non_extensible_predicate").
hasArgument("m1A:49","m1A:50",0).
term("m1A:50").
hasSerialization("m1A:50","""iRel1""").
hasArgument("m1A:49","m1A:51",1).
term("m1A:51").
hasSerialization("m1A:51","""bind""").
hasAnnotation("m1A","m1A:52").
annotation("m1A:52").
hasName("m1A:52","non_shrinkable").
hasArgument("m1A:52","m1A:53",0).
term("m1A:53").
hasSerialization("m1A:53","""oRelA""").
hasAnnotation("m1A","m1A:54").
annotation("m1A:54").
hasName("m1A:54","input").
hasArgument("m1A:54","m1A:55",0).
term("m1A:55").
hasSerialization("m1A:55","""iRel1""").
hasAnnotation("m1A","m1A:56").
annotation("m1A:56").
hasName("m1A:56","bind").
hasArgument("m1A:56","m1A:57",0).
term("m1A:57").
hasSerialization("m1A:57","""iRel1""").
hasArgument("m1A:56","m1A:58",1).
term("m1A:58").
hasSerialization("m1A:58","""...""").
hasAnnotation("m1A","m1A:59").
annotation("m1A:59").
hasName("m1A:59","input").
hasArgument("m1A:59","m1A:60",0).
term("m1A:60").
hasSerialization("m1A:60","""iRel2""").
hasAnnotation("m1A","m1A:61").
annotation("m1A:61").
hasName("m1A:61","bind").
hasArgument("m1A:61","m1A:62",0).
term("m1A:62").
hasSerialization("m1A:62","""iRel2""").
hasArgument("m1A:61","m1A:63",1).
term("m1A:63").
hasSerialization("m1A:63","""...""").
hasAnnotation("m1A","m1A:64").
annotation("m1A:64").
hasName("m1A:64","output").
hasArgument("m1A:64","m1A:65",0).
term("m1A:65").
hasSerialization("m1A:65","""oRelA""").
hasAnnotation("m1A","m1A:66").
annotation("m1A:66").
hasName("m1A:66","post").
hasArgument("m1A:66","m1A:67",0).
term("m1A:67").
hasSerialization("m1A:67","""oRelA""").
hasArgument("m1A:66","m1A:68",1).
term("m1A:68").
hasSerialization("m1A:68","""orderby(1)""").
hasAnnotation("m1A","m1A:69").
annotation("m1A:69").
hasName("m1A:69","output").
hasArgument("m1A:69","m1A:70",0).
term("m1A:70").
hasSerialization("m1A:70","""oRelB""").
hasAnnotation("m1A","m1A:71").
annotation("m1A:71").
hasName("m1A:71","output").
hasArgument("m1A:71","m1A:72",0).
term("m1A:72").
hasSerialization("m1A:72","""oRelC""").


%-------------------------------------------------------------------------
% Abstract Modules
% Resolved module as input
%-------------------------------------------------------------------------
% Predicates in a module
inputPredicate(M,P) :- program(M), hasAnnotation(M,A), hasName(A,"input"), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- program(M), hasAnnotation(M,A), hasName(A,"output"), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

predicate(M,P) :- inputPredicate(M,P).
predicate(M,P) :- outputPredicate(M,P).
predicate(M,P) :- hasFact(M,F), relationalAtom(F), hasName(F,P).
predicate(M,P) :- hasRule(M,R), ruleHeadPredicate(R,P).
predicate(M,P) :- hasRule(M,R), ruleBodyPredicate(R,P).

ruleBodyPredicate(R,P):- hasRule(M,R), hasNegativeBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleBodyPredicate(R,P):- hasRule(M,R), hasPositiveBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- hasRule(M,R), hasNegativeHeadAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- hasRule(M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P).

% Derving abstract and concrete predicates
predicateDependency(M,P,P2) :- hasRule(M,R), ruleHeadPredicate(R,P), ruleBodyPredicate(R,P2).
concretePredicate(M,P) :- hasFact(M,F), relationalAtom(F), hasName(F,P).
concretePredicate(M,P) :- inputPredicate(M,P).
concretePredicate(M,P) :- hasConcreteDependency(M,P), not hasAbstractDependency(M,P).
hasConcreteDependency(M,X) :- predicateDependency(M,X,Y), concretePredicate(M,Y).
hasAbstractDependency(M,X) :- predicateDependency(M,X,Y), abstractPredicate(M,Y).

abstractPredicate(M,P) :- predicate(M,P), predicate(M,P2), not concretePredicate(M,P2), P2 = P. % P2 necessary as otherwise not warded
abstractModule(M) :- abstractPredicate(M,_).

@output("abstractPredicate").
@output("abstractModule").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %% [markdown]
# **Expected:** abstract due to `oRelB` whose deriving rule is redefined
# ## Module m1B

# %%
program("m1B").
hasRule("m1B","m1B:0").
rule("m1B:0").
hasPositiveHeadAtom("m1B:0","m1B:1").
relationalAtom("m1B:1").
hasName("m1B:1","oRelD").
hasArgument("m1B:1","m1B:2",0).
term("m1B:2").
hasSerialization("m1B:2","X").
hasPositiveBodyAtom("m1B:0","m1B:3").
relationalAtom("m1B:3").
hasName("m1B:3","oRelA").
hasArgument("m1B:3","m1B:4",0).
term("m1B:4").
hasSerialization("m1B:4","X").
hasPositiveBodyAtom("m1B:0","m1B:5").
relationalAtom("m1B:5").
hasName("m1B:5","oRelB").
hasArgument("m1B:5","m1B:6",0).
term("m1B:6").
hasSerialization("m1B:6","X").
hasPositiveBodyAtom("m1B:0","m1B:7").
relationalAtom("m1B:7").
hasName("m1B:7","f3").
hasArgument("m1B:7","m1B:8",0).
term("m1B:8").
hasSerialization("m1B:8","X").
hasPositiveBodyAtom("m1B:0","m1B:9").
relationalAtom("m1B:9").
hasName("m1B:9","iRel4").
hasArgument("m1B:9","m1B:10",0).
term("m1B:10").
hasSerialization("m1B:10","X").
hasAnnotation("m1B:0","m1B:11").
annotation("m1B:11").
hasName("m1B:11","label").
hasArgument("m1B:11","m1B:12",0).
term("m1B:12").
hasSerialization("m1B:12","""R3""").
hasFact("m1B","m1B:13").
relationalAtom("m1B:13").
hasName("m1B:13","iRel4").
hasArgument("m1B:13","m1B:14",0).
term("m1B:14").
hasSerialization("m1B:14","""l1""").
hasFact("m1B","m1B:15").
relationalAtom("m1B:15").
hasName("m1B:15","iRel4").
hasArgument("m1B:15","m1B:16",0).
term("m1B:16").
hasSerialization("m1B:16","""l3""").
hasFact("m1B","m1B:17").
relationalAtom("m1B:17").
hasName("m1B:17","f3").
hasArgument("m1B:17","m1B:18",0).
term("m1B:18").
hasSerialization("m1B:18","""l2""").
hasFact("m1B","m1B:19").
relationalAtom("m1B:19").
hasName("m1B:19","f3").
hasArgument("m1B:19","m1B:20",0).
term("m1B:20").
hasSerialization("m1B:20","""l3""").
hasFact("m1B","m1B:21").
relationalAtom("m1B:21").
hasName("m1B:21","f3").
hasArgument("m1B:21","m1B:22",0).
term("m1B:22").
hasSerialization("m1B:22","""l1""").
hasAnnotation("m1B:21","m1B:23").
annotation("m1B:23").
hasName("m1B:23","label").
hasArgument("m1B:23","m1B:24",0).
term("m1B:24").
hasSerialization("m1B:24","""F1""").
hasAnnotation("m1B","m1B:25").
annotation("m1B:25").
hasName("m1B:25","module").
hasArgument("m1B:25","m1B:26",0).
term("m1B:26").
hasSerialization("m1B:26","""m1B""").
hasAnnotation("m1B","m1B:27").
annotation("m1B:27").
hasName("m1B:27","input").
hasArgument("m1B:27","m1B:28",0).
term("m1B:28").
hasSerialization("m1B:28","""iRel4""").
hasAnnotation("m1B","m1B:29").
annotation("m1B:29").
hasName("m1B:29","bind").
hasArgument("m1B:29","m1B:30",0).
term("m1B:30").
hasSerialization("m1B:30","""iRel4""").
hasArgument("m1B:29","m1B:31",1).
term("m1B:31").
hasSerialization("m1B:31","""...""").
hasAnnotation("m1B","m1B:32").
annotation("m1B:32").
hasName("m1B:32","output").
hasArgument("m1B:32","m1B:33",0).
term("m1B:33").
hasSerialization("m1B:33","""oRelD""").

%-------------------------------------------------------------------------
% Abstract Modules
% Resolved module as input
%-------------------------------------------------------------------------
% Predicates in a module
inputPredicate(M,P) :- program(M), hasAnnotation(M,A), hasName(A,"input"), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- program(M), hasAnnotation(M,A), hasName(A,"output"), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

predicate(M,P) :- inputPredicate(M,P).
predicate(M,P) :- outputPredicate(M,P).
predicate(M,P) :- hasFact(M,F), relationalAtom(F), hasName(F,P).
predicate(M,P) :- hasRule(M,R), ruleHeadPredicate(R,P).
predicate(M,P) :- hasRule(M,R), ruleBodyPredicate(R,P).

ruleBodyPredicate(R,P):- hasRule(M,R), hasNegativeBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleBodyPredicate(R,P):- hasRule(M,R), hasPositiveBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- hasRule(M,R), hasNegativeHeadAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- hasRule(M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P).

% Derving abstract and concrete predicates
predicateDependency(M,P,P2) :- hasRule(M,R), ruleHeadPredicate(R,P), ruleBodyPredicate(R,P2).
concretePredicate(M,P) :- hasFact(M,F), relationalAtom(F), hasName(F,P).
concretePredicate(M,P) :- inputPredicate(M,P).
concretePredicate(M,P) :- hasConcreteDependency(M,P), not hasAbstractDependency(M,P).
hasConcreteDependency(M,X) :- predicateDependency(M,X,Y), concretePredicate(M,Y).
hasAbstractDependency(M,X) :- predicateDependency(M,X,Y), abstractPredicate(M,Y).

abstractPredicate(M,P) :- predicate(M,P), predicate(M,P2), not concretePredicate(M,P2), P2 = P. % P2 necessary as otherwise not warded
abstractModule(M) :- abstractPredicate(M,_).

@output("abstractPredicate").
@output("abstractModule").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %% [markdown]
# **Expected:** m1B is abstract due to `oRelA`, `oRelB`
# ## M1C

# %%
program("m1C").
hasRule("m1C","m1C:0").
rule("m1C:0").
hasPositiveHeadAtom("m1C:0","m1C:1").
relationalAtom("m1C:1").
hasName("m1C:1","oRelC").
hasArgument("m1C:1","m1C:2",0).
term("m1C:2").
hasSerialization("m1C:2","X").
hasArgument("m1C:1","m1C:3",1).
term("m1C:3").
hasSerialization("m1C:3","Y").
hasPositiveBodyAtom("m1C:0","m1C:4").
relationalAtom("m1C:4").
hasName("m1C:4","iRel3").
hasArgument("m1C:4","m1C:5",0).
term("m1C:5").
hasSerialization("m1C:5","X").
hasArgument("m1C:4","m1C:6",1).
term("m1C:6").
hasSerialization("m1C:6","Y").
hasPositiveBodyAtom("m1C:0","m1C:7").
relationalAtom("m1C:7").
hasName("m1C:7","f1").
hasArgument("m1C:7","m1C:8",0).
term("m1C:8").
hasSerialization("m1C:8","Y").
hasAnnotation("m1C:0","m1C:9").
annotation("m1C:9").
hasName("m1C:9","label").
hasArgument("m1C:9","m1C:10",0).
term("m1C:10").
hasSerialization("m1C:10","""R3""").
hasRule("m1C","m1C:11").
rule("m1C:11").
hasPositiveHeadAtom("m1C:11","m1C:12").
relationalAtom("m1C:12").
hasName("m1C:12","oRelA").
hasArgument("m1C:12","m1C:13",0).
term("m1C:13").
hasSerialization("m1C:13","X").
hasPositiveBodyAtom("m1C:11","m1C:14").
relationalAtom("m1C:14").
hasName("m1C:14","iRel1").
hasArgument("m1C:14","m1C:15",0).
term("m1C:15").
hasSerialization("m1C:15","X").
hasPositiveBodyAtom("m1C:11","m1C:16").
relationalAtom("m1C:16").
hasName("m1C:16","f1").
hasArgument("m1C:16","m1C:17",0).
term("m1C:17").
hasSerialization("m1C:17","X").
hasRule("m1C","m1C:18").
rule("m1C:18").
hasPositiveHeadAtom("m1C:18","m1C:19").
relationalAtom("m1C:19").
hasName("m1C:19","oRelB").
hasArgument("m1C:19","m1C:20",0).
term("m1C:20").
hasSerialization("m1C:20","X").
hasPositiveBodyAtom("m1C:18","m1C:21").
relationalAtom("m1C:21").
hasName("m1C:21","iRel1").
hasArgument("m1C:21","m1C:22",0).
term("m1C:22").
hasSerialization("m1C:22","X").
hasPositiveBodyAtom("m1C:18","m1C:23").
relationalAtom("m1C:23").
hasName("m1C:23","f2").
hasArgument("m1C:23","m1C:24",0).
term("m1C:24").
hasSerialization("m1C:24","X").
hasAnnotation("m1C:18","m1C:25").
annotation("m1C:25").
hasName("m1C:25","label").
hasArgument("m1C:25","m1C:26",0).
term("m1C:26").
hasSerialization("m1C:26","""M-R2""").
hasFact("m1C","m1C:27").
relationalAtom("m1C:27").
hasName("m1C:27","iRel3").
hasArgument("m1C:27","m1C:28",0).
term("m1C:28").
hasSerialization("m1C:28","""l1""").
hasArgument("m1C:27","m1C:29",1).
term("m1C:29").
hasSerialization("m1C:29","""l1""").
hasFact("m1C","m1C:30").
relationalAtom("m1C:30").
hasName("m1C:30","iRel3").
hasArgument("m1C:30","m1C:31",0).
term("m1C:31").
hasSerialization("m1C:31","""l2""").
hasArgument("m1C:30","m1C:32",1).
term("m1C:32").
hasSerialization("m1C:32","""l3""").
hasFact("m1C","m1C:33").
relationalAtom("m1C:33").
hasName("m1C:33","iRel1").
hasArgument("m1C:33","m1C:34",0).
term("m1C:34").
hasSerialization("m1C:34","""l1""").
hasFact("m1C","m1C:35").
relationalAtom("m1C:35").
hasName("m1C:35","iRel1").
hasArgument("m1C:35","m1C:36",0).
term("m1C:36").
hasSerialization("m1C:36","""l2""").
hasFact("m1C","m1C:37").
relationalAtom("m1C:37").
hasName("m1C:37","f1").
hasArgument("m1C:37","m1C:38",0).
term("m1C:38").
hasSerialization("m1C:38","""l1""").
hasAnnotation("m1C","m1C:39").
annotation("m1C:39").
hasName("m1C:39","module").
hasArgument("m1C:39","m1C:40",0).
term("m1C:40").
hasSerialization("m1C:40","""m1C""").
hasAnnotation("m1C","m1C:41").
annotation("m1C:41").
hasName("m1C:41","inherits").
hasArgument("m1C:41","m1C:42",0).
term("m1C:42").
hasSerialization("m1C:42","""m""").
hasAnnotation("m1C","m1C:43").
annotation("m1C:43").
hasName("m1C:43","non_omitable").
hasArgument("m1C:43","m1C:44",0).
term("m1C:44").
hasSerialization("m1C:44","""iRel1""").
hasAnnotation("m1C","m1C:45").
annotation("m1C:45").
hasName("m1C:45","non_extensible_predicate").
hasArgument("m1C:45","m1C:46",0).
term("m1C:46").
hasSerialization("m1C:46","""iRel1""").
hasArgument("m1C:45","m1C:47",1).
term("m1C:47").
hasSerialization("m1C:47","""bind""").
hasAnnotation("m1C","m1C:48").
annotation("m1C:48").
hasName("m1C:48","non_shrinkable").
hasArgument("m1C:48","m1C:49",0).
term("m1C:49").
hasSerialization("m1C:49","""oRelA""").
hasAnnotation("m1C","m1C:50").
annotation("m1C:50").
hasName("m1C:50","input").
hasArgument("m1C:50","m1C:51",0).
term("m1C:51").
hasSerialization("m1C:51","""iRel1""").
hasAnnotation("m1C","m1C:52").
annotation("m1C:52").
hasName("m1C:52","bind").
hasArgument("m1C:52","m1C:53",0).
term("m1C:53").
hasSerialization("m1C:53","""iRel1""").
hasArgument("m1C:52","m1C:54",1).
term("m1C:54").
hasSerialization("m1C:54","""...""").
hasAnnotation("m1C","m1C:55").
annotation("m1C:55").
hasName("m1C:55","non_extensible_input").
hasAnnotation("m1C","m1C:56").
annotation("m1C:56").
hasName("m1C:56","input").
hasArgument("m1C:56","m1C:57",0).
term("m1C:57").
hasSerialization("m1C:57","""iRel3""").
hasAnnotation("m1C","m1C:58").
annotation("m1C:58").
hasName("m1C:58","bind").
hasArgument("m1C:58","m1C:59",0).
term("m1C:59").
hasSerialization("m1C:59","""iRel3""").
hasArgument("m1C:58","m1C:60",1).
term("m1C:60").
hasSerialization("m1C:60","""...""").
hasAnnotation("m1C","m1C:61").
annotation("m1C:61").
hasName("m1C:61","output").
hasArgument("m1C:61","m1C:62",0).
term("m1C:62").
hasSerialization("m1C:62","""oRelA""").
hasAnnotation("m1C","m1C:63").
annotation("m1C:63").
hasName("m1C:63","post").
hasArgument("m1C:63","m1C:64",0).
term("m1C:64").
hasSerialization("m1C:64","""oRelA""").
hasArgument("m1C:63","m1C:65",1).
term("m1C:65").
hasSerialization("m1C:65","""orderby(1)""").
hasAnnotation("m1C","m1C:66").
annotation("m1C:66").
hasName("m1C:66","output").
hasArgument("m1C:66","m1C:67",0).
term("m1C:67").
hasSerialization("m1C:67","""oRelB""").
hasAnnotation("m1C","m1C:68").
annotation("m1C:68").
hasName("m1C:68","output").
hasArgument("m1C:68","m1C:69",0).
term("m1C:69").
hasSerialization("m1C:69","""oRelC""").

%-------------------------------------------------------------------------
% Abstract Modules
% Resolved module as input
%-------------------------------------------------------------------------
% Predicates in a module
inputPredicate(M,P) :- program(M), hasAnnotation(M,A), hasName(A,"input"), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- program(M), hasAnnotation(M,A), hasName(A,"output"), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

predicate(M,P) :- inputPredicate(M,P).
predicate(M,P) :- outputPredicate(M,P).
predicate(M,P) :- hasFact(M,F), relationalAtom(F), hasName(F,P).
predicate(M,P) :- hasRule(M,R), ruleHeadPredicate(R,P).
predicate(M,P) :- hasRule(M,R), ruleBodyPredicate(R,P).

ruleBodyPredicate(R,P):- hasRule(M,R), hasNegativeBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleBodyPredicate(R,P):- hasRule(M,R), hasPositiveBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- hasRule(M,R), hasNegativeHeadAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- hasRule(M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P).

% Derving abstract and concrete predicates
predicateDependency(M,P,P2) :- hasRule(M,R), ruleHeadPredicate(R,P), ruleBodyPredicate(R,P2).
concretePredicate(M,P) :- hasFact(M,F), relationalAtom(F), hasName(F,P).
concretePredicate(M,P) :- inputPredicate(M,P).
concretePredicate(M,P) :- hasConcreteDependency(M,P), not hasAbstractDependency(M,P).
hasConcreteDependency(M,X) :- predicateDependency(M,X,Y), concretePredicate(M,Y).
hasAbstractDependency(M,X) :- predicateDependency(M,X,Y), abstractPredicate(M,Y).

abstractPredicate(M,P) :- predicate(M,P), predicate(M,P2), not concretePredicate(M,P2), P2 = P. % P2 necessary as otherwise not warded
abstractModule(M) :- abstractPredicate(M,_).

@output("abstractPredicate").
@output("abstractModule").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %% [markdown]
# **Expected:** m1C is abstract due to inheriting from m and not defining f2
# ## M2

# %%
program("m2").
hasRule("m2","m2:0").
rule("m2:0").
hasPositiveHeadAtom("m2:0","m2:1").
relationalAtom("m2:1").
hasName("m2:1","oRelB").
hasArgument("m2:1","m2:2",0).
term("m2:2").
hasSerialization("m2:2","X").
hasPositiveBodyAtom("m2:0","m2:3").
relationalAtom("m2:3").
hasName("m2:3","iRel1").
hasArgument("m2:3","m2:4",0).
term("m2:4").
hasSerialization("m2:4","X").
hasPositiveBodyAtom("m2:0","m2:5").
relationalAtom("m2:5").
hasName("m2:5","f2").
hasArgument("m2:5","m2:6",0).
term("m2:6").
hasSerialization("m2:6","X").
hasAnnotation("m2:0","m2:7").
annotation("m2:7").
hasName("m2:7","label").
hasArgument("m2:7","m2:8",0).
term("m2:8").
hasSerialization("m2:8","""M-R2""").
hasRule("m2","m2:9").
rule("m2:9").
hasPositiveHeadAtom("m2:9","m2:10").
relationalAtom("m2:10").
hasName("m2:10","oRelC").
hasArgument("m2:10","m2:11",0).
term("m2:11").
hasSerialization("m2:11","X").
hasPositiveBodyAtom("m2:9","m2:12").
relationalAtom("m2:12").
hasName("m2:12","oRelA").
hasArgument("m2:12","m2:13",0).
term("m2:13").
hasSerialization("m2:13","X").
hasPositiveBodyAtom("m2:9","m2:14").
relationalAtom("m2:14").
hasName("m2:14","oRelB").
hasArgument("m2:14","m2:15",0).
term("m2:15").
hasSerialization("m2:15","X").
hasPositiveBodyAtom("m2:9","m2:16").
relationalAtom("m2:16").
hasName("m2:16","temp").
hasArgument("m2:16","m2:17",0).
term("m2:17").
hasSerialization("m2:17","X").
hasAnnotation("m2:9","m2:18").
annotation("m2:18").
hasName("m2:18","label").
hasArgument("m2:18","m2:19",0).
term("m2:19").
hasSerialization("m2:19","""R3""").
hasRule("m2","m2:20").
rule("m2:20").
hasPositiveHeadAtom("m2:20","m2:21").
relationalAtom("m2:21").
hasName("m2:21","oRelC").
hasArgument("m2:21","m2:22",0).
term("m2:22").
hasSerialization("m2:22","X").
hasArgument("m2:21","m2:23",1).
term("m2:23").
hasSerialization("m2:23","Y").
hasPositiveBodyAtom("m2:20","m2:24").
relationalAtom("m2:24").
hasName("m2:24","iRel3").
hasArgument("m2:24","m2:25",0).
term("m2:25").
hasSerialization("m2:25","X").
hasArgument("m2:24","m2:26",1).
term("m2:26").
hasSerialization("m2:26","Y").
hasPositiveBodyAtom("m2:20","m2:27").
relationalAtom("m2:27").
hasName("m2:27","f1").
hasArgument("m2:27","m2:28",0).
term("m2:28").
hasSerialization("m2:28","Y").
hasAnnotation("m2:20","m2:29").
annotation("m2:29").
hasName("m2:29","label").
hasArgument("m2:29","m2:30",0).
term("m2:30").
hasSerialization("m2:30","""R3""").
hasRule("m2","m2:31").
rule("m2:31").
hasPositiveHeadAtom("m2:31","m2:32").
relationalAtom("m2:32").
hasName("m2:32","oRelD").
hasArgument("m2:32","m2:33",0).
term("m2:33").
hasSerialization("m2:33","X").
hasPositiveBodyAtom("m2:31","m2:34").
relationalAtom("m2:34").
hasName("m2:34","oRelA").
hasArgument("m2:34","m2:35",0).
term("m2:35").
hasSerialization("m2:35","X").
hasPositiveBodyAtom("m2:31","m2:36").
relationalAtom("m2:36").
hasName("m2:36","oRelB").
hasArgument("m2:36","m2:37",0).
term("m2:37").
hasSerialization("m2:37","X").
hasPositiveBodyAtom("m2:31","m2:38").
relationalAtom("m2:38").
hasName("m2:38","f3").
hasArgument("m2:38","m2:39",0).
term("m2:39").
hasSerialization("m2:39","X").
hasPositiveBodyAtom("m2:31","m2:40").
relationalAtom("m2:40").
hasName("m2:40","iRel4").
hasArgument("m2:40","m2:41",0).
term("m2:41").
hasSerialization("m2:41","X").
hasAnnotation("m2:31","m2:42").
annotation("m2:42").
hasName("m2:42","label").
hasArgument("m2:42","m2:43",0).
term("m2:43").
hasSerialization("m2:43","""R3""").
hasRule("m2","m2:44").
rule("m2:44").
hasPositiveHeadAtom("m2:44","m2:45").
relationalAtom("m2:45").
hasName("m2:45","temp").
hasArgument("m2:45","m2:46",0).
term("m2:46").
hasSerialization("m2:46","T").
hasPositiveBodyAtom("m2:44","m2:47").
relationalAtom("m2:47").
hasName("m2:47","iRel2").
hasArgument("m2:47","m2:48",0).
term("m2:48").
hasSerialization("m2:48","T").
hasPositiveBodyAtom("m2:44","m2:49").
relationalAtom("m2:49").
hasName("m2:49","f1").
hasArgument("m2:49","m2:50",0).
term("m2:50").
hasSerialization("m2:50","T").
hasAnnotation("m2:44","m2:51").
annotation("m2:51").
hasName("m2:51","label").
hasArgument("m2:51","m2:52",0).
term("m2:52").
hasSerialization("m2:52","""R4""").
hasRule("m2","m2:53").
rule("m2:53").
hasPositiveHeadAtom("m2:53","m2:54").
relationalAtom("m2:54").
hasName("m2:54","oRelE").
hasArgument("m2:54","m2:55",0).
term("m2:55").
hasSerialization("m2:55","X").
hasPositiveBodyAtom("m2:53","m2:56").
relationalAtom("m2:56").
hasName("m2:56","f1").
hasArgument("m2:56","m2:57",0).
term("m2:57").
hasSerialization("m2:57","X").
hasPositiveBodyAtom("m2:53","m2:58").
relationalAtom("m2:58").
hasName("m2:58","f2").
hasArgument("m2:58","m2:59",0).
term("m2:59").
hasSerialization("m2:59","A").
hasPositiveBodyAtom("m2:53","m2:60").
relationalAtom("m2:60").
hasName("m2:60","f3").
hasArgument("m2:60","m2:61",0).
term("m2:61").
hasSerialization("m2:61","X").
hasPositiveBodyAtom("m2:53","m2:62").
relationalAtom("m2:62").
hasName("m2:62","iRel1").
hasArgument("m2:62","m2:63",0).
term("m2:63").
hasSerialization("m2:63","X").
hasPositiveBodyAtom("m2:53","m2:64").
relationalAtom("m2:64").
hasName("m2:64","iRel3").
hasArgument("m2:64","m2:65",0).
term("m2:65").
hasSerialization("m2:65","A").
hasArgument("m2:64","m2:66",1).
term("m2:66").
hasSerialization("m2:66","X").
hasAnnotation("m2:53","m2:67").
annotation("m2:67").
hasName("m2:67","label").
hasArgument("m2:67","m2:68",0).
term("m2:68").
hasSerialization("m2:68","""R5""").
hasRule("m2","m2:69").
rule("m2:69").
hasPositiveHeadAtom("m2:69","m2:70").
relationalAtom("m2:70").
hasName("m2:70","oRelA").
hasArgument("m2:70","m2:71",0).
term("m2:71").
hasSerialization("m2:71","X").
hasPositiveBodyAtom("m2:69","m2:72").
relationalAtom("m2:72").
hasName("m2:72","iRel1").
hasArgument("m2:72","m2:73",0).
term("m2:73").
hasSerialization("m2:73","X").
hasPositiveBodyAtom("m2:69","m2:74").
relationalAtom("m2:74").
hasName("m2:74","f1").
hasArgument("m2:74","m2:75",0).
term("m2:75").
hasSerialization("m2:75","X").
hasFact("m2","m2:76").
relationalAtom("m2:76").
hasName("m2:76","f1").
hasArgument("m2:76","m2:77",0).
term("m2:77").
hasSerialization("m2:77","""l2""").
hasFact("m2","m2:78").
relationalAtom("m2:78").
hasName("m2:78","f1").
hasArgument("m2:78","m2:79",0).
term("m2:79").
hasSerialization("m2:79","""l1""").
hasFact("m2","m2:80").
relationalAtom("m2:80").
hasName("m2:80","f2").
hasArgument("m2:80","m2:81",0).
term("m2:81").
hasSerialization("m2:81","""l1""").
hasAnnotation("m2:80","m2:82").
annotation("m2:82").
hasName("m2:82","label").
hasArgument("m2:82","m2:83",0).
term("m2:83").
hasSerialization("m2:83","""F1""").
hasFact("m2","m2:84").
relationalAtom("m2:84").
hasName("m2:84","iRel1").
hasArgument("m2:84","m2:85",0).
term("m2:85").
hasSerialization("m2:85","""l1""").
hasFact("m2","m2:86").
relationalAtom("m2:86").
hasName("m2:86","iRel1").
hasArgument("m2:86","m2:87",0).
term("m2:87").
hasSerialization("m2:87","""l2""").
hasFact("m2","m2:88").
relationalAtom("m2:88").
hasName("m2:88","iRel2").
hasArgument("m2:88","m2:89",0).
term("m2:89").
hasSerialization("m2:89","""l1""").
hasFact("m2","m2:90").
relationalAtom("m2:90").
hasName("m2:90","iRel3").
hasArgument("m2:90","m2:91",0).
term("m2:91").
hasSerialization("m2:91","""l1""").
hasArgument("m2:90","m2:92",1).
term("m2:92").
hasSerialization("m2:92","""l1""").
hasFact("m2","m2:93").
relationalAtom("m2:93").
hasName("m2:93","iRel3").
hasArgument("m2:93","m2:94",0).
term("m2:94").
hasSerialization("m2:94","""l2""").
hasArgument("m2:93","m2:95",1).
term("m2:95").
hasSerialization("m2:95","""l3""").
hasFact("m2","m2:96").
relationalAtom("m2:96").
hasName("m2:96","iRel4").
hasArgument("m2:96","m2:97",0).
term("m2:97").
hasSerialization("m2:97","""l1""").
hasFact("m2","m2:98").
relationalAtom("m2:98").
hasName("m2:98","iRel4").
hasArgument("m2:98","m2:99",0).
term("m2:99").
hasSerialization("m2:99","""l3""").
hasFact("m2","m2:100").
relationalAtom("m2:100").
hasName("m2:100","f3").
hasArgument("m2:100","m2:101",0).
term("m2:101").
hasSerialization("m2:101","""l2""").
hasFact("m2","m2:102").
relationalAtom("m2:102").
hasName("m2:102","f3").
hasArgument("m2:102","m2:103",0).
term("m2:103").
hasSerialization("m2:103","""l3""").
hasFact("m2","m2:104").
relationalAtom("m2:104").
hasName("m2:104","f3").
hasArgument("m2:104","m2:105",0).
term("m2:105").
hasSerialization("m2:105","""l1""").
hasAnnotation("m2:104","m2:106").
annotation("m2:106").
hasName("m2:106","label").
hasArgument("m2:106","m2:107",0).
term("m2:107").
hasSerialization("m2:107","""F1""").
hasFact("m2","m2:108").
relationalAtom("m2:108").
hasName("m2:108","f1").
hasArgument("m2:108","m2:109",0).
term("m2:109").
hasSerialization("m2:109","""l3""").
hasFact("m2","m2:110").
relationalAtom("m2:110").
hasName("m2:110","f2").
hasArgument("m2:110","m2:111",0).
term("m2:111").
hasSerialization("m2:111","""l3""").
hasFact("m2","m2:112").
relationalAtom("m2:112").
hasName("m2:112","f2").
hasArgument("m2:112","m2:113",0).
term("m2:113").
hasSerialization("m2:113","""f1""").
hasAnnotation("m2","m2:114").
annotation("m2:114").
hasName("m2:114","module").
hasArgument("m2:114","m2:115",0).
term("m2:115").
hasSerialization("m2:115","""m2""").
hasAnnotation("m2","m2:116").
annotation("m2:116").
hasName("m2:116","inherits").
hasArgument("m2:116","m2:117",0).
term("m2:117").
hasSerialization("m2:117","""m1A""").
hasAnnotation("m2","m2:118").
annotation("m2:118").
hasName("m2:118","inherits").
hasArgument("m2:118","m2:119",0).
term("m2:119").
hasSerialization("m2:119","""m1B""").
hasAnnotation("m2","m2:120").
annotation("m2:120").
hasName("m2:120","inherits").
hasArgument("m2:120","m2:121",0).
term("m2:121").
hasSerialization("m2:121","""m1C""").
hasAnnotation("m2","m2:122").
annotation("m2:122").
hasName("m2:122","non_growable").
hasArgument("m2:122","m2:123",0).
term("m2:123").
hasSerialization("m2:123","""oRelC""").
hasAnnotation("m2","m2:124").
annotation("m2:124").
hasName("m2:124","non_extensible_input").
hasAnnotation("m2","m2:125").
annotation("m2:125").
hasName("m2:125","non_extensible_output").
hasAnnotation("m2","m2:126").
annotation("m2:126").
hasName("m2:126","non_omitable").
hasArgument("m2:126","m2:127",0).
term("m2:127").
hasSerialization("m2:127","""iRel1""").
hasAnnotation("m2","m2:128").
annotation("m2:128").
hasName("m2:128","non_extensible_predicate").
hasArgument("m2:128","m2:129",0).
term("m2:129").
hasSerialization("m2:129","""iRel1""").
hasArgument("m2:128","m2:130",1).
term("m2:130").
hasSerialization("m2:130","""bind""").
hasAnnotation("m2","m2:131").
annotation("m2:131").
hasName("m2:131","non_shrinkable").
hasArgument("m2:131","m2:132",0).
term("m2:132").
hasSerialization("m2:132","""oRelA""").
hasAnnotation("m2","m2:133").
annotation("m2:133").
hasName("m2:133","non_omitable").
hasArgument("m2:133","m2:134",0).
term("m2:134").
hasSerialization("m2:134","""iRel1""").
hasAnnotation("m2","m2:135").
annotation("m2:135").
hasName("m2:135","non_extensible_predicate").
hasArgument("m2:135","m2:136",0).
term("m2:136").
hasSerialization("m2:136","""iRel1""").
hasArgument("m2:135","m2:137",1).
term("m2:137").
hasSerialization("m2:137","""bind""").
hasAnnotation("m2","m2:138").
annotation("m2:138").
hasName("m2:138","non_shrinkable").
hasArgument("m2:138","m2:139",0).
term("m2:139").
hasSerialization("m2:139","""oRelA""").
hasAnnotation("m2","m2:140").
annotation("m2:140").
hasName("m2:140","input").
hasArgument("m2:140","m2:141",0).
term("m2:141").
hasSerialization("m2:141","""iRel1""").
hasAnnotation("m2","m2:142").
annotation("m2:142").
hasName("m2:142","bind").
hasArgument("m2:142","m2:143",0).
term("m2:143").
hasSerialization("m2:143","""iRel1""").
hasArgument("m2:142","m2:144",1).
term("m2:144").
hasSerialization("m2:144","""...""").
hasAnnotation("m2","m2:145").
annotation("m2:145").
hasName("m2:145","input").
hasArgument("m2:145","m2:146",0).
term("m2:146").
hasSerialization("m2:146","""iRel1""").
hasAnnotation("m2","m2:147").
annotation("m2:147").
hasName("m2:147","bind").
hasArgument("m2:147","m2:148",0).
term("m2:148").
hasSerialization("m2:148","""iRel1""").
hasArgument("m2:147","m2:149",1).
term("m2:149").
hasSerialization("m2:149","""...""").
hasAnnotation("m2","m2:150").
annotation("m2:150").
hasName("m2:150","input").
hasArgument("m2:150","m2:151",0).
term("m2:151").
hasSerialization("m2:151","""iRel2""").
hasAnnotation("m2","m2:152").
annotation("m2:152").
hasName("m2:152","bind").
hasArgument("m2:152","m2:153",0).
term("m2:153").
hasSerialization("m2:153","""iRel2""").
hasArgument("m2:152","m2:154",1).
term("m2:154").
hasSerialization("m2:154","""...""").
hasAnnotation("m2","m2:155").
annotation("m2:155").
hasName("m2:155","input").
hasArgument("m2:155","m2:156",0).
term("m2:156").
hasSerialization("m2:156","""iRel3""").
hasAnnotation("m2","m2:157").
annotation("m2:157").
hasName("m2:157","bind").
hasArgument("m2:157","m2:158",0).
term("m2:158").
hasSerialization("m2:158","""iRel3""").
hasArgument("m2:157","m2:159",1).
term("m2:159").
hasSerialization("m2:159","""...""").
hasAnnotation("m2","m2:160").
annotation("m2:160").
hasName("m2:160","input").
hasArgument("m2:160","m2:161",0).
term("m2:161").
hasSerialization("m2:161","""iRel4""").
hasAnnotation("m2","m2:162").
annotation("m2:162").
hasName("m2:162","bind").
hasArgument("m2:162","m2:163",0).
term("m2:163").
hasSerialization("m2:163","""iRel4""").
hasArgument("m2:162","m2:164",1).
term("m2:164").
hasSerialization("m2:164","""...""").
hasAnnotation("m2","m2:165").
annotation("m2:165").
hasName("m2:165","output").
hasArgument("m2:165","m2:166",0).
term("m2:166").
hasSerialization("m2:166","""oRelA""").
hasAnnotation("m2","m2:167").
annotation("m2:167").
hasName("m2:167","post").
hasArgument("m2:167","m2:168",0).
term("m2:168").
hasSerialization("m2:168","""oRelA""").
hasArgument("m2:167","m2:169",1).
term("m2:169").
hasSerialization("m2:169","""orderby(1)""").
hasAnnotation("m2","m2:170").
annotation("m2:170").
hasName("m2:170","output").
hasArgument("m2:170","m2:171",0).
term("m2:171").
hasSerialization("m2:171","""oRelB""").
hasAnnotation("m2","m2:172").
annotation("m2:172").
hasName("m2:172","output").
hasArgument("m2:172","m2:173",0).
term("m2:173").
hasSerialization("m2:173","""oRelC""").
hasAnnotation("m2","m2:174").
annotation("m2:174").
hasName("m2:174","output").
hasArgument("m2:174","m2:175",0).
term("m2:175").
hasSerialization("m2:175","""oRelC""").
hasAnnotation("m2","m2:176").
annotation("m2:176").
hasName("m2:176","output").
hasArgument("m2:176","m2:177",0).
term("m2:177").
hasSerialization("m2:177","""oRelD""").
hasAnnotation("m2","m2:178").
annotation("m2:178").
hasName("m2:178","output").
hasArgument("m2:178","m2:179",0).
term("m2:179").
hasSerialization("m2:179","""oRelE""").


%-------------------------------------------------------------------------
% Abstract Modules
% Resolved module as input
%-------------------------------------------------------------------------
% Predicates in a module
inputPredicate(M,P) :- program(M), hasAnnotation(M,A), hasName(A,"input"), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- program(M), hasAnnotation(M,A), hasName(A,"output"), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

predicate(M,P) :- inputPredicate(M,P).
predicate(M,P) :- outputPredicate(M,P).
predicate(M,P) :- hasFact(M,F), relationalAtom(F), hasName(F,P).
predicate(M,P) :- hasRule(M,R), ruleHeadPredicate(R,P).
predicate(M,P) :- hasRule(M,R), ruleBodyPredicate(R,P).

ruleBodyPredicate(R,P):- hasRule(M,R), hasNegativeBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleBodyPredicate(R,P):- hasRule(M,R), hasPositiveBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- hasRule(M,R), hasNegativeHeadAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- hasRule(M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P).

% Derving abstract and concrete predicates
predicateDependency(M,P,P2) :- hasRule(M,R), ruleHeadPredicate(R,P), ruleBodyPredicate(R,P2).
concretePredicate(M,P) :- hasFact(M,F), relationalAtom(F), hasName(F,P).
concretePredicate(M,P) :- inputPredicate(M,P).
concretePredicate(M,P) :- hasConcreteDependency(M,P), not hasAbstractDependency(M,P).
hasConcreteDependency(M,X) :- predicateDependency(M,X,Y), concretePredicate(M,Y).
hasAbstractDependency(M,X) :- predicateDependency(M,X,Y), abstractPredicate(M,Y).

abstractPredicate(M,P) :- predicate(M,P), predicate(M,P2), not concretePredicate(M,P2), P2 = P. % P2 necessary as otherwise not warded
abstractModule(M) :- abstractPredicate(M,_).

@output("abstractPredicate").
@output("abstractModule").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %% [markdown]
# **Expected:** all concrete
