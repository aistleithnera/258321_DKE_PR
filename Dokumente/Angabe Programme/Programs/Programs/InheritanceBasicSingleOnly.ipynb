# %% [markdown]
# # Single Inheritance of Rules, Facts and Annotations

# %% [markdown]
# ## Modules

# %%
%%toMeta("m")
@module("m").
@input("iRel1"). @bind("iRel1","...").
iRel1("l1"). iRel1("l2").
f1("l1").
oRelA(X) :- iRel1(X), f1(X).
@label("M-R2") oRelB(X) :- iRel1(X), f2(X).
@output("oRelA"). @post("oRelA","orderby(1)").
@output("oRelB").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m").
# hasRule("m","m:0").
# rule("m:0").
# hasPositiveHeadAtom("m:0","m:1").
# relationalAtom("m:1").
# hasName("m:1","oRelA").
# hasArgument("m:1","m:2",0).
# term("m:2").
# hasSerialization("m:2","X").
# hasPositiveBodyAtom("m:0","m:3").
# relationalAtom("m:3").
# hasName("m:3","iRel1").
# hasArgument("m:3","m:4",0).
# term("m:4").
# hasSerialization("m:4","X").
# hasPositiveBodyAtom("m:0","m:5").
# relationalAtom("m:5").
# hasName("m:5","f1").
# hasArgument("m:5","m:6",0).
# term("m:6").
# hasSerialization("m:6","X").
# hasRule("m","m:7").
# rule("m:7").
# hasPositiveHeadAtom("m:7","m:8").
# relationalAtom("m:8").
# hasName("m:8","oRelB").
# hasArgument("m:8","m:9",0).
# term("m:9").
# hasSerialization("m:9","X").
# hasPositiveBodyAtom("m:7","m:10").
# relationalAtom("m:10").
# hasName("m:10","iRel1").
# hasArgument("m:10","m:11",0).
# term("m:11").
# hasSerialization("m:11","X").
# hasPositiveBodyAtom("m:7","m:12").
# relationalAtom("m:12").
# hasName("m:12","f2").
# hasArgument("m:12","m:13",0).
# term("m:13").
# hasSerialization("m:13","X").
# hasAnnotation("m:7","m:14").
# annotation("m:14").
# hasName("m:14","label").
# hasArgument("m:14","m:15",0).
# term("m:15").
# hasSerialization("m:15","""M-R2""").
# hasFact("m","m:16").
# relationalAtom("m:16").
# hasName("m:16","iRel1").
# hasArgument("m:16","m:17",0).
# term("m:17").
# hasSerialization("m:17","""l1""").
# hasFact("m","m:18").
# relationalAtom("m:18").
# hasName("m:18","iRel1").
# hasArgument("m:18","m:19",0).
# term("m:19").
# hasSerialization("m:19","""l2""").
# hasFact("m","m:20").
# relationalAtom("m:20").
# hasName("m:20","f1").
# hasArgument("m:20","m:21",0).
# term("m:21").
# hasSerialization("m:21","""l1""").
# hasAnnotation("m","m:22").
# annotation("m:22").
# hasName("m:22","module").
# hasArgument("m:22","m:23",0).
# term("m:23").
# hasSerialization("m:23","""m""").
# hasAnnotation("m","m:24").
# annotation("m:24").
# hasName("m:24","input").
# hasArgument("m:24","m:25",0).
# term("m:25").
# hasSerialization("m:25","""iRel1""").
# hasAnnotation("m","m:26").
# annotation("m:26").
# hasName("m:26","bind").
# hasArgument("m:26","m:27",0).
# term("m:27").
# hasSerialization("m:27","""iRel1""").
# hasArgument("m:26","m:28",1).
# term("m:28").
# hasSerialization("m:28","""...""").
# hasAnnotation("m","m:29").
# annotation("m:29").
# hasName("m:29","output").
# hasArgument("m:29","m:30",0).
# term("m:30").
# hasSerialization("m:30","""oRelA""").
# hasAnnotation("m","m:31").
# annotation("m:31").
# hasName("m:31","post").
# hasArgument("m:31","m:32",0).
# term("m:32").
# hasSerialization("m:32","""oRelA""").
# hasArgument("m:31","m:33",1).
# term("m:33").
# hasSerialization("m:33","""orderby(1)""").
# hasAnnotation("m","m:34").
# annotation("m:34").
# hasName("m:34","output").
# hasArgument("m:34","m:35",0).
# term("m:35").
# hasSerialization("m:35","""oRelB""").
# </textarea></div></div>

# %%
%%toMeta("m1A").
@module("m1A"). @inherits("m").
@input("iRel2"). @bind("iRel2","...").
iRel2("l1").
f1("l2").
@label("F1") f2("l1").
@label("R3") oRelC(X) :- oRelA(X), oRelB(X), temp(X).
@label("R4") temp(T) :- iRel2(T), f1(T).
@output("oRelC").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m1A").
# hasRule("m1A","m1A:0").
# rule("m1A:0").
# hasPositiveHeadAtom("m1A:0","m1A:1").
# relationalAtom("m1A:1").
# hasName("m1A:1","oRelC").
# hasArgument("m1A:1","m1A:2",0).
# term("m1A:2").
# hasSerialization("m1A:2","X").
# hasPositiveBodyAtom("m1A:0","m1A:3").
# relationalAtom("m1A:3").
# hasName("m1A:3","oRelA").
# hasArgument("m1A:3","m1A:4",0).
# term("m1A:4").
# hasSerialization("m1A:4","X").
# hasPositiveBodyAtom("m1A:0","m1A:5").
# relationalAtom("m1A:5").
# hasName("m1A:5","oRelB").
# hasArgument("m1A:5","m1A:6",0).
# term("m1A:6").
# hasSerialization("m1A:6","X").
# hasPositiveBodyAtom("m1A:0","m1A:7").
# relationalAtom("m1A:7").
# hasName("m1A:7","temp").
# hasArgument("m1A:7","m1A:8",0).
# term("m1A:8").
# hasSerialization("m1A:8","X").
# hasAnnotation("m1A:0","m1A:9").
# annotation("m1A:9").
# hasName("m1A:9","label").
# hasArgument("m1A:9","m1A:10",0).
# term("m1A:10").
# hasSerialization("m1A:10","""R3""").
# hasRule("m1A","m1A:11").
# rule("m1A:11").
# hasPositiveHeadAtom("m1A:11","m1A:12").
# relationalAtom("m1A:12").
# hasName("m1A:12","temp").
# hasArgument("m1A:12","m1A:13",0).
# term("m1A:13").
# hasSerialization("m1A:13","T").
# hasPositiveBodyAtom("m1A:11","m1A:14").
# relationalAtom("m1A:14").
# hasName("m1A:14","iRel2").
# hasArgument("m1A:14","m1A:15",0).
# term("m1A:15").
# hasSerialization("m1A:15","T").
# hasPositiveBodyAtom("m1A:11","m1A:16").
# relationalAtom("m1A:16").
# hasName("m1A:16","f1").
# hasArgument("m1A:16","m1A:17",0).
# term("m1A:17").
# hasSerialization("m1A:17","T").
# hasAnnotation("m1A:11","m1A:18").
# annotation("m1A:18").
# hasName("m1A:18","label").
# hasArgument("m1A:18","m1A:19",0).
# term("m1A:19").
# hasSerialization("m1A:19","""R4""").
# hasFact("m1A","m1A:20").
# relationalAtom("m1A:20").
# hasName("m1A:20","iRel2").
# hasArgument("m1A:20","m1A:21",0).
# term("m1A:21").
# hasSerialization("m1A:21","""l1""").
# hasFact("m1A","m1A:22").
# relationalAtom("m1A:22").
# hasName("m1A:22","f1").
# hasArgument("m1A:22","m1A:23",0).
# term("m1A:23").
# hasSerialization("m1A:23","""l2""").
# hasFact("m1A","m1A:24").
# relationalAtom("m1A:24").
# hasName("m1A:24","f2").
# hasArgument("m1A:24","m1A:25",0).
# term("m1A:25").
# hasSerialization("m1A:25","""l1""").
# hasAnnotation("m1A:24","m1A:26").
# annotation("m1A:26").
# hasName("m1A:26","label").
# hasArgument("m1A:26","m1A:27",0).
# term("m1A:27").
# hasSerialization("m1A:27","""F1""").
# hasAnnotation("m1A","m1A:28").
# annotation("m1A:28").
# hasName("m1A:28","module").
# hasArgument("m1A:28","m1A:29",0).
# term("m1A:29").
# hasSerialization("m1A:29","""m1A""").
# hasAnnotation("m1A","m1A:30").
# annotation("m1A:30").
# hasName("m1A:30","inherits").
# hasArgument("m1A:30","m1A:31",0).
# term("m1A:31").
# hasSerialization("m1A:31","""m""").
# hasAnnotation("m1A","m1A:32").
# annotation("m1A:32").
# hasName("m1A:32","input").
# hasArgument("m1A:32","m1A:33",0).
# term("m1A:33").
# hasSerialization("m1A:33","""iRel2""").
# hasAnnotation("m1A","m1A:34").
# annotation("m1A:34").
# hasName("m1A:34","bind").
# hasArgument("m1A:34","m1A:35",0).
# term("m1A:35").
# hasSerialization("m1A:35","""iRel2""").
# hasArgument("m1A:34","m1A:36",1).
# term("m1A:36").
# hasSerialization("m1A:36","""...""").
# hasAnnotation("m1A","m1A:37").
# annotation("m1A:37").
# hasName("m1A:37","output").
# hasArgument("m1A:37","m1A:38",0).
# term("m1A:38").
# hasSerialization("m1A:38","""oRelC""").
# </textarea></div></div>

# %%
%%toMeta("m1C").
@module("m1C"). @inherits("m").
@input("iRel3"). @bind("iRel3","...").
iRel3("l1","l1"). iRel3("l2","l3").
@label("R3") oRelC(X,Y) :- iRel3(X,Y), f1(Y).
@output("oRelC").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m1C").
# hasRule("m1C","m1C:0").
# rule("m1C:0").
# hasPositiveHeadAtom("m1C:0","m1C:1").
# relationalAtom("m1C:1").
# hasName("m1C:1","oRelC").
# hasArgument("m1C:1","m1C:2",0).
# term("m1C:2").
# hasSerialization("m1C:2","X").
# hasArgument("m1C:1","m1C:3",1).
# term("m1C:3").
# hasSerialization("m1C:3","Y").
# hasPositiveBodyAtom("m1C:0","m1C:4").
# relationalAtom("m1C:4").
# hasName("m1C:4","iRel3").
# hasArgument("m1C:4","m1C:5",0).
# term("m1C:5").
# hasSerialization("m1C:5","X").
# hasArgument("m1C:4","m1C:6",1).
# term("m1C:6").
# hasSerialization("m1C:6","Y").
# hasPositiveBodyAtom("m1C:0","m1C:7").
# relationalAtom("m1C:7").
# hasName("m1C:7","f1").
# hasArgument("m1C:7","m1C:8",0).
# term("m1C:8").
# hasSerialization("m1C:8","Y").
# hasAnnotation("m1C:0","m1C:9").
# annotation("m1C:9").
# hasName("m1C:9","label").
# hasArgument("m1C:9","m1C:10",0).
# term("m1C:10").
# hasSerialization("m1C:10","""R3""").
# hasFact("m1C","m1C:11").
# relationalAtom("m1C:11").
# hasName("m1C:11","iRel3").
# hasArgument("m1C:11","m1C:12",0).
# term("m1C:12").
# hasSerialization("m1C:12","""l1""").
# hasArgument("m1C:11","m1C:13",1).
# term("m1C:13").
# hasSerialization("m1C:13","""l1""").
# hasFact("m1C","m1C:14").
# relationalAtom("m1C:14").
# hasName("m1C:14","iRel3").
# hasArgument("m1C:14","m1C:15",0).
# term("m1C:15").
# hasSerialization("m1C:15","""l2""").
# hasArgument("m1C:14","m1C:16",1).
# term("m1C:16").
# hasSerialization("m1C:16","""l3""").
# hasAnnotation("m1C","m1C:17").
# annotation("m1C:17").
# hasName("m1C:17","module").
# hasArgument("m1C:17","m1C:18",0).
# term("m1C:18").
# hasSerialization("m1C:18","""m1C""").
# hasAnnotation("m1C","m1C:19").
# annotation("m1C:19").
# hasName("m1C:19","inherits").
# hasArgument("m1C:19","m1C:20",0).
# term("m1C:20").
# hasSerialization("m1C:20","""m""").
# hasAnnotation("m1C","m1C:21").
# annotation("m1C:21").
# hasName("m1C:21","input").
# hasArgument("m1C:21","m1C:22",0).
# term("m1C:22").
# hasSerialization("m1C:22","""iRel3""").
# hasAnnotation("m1C","m1C:23").
# annotation("m1C:23").
# hasName("m1C:23","bind").
# hasArgument("m1C:23","m1C:24",0).
# term("m1C:24").
# hasSerialization("m1C:24","""iRel3""").
# hasArgument("m1C:23","m1C:25",1).
# term("m1C:25").
# hasSerialization("m1C:25","""...""").
# hasAnnotation("m1C","m1C:26").
# annotation("m1C:26").
# hasName("m1C:26","output").
# hasArgument("m1C:26","m1C:27",0).
# term("m1C:27").
# hasSerialization("m1C:27","""oRelC""").
# </textarea></div></div>

# %%
%%toMeta("m2").
@module("m2"). @inherits("m1A").
f1("l3"). f2("l3"). f2("f1").
@label("R5") oRelE(X) :- f1(X), f2(A), f3(X), iRel1(X), iRel3(A,X).
@output("oRelE").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m2").
# hasRule("m2","m2:0").
# rule("m2:0").
# hasPositiveHeadAtom("m2:0","m2:1").
# relationalAtom("m2:1").
# hasName("m2:1","oRelE").
# hasArgument("m2:1","m2:2",0).
# term("m2:2").
# hasSerialization("m2:2","X").
# hasPositiveBodyAtom("m2:0","m2:3").
# relationalAtom("m2:3").
# hasName("m2:3","f1").
# hasArgument("m2:3","m2:4",0).
# term("m2:4").
# hasSerialization("m2:4","X").
# hasPositiveBodyAtom("m2:0","m2:5").
# relationalAtom("m2:5").
# hasName("m2:5","f2").
# hasArgument("m2:5","m2:6",0).
# term("m2:6").
# hasSerialization("m2:6","A").
# hasPositiveBodyAtom("m2:0","m2:7").
# relationalAtom("m2:7").
# hasName("m2:7","f3").
# hasArgument("m2:7","m2:8",0).
# term("m2:8").
# hasSerialization("m2:8","X").
# hasPositiveBodyAtom("m2:0","m2:9").
# relationalAtom("m2:9").
# hasName("m2:9","iRel1").
# hasArgument("m2:9","m2:10",0).
# term("m2:10").
# hasSerialization("m2:10","X").
# hasPositiveBodyAtom("m2:0","m2:11").
# relationalAtom("m2:11").
# hasName("m2:11","iRel3").
# hasArgument("m2:11","m2:12",0).
# term("m2:12").
# hasSerialization("m2:12","A").
# hasArgument("m2:11","m2:13",1).
# term("m2:13").
# hasSerialization("m2:13","X").
# hasAnnotation("m2:0","m2:14").
# annotation("m2:14").
# hasName("m2:14","label").
# hasArgument("m2:14","m2:15",0).
# term("m2:15").
# hasSerialization("m2:15","""R5""").
# hasFact("m2","m2:16").
# relationalAtom("m2:16").
# hasName("m2:16","f1").
# hasArgument("m2:16","m2:17",0).
# term("m2:17").
# hasSerialization("m2:17","""l3""").
# hasFact("m2","m2:18").
# relationalAtom("m2:18").
# hasName("m2:18","f2").
# hasArgument("m2:18","m2:19",0).
# term("m2:19").
# hasSerialization("m2:19","""l3""").
# hasFact("m2","m2:20").
# relationalAtom("m2:20").
# hasName("m2:20","f2").
# hasArgument("m2:20","m2:21",0).
# term("m2:21").
# hasSerialization("m2:21","""f1""").
# hasAnnotation("m2","m2:22").
# annotation("m2:22").
# hasName("m2:22","module").
# hasArgument("m2:22","m2:23",0).
# term("m2:23").
# hasSerialization("m2:23","""m2""").
# hasAnnotation("m2","m2:24").
# annotation("m2:24").
# hasName("m2:24","inherits").
# hasArgument("m2:24","m2:25",0).
# term("m2:25").
# hasSerialization("m2:25","""m1A""").
# hasAnnotation("m2","m2:26").
# annotation("m2:26").
# hasName("m2:26","output").
# hasArgument("m2:26","m2:27",0).
# term("m2:27").
# hasSerialization("m2:27","""oRelE""").
# </textarea></div></div>

# %%
%%toMeta("m3").
@module("m3"). @inherits("m2").
@label("R6") oRelF(X,Y) :- iRel1(X), iRel2(X), iRel3(X,Y), iRel4(Y).
@output("oRelF").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m3").
# hasRule("m3","m3:0").
# rule("m3:0").
# hasPositiveHeadAtom("m3:0","m3:1").
# relationalAtom("m3:1").
# hasName("m3:1","oRelF").
# hasArgument("m3:1","m3:2",0).
# term("m3:2").
# hasSerialization("m3:2","X").
# hasArgument("m3:1","m3:3",1).
# term("m3:3").
# hasSerialization("m3:3","Y").
# hasPositiveBodyAtom("m3:0","m3:4").
# relationalAtom("m3:4").
# hasName("m3:4","iRel1").
# hasArgument("m3:4","m3:5",0).
# term("m3:5").
# hasSerialization("m3:5","X").
# hasPositiveBodyAtom("m3:0","m3:6").
# relationalAtom("m3:6").
# hasName("m3:6","iRel2").
# hasArgument("m3:6","m3:7",0).
# term("m3:7").
# hasSerialization("m3:7","X").
# hasPositiveBodyAtom("m3:0","m3:8").
# relationalAtom("m3:8").
# hasName("m3:8","iRel3").
# hasArgument("m3:8","m3:9",0).
# term("m3:9").
# hasSerialization("m3:9","X").
# hasArgument("m3:8","m3:10",1).
# term("m3:10").
# hasSerialization("m3:10","Y").
# hasPositiveBodyAtom("m3:0","m3:11").
# relationalAtom("m3:11").
# hasName("m3:11","iRel4").
# hasArgument("m3:11","m3:12",0).
# term("m3:12").
# hasSerialization("m3:12","Y").
# hasAnnotation("m3:0","m3:13").
# annotation("m3:13").
# hasName("m3:13","label").
# hasArgument("m3:13","m3:14",0).
# term("m3:14").
# hasSerialization("m3:14","""R4""").
# hasAnnotation("m3","m3:15").
# annotation("m3:15").
# hasName("m3:15","module").
# hasArgument("m3:15","m3:16",0).
# term("m3:16").
# hasSerialization("m3:16","""m3""").
# hasAnnotation("m3","m3:17").
# annotation("m3:17").
# hasName("m3:17","inherits").
# hasArgument("m3:17","m3:18",0).
# term("m3:18").
# hasSerialization("m3:18","""m2""").
# hasAnnotation("m3","m3:19").
# annotation("m3:19").
# hasName("m3:19","output").
# hasArgument("m3:19","m3:20",0).
# term("m3:20").
# hasSerialization("m3:20","""oRelF""").
# </textarea></div></div>

# %% [markdown]
# ## Tests

# %% [markdown]
# ### Single Inheritance

# %% [markdown]
# m <- (m1A,m1C); m1A <- m2 <- m3

# %% [markdown]
# #### 0: m

# %%
% @input("toDerive").
toDerive("m").

program("m").
hasRule("m","m:0").
rule("m:0").
hasPositiveHeadAtom("m:0","m:1").
relationalAtom("m:1").
hasName("m:1","oRelA").
hasArgument("m:1","m:2",0).
term("m:2").
hasSerialization("m:2","X").
hasPositiveBodyAtom("m:0","m:3").
relationalAtom("m:3").
hasName("m:3","iRel1").
hasArgument("m:3","m:4",0).
term("m:4").
hasSerialization("m:4","X").
hasPositiveBodyAtom("m:0","m:5").
relationalAtom("m:5").
hasName("m:5","f1").
hasArgument("m:5","m:6",0).
term("m:6").
hasSerialization("m:6","X").
hasRule("m","m:7").
rule("m:7").
hasPositiveHeadAtom("m:7","m:8").
relationalAtom("m:8").
hasName("m:8","oRelB").
hasArgument("m:8","m:9",0).
term("m:9").
hasSerialization("m:9","X").
hasPositiveBodyAtom("m:7","m:10").
relationalAtom("m:10").
hasName("m:10","iRel1").
hasArgument("m:10","m:11",0).
term("m:11").
hasSerialization("m:11","X").
hasPositiveBodyAtom("m:7","m:12").
relationalAtom("m:12").
hasName("m:12","f2").
hasArgument("m:12","m:13",0).
term("m:13").
hasSerialization("m:13","X").
hasAnnotation("m:7","m:14").
annotation("m:14").
hasName("m:14","label").
hasArgument("m:14","m:15",0).
term("m:15").
hasSerialization("m:15","""M-R2""").
hasFact("m","m:16").
relationalAtom("m:16").
hasName("m:16","iRel1").
hasArgument("m:16","m:17",0).
term("m:17").
hasSerialization("m:17","""l1""").
hasFact("m","m:18").
relationalAtom("m:18").
hasName("m:18","iRel1").
hasArgument("m:18","m:19",0).
term("m:19").
hasSerialization("m:19","""l2""").
hasFact("m","m:20").
relationalAtom("m:20").
hasName("m:20","f1").
hasArgument("m:20","m:21",0).
term("m:21").
hasSerialization("m:21","""l1""").
hasAnnotation("m","m:22").
annotation("m:22").
hasName("m:22","module").
hasArgument("m:22","m:23",0).
term("m:23").
hasSerialization("m:23","""m""").
hasAnnotation("m","m:24").
annotation("m:24").
hasName("m:24","input").
hasArgument("m:24","m:25",0).
term("m:25").
hasSerialization("m:25","""iRel1""").
hasAnnotation("m","m:26").
annotation("m:26").
hasName("m:26","bind").
hasArgument("m:26","m:27",0).
term("m:27").
hasSerialization("m:27","""iRel1""").
hasArgument("m:26","m:28",1).
term("m:28").
hasSerialization("m:28","""...""").
hasAnnotation("m","m:29").
annotation("m:29").
hasName("m:29","output").
hasArgument("m:29","m:30",0).
term("m:30").
hasSerialization("m:30","""oRelA""").
hasAnnotation("m","m:31").
annotation("m:31").
hasName("m:31","post").
hasArgument("m:31","m:32",0).
term("m:32").
hasSerialization("m:32","""oRelA""").
hasArgument("m:31","m:33",1).
term("m:33").
hasSerialization("m:33","""orderby(1)""").
hasAnnotation("m","m:34").
annotation("m:34").
hasName("m:34","output").
hasArgument("m:34","m:35",0).
term("m:35").
hasSerialization("m:35","""oRelB""").

program("m1A").
hasRule("m1A","m1A:0").
rule("m1A:0").
hasPositiveHeadAtom("m1A:0","m1A:1").
relationalAtom("m1A:1").
hasName("m1A:1","oRelC").
hasArgument("m1A:1","m1A:2",0).
term("m1A:2").
hasSerialization("m1A:2","X").
hasPositiveBodyAtom("m1A:0","m1A:3").
relationalAtom("m1A:3").
hasName("m1A:3","oRelA").
hasArgument("m1A:3","m1A:4",0).
term("m1A:4").
hasSerialization("m1A:4","X").
hasPositiveBodyAtom("m1A:0","m1A:5").
relationalAtom("m1A:5").
hasName("m1A:5","oRelB").
hasArgument("m1A:5","m1A:6",0).
term("m1A:6").
hasSerialization("m1A:6","X").
hasPositiveBodyAtom("m1A:0","m1A:7").
relationalAtom("m1A:7").
hasName("m1A:7","temp").
hasArgument("m1A:7","m1A:8",0).
term("m1A:8").
hasSerialization("m1A:8","X").
hasAnnotation("m1A:0","m1A:9").
annotation("m1A:9").
hasName("m1A:9","label").
hasArgument("m1A:9","m1A:10",0).
term("m1A:10").
hasSerialization("m1A:10","""R3""").
hasRule("m1A","m1A:11").
rule("m1A:11").
hasPositiveHeadAtom("m1A:11","m1A:12").
relationalAtom("m1A:12").
hasName("m1A:12","temp").
hasArgument("m1A:12","m1A:13",0).
term("m1A:13").
hasSerialization("m1A:13","T").
hasPositiveBodyAtom("m1A:11","m1A:14").
relationalAtom("m1A:14").
hasName("m1A:14","iRel2").
hasArgument("m1A:14","m1A:15",0).
term("m1A:15").
hasSerialization("m1A:15","T").
hasPositiveBodyAtom("m1A:11","m1A:16").
relationalAtom("m1A:16").
hasName("m1A:16","f1").
hasArgument("m1A:16","m1A:17",0).
term("m1A:17").
hasSerialization("m1A:17","T").
hasAnnotation("m1A:11","m1A:18").
annotation("m1A:18").
hasName("m1A:18","label").
hasArgument("m1A:18","m1A:19",0).
term("m1A:19").
hasSerialization("m1A:19","""R4""").
hasFact("m1A","m1A:20").
relationalAtom("m1A:20").
hasName("m1A:20","iRel2").
hasArgument("m1A:20","m1A:21",0).
term("m1A:21").
hasSerialization("m1A:21","""l1""").
hasFact("m1A","m1A:22").
relationalAtom("m1A:22").
hasName("m1A:22","f1").
hasArgument("m1A:22","m1A:23",0).
term("m1A:23").
hasSerialization("m1A:23","""l2""").
hasFact("m1A","m1A:24").
relationalAtom("m1A:24").
hasName("m1A:24","f2").
hasArgument("m1A:24","m1A:25",0).
term("m1A:25").
hasSerialization("m1A:25","""l1""").
hasAnnotation("m1A:24","m1A:26").
annotation("m1A:26").
hasName("m1A:26","label").
hasArgument("m1A:26","m1A:27",0).
term("m1A:27").
hasSerialization("m1A:27","""F1""").
hasAnnotation("m1A","m1A:28").
annotation("m1A:28").
hasName("m1A:28","module").
hasArgument("m1A:28","m1A:29",0).
term("m1A:29").
hasSerialization("m1A:29","""m1A""").
hasAnnotation("m1A","m1A:30").
annotation("m1A:30").
hasName("m1A:30","inherits").
hasArgument("m1A:30","m1A:31",0).
term("m1A:31").
hasSerialization("m1A:31","""m""").
hasAnnotation("m1A","m1A:32").
annotation("m1A:32").
hasName("m1A:32","input").
hasArgument("m1A:32","m1A:33",0).
term("m1A:33").
hasSerialization("m1A:33","""iRel2""").
hasAnnotation("m1A","m1A:34").
annotation("m1A:34").
hasName("m1A:34","bind").
hasArgument("m1A:34","m1A:35",0).
term("m1A:35").
hasSerialization("m1A:35","""iRel2""").
hasArgument("m1A:34","m1A:36",1).
term("m1A:36").
hasSerialization("m1A:36","""...""").
hasAnnotation("m1A","m1A:37").
annotation("m1A:37").
hasName("m1A:37","output").
hasArgument("m1A:37","m1A:38",0).
term("m1A:38").
hasSerialization("m1A:38","""oRelC""").

program("m1C").
hasRule("m1C","m1C:0").
rule("m1C:0").
hasPositiveHeadAtom("m1C:0","m1C:1").
relationalAtom("m1C:1").
hasName("m1C:1","oRelC").
hasArgument("m1C:1","m1C:2",0).
term("m1C:2").
hasSerialization("m1C:2","X").
hasArgument("m1C:1","m1C:3",1).
term("m1C:3").
hasSerialization("m1C:3","Y").
hasPositiveBodyAtom("m1C:0","m1C:4").
relationalAtom("m1C:4").
hasName("m1C:4","iRel3").
hasArgument("m1C:4","m1C:5",0).
term("m1C:5").
hasSerialization("m1C:5","X").
hasArgument("m1C:4","m1C:6",1).
term("m1C:6").
hasSerialization("m1C:6","Y").
hasPositiveBodyAtom("m1C:0","m1C:7").
relationalAtom("m1C:7").
hasName("m1C:7","f1").
hasArgument("m1C:7","m1C:8",0).
term("m1C:8").
hasSerialization("m1C:8","Y").
hasAnnotation("m1C:0","m1C:9").
annotation("m1C:9").
hasName("m1C:9","label").
hasArgument("m1C:9","m1C:10",0).
term("m1C:10").
hasSerialization("m1C:10","""R3""").
hasFact("m1C","m1C:11").
relationalAtom("m1C:11").
hasName("m1C:11","iRel3").
hasArgument("m1C:11","m1C:12",0).
term("m1C:12").
hasSerialization("m1C:12","""l1""").
hasArgument("m1C:11","m1C:13",1).
term("m1C:13").
hasSerialization("m1C:13","""l1""").
hasFact("m1C","m1C:14").
relationalAtom("m1C:14").
hasName("m1C:14","iRel3").
hasArgument("m1C:14","m1C:15",0).
term("m1C:15").
hasSerialization("m1C:15","""l2""").
hasArgument("m1C:14","m1C:16",1).
term("m1C:16").
hasSerialization("m1C:16","""l3""").
hasAnnotation("m1C","m1C:17").
annotation("m1C:17").
hasName("m1C:17","module").
hasArgument("m1C:17","m1C:18",0).
term("m1C:18").
hasSerialization("m1C:18","""m1C""").
hasAnnotation("m1C","m1C:19").
annotation("m1C:19").
hasName("m1C:19","inherits").
hasArgument("m1C:19","m1C:20",0).
term("m1C:20").
hasSerialization("m1C:20","""m""").
hasAnnotation("m1C","m1C:21").
annotation("m1C:21").
hasName("m1C:21","input").
hasArgument("m1C:21","m1C:22",0).
term("m1C:22").
hasSerialization("m1C:22","""iRel3""").
hasAnnotation("m1C","m1C:23").
annotation("m1C:23").
hasName("m1C:23","bind").
hasArgument("m1C:23","m1C:24",0).
term("m1C:24").
hasSerialization("m1C:24","""iRel3""").
hasArgument("m1C:23","m1C:25",1).
term("m1C:25").
hasSerialization("m1C:25","""...""").
hasAnnotation("m1C","m1C:26").
annotation("m1C:26").
hasName("m1C:26","output").
hasArgument("m1C:26","m1C:27",0).
term("m1C:27").
hasSerialization("m1C:27","""oRelC""").

program("m2").
hasRule("m2","m2:0").
rule("m2:0").
hasPositiveHeadAtom("m2:0","m2:1").
relationalAtom("m2:1").
hasName("m2:1","oRelE").
hasArgument("m2:1","m2:2",0).
term("m2:2").
hasSerialization("m2:2","X").
hasPositiveBodyAtom("m2:0","m2:3").
relationalAtom("m2:3").
hasName("m2:3","f1").
hasArgument("m2:3","m2:4",0).
term("m2:4").
hasSerialization("m2:4","X").
hasPositiveBodyAtom("m2:0","m2:5").
relationalAtom("m2:5").
hasName("m2:5","f2").
hasArgument("m2:5","m2:6",0).
term("m2:6").
hasSerialization("m2:6","A").
hasPositiveBodyAtom("m2:0","m2:7").
relationalAtom("m2:7").
hasName("m2:7","f3").
hasArgument("m2:7","m2:8",0).
term("m2:8").
hasSerialization("m2:8","X").
hasPositiveBodyAtom("m2:0","m2:9").
relationalAtom("m2:9").
hasName("m2:9","iRel1").
hasArgument("m2:9","m2:10",0).
term("m2:10").
hasSerialization("m2:10","X").
hasPositiveBodyAtom("m2:0","m2:11").
relationalAtom("m2:11").
hasName("m2:11","iRel3").
hasArgument("m2:11","m2:12",0).
term("m2:12").
hasSerialization("m2:12","A").
hasArgument("m2:11","m2:13",1).
term("m2:13").
hasSerialization("m2:13","X").
hasAnnotation("m2:0","m2:14").
annotation("m2:14").
hasName("m2:14","label").
hasArgument("m2:14","m2:15",0).
term("m2:15").
hasSerialization("m2:15","""R4""").
hasFact("m2","m2:16").
relationalAtom("m2:16").
hasName("m2:16","f1").
hasArgument("m2:16","m2:17",0).
term("m2:17").
hasSerialization("m2:17","""l3""").
hasFact("m2","m2:18").
relationalAtom("m2:18").
hasName("m2:18","f2").
hasArgument("m2:18","m2:19",0).
term("m2:19").
hasSerialization("m2:19","""l3""").
hasFact("m2","m2:20").
relationalAtom("m2:20").
hasName("m2:20","f2").
hasArgument("m2:20","m2:21",0).
term("m2:21").
hasSerialization("m2:21","""f1""").
hasAnnotation("m2","m2:22").
annotation("m2:22").
hasName("m2:22","module").
hasArgument("m2:22","m2:23",0).
term("m2:23").
hasSerialization("m2:23","""m2""").
hasAnnotation("m2","m2:24").
annotation("m2:24").
hasName("m2:24","inherits").
hasArgument("m2:24","m2:25",0).
term("m2:25").
hasSerialization("m2:25","""m1A""").
hasAnnotation("m2","m2:26").
annotation("m2:26").
hasName("m2:26","inherits").
hasArgument("m2:26","m2:27",0).
term("m2:27").
hasSerialization("m2:27","""m1B""").
hasAnnotation("m2","m2:28").
annotation("m2:28").
hasName("m2:28","inherits").
hasArgument("m2:28","m2:29",0).
term("m2:29").
hasSerialization("m2:29","""m1C""").
hasAnnotation("m2","m2:30").
annotation("m2:30").
hasName("m2:30","output").
hasArgument("m2:30","m2:31",0).
term("m2:31").
hasSerialization("m2:31","""oRelE""").

program("m3").
hasRule("m3","m3:0").
rule("m3:0").
hasPositiveHeadAtom("m3:0","m3:1").
relationalAtom("m3:1").
hasName("m3:1","oRelF").
hasArgument("m3:1","m3:2",0).
term("m3:2").
hasSerialization("m3:2","X").
hasArgument("m3:1","m3:3",1).
term("m3:3").
hasSerialization("m3:3","Y").
hasPositiveBodyAtom("m3:0","m3:4").
relationalAtom("m3:4").
hasName("m3:4","iRel1").
hasArgument("m3:4","m3:5",0).
term("m3:5").
hasSerialization("m3:5","X").
hasPositiveBodyAtom("m3:0","m3:6").
relationalAtom("m3:6").
hasName("m3:6","iRel2").
hasArgument("m3:6","m3:7",0).
term("m3:7").
hasSerialization("m3:7","X").
hasPositiveBodyAtom("m3:0","m3:8").
relationalAtom("m3:8").
hasName("m3:8","iRel3").
hasArgument("m3:8","m3:9",0).
term("m3:9").
hasSerialization("m3:9","X").
hasArgument("m3:8","m3:10",1).
term("m3:10").
hasSerialization("m3:10","Y").
hasPositiveBodyAtom("m3:0","m3:11").
relationalAtom("m3:11").
hasName("m3:11","iRel4").
hasArgument("m3:11","m3:12",0).
term("m3:12").
hasSerialization("m3:12","Y").
hasAnnotation("m3:0","m3:13").
annotation("m3:13").
hasName("m3:13","label").
hasArgument("m3:13","m3:14",0).
term("m3:14").
hasSerialization("m3:14","""R4""").
hasAnnotation("m3","m3:15").
annotation("m3:15").
hasName("m3:15","module").
hasArgument("m3:15","m3:16",0).
term("m3:16").
hasSerialization("m3:16","""m3""").
hasAnnotation("m3","m3:17").
annotation("m3:17").
hasName("m3:17","inherits").
hasArgument("m3:17","m3:18",0).
term("m3:18").
hasSerialization("m3:18","""m2""").
hasAnnotation("m3","m3:19").
annotation("m3:19").
hasName("m3:19","output").
hasArgument("m3:19","m3:20",0).
term("m3:20").
hasSerialization("m3:20","""oRelF""").

% ------------------------------------------------------------------------
% INPUT
% ------------------------------------------------------------------------
% @input("toDerive").
toDerive("d").

% ------------------------------------------------------------------------
% GENERAL PREDICATES USED IN OTHER CODE SECTIONS
% ------------------------------------------------------------------------
% Definition of true needed for triple quotes
true(#T). false(#F).

% Find module labels for module IDs
moduleLbl(M,L) :- hasAnnotation(M,A), hasName(A,"module"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).

% Find Id of module to be derived
deriveModule(M) :- toDerive(L), moduleLbl(M,L).

% Determine inheritance relationships in provided meta-representations
inherits(MC,MP) :- hasAnnotation(MC,A), hasName(A,"inherits"), hasArgument(A,Arg,0), hasSerialization(Arg,MP1), moduleLbl(MP,MPL), MPL = substring(MP1,1,string_length(MP1)-1).
tInherits(M,M2) :- inherits(M,M2).
tInherits(M,M2) :- tInherits(M,M1), inherits(M1,M2).

% Input and Output predicates
inputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"input"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"output"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

% Defined restrictions and modification operations
restriction("no_additional_input").
restriction("no_additional_output").
restriction("no_additional_annotation").
restriction("non_omitable").
restriction("non_redefinable").
restriction("non_shrinkable").
restriction("non_growable").
modOp("remove"). modOp("removeQ").
modOp("redefines"). modOp("redefinesQ").
modOp("inherits").

% Inheritance Annotations
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), restriction(N).
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), modOp(N).

% Which statements exist in a module?
hasStmt(M,S) :- hasRule(M,S).
hasStmt(M,S) :- hasFact(M,S).
hasStmt(M,S) :- moduleLbl(M,_), hasAnnotation(M,S).

% Only labeled statements are interesting, others always propagated
stmtLbl(R,L) :- hasRule(M,R), hasAnnotation(R,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(F,L) :- hasFact(M,F), hasAnnotation(F,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(A,L) :- hasAnnotation(M,A), hasAnnotation(A,A2), hasName(A2,"label"), hasArgument(A2,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtML(M,S,L) :- stmtLbl(S,L), hasStmt(M,S).

% RESOLVE INHERITANCE
% Unqualified remove and redefine
redefineStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"redefines"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), L = substring(L1,1,string_length(L1)-1).
removeStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"remove"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), L = substring(L1,1,string_length(L1)-1).
% Any statement except inheritance annotations can be removed
redefineStmt(M,S):- redefineStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).
removeStmt(M,S):- removeStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).

% Qualified remove and redefine
redefineStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"redefinesQ"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), hasArgument(A,Arg3,2), hasSerialization(Arg3,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
removeStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"removeQ"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
redefineStmt(M,S) :- redefineStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).
removeStmt(M,S) :- removeStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).

% Module name annotations are not inherited
removeStmt(M,A) :- hasAnnotation(M,A), hasName(A,"module"), not deriveModule(M).

% Summarize modification operation statements
modOpStmt(M,S) :- removeStmt(M,S).
modOpStmt(M,S) :- redefineStmt(M,S).
tModOpStmt(M,M,S) :- modOpStmt(M,S).
tModOpStmt(M,Morg,S) :- inherits(M,M2), tModOpStmt(M2,Morg,S).

% DETERMINE ACTIVE STATEMENTS AND MODULE/STATEMENT ANNOTATIONS FOR MODULES
% Derive for each module its active rules by inheriting
tHasRule(M,R) :- hasRule(M,R).
tHasRule(M,R) :- inherits(M,MP), tHasRule(MP,R).
moduleStmt(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).
mHasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).

% Determine for each module its active facts by inheriting
tHasFact(M,F) :- hasFact(M,F).
tHasFact(M,F) :- inherits(M,MP), tHasFact(MP,F).
moduleStmt(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F).

% Determine for each module its active module and statement annotations
tHasAnnotationM(M,A) :- moduleLbl(M,L), hasAnnotation(M,A), hasName(A,N), not modOp(N).
tHasAnnotationM(M,A) :- inherits(M,MP), tHasAnnotationM(MP,A).
tHasAnnotationS(M,Stmt,A) :- hasStmt(M,Stmt), hasAnnotation(Stmt,A).
tHasAnnotationS(M,Stmt,A) :- inherits(M,MP), tHasAnnotationS(MP,Stmt,A).
moduleStmt(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A).

% Determine Restrictions defined in modules
noAdditionalInput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_input").
noAdditionalOutput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_output").
noAdditionalAnnotation(M,ANN,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_annotation"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), P = substring(L1,1,string_length(L1)-1), ANN = substring(L2,1,string_length(L2)-1).
nonOmitable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_omitable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonRedefinable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_redefinable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonGrowable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_growable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P  =substring(L1,1,string_length(L1)-1).
nonShrinkable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_shrinkable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).

% ------------------------------------------------------------------------
% DETERMINE ACTIVE STATEMENTS AND ANNOTATIONS FOR THE MODULE TO BE DERIVED
% ------------------------------------------------------------------------
m_hasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R), deriveModule(M).
m_hasPositiveHeadAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasPositiveHeadAtom(R,AtomID).
m_hasNegativeHeadAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasNegativeHeadAtom(R,AtomID).
m_hasPositiveBodyAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasPositiveBodyAtom(R,AtomID).
m_hasNegativeBodyAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasNegativeBodyAtom(R,AtomID).
m_relationalAtom(Atom) :- m_hasAtom(_,Atom), relationalAtom(Atom).
m_hasName(Atom,N) :- m_relationalAtom(Atom), hasName(Atom,N).
m_hasArgument(Atom,Arg,Pos), m_term(Arg) :- m_relationalAtom(Atom), hasArgument(Atom,Arg,Pos).
m_hasSerialization(Term,S) :- m_term(Term), hasSerialization(Term,S).
m_nonRelationalAtom(Atom), m_hasSerialization(Atom,S) :- m_hasAtom(_,Atom), nonRelationalAtom(Atom), hasSerialization(Atom,S).

% Determine the facts active in the module to be derived
m_hasFact(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F), deriveModule(M).
m_relationalAtom(Atom) :- m_hasFact(_,Atom).

% Determine the annotations in the module to be derived
m_hasAnnotation(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A), deriveModule(M).
m_hasAnnotation(Stmt,A) :- tHasAnnotationS(M,Stmt,A), not tModOpStmt(M,_,Stmt), deriveModule(M).
m_annotation(A) :- m_hasAnnotation(_,A).
m_hasName(A,N) :- m_annotation(A), hasName(A,N).
m_hasArgument(A,Arg,Pos), m_term(Arg) :- m_annotation(A), hasArgument(A,Arg,Pos).

% EXPORTING THE RESULTING META-REPRESENTATION
line(L) :- deriveModule(M), L = "program("""+M+"""). annotation("""+M+":""). hasAnnotation("""+M+""","""+M+":""). hasName("""+M+":"",""resolved"").".
line(L) :- m_hasRule(M,R), L = "rule("""+R+"""). hasRule("""+M+""","""+R+""").".
line(L) :- m_hasPositiveHeadAtom(R,AtomID), L = "hasPositiveHeadAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasNegativeHeadAtom(R,AtomID), L = "hasNegativeHeadAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasPositiveBodyAtom(R,AtomID), L = "hasPositiveBodyAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasNegativeBodyAtom(R,AtomID), L = "hasNegativeBodyAtom("""+R+""","""+AtomID+""").".
line(L) :- m_relationalAtom(A), L= "relationalAtom("""+A+""").".
line(L) :- m_hasName(A,N), L= "hasName("""+A+""","""+N+""").".
line(L) :- m_hasSerialization(Term,S), true(T), T = starts_with(S,""""), T = ends_with(S,""""), L= "hasSerialization("""+Term+""","""""+S+""""").".
line(L) :- m_hasSerialization(Term,S), false(F), F = starts_with(S,""""), F = ends_with(S,""""), L= "hasSerialization("""+Term+""","""+S+""").".
line(L) :- m_nonRelationalAtom(A), L= "nonRelationalAtom("""+A+""").".
line(L) :- m_hasFact(M,F), L= "hasFact("""+M+""","""+F+""").".
line(L) :- m_hasAnnotation(Stmt,A), L="annotation("""+A+"""). hasAnnotation("""+Stmt+""","""+A+""").".
line(L) :- m_hasArgument(A,Arg,Pos), L = "hasArgument("""+A+""","""+Arg+""","+Pos+").".
line(L) :- m_term(Arg), L = "term("""+Arg+""").".

@output("line").

% ------------------------------------------------------------------------
% WARNINGS REGARDING INHERITANCE
% ------------------------------------------------------------------------
% Warn if restrictions or mod ops are modified
w_modifiedInhAnnotation(M,S) :- modOpStmt(M,S), inhAnnotation(S).

% Warn if non-existing statement is modified
w_modifyUnknownStmt(M,X) :- removeStmtLbl(M,L), not stmtLbl(_,L), X = L.
w_modifyUnknownStmt(M,X) :- redefineStmtLbl(M,L), not stmtLbl(_,L), X = L.
w_modifyUnknownStmtQ(M,X,Y) :- removeStmtQ(M,L,MQ), not stmtML(MQ,_,L), X = L, Y = MQ.
w_modifyUnknownStmtQ(M,X,Y) :- redefineStmtQ(M,L,MQ), not stmtML(MQ,_,L), X = L, Y = MQ.

% Two different modules employ the same ID
w_labelMultiplicity(M,S,M2,S2,L) :- stmtML(M,S,L), stmtML(M2,S2,L2), moduleLbl(M,_), tInherits(MC,M2), tInherits(MC,M), L = L2, M != M2, S != S2.
w_labelMultiplicity(M,S,M2,S2,L) :- stmtML(M,S,L), stmtML(M2,S2,L2), moduleLbl(M,_), tInherits(M,M2), L = L2, M != M2, S != S2.

% An annotation is defined multiple times for the same predicate
moduleAnnotation(M,A,N,P) :- moduleStmt(M,A), hasAnnotation(_,A), hasName(A,N), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
w_annotationMultiplyDefined(M,A1,A2,Type,Predicate) :- moduleAnnotation(M,A1,Type,P1), moduleAnnotation(M,A2,Type,Predicate), A1 != A2, P1 = Predicate.

@output("w_modifiedInhAnnotation").
@output("w_modifyUnknownStmt").
@output("w_modifyUnknownStmtQ").
@output("w_labelMultiplicity").
@output("w_annotationMultiplyDefined").

% Multi-inheritance: Statement modified differently in two branches!
tRemoveStmt(M,S) :- removeStmt(M,S).
tRemoveStmt(M,S) :- inherits(M,M2), tRemoveStmt(M2,S).
tRedefineStmt(M,S) :- redefineStmt(M,S).
tRedefineStmt(M,S) :- inherits(M,M2), redefineStmt(M2,S).

w_mergeWithCommonStmtsRemoved(C,GP,P1,P2,S) :- moduleLbl(GP,_), moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), tInherits(P1,GP), tInherits(P2,GP), moduleStmt(GP,S), tRemoveStmt(P1,S), P1 != P2.
w_mergeWithCommonStmtsRedefined(C,GP,P1,P2,S) :- moduleLbl(GP,_), moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), tInherits(P1,GP), tInherits(P2,GP), moduleStmt(GP,S), tRedefineStmt(P1,S), P1 != P2.
w_diffModifiedParent(C,P1,P2,S) :- w_mergeWithCommonStmtsRemoved(C,_,P1,P2,S), not tRemoveStmt(P2,S).
w_diffModifiedParent(C,P1,P2,S) :- w_mergeWithCommonStmtsRedefined(C,_,P1,P2,S), not tRedefineStmt(P2,S).

% Multi-inheritance: Warning about different restrictions in parents
w_diffParentRestriction(C,P1,P2,"noAdditionalInput") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalInput(P1), not noAdditionalInput(P2), P1 != P2.
w_diffParentRestriction(C,P1,P2,"noAdditionalOutput") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalOutput(P1), not noAdditionalOutput(P2), P1 != P2.
w_diffParentRestriction(C,P1,P2,"noAdditionalAnnotation") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalAnnotation(P1,ANN,Predicate), not noAdditionalAnnotation(P2,ANN,Predicate), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonOmitable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonOmitable(P1,Predicate), not nonOmitable(P2,Predicate), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonRedefinable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonGrowable(P1,PRED), not nonGrowable(P2,PRED), P1 != P2.

w_diffParentRestriction(C,P1,P2,"nonGrowable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonGrowable(P1,PRED), not nonGrowable(P2,PRED), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonShrinkable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonShrinkable(P1,PRED), not nonShrinkable(P2,PRED), P1 != P2.

@output("w_diffModifiedParent").
@output("w_diffParentRestriction").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">line</caption><thead><tr><th>string</th></tr></thead><tbody><tr><td>hasPositiveHeadAtom(&quot;m:0&quot;,&quot;m:1&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:16&quot;,&quot;iRel1&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m&quot;,&quot;m:16&quot;).</td></tr></tbody><tbody><tr><td>program(&quot;m&quot;). annotation(&quot;m:&quot;). hasAnnotation(&quot;m&quot;,&quot;m:&quot;). hasName(&quot;m:&quot;,&quot;resolved&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:17&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:16&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:14&quot;). hasAnnotation(&quot;m:7&quot;,&quot;m:14&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m:0&quot;,&quot;m:3&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m:0&quot;). hasRule(&quot;m&quot;,&quot;m:0&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:4&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:14&quot;,&quot;m:15&quot;,0).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:17&quot;,&quot;&quot;&quot;l1&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m:7&quot;,&quot;m:8&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:14&quot;,&quot;label&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m&quot;,&quot;m:18&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:15&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:3&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:22&quot;). hasAnnotation(&quot;m&quot;,&quot;m:22&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m:0&quot;,&quot;m:5&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m:7&quot;). hasRule(&quot;m&quot;,&quot;m:7&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:2&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:16&quot;,&quot;m:17&quot;,0).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:15&quot;,&quot;&quot;&quot;M-R2&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:3&quot;,&quot;iRel1&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m&quot;,&quot;m:20&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:4&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:18&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:24&quot;). hasAnnotation(&quot;m&quot;,&quot;m:24&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m:7&quot;,&quot;m:10&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:6&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:22&quot;,&quot;m:23&quot;,0).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:23&quot;,&quot;&quot;&quot;m&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:22&quot;,&quot;module&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:23&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:1&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:26&quot;). hasAnnotation(&quot;m&quot;,&quot;m:26&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m:7&quot;,&quot;m:12&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:9&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:3&quot;,&quot;m:4&quot;,0).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:19&quot;,&quot;&quot;&quot;l2&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:18&quot;,&quot;iRel1&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:19&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:20&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:29&quot;). hasAnnotation(&quot;m&quot;,&quot;m:29&quot;).</td></tr></tbody><tbody><tr><td>hasSerializati ...

# %%
%%fromMeta
hasPositiveHeadAtom("m:0","m:1").
hasName("m:16","iRel1").
hasFact("m","m:16").
program("m"). annotation("m:"). hasAnnotation("m","m:"). hasName("m:","resolved").
term("m:17").
relationalAtom("m:16").
annotation("m:14"). hasAnnotation("m:7","m:14").
hasPositiveBodyAtom("m:0","m:3").
rule("m:0"). hasRule("m","m:0").
hasSerialization("m:4","X").
hasArgument("m:14","m:15",0).
hasSerialization("m:17","""l1""").
hasPositiveHeadAtom("m:7","m:8").
hasName("m:14","label").
hasFact("m","m:18").
term("m:15").
relationalAtom("m:3").
annotation("m:22"). hasAnnotation("m","m:22").
hasPositiveBodyAtom("m:0","m:5").
rule("m:7"). hasRule("m","m:7").
hasSerialization("m:2","X").
hasArgument("m:16","m:17",0).
hasSerialization("m:15","""M-R2""").
hasName("m:3","iRel1").
hasFact("m","m:20").
term("m:4").
relationalAtom("m:18").
annotation("m:24"). hasAnnotation("m","m:24").
hasPositiveBodyAtom("m:7","m:10").
hasSerialization("m:6","X").
hasArgument("m:22","m:23",0).
hasSerialization("m:23","""m""").
hasName("m:22","module").
term("m:23").
relationalAtom("m:1").
annotation("m:26"). hasAnnotation("m","m:26").
hasPositiveBodyAtom("m:7","m:12").
hasSerialization("m:9","X").
hasArgument("m:3","m:4",0).
hasSerialization("m:19","""l2""").
hasName("m:18","iRel1").
term("m:19").
relationalAtom("m:20").
annotation("m:29"). hasAnnotation("m","m:29").
hasSerialization("m:11","X").
hasArgument("m:24","m:25",0).
hasSerialization("m:25","""iRel1""").
hasName("m:24","input").
term("m:25").
relationalAtom("m:5").
annotation("m:31"). hasAnnotation("m","m:31").
hasSerialization("m:13","X").
hasArgument("m:18","m:19",0).
hasSerialization("m:27","""iRel1""").
hasName("m:1","oRelA").
term("m:2").
relationalAtom("m:8").
annotation("m:34"). hasAnnotation("m","m:34").
hasArgument("m:26","m:27",0).
hasSerialization("m:21","""l1""").
hasName("m:26","bind").
term("m:27").
relationalAtom("m:10").
hasArgument("m:1","m:2",0).
hasSerialization("m:28","""...""").
hasName("m:20","f1").
term("m:21").
relationalAtom("m:12").
hasArgument("m:26","m:28",1).
hasSerialization("m:30","""oRelA""").
hasName("m:29","output").
term("m:28").
hasArgument("m:20","m:21",0).
hasSerialization("m:32","""oRelA""").
hasName("m:5","f1").
term("m:6").
hasArgument("m:29","m:30",0).
hasSerialization("m:33","""orderby(1)""").
hasName("m:31","post").
term("m:30").
hasArgument("m:5","m:6",0).
hasSerialization("m:35","""oRelB""").
hasName("m:8","oRelB").
term("m:9").
hasArgument("m:31","m:32",0).
hasName("m:34","output").
term("m:32").
hasArgument("m:8","m:9",0).
hasName("m:10","iRel1").
term("m:11").
hasArgument("m:31","m:33",1).
hasName("m:12","f2").
term("m:33").
hasArgument("m:10","m:11",0).
term("m:13").
hasArgument("m:34","m:35",0).
term("m:35").
hasArgument("m:12","m:13",0).
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">m</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# @resolved.
# @module("m").
# @input("iRel1").
# @bind("iRel1","...").
# @output("oRelA").
# @post("oRelA","orderby(1)").
# @output("oRelB").
# iRel1("l1").
# iRel1("l2").
# f1("l1").
# oRelA(X) :- iRel1(X), f1(X).
# @label("M-R2") oRelB(X) :- iRel1(X), f2(X).
# </textarea></div></div>

# %% [markdown]
# **Expected Result:**

# %%
@resolved.
@module("m").
@input("iRel1"). @bind("iRel1","...").
iRel1("l1"). iRel1("l2").
f1("l1").
oRelA(X) :- iRel1(X), f1(X).
@label("M-R2") oRelB(X) :- iRel1(X), f2(X).
@output("oRelA"). @post("oRelA","orderby(1)").
@output("oRelB").

# %% [markdown]
# #### 1: m1A

# %%
% @input("toDerive").
toDerive("m1A").

program("m").
hasRule("m","m:0").
rule("m:0").
hasPositiveHeadAtom("m:0","m:1").
relationalAtom("m:1").
hasName("m:1","oRelA").
hasArgument("m:1","m:2",0).
term("m:2").
hasSerialization("m:2","X").
hasPositiveBodyAtom("m:0","m:3").
relationalAtom("m:3").
hasName("m:3","iRel1").
hasArgument("m:3","m:4",0).
term("m:4").
hasSerialization("m:4","X").
hasPositiveBodyAtom("m:0","m:5").
relationalAtom("m:5").
hasName("m:5","f1").
hasArgument("m:5","m:6",0).
term("m:6").
hasSerialization("m:6","X").
hasRule("m","m:7").
rule("m:7").
hasPositiveHeadAtom("m:7","m:8").
relationalAtom("m:8").
hasName("m:8","oRelB").
hasArgument("m:8","m:9",0).
term("m:9").
hasSerialization("m:9","X").
hasPositiveBodyAtom("m:7","m:10").
relationalAtom("m:10").
hasName("m:10","iRel1").
hasArgument("m:10","m:11",0).
term("m:11").
hasSerialization("m:11","X").
hasPositiveBodyAtom("m:7","m:12").
relationalAtom("m:12").
hasName("m:12","f2").
hasArgument("m:12","m:13",0).
term("m:13").
hasSerialization("m:13","X").
hasAnnotation("m:7","m:14").
annotation("m:14").
hasName("m:14","label").
hasArgument("m:14","m:15",0).
term("m:15").
hasSerialization("m:15","""M-R2""").
hasFact("m","m:16").
relationalAtom("m:16").
hasName("m:16","iRel1").
hasArgument("m:16","m:17",0).
term("m:17").
hasSerialization("m:17","""l1""").
hasFact("m","m:18").
relationalAtom("m:18").
hasName("m:18","iRel1").
hasArgument("m:18","m:19",0).
term("m:19").
hasSerialization("m:19","""l2""").
hasFact("m","m:20").
relationalAtom("m:20").
hasName("m:20","f1").
hasArgument("m:20","m:21",0).
term("m:21").
hasSerialization("m:21","""l1""").
hasAnnotation("m","m:22").
annotation("m:22").
hasName("m:22","module").
hasArgument("m:22","m:23",0).
term("m:23").
hasSerialization("m:23","""m""").
hasAnnotation("m","m:24").
annotation("m:24").
hasName("m:24","input").
hasArgument("m:24","m:25",0).
term("m:25").
hasSerialization("m:25","""iRel1""").
hasAnnotation("m","m:26").
annotation("m:26").
hasName("m:26","bind").
hasArgument("m:26","m:27",0).
term("m:27").
hasSerialization("m:27","""iRel1""").
hasArgument("m:26","m:28",1).
term("m:28").
hasSerialization("m:28","""...""").
hasAnnotation("m","m:29").
annotation("m:29").
hasName("m:29","output").
hasArgument("m:29","m:30",0).
term("m:30").
hasSerialization("m:30","""oRelA""").
hasAnnotation("m","m:31").
annotation("m:31").
hasName("m:31","post").
hasArgument("m:31","m:32",0).
term("m:32").
hasSerialization("m:32","""oRelA""").
hasArgument("m:31","m:33",1).
term("m:33").
hasSerialization("m:33","""orderby(1)""").
hasAnnotation("m","m:34").
annotation("m:34").
hasName("m:34","output").
hasArgument("m:34","m:35",0).
term("m:35").
hasSerialization("m:35","""oRelB""").

program("m1A").
hasRule("m1A","m1A:0").
rule("m1A:0").
hasPositiveHeadAtom("m1A:0","m1A:1").
relationalAtom("m1A:1").
hasName("m1A:1","oRelC").
hasArgument("m1A:1","m1A:2",0).
term("m1A:2").
hasSerialization("m1A:2","X").
hasPositiveBodyAtom("m1A:0","m1A:3").
relationalAtom("m1A:3").
hasName("m1A:3","oRelA").
hasArgument("m1A:3","m1A:4",0).
term("m1A:4").
hasSerialization("m1A:4","X").
hasPositiveBodyAtom("m1A:0","m1A:5").
relationalAtom("m1A:5").
hasName("m1A:5","oRelB").
hasArgument("m1A:5","m1A:6",0).
term("m1A:6").
hasSerialization("m1A:6","X").
hasPositiveBodyAtom("m1A:0","m1A:7").
relationalAtom("m1A:7").
hasName("m1A:7","temp").
hasArgument("m1A:7","m1A:8",0).
term("m1A:8").
hasSerialization("m1A:8","X").
hasAnnotation("m1A:0","m1A:9").
annotation("m1A:9").
hasName("m1A:9","label").
hasArgument("m1A:9","m1A:10",0).
term("m1A:10").
hasSerialization("m1A:10","""R3""").
hasRule("m1A","m1A:11").
rule("m1A:11").
hasPositiveHeadAtom("m1A:11","m1A:12").
relationalAtom("m1A:12").
hasName("m1A:12","temp").
hasArgument("m1A:12","m1A:13",0).
term("m1A:13").
hasSerialization("m1A:13","T").
hasPositiveBodyAtom("m1A:11","m1A:14").
relationalAtom("m1A:14").
hasName("m1A:14","iRel2").
hasArgument("m1A:14","m1A:15",0).
term("m1A:15").
hasSerialization("m1A:15","T").
hasPositiveBodyAtom("m1A:11","m1A:16").
relationalAtom("m1A:16").
hasName("m1A:16","f1").
hasArgument("m1A:16","m1A:17",0).
term("m1A:17").
hasSerialization("m1A:17","T").
hasAnnotation("m1A:11","m1A:18").
annotation("m1A:18").
hasName("m1A:18","label").
hasArgument("m1A:18","m1A:19",0).
term("m1A:19").
hasSerialization("m1A:19","""R4""").
hasFact("m1A","m1A:20").
relationalAtom("m1A:20").
hasName("m1A:20","iRel2").
hasArgument("m1A:20","m1A:21",0).
term("m1A:21").
hasSerialization("m1A:21","""l1""").
hasFact("m1A","m1A:22").
relationalAtom("m1A:22").
hasName("m1A:22","f1").
hasArgument("m1A:22","m1A:23",0).
term("m1A:23").
hasSerialization("m1A:23","""l2""").
hasFact("m1A","m1A:24").
relationalAtom("m1A:24").
hasName("m1A:24","f2").
hasArgument("m1A:24","m1A:25",0).
term("m1A:25").
hasSerialization("m1A:25","""l1""").
hasAnnotation("m1A:24","m1A:26").
annotation("m1A:26").
hasName("m1A:26","label").
hasArgument("m1A:26","m1A:27",0).
term("m1A:27").
hasSerialization("m1A:27","""F1""").
hasAnnotation("m1A","m1A:28").
annotation("m1A:28").
hasName("m1A:28","module").
hasArgument("m1A:28","m1A:29",0).
term("m1A:29").
hasSerialization("m1A:29","""m1A""").
hasAnnotation("m1A","m1A:30").
annotation("m1A:30").
hasName("m1A:30","inherits").
hasArgument("m1A:30","m1A:31",0).
term("m1A:31").
hasSerialization("m1A:31","""m""").
hasAnnotation("m1A","m1A:32").
annotation("m1A:32").
hasName("m1A:32","input").
hasArgument("m1A:32","m1A:33",0).
term("m1A:33").
hasSerialization("m1A:33","""iRel2""").
hasAnnotation("m1A","m1A:34").
annotation("m1A:34").
hasName("m1A:34","bind").
hasArgument("m1A:34","m1A:35",0).
term("m1A:35").
hasSerialization("m1A:35","""iRel2""").
hasArgument("m1A:34","m1A:36",1).
term("m1A:36").
hasSerialization("m1A:36","""...""").
hasAnnotation("m1A","m1A:37").
annotation("m1A:37").
hasName("m1A:37","output").
hasArgument("m1A:37","m1A:38",0).
term("m1A:38").
hasSerialization("m1A:38","""oRelC""").

program("m1C").
hasRule("m1C","m1C:0").
rule("m1C:0").
hasPositiveHeadAtom("m1C:0","m1C:1").
relationalAtom("m1C:1").
hasName("m1C:1","oRelC").
hasArgument("m1C:1","m1C:2",0).
term("m1C:2").
hasSerialization("m1C:2","X").
hasArgument("m1C:1","m1C:3",1).
term("m1C:3").
hasSerialization("m1C:3","Y").
hasPositiveBodyAtom("m1C:0","m1C:4").
relationalAtom("m1C:4").
hasName("m1C:4","iRel3").
hasArgument("m1C:4","m1C:5",0).
term("m1C:5").
hasSerialization("m1C:5","X").
hasArgument("m1C:4","m1C:6",1).
term("m1C:6").
hasSerialization("m1C:6","Y").
hasPositiveBodyAtom("m1C:0","m1C:7").
relationalAtom("m1C:7").
hasName("m1C:7","f1").
hasArgument("m1C:7","m1C:8",0).
term("m1C:8").
hasSerialization("m1C:8","Y").
hasAnnotation("m1C:0","m1C:9").
annotation("m1C:9").
hasName("m1C:9","label").
hasArgument("m1C:9","m1C:10",0).
term("m1C:10").
hasSerialization("m1C:10","""R3""").
hasFact("m1C","m1C:11").
relationalAtom("m1C:11").
hasName("m1C:11","iRel3").
hasArgument("m1C:11","m1C:12",0).
term("m1C:12").
hasSerialization("m1C:12","""l1""").
hasArgument("m1C:11","m1C:13",1).
term("m1C:13").
hasSerialization("m1C:13","""l1""").
hasFact("m1C","m1C:14").
relationalAtom("m1C:14").
hasName("m1C:14","iRel3").
hasArgument("m1C:14","m1C:15",0).
term("m1C:15").
hasSerialization("m1C:15","""l2""").
hasArgument("m1C:14","m1C:16",1).
term("m1C:16").
hasSerialization("m1C:16","""l3""").
hasAnnotation("m1C","m1C:17").
annotation("m1C:17").
hasName("m1C:17","module").
hasArgument("m1C:17","m1C:18",0).
term("m1C:18").
hasSerialization("m1C:18","""m1C""").
hasAnnotation("m1C","m1C:19").
annotation("m1C:19").
hasName("m1C:19","inherits").
hasArgument("m1C:19","m1C:20",0).
term("m1C:20").
hasSerialization("m1C:20","""m""").
hasAnnotation("m1C","m1C:21").
annotation("m1C:21").
hasName("m1C:21","input").
hasArgument("m1C:21","m1C:22",0).
term("m1C:22").
hasSerialization("m1C:22","""iRel3""").
hasAnnotation("m1C","m1C:23").
annotation("m1C:23").
hasName("m1C:23","bind").
hasArgument("m1C:23","m1C:24",0).
term("m1C:24").
hasSerialization("m1C:24","""iRel3""").
hasArgument("m1C:23","m1C:25",1).
term("m1C:25").
hasSerialization("m1C:25","""...""").
hasAnnotation("m1C","m1C:26").
annotation("m1C:26").
hasName("m1C:26","output").
hasArgument("m1C:26","m1C:27",0).
term("m1C:27").
hasSerialization("m1C:27","""oRelC""").

program("m2").
hasRule("m2","m2:0").
rule("m2:0").
hasPositiveHeadAtom("m2:0","m2:1").
relationalAtom("m2:1").
hasName("m2:1","oRelE").
hasArgument("m2:1","m2:2",0).
term("m2:2").
hasSerialization("m2:2","X").
hasPositiveBodyAtom("m2:0","m2:3").
relationalAtom("m2:3").
hasName("m2:3","f1").
hasArgument("m2:3","m2:4",0).
term("m2:4").
hasSerialization("m2:4","X").
hasPositiveBodyAtom("m2:0","m2:5").
relationalAtom("m2:5").
hasName("m2:5","f2").
hasArgument("m2:5","m2:6",0).
term("m2:6").
hasSerialization("m2:6","A").
hasPositiveBodyAtom("m2:0","m2:7").
relationalAtom("m2:7").
hasName("m2:7","f3").
hasArgument("m2:7","m2:8",0).
term("m2:8").
hasSerialization("m2:8","X").
hasPositiveBodyAtom("m2:0","m2:9").
relationalAtom("m2:9").
hasName("m2:9","iRel1").
hasArgument("m2:9","m2:10",0).
term("m2:10").
hasSerialization("m2:10","X").
hasPositiveBodyAtom("m2:0","m2:11").
relationalAtom("m2:11").
hasName("m2:11","iRel3").
hasArgument("m2:11","m2:12",0).
term("m2:12").
hasSerialization("m2:12","A").
hasArgument("m2:11","m2:13",1).
term("m2:13").
hasSerialization("m2:13","X").
hasAnnotation("m2:0","m2:14").
annotation("m2:14").
hasName("m2:14","label").
hasArgument("m2:14","m2:15",0).
term("m2:15").
hasSerialization("m2:15","""R4""").
hasFact("m2","m2:16").
relationalAtom("m2:16").
hasName("m2:16","f1").
hasArgument("m2:16","m2:17",0).
term("m2:17").
hasSerialization("m2:17","""l3""").
hasFact("m2","m2:18").
relationalAtom("m2:18").
hasName("m2:18","f2").
hasArgument("m2:18","m2:19",0).
term("m2:19").
hasSerialization("m2:19","""l3""").
hasFact("m2","m2:20").
relationalAtom("m2:20").
hasName("m2:20","f2").
hasArgument("m2:20","m2:21",0).
term("m2:21").
hasSerialization("m2:21","""f1""").
hasAnnotation("m2","m2:22").
annotation("m2:22").
hasName("m2:22","module").
hasArgument("m2:22","m2:23",0).
term("m2:23").
hasSerialization("m2:23","""m2""").
hasAnnotation("m2","m2:24").
annotation("m2:24").
hasName("m2:24","inherits").
hasArgument("m2:24","m2:25",0).
term("m2:25").
hasSerialization("m2:25","""m1A""").
hasAnnotation("m2","m2:26").
annotation("m2:26").
hasName("m2:26","inherits").
hasArgument("m2:26","m2:27",0).
term("m2:27").
hasSerialization("m2:27","""m1B""").
hasAnnotation("m2","m2:28").
annotation("m2:28").
hasName("m2:28","inherits").
hasArgument("m2:28","m2:29",0).
term("m2:29").
hasSerialization("m2:29","""m1C""").
hasAnnotation("m2","m2:30").
annotation("m2:30").
hasName("m2:30","output").
hasArgument("m2:30","m2:31",0).
term("m2:31").
hasSerialization("m2:31","""oRelE""").

program("m3").
hasRule("m3","m3:0").
rule("m3:0").
hasPositiveHeadAtom("m3:0","m3:1").
relationalAtom("m3:1").
hasName("m3:1","oRelF").
hasArgument("m3:1","m3:2",0).
term("m3:2").
hasSerialization("m3:2","X").
hasArgument("m3:1","m3:3",1).
term("m3:3").
hasSerialization("m3:3","Y").
hasPositiveBodyAtom("m3:0","m3:4").
relationalAtom("m3:4").
hasName("m3:4","iRel1").
hasArgument("m3:4","m3:5",0).
term("m3:5").
hasSerialization("m3:5","X").
hasPositiveBodyAtom("m3:0","m3:6").
relationalAtom("m3:6").
hasName("m3:6","iRel2").
hasArgument("m3:6","m3:7",0).
term("m3:7").
hasSerialization("m3:7","X").
hasPositiveBodyAtom("m3:0","m3:8").
relationalAtom("m3:8").
hasName("m3:8","iRel3").
hasArgument("m3:8","m3:9",0).
term("m3:9").
hasSerialization("m3:9","X").
hasArgument("m3:8","m3:10",1).
term("m3:10").
hasSerialization("m3:10","Y").
hasPositiveBodyAtom("m3:0","m3:11").
relationalAtom("m3:11").
hasName("m3:11","iRel4").
hasArgument("m3:11","m3:12",0).
term("m3:12").
hasSerialization("m3:12","Y").
hasAnnotation("m3:0","m3:13").
annotation("m3:13").
hasName("m3:13","label").
hasArgument("m3:13","m3:14",0).
term("m3:14").
hasSerialization("m3:14","""R4""").
hasAnnotation("m3","m3:15").
annotation("m3:15").
hasName("m3:15","module").
hasArgument("m3:15","m3:16",0).
term("m3:16").
hasSerialization("m3:16","""m3""").
hasAnnotation("m3","m3:17").
annotation("m3:17").
hasName("m3:17","inherits").
hasArgument("m3:17","m3:18",0).
term("m3:18").
hasSerialization("m3:18","""m2""").
hasAnnotation("m3","m3:19").
annotation("m3:19").
hasName("m3:19","output").
hasArgument("m3:19","m3:20",0).
term("m3:20").
hasSerialization("m3:20","""oRelF""").

% ------------------------------------------------------------------------
% INPUT
% ------------------------------------------------------------------------
% @input("toDerive").
toDerive("d").

% ------------------------------------------------------------------------
% GENERAL PREDICATES USED IN OTHER CODE SECTIONS
% ------------------------------------------------------------------------
% Definition of true needed for triple quotes
true(#T). false(#F).

% Find module labels for module IDs
moduleLbl(M,L) :- hasAnnotation(M,A), hasName(A,"module"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).

% Find Id of module to be derived
deriveModule(M) :- toDerive(L), moduleLbl(M,L).

% Determine inheritance relationships in provided meta-representations
inherits(MC,MP) :- hasAnnotation(MC,A), hasName(A,"inherits"), hasArgument(A,Arg,0), hasSerialization(Arg,MP1), moduleLbl(MP,MPL), MPL = substring(MP1,1,string_length(MP1)-1).
tInherits(M,M2) :- inherits(M,M2).
tInherits(M,M2) :- tInherits(M,M1), inherits(M1,M2).

% Input and Output predicates
inputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"input"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"output"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

% Defined restrictions and modification operations
restriction("no_additional_input").
restriction("no_additional_output").
restriction("no_additional_annotation").
restriction("non_omitable").
restriction("non_redefinable").
restriction("non_shrinkable").
restriction("non_growable").
modOp("remove"). modOp("removeQ").
modOp("redefines"). modOp("redefinesQ").
modOp("inherits").

% Inheritance Annotations
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), restriction(N).
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), modOp(N).

% Which statements exist in a module?
hasStmt(M,S) :- hasRule(M,S).
hasStmt(M,S) :- hasFact(M,S).
hasStmt(M,S) :- moduleLbl(M,_), hasAnnotation(M,S).

% Only labeled statements are interesting, others always propagated
stmtLbl(R,L) :- hasRule(M,R), hasAnnotation(R,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(F,L) :- hasFact(M,F), hasAnnotation(F,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(A,L) :- hasAnnotation(M,A), hasAnnotation(A,A2), hasName(A2,"label"), hasArgument(A2,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtML(M,S,L) :- stmtLbl(S,L), hasStmt(M,S).

% RESOLVE INHERITANCE
% Unqualified remove and redefine
redefineStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"redefines"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), L = substring(L1,1,string_length(L1)-1).
removeStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"remove"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), L = substring(L1,1,string_length(L1)-1).
% Any statement except inheritance annotations can be removed
redefineStmt(M,S):- redefineStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).
removeStmt(M,S):- removeStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).

% Qualified remove and redefine
redefineStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"redefinesQ"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), hasArgument(A,Arg3,2), hasSerialization(Arg3,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
removeStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"removeQ"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
redefineStmt(M,S) :- redefineStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).
removeStmt(M,S) :- removeStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).

% Module name annotations are not inherited
removeStmt(M,A) :- hasAnnotation(M,A), hasName(A,"module"), not deriveModule(M).

% Summarize modification operation statements
modOpStmt(M,S) :- removeStmt(M,S).
modOpStmt(M,S) :- redefineStmt(M,S).
tModOpStmt(M,M,S) :- modOpStmt(M,S).
tModOpStmt(M,Morg,S) :- inherits(M,M2), tModOpStmt(M2,Morg,S).

% DETERMINE ACTIVE STATEMENTS AND MODULE/STATEMENT ANNOTATIONS FOR MODULES
% Derive for each module its active rules by inheriting
tHasRule(M,R) :- hasRule(M,R).
tHasRule(M,R) :- inherits(M,MP), tHasRule(MP,R).
moduleStmt(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).
mHasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).

% Determine for each module its active facts by inheriting
tHasFact(M,F) :- hasFact(M,F).
tHasFact(M,F) :- inherits(M,MP), tHasFact(MP,F).
moduleStmt(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F).

% Determine for each module its active module and statement annotations
tHasAnnotationM(M,A) :- moduleLbl(M,L), hasAnnotation(M,A), hasName(A,N), not modOp(N).
tHasAnnotationM(M,A) :- inherits(M,MP), tHasAnnotationM(MP,A).
tHasAnnotationS(M,Stmt,A) :- hasStmt(M,Stmt), hasAnnotation(Stmt,A).
tHasAnnotationS(M,Stmt,A) :- inherits(M,MP), tHasAnnotationS(MP,Stmt,A).
moduleStmt(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A).

% Determine Restrictions defined in modules
noAdditionalInput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_input").
noAdditionalOutput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_output").
noAdditionalAnnotation(M,ANN,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_annotation"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), P = substring(L1,1,string_length(L1)-1), ANN = substring(L2,1,string_length(L2)-1).
nonOmitable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_omitable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonRedefinable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_redefinable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonGrowable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_growable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P  =substring(L1,1,string_length(L1)-1).
nonShrinkable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_shrinkable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).

% ------------------------------------------------------------------------
% DETERMINE ACTIVE STATEMENTS AND ANNOTATIONS FOR THE MODULE TO BE DERIVED
% ------------------------------------------------------------------------
m_hasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R), deriveModule(M).
m_hasPositiveHeadAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasPositiveHeadAtom(R,AtomID).
m_hasNegativeHeadAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasNegativeHeadAtom(R,AtomID).
m_hasPositiveBodyAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasPositiveBodyAtom(R,AtomID).
m_hasNegativeBodyAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasNegativeBodyAtom(R,AtomID).
m_relationalAtom(Atom) :- m_hasAtom(_,Atom), relationalAtom(Atom).
m_hasName(Atom,N) :- m_relationalAtom(Atom), hasName(Atom,N).
m_hasArgument(Atom,Arg,Pos), m_term(Arg) :- m_relationalAtom(Atom), hasArgument(Atom,Arg,Pos).
m_hasSerialization(Term,S) :- m_term(Term), hasSerialization(Term,S).
m_nonRelationalAtom(Atom), m_hasSerialization(Atom,S) :- m_hasAtom(_,Atom), nonRelationalAtom(Atom), hasSerialization(Atom,S).

% Determine the facts active in the module to be derived
m_hasFact(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F), deriveModule(M).
m_relationalAtom(Atom) :- m_hasFact(_,Atom).

% Determine the annotations in the module to be derived
m_hasAnnotation(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A), deriveModule(M).
m_hasAnnotation(Stmt,A) :- tHasAnnotationS(M,Stmt,A), not tModOpStmt(M,_,Stmt), deriveModule(M).
m_annotation(A) :- m_hasAnnotation(_,A).
m_hasName(A,N) :- m_annotation(A), hasName(A,N).
m_hasArgument(A,Arg,Pos), m_term(Arg) :- m_annotation(A), hasArgument(A,Arg,Pos).

% EXPORTING THE RESULTING META-REPRESENTATION
line(L) :- deriveModule(M), L = "program("""+M+"""). annotation("""+M+":""). hasAnnotation("""+M+""","""+M+":""). hasName("""+M+":"",""resolved"").".
line(L) :- m_hasRule(M,R), L = "rule("""+R+"""). hasRule("""+M+""","""+R+""").".
line(L) :- m_hasPositiveHeadAtom(R,AtomID), L = "hasPositiveHeadAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasNegativeHeadAtom(R,AtomID), L = "hasNegativeHeadAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasPositiveBodyAtom(R,AtomID), L = "hasPositiveBodyAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasNegativeBodyAtom(R,AtomID), L = "hasNegativeBodyAtom("""+R+""","""+AtomID+""").".
line(L) :- m_relationalAtom(A), L= "relationalAtom("""+A+""").".
line(L) :- m_hasName(A,N), L= "hasName("""+A+""","""+N+""").".
line(L) :- m_hasSerialization(Term,S), true(T), T = starts_with(S,""""), T = ends_with(S,""""), L= "hasSerialization("""+Term+""","""""+S+""""").".
line(L) :- m_hasSerialization(Term,S), false(F), F = starts_with(S,""""), F = ends_with(S,""""), L= "hasSerialization("""+Term+""","""+S+""").".
line(L) :- m_nonRelationalAtom(A), L= "nonRelationalAtom("""+A+""").".
line(L) :- m_hasFact(M,F), L= "hasFact("""+M+""","""+F+""").".
line(L) :- m_hasAnnotation(Stmt,A), L="annotation("""+A+"""). hasAnnotation("""+Stmt+""","""+A+""").".
line(L) :- m_hasArgument(A,Arg,Pos), L = "hasArgument("""+A+""","""+Arg+""","+Pos+").".
line(L) :- m_term(Arg), L = "term("""+Arg+""").".

@output("line").

% ------------------------------------------------------------------------
% WARNINGS REGARDING INHERITANCE
% ------------------------------------------------------------------------
% Warn if restrictions or mod ops are modified
w_modifiedInhAnnotation(M,S) :- modOpStmt(M,S), inhAnnotation(S).

% Warn if non-existing statement is modified
w_modifyUnknownStmt(M,X) :- removeStmtLbl(M,L), not stmtLbl(_,L), X = L.
w_modifyUnknownStmt(M,X) :- redefineStmtLbl(M,L), not stmtLbl(_,L), X = L.
w_modifyUnknownStmtQ(M,X,Y) :- removeStmtQ(M,L,MQ), not stmtML(MQ,_,L), X = L, Y = MQ.
w_modifyUnknownStmtQ(M,X,Y) :- redefineStmtQ(M,L,MQ), not stmtML(MQ,_,L), X = L, Y = MQ.

% Two different modules employ the same ID
w_labelMultiplicity(M,S,M2,S2,L) :- stmtML(M,S,L), stmtML(M2,S2,L2), moduleLbl(M,_), tInherits(MC,M2), tInherits(MC,M), L = L2, M != M2, S != S2.
w_labelMultiplicity(M,S,M2,S2,L) :- stmtML(M,S,L), stmtML(M2,S2,L2), moduleLbl(M,_), tInherits(M,M2), L = L2, M != M2, S != S2.

% An annotation is defined multiple times for the same predicate
moduleAnnotation(M,A,N,P) :- moduleStmt(M,A), hasAnnotation(_,A), hasName(A,N), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
w_annotationMultiplyDefined(M,A1,A2,Type,Predicate) :- moduleAnnotation(M,A1,Type,P1), moduleAnnotation(M,A2,Type,Predicate), A1 != A2, P1 = Predicate.

@output("w_modifiedInhAnnotation").
@output("w_modifyUnknownStmt").
@output("w_modifyUnknownStmtQ").
@output("w_labelMultiplicity").
@output("w_annotationMultiplyDefined").

% Multi-inheritance: Statement modified differently in two branches!
tRemoveStmt(M,S) :- removeStmt(M,S).
tRemoveStmt(M,S) :- inherits(M,M2), tRemoveStmt(M2,S).
tRedefineStmt(M,S) :- redefineStmt(M,S).
tRedefineStmt(M,S) :- inherits(M,M2), redefineStmt(M2,S).

w_mergeWithCommonStmtsRemoved(C,GP,P1,P2,S) :- moduleLbl(GP,_), moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), tInherits(P1,GP), tInherits(P2,GP), moduleStmt(GP,S), tRemoveStmt(P1,S), P1 != P2.
w_mergeWithCommonStmtsRedefined(C,GP,P1,P2,S) :- moduleLbl(GP,_), moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), tInherits(P1,GP), tInherits(P2,GP), moduleStmt(GP,S), tRedefineStmt(P1,S), P1 != P2.
w_diffModifiedParent(C,P1,P2,S) :- w_mergeWithCommonStmtsRemoved(C,_,P1,P2,S), not tRemoveStmt(P2,S).
w_diffModifiedParent(C,P1,P2,S) :- w_mergeWithCommonStmtsRedefined(C,_,P1,P2,S), not tRedefineStmt(P2,S).

% Multi-inheritance: Warning about different restrictions in parents
w_diffParentRestriction(C,P1,P2,"noAdditionalInput") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalInput(P1), not noAdditionalInput(P2), P1 != P2.
w_diffParentRestriction(C,P1,P2,"noAdditionalOutput") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalOutput(P1), not noAdditionalOutput(P2), P1 != P2.
w_diffParentRestriction(C,P1,P2,"noAdditionalAnnotation") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalAnnotation(P1,ANN,Predicate), not noAdditionalAnnotation(P2,ANN,Predicate), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonOmitable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonOmitable(P1,Predicate), not nonOmitable(P2,Predicate), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonRedefinable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonGrowable(P1,PRED), not nonGrowable(P2,PRED), P1 != P2.

w_diffParentRestriction(C,P1,P2,"nonGrowable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonGrowable(P1,PRED), not nonGrowable(P2,PRED), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonShrinkable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonShrinkable(P1,PRED), not nonShrinkable(P2,PRED), P1 != P2.

@output("w_diffModifiedParent").
@output("w_diffParentRestriction").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">line</caption><thead><tr><th>string</th></tr></thead><tbody><tr><td>hasName(&quot;m:16&quot;,&quot;iRel1&quot;).</td></tr></tbody><tbody><tr><td>program(&quot;m1A&quot;). annotation(&quot;m1A:&quot;). hasAnnotation(&quot;m1A&quot;,&quot;m1A:&quot;). hasName(&quot;m1A:&quot;,&quot;resolved&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:17&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:24&quot;,&quot;m:25&quot;,0).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m:0&quot;,&quot;m:1&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m:0&quot;). hasRule(&quot;m1A&quot;,&quot;m:0&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:24&quot;). hasAnnotation(&quot;m1A&quot;,&quot;m:24&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:4&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:17&quot;,&quot;&quot;&quot;l1&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:16&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m:0&quot;,&quot;m:3&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m1A&quot;,&quot;m:16&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:24&quot;,&quot;input&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:25&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:16&quot;,&quot;m:17&quot;,0).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m1A:0&quot;,&quot;m1A:1&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m1A:0&quot;). hasRule(&quot;m1A&quot;,&quot;m1A:0&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:14&quot;). hasAnnotation(&quot;m:7&quot;,&quot;m:14&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:2&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:25&quot;,&quot;&quot;&quot;iRel1&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:3&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m:0&quot;,&quot;m:5&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m1A&quot;,&quot;m:18&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:3&quot;,&quot;iRel1&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:4&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:14&quot;,&quot;m:15&quot;,0).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m1A:11&quot;,&quot;m1A:12&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m1A:11&quot;). hasRule(&quot;m1A&quot;,&quot;m1A:11&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:26&quot;). hasAnnotation(&quot;m1A&quot;,&quot;m:26&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:6&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:15&quot;,&quot;&quot;&quot;M-R2&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:18&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m1A:0&quot;,&quot;m1A:3&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m1A&quot;,&quot;m1A:20&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:14&quot;,&quot;label&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:15&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:3&quot;,&quot;m:4&quot;,0).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m:7&quot;,&quot;m:8&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m:7&quot;). hasRule(&quot;m1A&quot;,&quot;m:7&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m1A:9&quot;). hasAnnotation(&quot;m1A:0&quot;,&quot;m1A:9&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m1A:2&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:19&quot;,&quot;&quot;&quot;l2&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:1&quot;).</td></tr></tbod ...

# %%
%%fromMeta
hasName("m:16","iRel1").
program("m1A"). annotation("m1A:"). hasAnnotation("m1A","m1A:"). hasName("m1A:","resolved").
term("m:17").
hasArgument("m:24","m:25",0).
hasPositiveHeadAtom("m:0","m:1").
rule("m:0"). hasRule("m1A","m:0").
annotation("m:24"). hasAnnotation("m1A","m:24").
hasSerialization("m:4","X").
hasSerialization("m:17","""l1""").
relationalAtom("m:16").
hasPositiveBodyAtom("m:0","m:3").
hasFact("m1A","m:16").
hasName("m:24","input").
term("m:25").
hasArgument("m:16","m:17",0).
hasPositiveHeadAtom("m1A:0","m1A:1").
rule("m1A:0"). hasRule("m1A","m1A:0").
annotation("m:14"). hasAnnotation("m:7","m:14").
hasSerialization("m:2","X").
hasSerialization("m:25","""iRel1""").
relationalAtom("m:3").
hasPositiveBodyAtom("m:0","m:5").
hasFact("m1A","m:18").
hasName("m:3","iRel1").
term("m:4").
hasArgument("m:14","m:15",0).
hasPositiveHeadAtom("m1A:11","m1A:12").
rule("m1A:11"). hasRule("m1A","m1A:11").
annotation("m:26"). hasAnnotation("m1A","m:26").
hasSerialization("m:6","X").
hasSerialization("m:15","""M-R2""").
relationalAtom("m:18").
hasPositiveBodyAtom("m1A:0","m1A:3").
hasFact("m1A","m1A:20").
hasName("m:14","label").
term("m:15").
hasArgument("m:3","m:4",0).
hasPositiveHeadAtom("m:7","m:8").
rule("m:7"). hasRule("m1A","m:7").
annotation("m1A:9"). hasAnnotation("m1A:0","m1A:9").
hasSerialization("m1A:2","X").
hasSerialization("m:19","""l2""").
relationalAtom("m:1").
hasPositiveBodyAtom("m1A:0","m1A:5").
hasFact("m1A","m1A:22").
hasName("m:18","iRel1").
term("m:19").
hasArgument("m:26","m:27",0).
annotation("m1A:28"). hasAnnotation("m1A","m1A:28").
hasSerialization("m1A:4","X").
hasSerialization("m:27","""iRel1""").
relationalAtom("m1A:20").
hasPositiveBodyAtom("m1A:0","m1A:7").
hasFact("m1A","m:20").
hasName("m:26","bind").
term("m:27").
hasArgument("m:18","m:19",0).
annotation("m1A:18"). hasAnnotation("m1A:11","m1A:18").
hasSerialization("m1A:13","T").
hasSerialization("m:28","""...""").
relationalAtom("m:5").
hasPositiveBodyAtom("m1A:11","m1A:14").
hasFact("m1A","m1A:24").
hasName("m:1","oRelA").
term("m:2").
hasArgument("m:26","m:28",1).
annotation("m1A:32"). hasAnnotation("m1A","m1A:32").
hasSerialization("m1A:6","X").
hasSerialization("m1A:21","""l1""").
relationalAtom("m1A:22").
hasPositiveBodyAtom("m1A:11","m1A:16").
hasName("m1A:9","label").
term("m:28").
hasArgument("m:1","m:2",0).
annotation("m1A:26"). hasAnnotation("m1A:24","m1A:26").
hasSerialization("m:9","X").
hasSerialization("m1A:10","""R3""").
relationalAtom("m1A:1").
hasPositiveBodyAtom("m:7","m:10").
hasName("m1A:20","iRel2").
term("m1A:21").
hasArgument("m1A:9","m1A:10",0).
annotation("m:29"). hasAnnotation("m1A","m:29").
hasSerialization("m1A:8","X").
hasSerialization("m1A:29","""m1A""").
relationalAtom("m:20").
hasPositiveBodyAtom("m:7","m:12").
hasName("m1A:28","module").
term("m1A:10").
hasArgument("m1A:20","m1A:21",0).
annotation("m1A:34"). hasAnnotation("m1A","m1A:34").
hasSerialization("m1A:15","T").
hasSerialization("m1A:23","""l2""").
relationalAtom("m1A:3").
hasName("m:5","f1").
term("m:6").
hasArgument("m1A:28","m1A:29",0).
annotation("m1A:37"). hasAnnotation("m1A","m1A:37").
hasSerialization("m1A:17","T").
hasSerialization("m1A:19","""R4""").
relationalAtom("m1A:24").
hasName("m1A:18","label").
term("m1A:29").
hasArgument("m:5","m:6",0).
annotation("m:31"). hasAnnotation("m1A","m:31").
hasSerialization("m:11","X").
hasSerialization("m1A:33","""iRel2""").
relationalAtom("m1A:12").
hasName("m1A:22","f1").
term("m1A:23").
hasArgument("m1A:18","m1A:19",0).
annotation("m:34"). hasAnnotation("m1A","m:34").
hasSerialization("m:13","X").
hasSerialization("m:21","""l1""").
relationalAtom("m1A:5").
hasName("m1A:32","input").
term("m1A:19").
hasArgument("m1A:22","m1A:23",0).
hasSerialization("m1A:27","""F1""").
relationalAtom("m:8").
hasName("m1A:1","oRelC").
term("m1A:2").
hasArgument("m1A:32","m1A:33",0).
hasSerialization("m:30","""oRelA""").
relationalAtom("m1A:7").
hasName("m1A:26","label").
term("m1A:33").
hasArgument("m1A:1","m1A:2",0).
hasSerialization("m1A:25","""l1""").
relationalAtom("m1A:14").
hasName("m:20","f1").
term("m:21").
hasArgument("m1A:26","m1A:27",0).
hasSerialization("m1A:35","""iRel2""").
relationalAtom("m1A:16").
hasName("m:29","output").
term("m1A:27").
hasArgument("m:20","m:21",0).
hasSerialization("m1A:36","""...""").
relationalAtom("m:10").
hasName("m1A:3","oRelA").
term("m1A:4").
hasArgument("m:29","m:30",0).
hasSerialization("m1A:38","""oRelC""").
relationalAtom("m:12").
hasName("m1A:34","bind").
term("m:30").
hasArgument("m1A:3","m1A:4",0).
hasSerialization("m:32","""oRelA""").
hasName("m1A:24","f2").
term("m1A:25").
hasArgument("m1A:34","m1A:35",0).
hasSerialization("m:33","""orderby(1)""").
hasName("m1A:37","output").
term("m1A:35").
hasArgument("m1A:24","m1A:25",0).
hasSerialization("m:35","""oRelB""").
hasName("m1A:12","temp").
term("m1A:13").
hasArgument("m1A:34","m1A:36",1).
hasName("m:31","post").
term("m1A:36").
hasArgument("m1A:12","m1A:13",0).
hasName("m1A:5","oRelB").
term("m1A:6").
hasArgument("m1A:37","m1A:38",0).
hasName("m:34","output").
term("m1A:38").
hasArgument("m1A:5","m1A:6",0).
hasName("m:8","oRelB").
term("m:9").
hasArgument("m:31","m:32",0).
hasName("m1A:7","temp").
term("m:32").
hasArgument("m:8","m:9",0).
hasName("m1A:14","iRel2").
term("m1A:8").
hasArgument("m:31","m:33",1).
hasName("m1A:16","f1").
term("m:33").
hasArgument("m1A:7","m1A:8",0).
hasName("m:10","iRel1").
term("m1A:15").
hasArgument("m:34","m:35",0).
hasName("m:12","f2").
term("m:35").
hasArgument("m1A:14","m1A:15",0).
term("m1A:17").
hasArgument("m1A:16","m1A:17",0).
term("m:11").
hasArgument("m:10","m:11",0).
term("m:13").
hasArgument("m:12","m:13",0).
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">m1A</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# @resolved.
# @input("iRel1").
# @bind("iRel1","...").
# @module("m1A").
# @input("iRel2").
# @output("oRelA").
# @bind("iRel2","...").
# @output("oRelC").
# @post("oRelA","orderby(1)").
# @output("oRelB").
# iRel1("l1").
# iRel1("l2").
# iRel2("l1").
# f1("l2").
# f1("l1").
# @label("F1") f2("l1").
# oRelA(X) :- iRel1(X), f1(X).
# @label("R3") oRelC(X) :- oRelA(X), oRelB(X), temp(X).
# @label("R4") temp(T) :- iRel2(T), f1(T).
# @label("M-R2") oRelB(X) :- iRel1(X), f2(X).
# </textarea></div></div>

# %% [markdown]
# **Expected Result:**

# %%
@resolved.@module("m1A").
@input("iRel1"). @bind("iRel1","...").
@input("iRel2"). @bind("iRel2","...").

iRel1("l1"). iRel1("l2").
iRel2("l1").
f1("l1"). f1("l2"). 
@label("F1") f2("l1").

oRelA(X) :- iRel1(X), f1(X).
@label("M-R2") oRelB(X) :- iRel1(X), f2(X).
@label("R3") oRelC(X) :- oRelA(X), oRelB(X), temp(X).
@label("R4") temp(T) :- iRel2(T), f1(T).

@output("oRelA"). @post("oRelA","orderby(1)").
@output("oRelB").
@output("oRelC").

# %% [markdown]
# #### 2: m1C

# %%
% @input("toDerive").
toDerive("m1C").

program("m").
hasRule("m","m:0").
rule("m:0").
hasPositiveHeadAtom("m:0","m:1").
relationalAtom("m:1").
hasName("m:1","oRelA").
hasArgument("m:1","m:2",0).
term("m:2").
hasSerialization("m:2","X").
hasPositiveBodyAtom("m:0","m:3").
relationalAtom("m:3").
hasName("m:3","iRel1").
hasArgument("m:3","m:4",0).
term("m:4").
hasSerialization("m:4","X").
hasPositiveBodyAtom("m:0","m:5").
relationalAtom("m:5").
hasName("m:5","f1").
hasArgument("m:5","m:6",0).
term("m:6").
hasSerialization("m:6","X").
hasRule("m","m:7").
rule("m:7").
hasPositiveHeadAtom("m:7","m:8").
relationalAtom("m:8").
hasName("m:8","oRelB").
hasArgument("m:8","m:9",0).
term("m:9").
hasSerialization("m:9","X").
hasPositiveBodyAtom("m:7","m:10").
relationalAtom("m:10").
hasName("m:10","iRel1").
hasArgument("m:10","m:11",0).
term("m:11").
hasSerialization("m:11","X").
hasPositiveBodyAtom("m:7","m:12").
relationalAtom("m:12").
hasName("m:12","f2").
hasArgument("m:12","m:13",0).
term("m:13").
hasSerialization("m:13","X").
hasAnnotation("m:7","m:14").
annotation("m:14").
hasName("m:14","label").
hasArgument("m:14","m:15",0).
term("m:15").
hasSerialization("m:15","""M-R2""").
hasFact("m","m:16").
relationalAtom("m:16").
hasName("m:16","iRel1").
hasArgument("m:16","m:17",0).
term("m:17").
hasSerialization("m:17","""l1""").
hasFact("m","m:18").
relationalAtom("m:18").
hasName("m:18","iRel1").
hasArgument("m:18","m:19",0).
term("m:19").
hasSerialization("m:19","""l2""").
hasFact("m","m:20").
relationalAtom("m:20").
hasName("m:20","f1").
hasArgument("m:20","m:21",0).
term("m:21").
hasSerialization("m:21","""l1""").
hasAnnotation("m","m:22").
annotation("m:22").
hasName("m:22","module").
hasArgument("m:22","m:23",0).
term("m:23").
hasSerialization("m:23","""m""").
hasAnnotation("m","m:24").
annotation("m:24").
hasName("m:24","input").
hasArgument("m:24","m:25",0).
term("m:25").
hasSerialization("m:25","""iRel1""").
hasAnnotation("m","m:26").
annotation("m:26").
hasName("m:26","bind").
hasArgument("m:26","m:27",0).
term("m:27").
hasSerialization("m:27","""iRel1""").
hasArgument("m:26","m:28",1).
term("m:28").
hasSerialization("m:28","""...""").
hasAnnotation("m","m:29").
annotation("m:29").
hasName("m:29","output").
hasArgument("m:29","m:30",0).
term("m:30").
hasSerialization("m:30","""oRelA""").
hasAnnotation("m","m:31").
annotation("m:31").
hasName("m:31","post").
hasArgument("m:31","m:32",0).
term("m:32").
hasSerialization("m:32","""oRelA""").
hasArgument("m:31","m:33",1).
term("m:33").
hasSerialization("m:33","""orderby(1)""").
hasAnnotation("m","m:34").
annotation("m:34").
hasName("m:34","output").
hasArgument("m:34","m:35",0).
term("m:35").
hasSerialization("m:35","""oRelB""").

program("m1A").
hasRule("m1A","m1A:0").
rule("m1A:0").
hasPositiveHeadAtom("m1A:0","m1A:1").
relationalAtom("m1A:1").
hasName("m1A:1","oRelC").
hasArgument("m1A:1","m1A:2",0).
term("m1A:2").
hasSerialization("m1A:2","X").
hasPositiveBodyAtom("m1A:0","m1A:3").
relationalAtom("m1A:3").
hasName("m1A:3","oRelA").
hasArgument("m1A:3","m1A:4",0).
term("m1A:4").
hasSerialization("m1A:4","X").
hasPositiveBodyAtom("m1A:0","m1A:5").
relationalAtom("m1A:5").
hasName("m1A:5","oRelB").
hasArgument("m1A:5","m1A:6",0).
term("m1A:6").
hasSerialization("m1A:6","X").
hasPositiveBodyAtom("m1A:0","m1A:7").
relationalAtom("m1A:7").
hasName("m1A:7","temp").
hasArgument("m1A:7","m1A:8",0).
term("m1A:8").
hasSerialization("m1A:8","X").
hasAnnotation("m1A:0","m1A:9").
annotation("m1A:9").
hasName("m1A:9","label").
hasArgument("m1A:9","m1A:10",0).
term("m1A:10").
hasSerialization("m1A:10","""R3""").
hasRule("m1A","m1A:11").
rule("m1A:11").
hasPositiveHeadAtom("m1A:11","m1A:12").
relationalAtom("m1A:12").
hasName("m1A:12","temp").
hasArgument("m1A:12","m1A:13",0).
term("m1A:13").
hasSerialization("m1A:13","T").
hasPositiveBodyAtom("m1A:11","m1A:14").
relationalAtom("m1A:14").
hasName("m1A:14","iRel2").
hasArgument("m1A:14","m1A:15",0).
term("m1A:15").
hasSerialization("m1A:15","T").
hasPositiveBodyAtom("m1A:11","m1A:16").
relationalAtom("m1A:16").
hasName("m1A:16","f1").
hasArgument("m1A:16","m1A:17",0).
term("m1A:17").
hasSerialization("m1A:17","T").
hasAnnotation("m1A:11","m1A:18").
annotation("m1A:18").
hasName("m1A:18","label").
hasArgument("m1A:18","m1A:19",0).
term("m1A:19").
hasSerialization("m1A:19","""R4""").
hasFact("m1A","m1A:20").
relationalAtom("m1A:20").
hasName("m1A:20","iRel2").
hasArgument("m1A:20","m1A:21",0).
term("m1A:21").
hasSerialization("m1A:21","""l1""").
hasFact("m1A","m1A:22").
relationalAtom("m1A:22").
hasName("m1A:22","f1").
hasArgument("m1A:22","m1A:23",0).
term("m1A:23").
hasSerialization("m1A:23","""l2""").
hasFact("m1A","m1A:24").
relationalAtom("m1A:24").
hasName("m1A:24","f2").
hasArgument("m1A:24","m1A:25",0).
term("m1A:25").
hasSerialization("m1A:25","""l1""").
hasAnnotation("m1A:24","m1A:26").
annotation("m1A:26").
hasName("m1A:26","label").
hasArgument("m1A:26","m1A:27",0).
term("m1A:27").
hasSerialization("m1A:27","""F1""").
hasAnnotation("m1A","m1A:28").
annotation("m1A:28").
hasName("m1A:28","module").
hasArgument("m1A:28","m1A:29",0).
term("m1A:29").
hasSerialization("m1A:29","""m1A""").
hasAnnotation("m1A","m1A:30").
annotation("m1A:30").
hasName("m1A:30","inherits").
hasArgument("m1A:30","m1A:31",0).
term("m1A:31").
hasSerialization("m1A:31","""m""").
hasAnnotation("m1A","m1A:32").
annotation("m1A:32").
hasName("m1A:32","input").
hasArgument("m1A:32","m1A:33",0).
term("m1A:33").
hasSerialization("m1A:33","""iRel2""").
hasAnnotation("m1A","m1A:34").
annotation("m1A:34").
hasName("m1A:34","bind").
hasArgument("m1A:34","m1A:35",0).
term("m1A:35").
hasSerialization("m1A:35","""iRel2""").
hasArgument("m1A:34","m1A:36",1).
term("m1A:36").
hasSerialization("m1A:36","""...""").
hasAnnotation("m1A","m1A:37").
annotation("m1A:37").
hasName("m1A:37","output").
hasArgument("m1A:37","m1A:38",0).
term("m1A:38").
hasSerialization("m1A:38","""oRelC""").

program("m1C").
hasRule("m1C","m1C:0").
rule("m1C:0").
hasPositiveHeadAtom("m1C:0","m1C:1").
relationalAtom("m1C:1").
hasName("m1C:1","oRelC").
hasArgument("m1C:1","m1C:2",0).
term("m1C:2").
hasSerialization("m1C:2","X").
hasArgument("m1C:1","m1C:3",1).
term("m1C:3").
hasSerialization("m1C:3","Y").
hasPositiveBodyAtom("m1C:0","m1C:4").
relationalAtom("m1C:4").
hasName("m1C:4","iRel3").
hasArgument("m1C:4","m1C:5",0).
term("m1C:5").
hasSerialization("m1C:5","X").
hasArgument("m1C:4","m1C:6",1).
term("m1C:6").
hasSerialization("m1C:6","Y").
hasPositiveBodyAtom("m1C:0","m1C:7").
relationalAtom("m1C:7").
hasName("m1C:7","f1").
hasArgument("m1C:7","m1C:8",0).
term("m1C:8").
hasSerialization("m1C:8","Y").
hasAnnotation("m1C:0","m1C:9").
annotation("m1C:9").
hasName("m1C:9","label").
hasArgument("m1C:9","m1C:10",0).
term("m1C:10").
hasSerialization("m1C:10","""R3""").
hasFact("m1C","m1C:11").
relationalAtom("m1C:11").
hasName("m1C:11","iRel3").
hasArgument("m1C:11","m1C:12",0).
term("m1C:12").
hasSerialization("m1C:12","""l1""").
hasArgument("m1C:11","m1C:13",1).
term("m1C:13").
hasSerialization("m1C:13","""l1""").
hasFact("m1C","m1C:14").
relationalAtom("m1C:14").
hasName("m1C:14","iRel3").
hasArgument("m1C:14","m1C:15",0).
term("m1C:15").
hasSerialization("m1C:15","""l2""").
hasArgument("m1C:14","m1C:16",1).
term("m1C:16").
hasSerialization("m1C:16","""l3""").
hasAnnotation("m1C","m1C:17").
annotation("m1C:17").
hasName("m1C:17","module").
hasArgument("m1C:17","m1C:18",0).
term("m1C:18").
hasSerialization("m1C:18","""m1C""").
hasAnnotation("m1C","m1C:19").
annotation("m1C:19").
hasName("m1C:19","inherits").
hasArgument("m1C:19","m1C:20",0).
term("m1C:20").
hasSerialization("m1C:20","""m""").
hasAnnotation("m1C","m1C:21").
annotation("m1C:21").
hasName("m1C:21","input").
hasArgument("m1C:21","m1C:22",0).
term("m1C:22").
hasSerialization("m1C:22","""iRel3""").
hasAnnotation("m1C","m1C:23").
annotation("m1C:23").
hasName("m1C:23","bind").
hasArgument("m1C:23","m1C:24",0).
term("m1C:24").
hasSerialization("m1C:24","""iRel3""").
hasArgument("m1C:23","m1C:25",1).
term("m1C:25").
hasSerialization("m1C:25","""...""").
hasAnnotation("m1C","m1C:26").
annotation("m1C:26").
hasName("m1C:26","output").
hasArgument("m1C:26","m1C:27",0).
term("m1C:27").
hasSerialization("m1C:27","""oRelC""").

program("m2").
hasRule("m2","m2:0").
rule("m2:0").
hasPositiveHeadAtom("m2:0","m2:1").
relationalAtom("m2:1").
hasName("m2:1","oRelE").
hasArgument("m2:1","m2:2",0).
term("m2:2").
hasSerialization("m2:2","X").
hasPositiveBodyAtom("m2:0","m2:3").
relationalAtom("m2:3").
hasName("m2:3","f1").
hasArgument("m2:3","m2:4",0).
term("m2:4").
hasSerialization("m2:4","X").
hasPositiveBodyAtom("m2:0","m2:5").
relationalAtom("m2:5").
hasName("m2:5","f2").
hasArgument("m2:5","m2:6",0).
term("m2:6").
hasSerialization("m2:6","A").
hasPositiveBodyAtom("m2:0","m2:7").
relationalAtom("m2:7").
hasName("m2:7","f3").
hasArgument("m2:7","m2:8",0).
term("m2:8").
hasSerialization("m2:8","X").
hasPositiveBodyAtom("m2:0","m2:9").
relationalAtom("m2:9").
hasName("m2:9","iRel1").
hasArgument("m2:9","m2:10",0).
term("m2:10").
hasSerialization("m2:10","X").
hasPositiveBodyAtom("m2:0","m2:11").
relationalAtom("m2:11").
hasName("m2:11","iRel3").
hasArgument("m2:11","m2:12",0).
term("m2:12").
hasSerialization("m2:12","A").
hasArgument("m2:11","m2:13",1).
term("m2:13").
hasSerialization("m2:13","X").
hasAnnotation("m2:0","m2:14").
annotation("m2:14").
hasName("m2:14","label").
hasArgument("m2:14","m2:15",0).
term("m2:15").
hasSerialization("m2:15","""R4""").
hasFact("m2","m2:16").
relationalAtom("m2:16").
hasName("m2:16","f1").
hasArgument("m2:16","m2:17",0).
term("m2:17").
hasSerialization("m2:17","""l3""").
hasFact("m2","m2:18").
relationalAtom("m2:18").
hasName("m2:18","f2").
hasArgument("m2:18","m2:19",0).
term("m2:19").
hasSerialization("m2:19","""l3""").
hasFact("m2","m2:20").
relationalAtom("m2:20").
hasName("m2:20","f2").
hasArgument("m2:20","m2:21",0).
term("m2:21").
hasSerialization("m2:21","""f1""").
hasAnnotation("m2","m2:22").
annotation("m2:22").
hasName("m2:22","module").
hasArgument("m2:22","m2:23",0).
term("m2:23").
hasSerialization("m2:23","""m2""").
hasAnnotation("m2","m2:24").
annotation("m2:24").
hasName("m2:24","inherits").
hasArgument("m2:24","m2:25",0).
term("m2:25").
hasSerialization("m2:25","""m1A""").
hasAnnotation("m2","m2:30").
annotation("m2:30").
hasName("m2:30","output").
hasArgument("m2:30","m2:31",0).
term("m2:31").
hasSerialization("m2:31","""oRelE""").

program("m3").
hasRule("m3","m3:0").
rule("m3:0").
hasPositiveHeadAtom("m3:0","m3:1").
relationalAtom("m3:1").
hasName("m3:1","oRelF").
hasArgument("m3:1","m3:2",0).
term("m3:2").
hasSerialization("m3:2","X").
hasArgument("m3:1","m3:3",1).
term("m3:3").
hasSerialization("m3:3","Y").
hasPositiveBodyAtom("m3:0","m3:4").
relationalAtom("m3:4").
hasName("m3:4","iRel1").
hasArgument("m3:4","m3:5",0).
term("m3:5").
hasSerialization("m3:5","X").
hasPositiveBodyAtom("m3:0","m3:6").
relationalAtom("m3:6").
hasName("m3:6","iRel2").
hasArgument("m3:6","m3:7",0).
term("m3:7").
hasSerialization("m3:7","X").
hasPositiveBodyAtom("m3:0","m3:8").
relationalAtom("m3:8").
hasName("m3:8","iRel3").
hasArgument("m3:8","m3:9",0).
term("m3:9").
hasSerialization("m3:9","X").
hasArgument("m3:8","m3:10",1).
term("m3:10").
hasSerialization("m3:10","Y").
hasPositiveBodyAtom("m3:0","m3:11").
relationalAtom("m3:11").
hasName("m3:11","iRel4").
hasArgument("m3:11","m3:12",0).
term("m3:12").
hasSerialization("m3:12","Y").
hasAnnotation("m3:0","m3:13").
annotation("m3:13").
hasName("m3:13","label").
hasArgument("m3:13","m3:14",0).
term("m3:14").
hasSerialization("m3:14","""R4""").
hasAnnotation("m3","m3:15").
annotation("m3:15").
hasName("m3:15","module").
hasArgument("m3:15","m3:16",0).
term("m3:16").
hasSerialization("m3:16","""m3""").
hasAnnotation("m3","m3:17").
annotation("m3:17").
hasName("m3:17","inherits").
hasArgument("m3:17","m3:18",0).
term("m3:18").
hasSerialization("m3:18","""m2""").
hasAnnotation("m3","m3:19").
annotation("m3:19").
hasName("m3:19","output").
hasArgument("m3:19","m3:20",0).
term("m3:20").
hasSerialization("m3:20","""oRelF""").

% ------------------------------------------------------------------------
% INPUT
% ------------------------------------------------------------------------
% @input("toDerive").
toDerive("d").

% ------------------------------------------------------------------------
% GENERAL PREDICATES USED IN OTHER CODE SECTIONS
% ------------------------------------------------------------------------
% Definition of true needed for triple quotes
true(#T). false(#F).

% Find module labels for module IDs
moduleLbl(M,L) :- hasAnnotation(M,A), hasName(A,"module"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).

% Find Id of module to be derived
deriveModule(M) :- toDerive(L), moduleLbl(M,L).

% Determine inheritance relationships in provided meta-representations
inherits(MC,MP) :- hasAnnotation(MC,A), hasName(A,"inherits"), hasArgument(A,Arg,0), hasSerialization(Arg,MP1), moduleLbl(MP,MPL), MPL = substring(MP1,1,string_length(MP1)-1).
tInherits(M,M2) :- inherits(M,M2).
tInherits(M,M2) :- tInherits(M,M1), inherits(M1,M2).

% Input and Output predicates
inputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"input"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"output"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

% Defined restrictions and modification operations
restriction("no_additional_input").
restriction("no_additional_output").
restriction("no_additional_annotation").
restriction("non_omitable").
restriction("non_redefinable").
restriction("non_shrinkable").
restriction("non_growable").
modOp("remove"). modOp("removeQ").
modOp("redefines"). modOp("redefinesQ").
modOp("inherits").

% Inheritance Annotations
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), restriction(N).
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), modOp(N).

% Which statements exist in a module?
hasStmt(M,S) :- hasRule(M,S).
hasStmt(M,S) :- hasFact(M,S).
hasStmt(M,S) :- moduleLbl(M,_), hasAnnotation(M,S).

% Only labeled statements are interesting, others always propagated
stmtLbl(R,L) :- hasRule(M,R), hasAnnotation(R,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(F,L) :- hasFact(M,F), hasAnnotation(F,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(A,L) :- hasAnnotation(M,A), hasAnnotation(A,A2), hasName(A2,"label"), hasArgument(A2,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtML(M,S,L) :- stmtLbl(S,L), hasStmt(M,S).

% RESOLVE INHERITANCE
% Unqualified remove and redefine
redefineStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"redefines"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), L = substring(L1,1,string_length(L1)-1).
removeStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"remove"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), L = substring(L1,1,string_length(L1)-1).
% Any statement except inheritance annotations can be removed
redefineStmt(M,S):- redefineStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).
removeStmt(M,S):- removeStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).

% Qualified remove and redefine
redefineStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"redefinesQ"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), hasArgument(A,Arg3,2), hasSerialization(Arg3,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
removeStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"removeQ"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
redefineStmt(M,S) :- redefineStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).
removeStmt(M,S) :- removeStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).

% Module name annotations are not inherited
removeStmt(M,A) :- hasAnnotation(M,A), hasName(A,"module"), not deriveModule(M).

% Summarize modification operation statements
modOpStmt(M,S) :- removeStmt(M,S).
modOpStmt(M,S) :- redefineStmt(M,S).
tModOpStmt(M,M,S) :- modOpStmt(M,S).
tModOpStmt(M,Morg,S) :- inherits(M,M2), tModOpStmt(M2,Morg,S).

% DETERMINE ACTIVE STATEMENTS AND MODULE/STATEMENT ANNOTATIONS FOR MODULES
% Derive for each module its active rules by inheriting
tHasRule(M,R) :- hasRule(M,R).
tHasRule(M,R) :- inherits(M,MP), tHasRule(MP,R).
moduleStmt(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).
mHasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).

% Determine for each module its active facts by inheriting
tHasFact(M,F) :- hasFact(M,F).
tHasFact(M,F) :- inherits(M,MP), tHasFact(MP,F).
moduleStmt(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F).

% Determine for each module its active module and statement annotations
tHasAnnotationM(M,A) :- moduleLbl(M,L), hasAnnotation(M,A), hasName(A,N), not modOp(N).
tHasAnnotationM(M,A) :- inherits(M,MP), tHasAnnotationM(MP,A).
tHasAnnotationS(M,Stmt,A) :- hasStmt(M,Stmt), hasAnnotation(Stmt,A).
tHasAnnotationS(M,Stmt,A) :- inherits(M,MP), tHasAnnotationS(MP,Stmt,A).
moduleStmt(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A).

% Determine Restrictions defined in modules
noAdditionalInput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_input").
noAdditionalOutput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_output").
noAdditionalAnnotation(M,ANN,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_annotation"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), P = substring(L1,1,string_length(L1)-1), ANN = substring(L2,1,string_length(L2)-1).
nonOmitable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_omitable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonRedefinable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_redefinable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonGrowable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_growable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P  =substring(L1,1,string_length(L1)-1).
nonShrinkable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_shrinkable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).

% ------------------------------------------------------------------------
% DETERMINE ACTIVE STATEMENTS AND ANNOTATIONS FOR THE MODULE TO BE DERIVED
% ------------------------------------------------------------------------
m_hasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R), deriveModule(M).
m_hasPositiveHeadAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasPositiveHeadAtom(R,AtomID).
m_hasNegativeHeadAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasNegativeHeadAtom(R,AtomID).
m_hasPositiveBodyAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasPositiveBodyAtom(R,AtomID).
m_hasNegativeBodyAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasNegativeBodyAtom(R,AtomID).
m_relationalAtom(Atom) :- m_hasAtom(_,Atom), relationalAtom(Atom).
m_hasName(Atom,N) :- m_relationalAtom(Atom), hasName(Atom,N).
m_hasArgument(Atom,Arg,Pos), m_term(Arg) :- m_relationalAtom(Atom), hasArgument(Atom,Arg,Pos).
m_hasSerialization(Term,S) :- m_term(Term), hasSerialization(Term,S).
m_nonRelationalAtom(Atom), m_hasSerialization(Atom,S) :- m_hasAtom(_,Atom), nonRelationalAtom(Atom), hasSerialization(Atom,S).

% Determine the facts active in the module to be derived
m_hasFact(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F), deriveModule(M).
m_relationalAtom(Atom) :- m_hasFact(_,Atom).

% Determine the annotations in the module to be derived
m_hasAnnotation(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A), deriveModule(M).
m_hasAnnotation(Stmt,A) :- tHasAnnotationS(M,Stmt,A), not tModOpStmt(M,_,Stmt), deriveModule(M).
m_annotation(A) :- m_hasAnnotation(_,A).
m_hasName(A,N) :- m_annotation(A), hasName(A,N).
m_hasArgument(A,Arg,Pos), m_term(Arg) :- m_annotation(A), hasArgument(A,Arg,Pos).

% EXPORTING THE RESULTING META-REPRESENTATION
line(L) :- deriveModule(M), L = "program("""+M+"""). annotation("""+M+":""). hasAnnotation("""+M+""","""+M+":""). hasName("""+M+":"",""resolved"").".
line(L) :- m_hasRule(M,R), L = "rule("""+R+"""). hasRule("""+M+""","""+R+""").".
line(L) :- m_hasPositiveHeadAtom(R,AtomID), L = "hasPositiveHeadAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasNegativeHeadAtom(R,AtomID), L = "hasNegativeHeadAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasPositiveBodyAtom(R,AtomID), L = "hasPositiveBodyAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasNegativeBodyAtom(R,AtomID), L = "hasNegativeBodyAtom("""+R+""","""+AtomID+""").".
line(L) :- m_relationalAtom(A), L= "relationalAtom("""+A+""").".
line(L) :- m_hasName(A,N), L= "hasName("""+A+""","""+N+""").".
line(L) :- m_hasSerialization(Term,S), true(T), T = starts_with(S,""""), T = ends_with(S,""""), L= "hasSerialization("""+Term+""","""""+S+""""").".
line(L) :- m_hasSerialization(Term,S), false(F), F = starts_with(S,""""), F = ends_with(S,""""), L= "hasSerialization("""+Term+""","""+S+""").".
line(L) :- m_nonRelationalAtom(A), L= "nonRelationalAtom("""+A+""").".
line(L) :- m_hasFact(M,F), L= "hasFact("""+M+""","""+F+""").".
line(L) :- m_hasAnnotation(Stmt,A), L="annotation("""+A+"""). hasAnnotation("""+Stmt+""","""+A+""").".
line(L) :- m_hasArgument(A,Arg,Pos), L = "hasArgument("""+A+""","""+Arg+""","+Pos+").".
line(L) :- m_term(Arg), L = "term("""+Arg+""").".

@output("line").

% ------------------------------------------------------------------------
% WARNINGS REGARDING INHERITANCE
% ------------------------------------------------------------------------
% Warn if restrictions or mod ops are modified
w_modifiedInhAnnotation(M,S) :- modOpStmt(M,S), inhAnnotation(S).

% Warn if non-existing statement is modified
w_modifyUnknownStmt(M,X) :- removeStmtLbl(M,L), not stmtLbl(_,L), X = L.
w_modifyUnknownStmt(M,X) :- redefineStmtLbl(M,L), not stmtLbl(_,L), X = L.
w_modifyUnknownStmtQ(M,X,Y) :- removeStmtQ(M,L,MQ), not stmtML(MQ,_,L), X = L, Y = MQ.
w_modifyUnknownStmtQ(M,X,Y) :- redefineStmtQ(M,L,MQ), not stmtML(MQ,_,L), X = L, Y = MQ.

% Two different modules employ the same ID
w_labelMultiplicity(M,S,M2,S2,L) :- stmtML(M,S,L), stmtML(M2,S2,L2), moduleLbl(M,_), tInherits(MC,M2), tInherits(MC,M), L = L2, M != M2, S != S2.
w_labelMultiplicity(M,S,M2,S2,L) :- stmtML(M,S,L), stmtML(M2,S2,L2), moduleLbl(M,_), tInherits(M,M2), L = L2, M != M2, S != S2.

% An annotation is defined multiple times for the same predicate
moduleAnnotation(M,A,N,P) :- moduleStmt(M,A), hasAnnotation(_,A), hasName(A,N), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
w_annotationMultiplyDefined(M,A1,A2,Type,Predicate) :- moduleAnnotation(M,A1,Type,P1), moduleAnnotation(M,A2,Type,Predicate), A1 != A2, P1 = Predicate.

@output("w_modifiedInhAnnotation").
@output("w_modifyUnknownStmt").
@output("w_modifyUnknownStmtQ").
@output("w_labelMultiplicity").
@output("w_annotationMultiplyDefined").

% Multi-inheritance: Statement modified differently in two branches!
tRemoveStmt(M,S) :- removeStmt(M,S).
tRemoveStmt(M,S) :- inherits(M,M2), tRemoveStmt(M2,S).
tRedefineStmt(M,S) :- redefineStmt(M,S).
tRedefineStmt(M,S) :- inherits(M,M2), redefineStmt(M2,S).

w_mergeWithCommonStmtsRemoved(C,GP,P1,P2,S) :- moduleLbl(GP,_), moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), tInherits(P1,GP), tInherits(P2,GP), moduleStmt(GP,S), tRemoveStmt(P1,S), P1 != P2.
w_mergeWithCommonStmtsRedefined(C,GP,P1,P2,S) :- moduleLbl(GP,_), moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), tInherits(P1,GP), tInherits(P2,GP), moduleStmt(GP,S), tRedefineStmt(P1,S), P1 != P2.
w_diffModifiedParent(C,P1,P2,S) :- w_mergeWithCommonStmtsRemoved(C,_,P1,P2,S), not tRemoveStmt(P2,S).
w_diffModifiedParent(C,P1,P2,S) :- w_mergeWithCommonStmtsRedefined(C,_,P1,P2,S), not tRedefineStmt(P2,S).

% Multi-inheritance: Warning about different restrictions in parents
w_diffParentRestriction(C,P1,P2,"noAdditionalInput") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalInput(P1), not noAdditionalInput(P2), P1 != P2.
w_diffParentRestriction(C,P1,P2,"noAdditionalOutput") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalOutput(P1), not noAdditionalOutput(P2), P1 != P2.
w_diffParentRestriction(C,P1,P2,"noAdditionalAnnotation") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalAnnotation(P1,ANN,Predicate), not noAdditionalAnnotation(P2,ANN,Predicate), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonOmitable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonOmitable(P1,Predicate), not nonOmitable(P2,Predicate), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonRedefinable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonGrowable(P1,PRED), not nonGrowable(P2,PRED), P1 != P2.

w_diffParentRestriction(C,P1,P2,"nonGrowable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonGrowable(P1,PRED), not nonGrowable(P2,PRED), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonShrinkable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonShrinkable(P1,PRED), not nonShrinkable(P2,PRED), P1 != P2.

@output("w_diffModifiedParent").
@output("w_diffParentRestriction").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">line</caption><thead><tr><th>string</th></tr></thead><tbody><tr><td>relationalAtom(&quot;m:1&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:24&quot;,&quot;m:25&quot;,0).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:24&quot;). hasAnnotation(&quot;m1C&quot;,&quot;m:24&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:25&quot;,&quot;&quot;&quot;iRel1&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:2&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m1C&quot;,&quot;m:16&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:25&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m:0&quot;). hasRule(&quot;m1C&quot;,&quot;m:0&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m:0&quot;,&quot;m:3&quot;).</td></tr></tbody><tbody><tr><td>program(&quot;m1C&quot;). annotation(&quot;m1C:&quot;). hasAnnotation(&quot;m1C&quot;,&quot;m1C:&quot;). hasName(&quot;m1C:&quot;,&quot;resolved&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:24&quot;,&quot;input&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m:0&quot;,&quot;m:1&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:16&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:1&quot;,&quot;m:2&quot;,0).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:14&quot;). hasAnnotation(&quot;m:7&quot;,&quot;m:14&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:15&quot;,&quot;&quot;&quot;M-R2&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:4&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m1C&quot;,&quot;m:18&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:2&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m:7&quot;). hasRule(&quot;m1C&quot;,&quot;m:7&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m:0&quot;,&quot;m:5&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:1&quot;,&quot;oRelA&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m:7&quot;,&quot;m:8&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:3&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:14&quot;,&quot;m:15&quot;,0).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:26&quot;). hasAnnotation(&quot;m1C&quot;,&quot;m:26&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:17&quot;,&quot;&quot;&quot;l1&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:9&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m1C&quot;,&quot;m:20&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:15&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m1C:0&quot;). hasRule(&quot;m1C&quot;,&quot;m1C:0&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m:7&quot;,&quot;m:10&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:14&quot;,&quot;label&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m1C:0&quot;,&quot;m1C:1&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:18&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:16&quot;,&quot;m:17&quot;,0).</td></tr></tbody><tbody><tr><td>annotation(&quot;m1C:9&quot;). hasAnnotation(&quot;m1C:0&quot;,&quot;m1C:9&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:27&quot;,&quot;&quot;&quot;iRel1&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:6&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m1C&quot;,&quot;m1C:11&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:17&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m:7&quot;,&quot;m:12&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:16&quot;,&quot;iRel1&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&qu ...

# %%
%%fromMeta
relationalAtom("m:1").
hasArgument("m:24","m:25",0).
annotation("m:24"). hasAnnotation("m1C","m:24").
hasSerialization("m:25","""iRel1""").
hasSerialization("m:2","X").
hasFact("m1C","m:16").
term("m:25").
rule("m:0"). hasRule("m1C","m:0").
hasPositiveBodyAtom("m:0","m:3").
program("m1C"). annotation("m1C:"). hasAnnotation("m1C","m1C:"). hasName("m1C:","resolved").
hasName("m:24","input").
hasPositiveHeadAtom("m:0","m:1").
relationalAtom("m:16").
hasArgument("m:1","m:2",0).
annotation("m:14"). hasAnnotation("m:7","m:14").
hasSerialization("m:15","""M-R2""").
hasSerialization("m:4","X").
hasFact("m1C","m:18").
term("m:2").
rule("m:7"). hasRule("m1C","m:7").
hasPositiveBodyAtom("m:0","m:5").
hasName("m:1","oRelA").
hasPositiveHeadAtom("m:7","m:8").
relationalAtom("m:3").
hasArgument("m:14","m:15",0).
annotation("m:26"). hasAnnotation("m1C","m:26").
hasSerialization("m:17","""l1""").
hasSerialization("m:9","X").
hasFact("m1C","m:20").
term("m:15").
rule("m1C:0"). hasRule("m1C","m1C:0").
hasPositiveBodyAtom("m:7","m:10").
hasName("m:14","label").
hasPositiveHeadAtom("m1C:0","m1C:1").
relationalAtom("m:18").
hasArgument("m:16","m:17",0).
annotation("m1C:9"). hasAnnotation("m1C:0","m1C:9").
hasSerialization("m:27","""iRel1""").
hasSerialization("m:6","X").
hasFact("m1C","m1C:11").
term("m:17").
hasPositiveBodyAtom("m:7","m:12").
hasName("m:16","iRel1").
relationalAtom("m:8").
hasArgument("m:26","m:27",0).
annotation("m:29"). hasAnnotation("m1C","m:29").
hasSerialization("m:28","""...""").
hasSerialization("m1C:2","X").
hasFact("m1C","m1C:14").
term("m:27").
hasPositiveBodyAtom("m1C:0","m1C:4").
hasName("m:26","bind").
relationalAtom("m:20").
hasArgument("m:3","m:4",0).
annotation("m1C:17"). hasAnnotation("m1C","m1C:17").
hasSerialization("m:19","""l2""").
hasSerialization("m1C:3","Y").
term("m:4").
hasPositiveBodyAtom("m1C:0","m1C:7").
hasName("m:3","iRel1").
relationalAtom("m:5").
hasArgument("m:26","m:28",1).
annotation("m1C:21"). hasAnnotation("m1C","m1C:21").
hasSerialization("m1C:10","""R3""").
hasSerialization("m:11","X").
term("m:28").
hasName("m1C:9","label").
relationalAtom("m1C:11").
hasArgument("m:18","m:19",0).
annotation("m1C:23"). hasAnnotation("m1C","m1C:23").
hasSerialization("m:30","""oRelA""").
hasSerialization("m:13","X").
term("m:19").
hasName("m:18","iRel1").
relationalAtom("m1C:1").
hasArgument("m1C:9","m1C:10",0).
annotation("m:31"). hasAnnotation("m1C","m:31").
hasSerialization("m:21","""l1""").
hasSerialization("m1C:5","X").
term("m1C:10").
hasName("m:29","output").
relationalAtom("m1C:14").
hasArgument("m:8","m:9",0).
annotation("m1C:26"). hasAnnotation("m1C","m1C:26").
hasSerialization("m1C:18","""m1C""").
hasSerialization("m1C:6","Y").
term("m:9").
hasName("m:8","oRelB").
relationalAtom("m:10").
hasArgument("m:29","m:30",0).
annotation("m:34"). hasAnnotation("m1C","m:34").
hasSerialization("m1C:22","""iRel3""").
hasSerialization("m1C:8","Y").
term("m:30").
hasName("m1C:17","module").
relationalAtom("m:12").
hasArgument("m:20","m:21",0).
hasSerialization("m1C:12","""l1""").
term("m:21").
hasName("m:20","f1").
relationalAtom("m1C:4").
hasArgument("m1C:17","m1C:18",0).
hasSerialization("m1C:24","""iRel3""").
term("m1C:18").
hasName("m1C:21","input").
relationalAtom("m1C:7").
hasArgument("m:5","m:6",0).
hasSerialization("m1C:13","""l1""").
term("m:6").
hasName("m:5","f1").
hasArgument("m1C:21","m1C:22",0).
hasSerialization("m1C:25","""...""").
term("m1C:22").
hasName("m1C:23","bind").
hasArgument("m1C:11","m1C:12",0).
hasSerialization("m:32","""oRelA""").
term("m1C:12").
hasName("m1C:11","iRel3").
hasArgument("m1C:23","m1C:24",0).
hasSerialization("m:33","""orderby(1)""").
term("m1C:24").
hasName("m:31","post").
hasArgument("m1C:11","m1C:13",1).
hasSerialization("m1C:15","""l2""").
term("m1C:13").
hasName("m1C:1","oRelC").
hasArgument("m1C:23","m1C:25",1).
hasSerialization("m1C:27","""oRelC""").
term("m1C:25").
hasName("m1C:26","output").
hasArgument("m1C:1","m1C:2",0).
hasSerialization("m1C:16","""l3""").
term("m1C:2").
hasName("m1C:14","iRel3").
hasArgument("m:31","m:32",0).
hasSerialization("m:35","""oRelB""").
term("m:32").
hasName("m:34","output").
hasArgument("m1C:1","m1C:3",1).
term("m1C:3").
hasName("m:10","iRel1").
hasArgument("m:31","m:33",1).
term("m:33").
hasName("m:12","f2").
hasArgument("m1C:14","m1C:15",0).
term("m1C:15").
hasName("m1C:4","iRel3").
hasArgument("m1C:26","m1C:27",0).
term("m1C:27").
hasName("m1C:7","f1").
hasArgument("m1C:14","m1C:16",1).
term("m1C:16").
hasArgument("m:34","m:35",0).
term("m:35").
hasArgument("m:10","m:11",0).
term("m:11").
hasArgument("m:12","m:13",0).
term("m:13").
hasArgument("m1C:4","m1C:5",0).
term("m1C:5").
hasArgument("m1C:4","m1C:6",1).
term("m1C:6").
hasArgument("m1C:7","m1C:8",0).
term("m1C:8").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">m1C</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# @input("iRel1").
# @resolved.
# @bind("iRel1","...").
# @output("oRelA").
# @module("m1C").
# @input("iRel3").
# @bind("iRel3","...").
# @post("oRelA","orderby(1)").
# @output("oRelC").
# @output("oRelB").
# iRel1("l1").
# iRel1("l2").
# f1("l1").
# iRel3("l1","l1").
# iRel3("l2","l3").
# oRelA(X) :- iRel1(X), f1(X).
# @label("M-R2") oRelB(X) :- iRel1(X), f2(X).
# @label("R3") oRelC(X,Y) :- iRel3(X,Y), f1(Y).
# </textarea></div></div>

# %% [markdown]
# **Expected Result**

# %%
@resolved. @module("m1C").
@input("iRel1"). @bind("iRel1","...").
@input("iRel3"). @bind("iRel3","...").

f1("l1").
iRel1("l1"). iRel1("l2").
iRel3("l1","l1"). iRel3("l2","l3").

oRelA(X) :- iRel1(X), f1(X).
@label("M-R2") oRelB(X) :- iRel1(X), f2(X).
@label("R3") oRelC(X,Y) :- iRel3(X,Y), f1(Y).

@output("oRelA"). @post("oRelA","orderby(1)").
@output("oRelB").
@output("oRelC").

# %% [markdown]
# #### 3: m3

# %%
% @input("toDerive").
toDerive("m3").

program("m").
hasRule("m","m:0").
rule("m:0").
hasPositiveHeadAtom("m:0","m:1").
relationalAtom("m:1").
hasName("m:1","oRelA").
hasArgument("m:1","m:2",0).
term("m:2").
hasSerialization("m:2","X").
hasPositiveBodyAtom("m:0","m:3").
relationalAtom("m:3").
hasName("m:3","iRel1").
hasArgument("m:3","m:4",0).
term("m:4").
hasSerialization("m:4","X").
hasPositiveBodyAtom("m:0","m:5").
relationalAtom("m:5").
hasName("m:5","f1").
hasArgument("m:5","m:6",0).
term("m:6").
hasSerialization("m:6","X").
hasRule("m","m:7").
rule("m:7").
hasPositiveHeadAtom("m:7","m:8").
relationalAtom("m:8").
hasName("m:8","oRelB").
hasArgument("m:8","m:9",0).
term("m:9").
hasSerialization("m:9","X").
hasPositiveBodyAtom("m:7","m:10").
relationalAtom("m:10").
hasName("m:10","iRel1").
hasArgument("m:10","m:11",0).
term("m:11").
hasSerialization("m:11","X").
hasPositiveBodyAtom("m:7","m:12").
relationalAtom("m:12").
hasName("m:12","f2").
hasArgument("m:12","m:13",0).
term("m:13").
hasSerialization("m:13","X").
hasAnnotation("m:7","m:14").
annotation("m:14").
hasName("m:14","label").
hasArgument("m:14","m:15",0).
term("m:15").
hasSerialization("m:15","""M-R2""").
hasFact("m","m:16").
relationalAtom("m:16").
hasName("m:16","iRel1").
hasArgument("m:16","m:17",0).
term("m:17").
hasSerialization("m:17","""l1""").
hasFact("m","m:18").
relationalAtom("m:18").
hasName("m:18","iRel1").
hasArgument("m:18","m:19",0).
term("m:19").
hasSerialization("m:19","""l2""").
hasFact("m","m:20").
relationalAtom("m:20").
hasName("m:20","f1").
hasArgument("m:20","m:21",0).
term("m:21").
hasSerialization("m:21","""l1""").
hasAnnotation("m","m:22").
annotation("m:22").
hasName("m:22","module").
hasArgument("m:22","m:23",0).
term("m:23").
hasSerialization("m:23","""m""").
hasAnnotation("m","m:24").
annotation("m:24").
hasName("m:24","input").
hasArgument("m:24","m:25",0).
term("m:25").
hasSerialization("m:25","""iRel1""").
hasAnnotation("m","m:26").
annotation("m:26").
hasName("m:26","bind").
hasArgument("m:26","m:27",0).
term("m:27").
hasSerialization("m:27","""iRel1""").
hasArgument("m:26","m:28",1).
term("m:28").
hasSerialization("m:28","""...""").
hasAnnotation("m","m:29").
annotation("m:29").
hasName("m:29","output").
hasArgument("m:29","m:30",0).
term("m:30").
hasSerialization("m:30","""oRelA""").
hasAnnotation("m","m:31").
annotation("m:31").
hasName("m:31","post").
hasArgument("m:31","m:32",0).
term("m:32").
hasSerialization("m:32","""oRelA""").
hasArgument("m:31","m:33",1).
term("m:33").
hasSerialization("m:33","""orderby(1)""").
hasAnnotation("m","m:34").
annotation("m:34").
hasName("m:34","output").
hasArgument("m:34","m:35",0).
term("m:35").
hasSerialization("m:35","""oRelB""").

program("m1A").
hasRule("m1A","m1A:0").
rule("m1A:0").
hasPositiveHeadAtom("m1A:0","m1A:1").
relationalAtom("m1A:1").
hasName("m1A:1","oRelC").
hasArgument("m1A:1","m1A:2",0).
term("m1A:2").
hasSerialization("m1A:2","X").
hasPositiveBodyAtom("m1A:0","m1A:3").
relationalAtom("m1A:3").
hasName("m1A:3","oRelA").
hasArgument("m1A:3","m1A:4",0).
term("m1A:4").
hasSerialization("m1A:4","X").
hasPositiveBodyAtom("m1A:0","m1A:5").
relationalAtom("m1A:5").
hasName("m1A:5","oRelB").
hasArgument("m1A:5","m1A:6",0).
term("m1A:6").
hasSerialization("m1A:6","X").
hasPositiveBodyAtom("m1A:0","m1A:7").
relationalAtom("m1A:7").
hasName("m1A:7","temp").
hasArgument("m1A:7","m1A:8",0).
term("m1A:8").
hasSerialization("m1A:8","X").
hasAnnotation("m1A:0","m1A:9").
annotation("m1A:9").
hasName("m1A:9","label").
hasArgument("m1A:9","m1A:10",0).
term("m1A:10").
hasSerialization("m1A:10","""R3""").
hasRule("m1A","m1A:11").
rule("m1A:11").
hasPositiveHeadAtom("m1A:11","m1A:12").
relationalAtom("m1A:12").
hasName("m1A:12","temp").
hasArgument("m1A:12","m1A:13",0).
term("m1A:13").
hasSerialization("m1A:13","T").
hasPositiveBodyAtom("m1A:11","m1A:14").
relationalAtom("m1A:14").
hasName("m1A:14","iRel2").
hasArgument("m1A:14","m1A:15",0).
term("m1A:15").
hasSerialization("m1A:15","T").
hasPositiveBodyAtom("m1A:11","m1A:16").
relationalAtom("m1A:16").
hasName("m1A:16","f1").
hasArgument("m1A:16","m1A:17",0).
term("m1A:17").
hasSerialization("m1A:17","T").
hasAnnotation("m1A:11","m1A:18").
annotation("m1A:18").
hasName("m1A:18","label").
hasArgument("m1A:18","m1A:19",0).
term("m1A:19").
hasSerialization("m1A:19","""R4""").
hasFact("m1A","m1A:20").
relationalAtom("m1A:20").
hasName("m1A:20","iRel2").
hasArgument("m1A:20","m1A:21",0).
term("m1A:21").
hasSerialization("m1A:21","""l1""").
hasFact("m1A","m1A:22").
relationalAtom("m1A:22").
hasName("m1A:22","f1").
hasArgument("m1A:22","m1A:23",0).
term("m1A:23").
hasSerialization("m1A:23","""l2""").
hasFact("m1A","m1A:24").
relationalAtom("m1A:24").
hasName("m1A:24","f2").
hasArgument("m1A:24","m1A:25",0).
term("m1A:25").
hasSerialization("m1A:25","""l1""").
hasAnnotation("m1A:24","m1A:26").
annotation("m1A:26").
hasName("m1A:26","label").
hasArgument("m1A:26","m1A:27",0).
term("m1A:27").
hasSerialization("m1A:27","""F1""").
hasAnnotation("m1A","m1A:28").
annotation("m1A:28").
hasName("m1A:28","module").
hasArgument("m1A:28","m1A:29",0).
term("m1A:29").
hasSerialization("m1A:29","""m1A""").
hasAnnotation("m1A","m1A:30").
annotation("m1A:30").
hasName("m1A:30","inherits").
hasArgument("m1A:30","m1A:31",0).
term("m1A:31").
hasSerialization("m1A:31","""m""").
hasAnnotation("m1A","m1A:32").
annotation("m1A:32").
hasName("m1A:32","input").
hasArgument("m1A:32","m1A:33",0).
term("m1A:33").
hasSerialization("m1A:33","""iRel2""").
hasAnnotation("m1A","m1A:34").
annotation("m1A:34").
hasName("m1A:34","bind").
hasArgument("m1A:34","m1A:35",0).
term("m1A:35").
hasSerialization("m1A:35","""iRel2""").
hasArgument("m1A:34","m1A:36",1).
term("m1A:36").
hasSerialization("m1A:36","""...""").
hasAnnotation("m1A","m1A:37").
annotation("m1A:37").
hasName("m1A:37","output").
hasArgument("m1A:37","m1A:38",0).
term("m1A:38").
hasSerialization("m1A:38","""oRelC""").

program("m1C").
hasRule("m1C","m1C:0").
rule("m1C:0").
hasPositiveHeadAtom("m1C:0","m1C:1").
relationalAtom("m1C:1").
hasName("m1C:1","oRelC").
hasArgument("m1C:1","m1C:2",0).
term("m1C:2").
hasSerialization("m1C:2","X").
hasArgument("m1C:1","m1C:3",1).
term("m1C:3").
hasSerialization("m1C:3","Y").
hasPositiveBodyAtom("m1C:0","m1C:4").
relationalAtom("m1C:4").
hasName("m1C:4","iRel3").
hasArgument("m1C:4","m1C:5",0).
term("m1C:5").
hasSerialization("m1C:5","X").
hasArgument("m1C:4","m1C:6",1).
term("m1C:6").
hasSerialization("m1C:6","Y").
hasPositiveBodyAtom("m1C:0","m1C:7").
relationalAtom("m1C:7").
hasName("m1C:7","f1").
hasArgument("m1C:7","m1C:8",0).
term("m1C:8").
hasSerialization("m1C:8","Y").
hasAnnotation("m1C:0","m1C:9").
annotation("m1C:9").
hasName("m1C:9","label").
hasArgument("m1C:9","m1C:10",0).
term("m1C:10").
hasSerialization("m1C:10","""R3""").
hasFact("m1C","m1C:11").
relationalAtom("m1C:11").
hasName("m1C:11","iRel3").
hasArgument("m1C:11","m1C:12",0).
term("m1C:12").
hasSerialization("m1C:12","""l1""").
hasArgument("m1C:11","m1C:13",1).
term("m1C:13").
hasSerialization("m1C:13","""l1""").
hasFact("m1C","m1C:14").
relationalAtom("m1C:14").
hasName("m1C:14","iRel3").
hasArgument("m1C:14","m1C:15",0).
term("m1C:15").
hasSerialization("m1C:15","""l2""").
hasArgument("m1C:14","m1C:16",1).
term("m1C:16").
hasSerialization("m1C:16","""l3""").
hasAnnotation("m1C","m1C:17").
annotation("m1C:17").
hasName("m1C:17","module").
hasArgument("m1C:17","m1C:18",0).
term("m1C:18").
hasSerialization("m1C:18","""m1C""").
hasAnnotation("m1C","m1C:19").
annotation("m1C:19").
hasName("m1C:19","inherits").
hasArgument("m1C:19","m1C:20",0).
term("m1C:20").
hasSerialization("m1C:20","""m""").
hasAnnotation("m1C","m1C:21").
annotation("m1C:21").
hasName("m1C:21","input").
hasArgument("m1C:21","m1C:22",0).
term("m1C:22").
hasSerialization("m1C:22","""iRel3""").
hasAnnotation("m1C","m1C:23").
annotation("m1C:23").
hasName("m1C:23","bind").
hasArgument("m1C:23","m1C:24",0).
term("m1C:24").
hasSerialization("m1C:24","""iRel3""").
hasArgument("m1C:23","m1C:25",1).
term("m1C:25").
hasSerialization("m1C:25","""...""").
hasAnnotation("m1C","m1C:26").
annotation("m1C:26").
hasName("m1C:26","output").
hasArgument("m1C:26","m1C:27",0).
term("m1C:27").
hasSerialization("m1C:27","""oRelC""").

program("m2").
hasRule("m2","m2:0").
rule("m2:0").
hasPositiveHeadAtom("m2:0","m2:1").
relationalAtom("m2:1").
hasName("m2:1","oRelE").
hasArgument("m2:1","m2:2",0).
term("m2:2").
hasSerialization("m2:2","X").
hasPositiveBodyAtom("m2:0","m2:3").
relationalAtom("m2:3").
hasName("m2:3","f1").
hasArgument("m2:3","m2:4",0).
term("m2:4").
hasSerialization("m2:4","X").
hasPositiveBodyAtom("m2:0","m2:5").
relationalAtom("m2:5").
hasName("m2:5","f2").
hasArgument("m2:5","m2:6",0).
term("m2:6").
hasSerialization("m2:6","A").
hasPositiveBodyAtom("m2:0","m2:7").
relationalAtom("m2:7").
hasName("m2:7","f3").
hasArgument("m2:7","m2:8",0).
term("m2:8").
hasSerialization("m2:8","X").
hasPositiveBodyAtom("m2:0","m2:9").
relationalAtom("m2:9").
hasName("m2:9","iRel1").
hasArgument("m2:9","m2:10",0).
term("m2:10").
hasSerialization("m2:10","X").
hasPositiveBodyAtom("m2:0","m2:11").
relationalAtom("m2:11").
hasName("m2:11","iRel3").
hasArgument("m2:11","m2:12",0).
term("m2:12").
hasSerialization("m2:12","A").
hasArgument("m2:11","m2:13",1).
term("m2:13").
hasSerialization("m2:13","X").
hasAnnotation("m2:0","m2:14").
annotation("m2:14").
hasName("m2:14","label").
hasArgument("m2:14","m2:15",0).
term("m2:15").
hasSerialization("m2:15","""R5""").
hasFact("m2","m2:16").
relationalAtom("m2:16").
hasName("m2:16","f1").
hasArgument("m2:16","m2:17",0).
term("m2:17").
hasSerialization("m2:17","""l3""").
hasFact("m2","m2:18").
relationalAtom("m2:18").
hasName("m2:18","f2").
hasArgument("m2:18","m2:19",0).
term("m2:19").
hasSerialization("m2:19","""l3""").
hasFact("m2","m2:20").
relationalAtom("m2:20").
hasName("m2:20","f2").
hasArgument("m2:20","m2:21",0).
term("m2:21").
hasSerialization("m2:21","""f1""").
hasAnnotation("m2","m2:22").
annotation("m2:22").
hasName("m2:22","module").
hasArgument("m2:22","m2:23",0).
term("m2:23").
hasSerialization("m2:23","""m2""").
hasAnnotation("m2","m2:24").
annotation("m2:24").
hasName("m2:24","inherits").
hasArgument("m2:24","m2:25",0).
term("m2:25").
hasSerialization("m2:25","""m1A""").
hasAnnotation("m2","m2:26").
annotation("m2:26").
hasName("m2:26","output").
hasArgument("m2:26","m2:27",0).
term("m2:27").
hasSerialization("m2:27","""oRelE""").

program("m3").
hasRule("m3","m3:0").
rule("m3:0").
hasPositiveHeadAtom("m3:0","m3:1").
relationalAtom("m3:1").
hasName("m3:1","oRelF").
hasArgument("m3:1","m3:2",0).
term("m3:2").
hasSerialization("m3:2","X").
hasArgument("m3:1","m3:3",1).
term("m3:3").
hasSerialization("m3:3","Y").
hasPositiveBodyAtom("m3:0","m3:4").
relationalAtom("m3:4").
hasName("m3:4","iRel1").
hasArgument("m3:4","m3:5",0).
term("m3:5").
hasSerialization("m3:5","X").
hasPositiveBodyAtom("m3:0","m3:6").
relationalAtom("m3:6").
hasName("m3:6","iRel2").
hasArgument("m3:6","m3:7",0).
term("m3:7").
hasSerialization("m3:7","X").
hasPositiveBodyAtom("m3:0","m3:8").
relationalAtom("m3:8").
hasName("m3:8","iRel3").
hasArgument("m3:8","m3:9",0).
term("m3:9").
hasSerialization("m3:9","X").
hasArgument("m3:8","m3:10",1).
term("m3:10").
hasSerialization("m3:10","Y").
hasPositiveBodyAtom("m3:0","m3:11").
relationalAtom("m3:11").
hasName("m3:11","iRel4").
hasArgument("m3:11","m3:12",0).
term("m3:12").
hasSerialization("m3:12","Y").
hasAnnotation("m3:0","m3:13").
annotation("m3:13").
hasName("m3:13","label").
hasArgument("m3:13","m3:14",0).
term("m3:14").
hasSerialization("m3:14","""R6""").
hasAnnotation("m3","m3:15").
annotation("m3:15").
hasName("m3:15","module").
hasArgument("m3:15","m3:16",0).
term("m3:16").
hasSerialization("m3:16","""m3""").
hasAnnotation("m3","m3:17").
annotation("m3:17").
hasName("m3:17","inherits").
hasArgument("m3:17","m3:18",0).
term("m3:18").
hasSerialization("m3:18","""m2""").
hasAnnotation("m3","m3:19").
annotation("m3:19").
hasName("m3:19","output").
hasArgument("m3:19","m3:20",0).
term("m3:20").
hasSerialization("m3:20","""oRelF""").

% ------------------------------------------------------------------------
% INPUT
% ------------------------------------------------------------------------
% @input("toDerive").
toDerive("d").

% ------------------------------------------------------------------------
% GENERAL PREDICATES USED IN OTHER CODE SECTIONS
% ------------------------------------------------------------------------
% Definition of true needed for triple quotes
true(#T). false(#F).

% Find module labels for module IDs
moduleLbl(M,L) :- hasAnnotation(M,A), hasName(A,"module"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).

% Find Id of module to be derived
deriveModule(M) :- toDerive(L), moduleLbl(M,L).

% Determine inheritance relationships in provided meta-representations
inherits(MC,MP) :- hasAnnotation(MC,A), hasName(A,"inherits"), hasArgument(A,Arg,0), hasSerialization(Arg,MP1), moduleLbl(MP,MPL), MPL = substring(MP1,1,string_length(MP1)-1).
tInherits(M,M2) :- inherits(M,M2).
tInherits(M,M2) :- tInherits(M,M1), inherits(M1,M2).

% Input and Output predicates
inputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"input"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"output"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

% Defined restrictions and modification operations
restriction("no_additional_input").
restriction("no_additional_output").
restriction("no_additional_annotation").
restriction("non_omitable").
restriction("non_redefinable").
restriction("non_shrinkable").
restriction("non_growable").
modOp("remove"). modOp("removeQ").
modOp("redefines"). modOp("redefinesQ").
modOp("inherits").

% Inheritance Annotations
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), restriction(N).
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), modOp(N).

% Which statements exist in a module?
hasStmt(M,S) :- hasRule(M,S).
hasStmt(M,S) :- hasFact(M,S).
hasStmt(M,S) :- moduleLbl(M,_), hasAnnotation(M,S).

% Only labeled statements are interesting, others always propagated
stmtLbl(R,L) :- hasRule(M,R), hasAnnotation(R,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(F,L) :- hasFact(M,F), hasAnnotation(F,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(A,L) :- hasAnnotation(M,A), hasAnnotation(A,A2), hasName(A2,"label"), hasArgument(A2,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtML(M,S,L) :- stmtLbl(S,L), hasStmt(M,S).

% RESOLVE INHERITANCE
% Unqualified remove and redefine
redefineStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"redefines"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), L = substring(L1,1,string_length(L1)-1).
removeStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"remove"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), L = substring(L1,1,string_length(L1)-1).
% Any statement except inheritance annotations can be removed
redefineStmt(M,S):- redefineStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).
removeStmt(M,S):- removeStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).

% Qualified remove and redefine
redefineStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"redefinesQ"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), hasArgument(A,Arg3,2), hasSerialization(Arg3,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
removeStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"removeQ"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
redefineStmt(M,S) :- redefineStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).
removeStmt(M,S) :- removeStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).

% Module name annotations are not inherited
removeStmt(M,A) :- hasAnnotation(M,A), hasName(A,"module"), not deriveModule(M).

% Summarize modification operation statements
modOpStmt(M,S) :- removeStmt(M,S).
modOpStmt(M,S) :- redefineStmt(M,S).
tModOpStmt(M,M,S) :- modOpStmt(M,S).
tModOpStmt(M,Morg,S) :- inherits(M,M2), tModOpStmt(M2,Morg,S).

% DETERMINE ACTIVE STATEMENTS AND MODULE/STATEMENT ANNOTATIONS FOR MODULES
% Derive for each module its active rules by inheriting
tHasRule(M,R) :- hasRule(M,R).
tHasRule(M,R) :- inherits(M,MP), tHasRule(MP,R).
moduleStmt(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).
mHasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).

% Determine for each module its active facts by inheriting
tHasFact(M,F) :- hasFact(M,F).
tHasFact(M,F) :- inherits(M,MP), tHasFact(MP,F).
moduleStmt(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F).

% Determine for each module its active module and statement annotations
tHasAnnotationM(M,A) :- moduleLbl(M,L), hasAnnotation(M,A), hasName(A,N), not modOp(N).
tHasAnnotationM(M,A) :- inherits(M,MP), tHasAnnotationM(MP,A).
tHasAnnotationS(M,Stmt,A) :- hasStmt(M,Stmt), hasAnnotation(Stmt,A).
tHasAnnotationS(M,Stmt,A) :- inherits(M,MP), tHasAnnotationS(MP,Stmt,A).
moduleStmt(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A).

% Determine Restrictions defined in modules
noAdditionalInput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_input").
noAdditionalOutput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_output").
noAdditionalAnnotation(M,ANN,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_annotation"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), P = substring(L1,1,string_length(L1)-1), ANN = substring(L2,1,string_length(L2)-1).
nonOmitable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_omitable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonRedefinable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_redefinable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonGrowable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_growable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P  =substring(L1,1,string_length(L1)-1).
nonShrinkable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_shrinkable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).

% ------------------------------------------------------------------------
% DETERMINE ACTIVE STATEMENTS AND ANNOTATIONS FOR THE MODULE TO BE DERIVED
% ------------------------------------------------------------------------
m_hasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R), deriveModule(M).
m_hasPositiveHeadAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasPositiveHeadAtom(R,AtomID).
m_hasNegativeHeadAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasNegativeHeadAtom(R,AtomID).
m_hasPositiveBodyAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasPositiveBodyAtom(R,AtomID).
m_hasNegativeBodyAtom(R,AtomID), m_hasAtom(R,AtomID) :- m_hasRule(_,R), hasNegativeBodyAtom(R,AtomID).
m_relationalAtom(Atom) :- m_hasAtom(_,Atom), relationalAtom(Atom).
m_hasName(Atom,N) :- m_relationalAtom(Atom), hasName(Atom,N).
m_hasArgument(Atom,Arg,Pos), m_term(Arg) :- m_relationalAtom(Atom), hasArgument(Atom,Arg,Pos).
m_hasSerialization(Term,S) :- m_term(Term), hasSerialization(Term,S).
m_nonRelationalAtom(Atom), m_hasSerialization(Atom,S) :- m_hasAtom(_,Atom), nonRelationalAtom(Atom), hasSerialization(Atom,S).

% Determine the facts active in the module to be derived
m_hasFact(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F), deriveModule(M).
m_relationalAtom(Atom) :- m_hasFact(_,Atom).

% Determine the annotations in the module to be derived
m_hasAnnotation(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A), deriveModule(M).
m_hasAnnotation(Stmt,A) :- tHasAnnotationS(M,Stmt,A), not tModOpStmt(M,_,Stmt), deriveModule(M).
m_annotation(A) :- m_hasAnnotation(_,A).
m_hasName(A,N) :- m_annotation(A), hasName(A,N).
m_hasArgument(A,Arg,Pos), m_term(Arg) :- m_annotation(A), hasArgument(A,Arg,Pos).

% EXPORTING THE RESULTING META-REPRESENTATION
line(L) :- deriveModule(M), L = "program("""+M+"""). annotation("""+M+":""). hasAnnotation("""+M+""","""+M+":""). hasName("""+M+":"",""resolved"").".
line(L) :- m_hasRule(M,R), L = "rule("""+R+"""). hasRule("""+M+""","""+R+""").".
line(L) :- m_hasPositiveHeadAtom(R,AtomID), L = "hasPositiveHeadAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasNegativeHeadAtom(R,AtomID), L = "hasNegativeHeadAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasPositiveBodyAtom(R,AtomID), L = "hasPositiveBodyAtom("""+R+""","""+AtomID+""").".
line(L) :- m_hasNegativeBodyAtom(R,AtomID), L = "hasNegativeBodyAtom("""+R+""","""+AtomID+""").".
line(L) :- m_relationalAtom(A), L= "relationalAtom("""+A+""").".
line(L) :- m_hasName(A,N), L= "hasName("""+A+""","""+N+""").".
line(L) :- m_hasSerialization(Term,S), true(T), T = starts_with(S,""""), T = ends_with(S,""""), L= "hasSerialization("""+Term+""","""""+S+""""").".
line(L) :- m_hasSerialization(Term,S), false(F), F = starts_with(S,""""), F = ends_with(S,""""), L= "hasSerialization("""+Term+""","""+S+""").".
line(L) :- m_nonRelationalAtom(A), L= "nonRelationalAtom("""+A+""").".
line(L) :- m_hasFact(M,F), L= "hasFact("""+M+""","""+F+""").".
line(L) :- m_hasAnnotation(Stmt,A), L="annotation("""+A+"""). hasAnnotation("""+Stmt+""","""+A+""").".
line(L) :- m_hasArgument(A,Arg,Pos), L = "hasArgument("""+A+""","""+Arg+""","+Pos+").".
line(L) :- m_term(Arg), L = "term("""+Arg+""").".

@output("line").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">line</caption><thead><tr><th>string</th></tr></thead><tbody><tr><td>hasSerialization(&quot;m3:2&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m3:0&quot;,&quot;m3:4&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m:14&quot;). hasAnnotation(&quot;m:7&quot;,&quot;m:14&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m:16&quot;).</td></tr></tbody><tbody><tr><td>program(&quot;m3&quot;). annotation(&quot;m3:&quot;). hasAnnotation(&quot;m3&quot;,&quot;m3:&quot;). hasName(&quot;m3:&quot;,&quot;resolved&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:16&quot;,&quot;iRel1&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m3:0&quot;,&quot;m3:1&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:15&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m3&quot;,&quot;m:16&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m3:0&quot;). hasRule(&quot;m3&quot;,&quot;m3:0&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:14&quot;,&quot;m:15&quot;,0).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:15&quot;,&quot;&quot;&quot;M-R2&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m3:3&quot;,&quot;Y&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m3:0&quot;,&quot;m3:6&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m3:15&quot;). hasAnnotation(&quot;m3&quot;,&quot;m3:15&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m3:1&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m:14&quot;,&quot;label&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m:0&quot;,&quot;m:1&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m:17&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m3&quot;,&quot;m2:16&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m:0&quot;). hasRule(&quot;m3&quot;,&quot;m:0&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m:16&quot;,&quot;m:17&quot;,0).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:17&quot;,&quot;&quot;&quot;l1&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m3:5&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m3:0&quot;,&quot;m3:8&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m1A:9&quot;). hasAnnotation(&quot;m1A:0&quot;,&quot;m1A:9&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m2:16&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m3:1&quot;,&quot;oRelF&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m2:0&quot;,&quot;m2:1&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m3:16&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m3&quot;,&quot;m1A:20&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m2:0&quot;). hasRule(&quot;m3&quot;,&quot;m2:0&quot;).</td></tr></tbody><tbody><tr><td>hasArgument(&quot;m3:15&quot;,&quot;m3:16&quot;,0).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m3:16&quot;,&quot;&quot;&quot;m3&quot;&quot;&quot;).</td></tr></tbody><tbody><tr><td>hasSerialization(&quot;m:2&quot;,&quot;X&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveBodyAtom(&quot;m3:0&quot;,&quot;m3:11&quot;).</td></tr></tbody><tbody><tr><td>annotation(&quot;m3:19&quot;). hasAnnotation(&quot;m3&quot;,&quot;m3:19&quot;).</td></tr></tbody><tbody><tr><td>relationalAtom(&quot;m3:4&quot;).</td></tr></tbody><tbody><tr><td>hasName(&quot;m3:15&quot;,&quot;module&quot;).</td></tr></tbody><tbody><tr><td>hasPositiveHeadAtom(&quot;m1A:0&quot;,&quot;m1A:1&quot;).</td></tr></tbody><tbody><tr><td>term(&quot;m3:2&quot;).</td></tr></tbody><tbody><tr><td>hasFact(&quot;m3&quot;,&quot;m2:18&quot;).</td></tr></tbody><tbody><tr><td>rule(&quot;m1A:0&quot;). hasRule(&quot;m3&quot;,&quot;m1A:0&quot;).</td></tr></tbody><tbody><tr><td>hasArgum ...

# %%
%%fromMeta
hasSerialization("m3:2","X").
hasPositiveBodyAtom("m3:0","m3:4").
annotation("m:14"). hasAnnotation("m:7","m:14").
relationalAtom("m:16").
program("m3"). annotation("m3:"). hasAnnotation("m3","m3:"). hasName("m3:","resolved").
hasName("m:16","iRel1").
hasPositiveHeadAtom("m3:0","m3:1").
term("m:15").
hasFact("m3","m:16").
rule("m3:0"). hasRule("m3","m3:0").
hasArgument("m:14","m:15",0).
hasSerialization("m:15","""M-R2""").
hasSerialization("m3:3","Y").
hasPositiveBodyAtom("m3:0","m3:6").
annotation("m3:15"). hasAnnotation("m3","m3:15").
relationalAtom("m3:1").
hasName("m:14","label").
hasPositiveHeadAtom("m:0","m:1").
term("m:17").
hasFact("m3","m2:16").
rule("m:0"). hasRule("m3","m:0").
hasArgument("m:16","m:17",0).
hasSerialization("m:17","""l1""").
hasSerialization("m3:5","X").
hasPositiveBodyAtom("m3:0","m3:8").
annotation("m1A:9"). hasAnnotation("m1A:0","m1A:9").
relationalAtom("m2:16").
hasName("m3:1","oRelF").
hasPositiveHeadAtom("m2:0","m2:1").
term("m3:16").
hasFact("m3","m1A:20").
rule("m2:0"). hasRule("m3","m2:0").
hasArgument("m3:15","m3:16",0).
hasSerialization("m3:16","""m3""").
hasSerialization("m:2","X").
hasPositiveBodyAtom("m3:0","m3:11").
annotation("m3:19"). hasAnnotation("m3","m3:19").
relationalAtom("m3:4").
hasName("m3:15","module").
hasPositiveHeadAtom("m1A:0","m1A:1").
term("m3:2").
hasFact("m3","m2:18").
rule("m1A:0"). hasRule("m3","m1A:0").
hasArgument("m3:1","m3:2",0).
hasSerialization("m1A:10","""R3""").
hasSerialization("m3:7","X").
hasPositiveBodyAtom("m:0","m:3").
annotation("m3:13"). hasAnnotation("m3:0","m3:13").
relationalAtom("m1A:20").
hasName("m2:16","f1").
hasPositiveHeadAtom("m1A:11","m1A:12").
term("m1A:10").
hasFact("m3","m:18").
rule("m1A:11"). hasRule("m3","m1A:11").
hasArgument("m1A:9","m1A:10",0).
hasSerialization("m3:20","""oRelF""").
hasSerialization("m2:2","X").
hasPositiveBodyAtom("m:0","m:5").
annotation("m:24"). hasAnnotation("m3","m:24").
relationalAtom("m:1").
hasName("m1A:9","label").
hasPositiveHeadAtom("m:7","m:8").
term("m3:3").
hasFact("m3","m2:20").
rule("m:7"). hasRule("m3","m:7").
hasArgument("m3:1","m3:3",1).
hasSerialization("m2:17","""l3""").
hasSerialization("m3:9","X").
hasPositiveBodyAtom("m2:0","m2:3").
annotation("m1A:18"). hasAnnotation("m1A:11","m1A:18").
relationalAtom("m2:18").
hasName("m3:4","iRel1").
term("m3:20").
hasFact("m3","m1A:22").
hasArgument("m3:19","m3:20",0).
hasSerialization("m3:14","""R6""").
hasSerialization("m3:10","Y").
hasPositiveBodyAtom("m2:0","m2:5").
annotation("m2:26"). hasAnnotation("m3","m2:26").
relationalAtom("m3:6").
hasName("m3:19","output").
term("m2:17").
hasFact("m3","m1A:24").
hasArgument("m2:16","m2:17",0).
hasSerialization("m:25","""iRel1""").
hasSerialization("m1A:2","X").
hasPositiveBodyAtom("m2:0","m2:7").
annotation("m2:14"). hasAnnotation("m2:0","m2:14").
relationalAtom("m:18").
hasName("m1A:20","iRel2").
term("m3:14").
hasFact("m3","m:20").
hasArgument("m3:13","m3:14",0).
hasSerialization("m1A:21","""l1""").
hasSerialization("m3:12","Y").
hasPositiveBodyAtom("m2:0","m2:9").
annotation("m:26"). hasAnnotation("m3","m:26").
relationalAtom("m2:1").
hasName("m3:13","label").
term("m3:5").
hasArgument("m3:4","m3:5",0).
hasSerialization("m1A:19","""R4""").
hasSerialization("m1A:13","T").
hasPositiveBodyAtom("m2:0","m2:11").
annotation("m1A:26"). hasAnnotation("m1A:24","m1A:26").
relationalAtom("m2:20").
hasName("m:1","oRelA").
term("m:25").
hasArgument("m:24","m:25",0).
hasSerialization("m2:27","""oRelE""").
hasSerialization("m:4","X").
hasPositiveBodyAtom("m1A:0","m1A:3").
annotation("m1A:32"). hasAnnotation("m3","m1A:32").
relationalAtom("m3:8").
hasName("m:24","input").
term("m1A:21").
hasArgument("m1A:20","m1A:21",0).
hasSerialization("m2:19","""l3""").
hasSerialization("m:9","X").
hasPositiveBodyAtom("m1A:0","m1A:5").
annotation("m1A:34"). hasAnnotation("m3","m1A:34").
relationalAtom("m1A:22").
hasName("m2:18","f2").
term("m1A:19").
hasArgument("m1A:18","m1A:19",0).
hasSerialization("m2:15","""R5""").
hasSerialization("m:6","X").
hasPositiveBodyAtom("m1A:0","m1A:7").
annotation("m:29"). hasAnnotation("m3","m:29").
relationalAtom("m1A:1").
hasName("m1A:18","label").
term("m:2").
hasArgument("m:1","m:2",0).
hasSerialization("m:27","""iRel1""").
hasSerialization("m2:4","X").
hasPositiveBodyAtom("m1A:11","m1A:14").
annotation("m1A:37"). hasAnnotation("m3","m1A:37").
relationalAtom("m1A:24").
hasName("m3:6","iRel2").
term("m2:27").
hasArgument("m2:26","m2:27",0).
hasSerialization("m:19","""l2""").
hasSerialization("m2:6","A").
hasPositiveBodyAtom("m1A:11","m1A:16").
annotation("m:31"). hasAnnotation("m3","m:31").
relationalAtom("m3:11").
hasName("m2:26","output").
term("m2:19").
hasArgument("m2:18","m2:19",0).
hasSerialization("m:28","""...""").
hasSerialization("m2:8","X").
hasPositiveBodyAtom("m:7","m:10").
annotation("m:34"). hasAnnotation("m3","m:34").
relationalAtom("m:20").
hasName("m:18","iRel1").
term("m2:15").
hasArgument("m2:14","m2:15",0).
hasSerialization("m1A:27","""F1""").
hasSerialization("m2:10","X").
hasPositiveBodyAtom("m:7","m:12").
relationalAtom("m1A:12").
hasName("m2:14","label").
term("m3:7").
hasArgument("m3:6","m3:7",0).
hasSerialization("m2:21","""f1""").
hasSerialization("m2:12","A").
relationalAtom("m:3").
hasName("m2:1","oRelE").
term("m:27").
hasArgument("m:26","m:27",0).
hasSerialization("m1A:33","""iRel2""").
hasSerialization("m2:13","X").
relationalAtom("m:8").
hasName("m:26","bind").
term("m:19").
hasArgument("m:18","m:19",0).
hasSerialization("m1A:35","""iRel2""").
hasSerialization("m1A:4","X").
relationalAtom("m:5").
hasName("m2:20","f2").
term("m:28").
hasArgument("m:26","m:28",1).
hasSerialization("m1A:36","""...""").
hasSerialization("m1A:6","X").
relationalAtom("m2:3").
hasName("m1A:26","label").
term("m2:2").
hasArgument("m2:1","m2:2",0).
hasSerialization("m1A:23","""l2""").
hasSerialization("m1A:8","X").
relationalAtom("m2:5").
hasName("m3:8","iRel3").
term("m1A:27").
hasArgument("m1A:26","m1A:27",0).
hasSerialization("m:30","""oRelA""").
hasSerialization("m1A:15","T").
relationalAtom("m2:7").
hasName("m1A:32","input").
term("m2:21").
hasArgument("m2:20","m2:21",0).
hasSerialization("m1A:38","""oRelC""").
hasSerialization("m1A:17","T").
relationalAtom("m2:9").
hasName("m1A:22","f1").
term("m1A:33").
hasArgument("m1A:32","m1A:33",0).
hasSerialization("m1A:25","""l1""").
hasSerialization("m:11","X").
relationalAtom("m2:11").
hasName("m1A:34","bind").
term("m3:9").
hasArgument("m3:8","m3:9",0).
hasSerialization("m:32","""oRelA""").
hasSerialization("m:13","X").
relationalAtom("m1A:3").
hasName("m1A:1","oRelC").
term("m1A:35").
hasArgument("m1A:34","m1A:35",0).
hasSerialization("m:33","""orderby(1)""").
relationalAtom("m1A:5").
hasName("m:29","output").
term("m3:10").
hasArgument("m3:8","m3:10",1).
hasSerialization("m:21","""l1""").
relationalAtom("m1A:7").
hasName("m1A:24","f2").
term("m1A:36").
hasArgument("m1A:34","m1A:36",1).
hasSerialization("m:35","""oRelB""").
relationalAtom("m1A:14").
hasName("m1A:37","output").
term("m1A:23").
hasArgument("m1A:22","m1A:23",0).
relationalAtom("m1A:16").
hasName("m3:11","iRel4").
term("m:30").
hasArgument("m:29","m:30",0).
relationalAtom("m:10").
hasName("m:31","post").
term("m1A:2").
hasArgument("m1A:1","m1A:2",0).
relationalAtom("m:12").
hasName("m:20","f1").
term("m1A:38").
hasArgument("m1A:37","m1A:38",0).
hasName("m:34","output").
term("m1A:25").
hasArgument("m1A:24","m1A:25",0).
hasName("m1A:12","temp").
term("m:32").
hasArgument("m:31","m:32",0).
hasName("m:3","iRel1").
term("m3:12").
hasArgument("m3:11","m3:12",0).
hasName("m:8","oRelB").
term("m:33").
hasArgument("m:31","m:33",1).
hasName("m:5","f1").
term("m:21").
hasArgument("m:20","m:21",0).
hasName("m2:3","f1").
term("m:35").
hasArgument("m:34","m:35",0).
hasName("m2:5","f2").
term("m1A:13").
hasArgument("m1A:12","m1A:13",0).
hasName("m2:7","f3").
term("m:4").
hasArgument("m:3","m:4",0).
hasName("m2:9","iRel1").
term("m:9").
hasArgument("m:8","m:9",0).
hasName("m2:11","iRel3").
term("m:6").
hasArgument("m:5","m:6",0).
hasName("m1A:3","oRelA").
term("m2:4").
hasArgument("m2:3","m2:4",0).
hasName("m1A:5","oRelB").
term("m2:6").
hasArgument("m2:5","m2:6",0).
hasName("m1A:7","temp").
term("m2:8").
hasArgument("m2:7","m2:8",0).
hasName("m1A:14","iRel2").
term("m2:10").
hasArgument("m2:9","m2:10",0).
hasName("m1A:16","f1").
term("m2:12").
hasArgument("m2:11","m2:12",0).
hasName("m:10","iRel1").
term("m2:13").
hasArgument("m2:11","m2:13",1).
hasName("m:12","f2").
term("m1A:4").
hasArgument("m1A:3","m1A:4",0).
term("m1A:6").
hasArgument("m1A:5","m1A:6",0).
term("m1A:8").
hasArgument("m1A:7","m1A:8",0).
term("m1A:15").
hasArgument("m1A:14","m1A:15",0).
term("m1A:17").
hasArgument("m1A:16","m1A:17",0).
term("m:11").
hasArgument("m:10","m:11",0).
term("m:13").
hasArgument("m:12","m:13",0).
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">m3</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# @resolved.
# @module("m3").
# @output("oRelF").
# @input("iRel1").
# @output("oRelE").
# @bind("iRel1","...").
# @input("iRel2").
# @bind("iRel2","...").
# @output("oRelA").
# @output("oRelC").
# @post("oRelA","orderby(1)").
# @output("oRelB").
# iRel1("l1").
# f1("l3").
# iRel2("l1").
# f2("l3").
# iRel1("l2").
# f2("f1").
# f1("l2").
# @label("F1") f2("l1").
# f1("l1").
# @label("R6") oRelF(X,Y) :- iRel1(X), iRel2(X), iRel3(X,Y), iRel4(Y).
# oRelA(X) :- iRel1(X), f1(X).
# @label("R5") oRelE(X) :- f1(X), f2(A), f3(X), iRel1(X), iRel3(A,X).
# @label("R3") oRelC(X) :- oRelA(X), oRelB(X), temp(X).
# @label("R4") temp(T) :- iRel2(T), f1(T).
# @label("M-R2") oRelB(X) :- iRel1(X), f2(X).
# </textarea></div></div>

# %% [markdown]
# **Expected Result:**

# %%
@resolved. @module("m3").
@input("iRel1"). @bind("iRel1","...").
@input("iRel2"). @bind("iRel2","...").

f1("l1"). f1("l2"). f1("l3"). 
f2("l3"). f2("f1"). @label("F1") f2("l1").
iRel1("l1"). iRel1("l2").
iRel2("l1").

oRelA(X) :- iRel1(X), f1(X).
@label("M-R2") oRelB(X) :- iRel1(X), f2(X).
@label("R3") oRelC(X) :- oRelA(X), oRelB(X), temp(X).
@label("R4") temp(T) :- iRel2(T), f1(T).
@label("R5") oRelE(X) :- f1(X), f2(A), f3(X), iRel1(X), iRel3(A,X).
@label("R6") oRelF(X,Y) :- iRel1(X), iRel2(X), iRel3(X,Y), iRel4(Y).

@output("oRelA"). @post("oRelA","orderby(1)").
@output("oRelB").
@output("oRelC").
@output("oRelE").
@output("oRelF").

# %% [markdown]
# #### 4. Labels multiply defined

# %%
% @input("toDerive").
toDerive("m3").

program("m").
hasRule("m","m:0").
rule("m:0").
hasPositiveHeadAtom("m:0","m:1").
relationalAtom("m:1").
hasName("m:1","oRelA").
hasArgument("m:1","m:2",0).
term("m:2").
hasSerialization("m:2","X").
hasPositiveBodyAtom("m:0","m:3").
relationalAtom("m:3").
hasName("m:3","iRel1").
hasArgument("m:3","m:4",0).
term("m:4").
hasSerialization("m:4","X").
hasPositiveBodyAtom("m:0","m:5").
relationalAtom("m:5").
hasName("m:5","f1").
hasArgument("m:5","m:6",0).
term("m:6").
hasSerialization("m:6","X").
hasRule("m","m:7").
rule("m:7").
hasPositiveHeadAtom("m:7","m:8").
relationalAtom("m:8").
hasName("m:8","oRelB").
hasArgument("m:8","m:9",0).
term("m:9").
hasSerialization("m:9","X").
hasPositiveBodyAtom("m:7","m:10").
relationalAtom("m:10").
hasName("m:10","iRel1").
hasArgument("m:10","m:11",0).
term("m:11").
hasSerialization("m:11","X").
hasPositiveBodyAtom("m:7","m:12").
relationalAtom("m:12").
hasName("m:12","f2").
hasArgument("m:12","m:13",0).
term("m:13").
hasSerialization("m:13","X").
hasAnnotation("m:7","m:14").
annotation("m:14").
hasName("m:14","label").
hasArgument("m:14","m:15",0).
term("m:15").
hasSerialization("m:15","""M-R2""").
hasFact("m","m:16").
relationalAtom("m:16").
hasName("m:16","iRel1").
hasArgument("m:16","m:17",0).
term("m:17").
hasSerialization("m:17","""l1""").
hasFact("m","m:18").
relationalAtom("m:18").
hasName("m:18","iRel1").
hasArgument("m:18","m:19",0).
term("m:19").
hasSerialization("m:19","""l2""").
hasFact("m","m:20").
relationalAtom("m:20").
hasName("m:20","f1").
hasArgument("m:20","m:21",0).
term("m:21").
hasSerialization("m:21","""l1""").
hasAnnotation("m","m:22").
annotation("m:22").
hasName("m:22","module").
hasArgument("m:22","m:23",0).
term("m:23").
hasSerialization("m:23","""m""").
hasAnnotation("m","m:24").
annotation("m:24").
hasName("m:24","output").
hasArgument("m:24","m:25",0).
term("m:25").
hasSerialization("m:25","""oRelA""").
hasAnnotation("m","m:26").
annotation("m:26").
hasName("m:26","post").
hasArgument("m:26","m:27",0).
term("m:27").
hasSerialization("m:27","""oRelA""").
hasArgument("m:26","m:28",1).
term("m:28").
hasSerialization("m:28","""orderby(1)""").
hasAnnotation("m","m:29").
annotation("m:29").
hasName("m:29","output").
hasArgument("m:29","m:30",0).
term("m:30").
hasSerialization("m:30","""oRelB""").

program("m1A").
hasRule("m1A","m1A:0").
rule("m1A:0").
hasPositiveHeadAtom("m1A:0","m1A:1").
relationalAtom("m1A:1").
hasName("m1A:1","oRelC").
hasArgument("m1A:1","m1A:2",0).
term("m1A:2").
hasSerialization("m1A:2","X").
hasPositiveBodyAtom("m1A:0","m1A:3").
relationalAtom("m1A:3").
hasName("m1A:3","oRelA").
hasArgument("m1A:3","m1A:4",0).
term("m1A:4").
hasSerialization("m1A:4","X").
hasPositiveBodyAtom("m1A:0","m1A:5").
relationalAtom("m1A:5").
hasName("m1A:5","oRelB").
hasArgument("m1A:5","m1A:6",0).
term("m1A:6").
hasSerialization("m1A:6","X").
hasPositiveBodyAtom("m1A:0","m1A:7").
relationalAtom("m1A:7").
hasName("m1A:7","temp").
hasArgument("m1A:7","m1A:8",0).
term("m1A:8").
hasSerialization("m1A:8","X").
hasAnnotation("m1A:0","m1A:9").
annotation("m1A:9").
hasName("m1A:9","label").
hasArgument("m1A:9","m1A:10",0).
term("m1A:10").
hasSerialization("m1A:10","""R3""").
hasRule("m1A","m1A:11").
rule("m1A:11").
hasPositiveHeadAtom("m1A:11","m1A:12").
relationalAtom("m1A:12").
hasName("m1A:12","temp").
hasArgument("m1A:12","m1A:13",0).
term("m1A:13").
hasSerialization("m1A:13","T").
hasPositiveBodyAtom("m1A:11","m1A:14").
relationalAtom("m1A:14").
hasName("m1A:14","iRel2").
hasArgument("m1A:14","m1A:15",0).
term("m1A:15").
hasSerialization("m1A:15","T").
hasPositiveBodyAtom("m1A:11","m1A:16").
relationalAtom("m1A:16").
hasName("m1A:16","f1").
hasArgument("m1A:16","m1A:17",0).
term("m1A:17").
hasSerialization("m1A:17","T").
hasAnnotation("m1A:11","m1A:18").
annotation("m1A:18").
hasName("m1A:18","label").
hasArgument("m1A:18","m1A:19",0).
term("m1A:19").
hasSerialization("m1A:19","""R4""").
hasFact("m1A","m1A:20").
relationalAtom("m1A:20").
hasName("m1A:20","iRel2").
hasArgument("m1A:20","m1A:21",0).
term("m1A:21").
hasSerialization("m1A:21","""l1""").
hasFact("m1A","m1A:22").
relationalAtom("m1A:22").
hasName("m1A:22","f1").
hasArgument("m1A:22","m1A:23",0).
term("m1A:23").
hasSerialization("m1A:23","""l2""").
hasFact("m1A","m1A:24").
relationalAtom("m1A:24").
hasName("m1A:24","f2").
hasArgument("m1A:24","m1A:25",0).
term("m1A:25").
hasSerialization("m1A:25","""l1""").
hasAnnotation("m1A:24","m1A:26").
annotation("m1A:26").
hasName("m1A:26","label").
hasArgument("m1A:26","m1A:27",0).
term("m1A:27").
hasSerialization("m1A:27","""F1""").
hasAnnotation("m1A","m1A:28").
annotation("m1A:28").
hasName("m1A:28","module").
hasArgument("m1A:28","m1A:29",0).
term("m1A:29").
hasSerialization("m1A:29","""m1A""").
hasAnnotation("m1A","m1A:30").
annotation("m1A:30").
hasName("m1A:30","inherits").
hasArgument("m1A:30","m1A:31",0).
term("m1A:31").
hasSerialization("m1A:31","""m""").
hasAnnotation("m1A","m1A:32").
annotation("m1A:32").
hasName("m1A:32","output").
hasArgument("m1A:32","m1A:33",0).
term("m1A:33").
hasSerialization("m1A:33","""oRelC""").

program("m1C").
hasRule("m1C","m1C:0").
rule("m1C:0").
hasPositiveHeadAtom("m1C:0","m1C:1").
relationalAtom("m1C:1").
hasName("m1C:1","oRelC").
hasArgument("m1C:1","m1C:2",0).
term("m1C:2").
hasSerialization("m1C:2","X").
hasArgument("m1C:1","m1C:3",1).
term("m1C:3").
hasSerialization("m1C:3","Y").
hasPositiveBodyAtom("m1C:0","m1C:4").
relationalAtom("m1C:4").
hasName("m1C:4","iRel3").
hasArgument("m1C:4","m1C:5",0).
term("m1C:5").
hasSerialization("m1C:5","X").
hasArgument("m1C:4","m1C:6",1).
term("m1C:6").
hasSerialization("m1C:6","Y").
hasPositiveBodyAtom("m1C:0","m1C:7").
relationalAtom("m1C:7").
hasName("m1C:7","f1").
hasArgument("m1C:7","m1C:8",0).
term("m1C:8").
hasSerialization("m1C:8","Y").
hasAnnotation("m1C:0","m1C:9").
annotation("m1C:9").
hasName("m1C:9","label").
hasArgument("m1C:9","m1C:10",0).
term("m1C:10").
hasSerialization("m1C:10","""R3""").
hasFact("m1C","m1C:11").
relationalAtom("m1C:11").
hasName("m1C:11","iRel3").
hasArgument("m1C:11","m1C:12",0).
term("m1C:12").
hasSerialization("m1C:12","""l1""").
hasArgument("m1C:11","m1C:13",1).
term("m1C:13").
hasSerialization("m1C:13","""l1""").
hasFact("m1C","m1C:14").
relationalAtom("m1C:14").
hasName("m1C:14","iRel3").
hasArgument("m1C:14","m1C:15",0).
term("m1C:15").
hasSerialization("m1C:15","""l2""").
hasArgument("m1C:14","m1C:16",1).
term("m1C:16").
hasSerialization("m1C:16","""l3""").
hasAnnotation("m1C","m1C:17").
annotation("m1C:17").
hasName("m1C:17","module").
hasArgument("m1C:17","m1C:18",0).
term("m1C:18").
hasSerialization("m1C:18","""m1C""").
hasAnnotation("m1C","m1C:19").
annotation("m1C:19").
hasName("m1C:19","inherits").
hasArgument("m1C:19","m1C:20",0).
term("m1C:20").
hasSerialization("m1C:20","""m""").
hasAnnotation("m1C","m1C:21").
annotation("m1C:21").
hasName("m1C:21","output").
hasArgument("m1C:21","m1C:22",0).
term("m1C:22").
hasSerialization("m1C:22","""oRelC""").

program("m2").
hasRule("m2","m2:0").
rule("m2:0").
hasPositiveHeadAtom("m2:0","m2:1").
relationalAtom("m2:1").
hasName("m2:1","oRelE").
hasArgument("m2:1","m2:2",0).
term("m2:2").
hasSerialization("m2:2","X").
hasPositiveBodyAtom("m2:0","m2:3").
relationalAtom("m2:3").
hasName("m2:3","f1").
hasArgument("m2:3","m2:4",0).
term("m2:4").
hasSerialization("m2:4","X").
hasPositiveBodyAtom("m2:0","m2:5").
relationalAtom("m2:5").
hasName("m2:5","f2").
hasArgument("m2:5","m2:6",0).
term("m2:6").
hasSerialization("m2:6","A").
hasPositiveBodyAtom("m2:0","m2:7").
relationalAtom("m2:7").
hasName("m2:7","f3").
hasArgument("m2:7","m2:8",0).
term("m2:8").
hasSerialization("m2:8","X").
hasPositiveBodyAtom("m2:0","m2:9").
relationalAtom("m2:9").
hasName("m2:9","iRel1").
hasArgument("m2:9","m2:10",0).
term("m2:10").
hasSerialization("m2:10","X").
hasPositiveBodyAtom("m2:0","m2:11").
relationalAtom("m2:11").
hasName("m2:11","iRel3").
hasArgument("m2:11","m2:12",0).
term("m2:12").
hasSerialization("m2:12","A").
hasArgument("m2:11","m2:13",1).
term("m2:13").
hasSerialization("m2:13","X").
hasAnnotation("m2:0","m2:14").
annotation("m2:14").
hasName("m2:14","label").
hasArgument("m2:14","m2:15",0).
term("m2:15").
hasSerialization("m2:15","""R1""").
hasFact("m2","m2:16").
relationalAtom("m2:16").
hasName("m2:16","f1").
hasArgument("m2:16","m2:17",0).
term("m2:17").
hasSerialization("m2:17","""l3""").
hasFact("m2","m2:18").
relationalAtom("m2:18").
hasName("m2:18","f2").
hasArgument("m2:18","m2:19",0).
term("m2:19").
hasSerialization("m2:19","""l3""").
hasFact("m2","m2:20").
relationalAtom("m2:20").
hasName("m2:20","f2").
hasArgument("m2:20","m2:21",0).
term("m2:21").
hasSerialization("m2:21","""f1""").
hasAnnotation("m2","m2:22").
annotation("m2:22").
hasName("m2:22","module").
hasArgument("m2:22","m2:23",0).
term("m2:23").
hasSerialization("m2:23","""m2""").
hasAnnotation("m2","m2:24").
annotation("m2:24").
hasName("m2:24","inherits").
hasArgument("m2:24","m2:25",0).
term("m2:25").
hasSerialization("m2:25","""m1A""").
hasAnnotation("m2","m2:30").
annotation("m2:30").
hasName("m2:30","output").
hasArgument("m2:30","m2:31",0).
term("m2:31").
hasSerialization("m2:31","""oRelE""").

program("m3").
hasRule("m3","m3:0").
rule("m3:0").
hasPositiveHeadAtom("m3:0","m3:1").
relationalAtom("m3:1").
hasName("m3:1","oRelF").
hasArgument("m3:1","m3:2",0).
term("m3:2").
hasSerialization("m3:2","X").
hasArgument("m3:1","m3:3",1).
term("m3:3").
hasSerialization("m3:3","Y").
hasPositiveBodyAtom("m3:0","m3:4").
relationalAtom("m3:4").
hasName("m3:4","iRel1").
hasArgument("m3:4","m3:5",0).
term("m3:5").
hasSerialization("m3:5","X").
hasPositiveBodyAtom("m3:0","m3:6").
relationalAtom("m3:6").
hasName("m3:6","iRel2").
hasArgument("m3:6","m3:7",0).
term("m3:7").
hasSerialization("m3:7","X").
hasPositiveBodyAtom("m3:0","m3:8").
relationalAtom("m3:8").
hasName("m3:8","iRel3").
hasArgument("m3:8","m3:9",0).
term("m3:9").
hasSerialization("m3:9","X").
hasArgument("m3:8","m3:10",1).
term("m3:10").
hasSerialization("m3:10","Y").
hasPositiveBodyAtom("m3:0","m3:11").
relationalAtom("m3:11").
hasName("m3:11","iRel4").
hasArgument("m3:11","m3:12",0).
term("m3:12").
hasSerialization("m3:12","Y").
hasAnnotation("m3:0","m3:13").
annotation("m3:13").
hasName("m3:13","label").
hasArgument("m3:13","m3:14",0).
term("m3:14").
hasSerialization("m3:14","""R1""").
hasAnnotation("m3","m3:15").
annotation("m3:15").
hasName("m3:15","module").
hasArgument("m3:15","m3:16",0).
term("m3:16").
hasSerialization("m3:16","""m3""").
hasAnnotation("m3","m3:17").
annotation("m3:17").
hasName("m3:17","inherits").
hasArgument("m3:17","m3:18",0).
term("m3:18").
hasSerialization("m3:18","""m2""").
hasAnnotation("m3","m3:19").
annotation("m3:19").
hasName("m3:19","output").
hasArgument("m3:19","m3:20",0).
term("m3:20").
hasSerialization("m3:20","""oRelA""").

% ------------------------------------------------------------------------
% INPUT
% ------------------------------------------------------------------------
% @input("toDerive").
toDerive("d").

% ------------------------------------------------------------------------
% GENERAL PREDICATES USED IN OTHER CODE SECTIONS
% ------------------------------------------------------------------------
% Definition of true needed for triple quotes
true(#T). false(#F).

% Find module labels for module IDs
moduleLbl(M,L) :- hasAnnotation(M,A), hasName(A,"module"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).

% Find Id of module to be derived
deriveModule(M) :- toDerive(L), moduleLbl(M,L).

% Determine inheritance relationships in provided meta-representations
inherits(MC,MP) :- hasAnnotation(MC,A), hasName(A,"inherits"), hasArgument(A,Arg,0), hasSerialization(Arg,MP1), moduleLbl(MP,MPL), MPL = substring(MP1,1,string_length(MP1)-1).
tInherits(M,M2) :- inherits(M,M2).
tInherits(M,M2) :- tInherits(M,M1), inherits(M1,M2).

% Input and Output predicates
inputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"input"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"output"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

% Defined restrictions and modification operations
restriction("no_additional_input").
restriction("no_additional_output").
restriction("no_additional_annotation").
restriction("non_omitable").
restriction("non_redefinable").
restriction("non_shrinkable").
restriction("non_growable").
modOp("remove"). modOp("removeQ").
modOp("redefines"). modOp("redefinesQ").
modOp("inherits").

% Inheritance Annotations
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), restriction(N).
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), modOp(N).

% Which statements exist in a module?
hasStmt(M,S) :- hasRule(M,S).
hasStmt(M,S) :- hasFact(M,S).
hasStmt(M,S) :- moduleLbl(M,_), hasAnnotation(M,S).

% Only labeled statements are interesting, others always propagated
stmtLbl(R,L) :- hasRule(M,R), hasAnnotation(R,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(F,L) :- hasFact(M,F), hasAnnotation(F,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(A,L) :- hasAnnotation(M,A), hasAnnotation(A,A2), hasName(A2,"label"), hasArgument(A2,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtML(M,S,L) :- stmtLbl(S,L), hasStmt(M,S).

% RESOLVE INHERITANCE
% Unqualified remove and redefine
redefineStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"redefines"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), L = substring(L1,1,string_length(L1)-1).
removeStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"remove"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), L = substring(L1,1,string_length(L1)-1).
% Any statement except inheritance annotations can be removed
redefineStmt(M,S):- redefineStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).
removeStmt(M,S):- removeStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).

% Qualified remove and redefine
redefineStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"redefinesQ"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), hasArgument(A,Arg3,2), hasSerialization(Arg3,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
removeStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"removeQ"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
redefineStmt(M,S) :- redefineStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).
removeStmt(M,S) :- removeStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).

% Module name annotations are not inherited
removeStmt(M,A) :- hasAnnotation(M,A), hasName(A,"module"), not deriveModule(M).

% Summarize modification operation statements
modOpStmt(M,S) :- removeStmt(M,S).
modOpStmt(M,S) :- redefineStmt(M,S).
tModOpStmt(M,M,S) :- modOpStmt(M,S).
tModOpStmt(M,Morg,S) :- inherits(M,M2), tModOpStmt(M2,Morg,S).

% DETERMINE ACTIVE STATEMENTS AND MODULE/STATEMENT ANNOTATIONS FOR MODULES
% Derive for each module its active rules by inheriting
tHasRule(M,R) :- hasRule(M,R).
tHasRule(M,R) :- inherits(M,MP), tHasRule(MP,R).
moduleStmt(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).
mHasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).

% Determine for each module its active facts by inheriting
tHasFact(M,F) :- hasFact(M,F).
tHasFact(M,F) :- inherits(M,MP), tHasFact(MP,F).
moduleStmt(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F).

% Determine for each module its active module and statement annotations
tHasAnnotationM(M,A) :- moduleLbl(M,L), hasAnnotation(M,A), hasName(A,N), not modOp(N).
tHasAnnotationM(M,A) :- inherits(M,MP), tHasAnnotationM(MP,A).
tHasAnnotationS(M,Stmt,A) :- hasStmt(M,Stmt), hasAnnotation(Stmt,A).
tHasAnnotationS(M,Stmt,A) :- inherits(M,MP), tHasAnnotationS(MP,Stmt,A).
moduleStmt(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A).

% Determine Restrictions defined in modules
noAdditionalInput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_input").
noAdditionalOutput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_output").
noAdditionalAnnotation(M,ANN,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_annotation"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), P = substring(L1,1,string_length(L1)-1), ANN = substring(L2,1,string_length(L2)-1).
nonOmitable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_omitable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonRedefinable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_redefinable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonGrowable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_growable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P  =substring(L1,1,string_length(L1)-1).
nonShrinkable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_shrinkable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).

% ------------------------------------------------------------------------
% WARNINGS REGARDING INHERITANCE
% ------------------------------------------------------------------------
% Warn if restrictions or mod ops are modified
w_modifiedInhAnnotation(M,S) :- modOpStmt(M,S), inhAnnotation(S).

% Warn if non-existing statement is modified
w_modifyUnknownStmt(M,X) :- removeStmtLbl(M,L), not stmtLbl(_,L), X = L.
w_modifyUnknownStmt(M,X) :- redefineStmtLbl(M,L), not stmtLbl(_,L), X = L.
w_modifyUnknownStmtQ(M,X,Y) :- removeStmtQ(M,L,MQ), not stmtML(MQ,_,L), X = L, Y = MQ.
w_modifyUnknownStmtQ(M,X,Y) :- redefineStmtQ(M,L,MQ), not stmtML(MQ,_,L), X = L, Y = MQ.

% Two different modules employ the same ID
w_labelMultiplicity(M,S,M2,S2,L) :- stmtML(M,S,L), stmtML(M2,S2,L2), moduleLbl(M,_), tInherits(MC,M2), tInherits(MC,M), L = L2, M != M2, S != S2.
w_labelMultiplicity(M,S,M2,S2,L) :- stmtML(M,S,L), stmtML(M2,S2,L2), moduleLbl(M,_), tInherits(M,M2), L = L2, M != M2, S != S2.

% An annotation is defined multiple times for the same predicate
moduleAnnotation(M,A,N,P) :- moduleStmt(M,A), hasAnnotation(_,A), hasName(A,N), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
w_annotationMultiplyDefined(M,A1,A2,Type,Predicate) :- moduleAnnotation(M,A1,Type,P1), moduleAnnotation(M,A2,Type,Predicate), A1 != A2, P1 = Predicate.

@output("w_modifiedInhAnnotation").
@output("w_modifyUnknownStmt").
@output("w_modifyUnknownStmtQ").
@output("w_labelMultiplicity").
@output("w_annotationMultiplyDefined").

% Multi-inheritance: Statement modified differently in two branches!
tRemoveStmt(M,S) :- removeStmt(M,S).
tRemoveStmt(M,S) :- inherits(M,M2), tRemoveStmt(M2,S).
tRedefineStmt(M,S) :- redefineStmt(M,S).
tRedefineStmt(M,S) :- inherits(M,M2), redefineStmt(M2,S).

w_mergeWithCommonStmtsRemoved(C,GP,P1,P2,S) :- moduleLbl(GP,_), moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), tInherits(P1,GP), tInherits(P2,GP), moduleStmt(GP,S), tRemoveStmt(P1,S), P1 != P2.
w_mergeWithCommonStmtsRedefined(C,GP,P1,P2,S) :- moduleLbl(GP,_), moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), tInherits(P1,GP), tInherits(P2,GP), moduleStmt(GP,S), tRedefineStmt(P1,S), P1 != P2.
w_diffModifiedParent(C,P1,P2,S) :- w_mergeWithCommonStmtsRemoved(C,_,P1,P2,S), not tRemoveStmt(P2,S).
w_diffModifiedParent(C,P1,P2,S) :- w_mergeWithCommonStmtsRedefined(C,_,P1,P2,S), not tRedefineStmt(P2,S).

% Multi-inheritance: Warning about different restrictions in parents
w_diffParentRestriction(C,P1,P2,"noAdditionalInput") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalInput(P1), not noAdditionalInput(P2), P1 != P2.
w_diffParentRestriction(C,P1,P2,"noAdditionalOutput") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalOutput(P1), not noAdditionalOutput(P2), P1 != P2.
w_diffParentRestriction(C,P1,P2,"noAdditionalAnnotation") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), noAdditionalAnnotation(P1,ANN,Predicate), not noAdditionalAnnotation(P2,ANN,Predicate), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonOmitable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonOmitable(P1,Predicate), not nonOmitable(P2,Predicate), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonRedefinable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonGrowable(P1,PRED), not nonGrowable(P2,PRED), P1 != P2.

w_diffParentRestriction(C,P1,P2,"nonGrowable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonGrowable(P1,PRED), not nonGrowable(P2,PRED), P1 != P2.
w_diffParentRestriction(C,P1,P2,"nonShrinkable") :- moduleLbl(P1,_), moduleLbl(P2,_), inherits(C,P1), inherits(C,P2), nonShrinkable(P1,PRED), not nonShrinkable(P2,PRED), P1 != P2.

@output("w_diffModifiedParent").
@output("w_diffParentRestriction").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">w_annotationMultiplyDefined</caption><thead><tr><th>string</th><th>string</th><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m3</td><td>m3:19</td><td>m:24</td><td>output</td><td>oRelA</td></tr></tbody><tbody><tr><td>m3</td><td>m:24</td><td>m3:19</td><td>output</td><td>oRelA</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">w_labelMultiplicity</caption><thead><tr><th>string</th><th>string</th><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m3</td><td>m3:0</td><td>m2</td><td>m2:0</td><td>R1</td></tr></tbody></table></div></div></div>

# %% [markdown]
# **Expected result:**

# %% [markdown]
# * label R1 multiply defined
# * output oRelA multiply defined (m, m3)
