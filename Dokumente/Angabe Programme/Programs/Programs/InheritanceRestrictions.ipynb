# %% [markdown]
# # Modules

# %%
%%toMeta("m")
@module("m").
@non_omitable("iRel1"). @non_redefinable("iRel1"). @no_additional_annotation("iRel1","bind"). @non_shrinkable("oRelA").
@input("iRel1"). @bind("iRel1","..."). @non_omitable_annotation("iRel1","bind").
iRel1("l1"). iRel1("l2").
f1("l1").
oRelA(X) :- iRel1(X), f1(X).
@label("M-R2") oRelB(X) :- iRel1(X), f2(X).
@output("oRelA"). @post("oRelA","orderby(1)").
@output("oRelB").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m").
# hasRule("m","m:0").
# rule("m:0").
# hasPositiveHeadAtom("m:0","m:1").
# relationalAtom("m:1").
# hasName("m:1","oRelA").
# hasArgument("m:1","m:2",0).
# term("m:2").
# hasSerialization("m:2","X").
# hasPositiveBodyAtom("m:0","m:3").
# relationalAtom("m:3").
# hasName("m:3","iRel1").
# hasArgument("m:3","m:4",0).
# term("m:4").
# hasSerialization("m:4","X").
# hasPositiveBodyAtom("m:0","m:5").
# relationalAtom("m:5").
# hasName("m:5","f1").
# hasArgument("m:5","m:6",0).
# term("m:6").
# hasSerialization("m:6","X").
# hasRule("m","m:7").
# rule("m:7").
# hasPositiveHeadAtom("m:7","m:8").
# relationalAtom("m:8").
# hasName("m:8","oRelB").
# hasArgument("m:8","m:9",0).
# term("m:9").
# hasSerialization("m:9","X").
# hasPositiveBodyAtom("m:7","m:10").
# relationalAtom("m:10").
# hasName("m:10","iRel1").
# hasArgument("m:10","m:11",0).
# term("m:11").
# hasSerialization("m:11","X").
# hasPositiveBodyAtom("m:7","m:12").
# relationalAtom("m:12").
# hasName("m:12","f2").
# hasArgument("m:12","m:13",0).
# term("m:13").
# hasSerialization("m:13","X").
# hasAnnotation("m:7","m:14").
# annotation("m:14").
# hasName("m:14","label").
# hasArgument("m:14","m:15",0).
# term("m:15").
# hasSerialization("m:15","""M-R2""").
# hasFact("m","m:16").
# relationalAtom("m:16").
# hasName("m:16","iRel1").
# hasArgument("m:16","m:17",0).
# term("m:17").
# hasSerialization("m:17","""l1""").
# hasFact("m","m:18").
# relationalAtom("m:18").
# hasName("m:18","iRel1").
# hasArgument("m:18","m:19",0).
# term("m:19").
# hasSerialization("m:19","""l2""").
# hasFact("m","m:20").
# relationalAtom("m:20").
# hasName("m:20","f1").
# hasArgument("m:20","m:21",0).
# term("m:21").
# hasSerialization("m:21","""l1""").
# hasAnnotation("m","m:22").
# annotation("m:22").
# hasName("m:22","module").
# hasArgument("m:22","m:23",0).
# term("m:23").
# hasSerialization("m:23","""m""").
# hasAnnotation("m","m:24").
# annotation("m:24").
# hasName("m:24","non_omitable").
# hasArgument("m:24","m:25",0).
# term("m:25").
# hasSerialization("m:25","""iRel1""").
# hasAnnotation("m","m:26").
# annotation("m:26").
# hasName("m:26","non_redefinable").
# hasArgument("m:26","m:27",0).
# term("m:27").
# hasSerialization("m:27","""iRel1""").
# hasAnnotation("m","m:28").
# annotation("m:28").
# hasName("m:28","no_additional_annotation").
# hasArgument("m:28","m:29",0).
# term("m:29").
# hasSerialization("m:29","""iRel1""").
# hasArgument("m:28","m:30",1).
# term("m:30").
# hasSerialization("m:30","""bind""").
# hasAnnotation("m","m:31").
# annotation("m:31").
# hasName("m:31","non_shrinkable").
# hasArgument("m:31","m:32",0).
# term("m:32").
# hasSerialization("m:32","""oRelA""").
# hasAnnotation("m","m:33").
# annotation("m:33").
# hasName("m:33","input").
# hasArgument("m:33","m:34",0).
# term("m:34").
# hasSerialization("m:34","""iRel1""").
# hasAnnotation("m","m:35").
# annotation("m:35").
# hasName("m:35","bind").
# hasArgument("m:35","m:36",0).
# term("m:36").
# hasSerialization("m:36","""iRel1""").
# hasArgument("m:35","m:37",1).
# term("m:37").
# hasSerialization("m:37","""...""").
# hasAnnotation("m","m:38").
# annotation("m:38").
# hasName("m:38","non_omitable_annotation").
# hasArgument("m:38","m:39",0).
# term("m:39").
# hasSerialization("m:39","""iRel1""").
# hasArgument("m:38","m:40",1).
# term("m:40").
# hasSerialization("m:40","""bind""").
# hasAnnotation("m","m:41").
# annotation("m:41").
# hasName("m:41","output").
# hasArgument("m:41","m:42",0).
# term("m:42").
# hasSerialization("m:42","""oRelA""").
# hasAnnotation("m","m:43").
# annotation("m:43").
# hasName("m:43","post").
# hasArgument("m:43","m:44",0).
# term("m:44").
# hasSerialization("m:44","""oRelA""").
# hasArgument("m:43","m:45",1).
# term("m:45").
# hasSerialization("m:45","""orderby(1)""").
# hasAnnotation("m","m:46").
# annotation("m:46").
# hasName("m:46","output").
# hasArgument("m:46","m:47",0).
# term("m:47").
# hasSerialization("m:47","""oRelB""").
# </textarea></div></div>

# %%
%%toMeta("m1A").
@module("m1A"). @inherits("m").
@non_growable("oRelC").
@input("iRel2"). @bind("iRel2","...").
iRel2("l1").
f1("l2").
@label("F1") f2("l1").
@label("R3") oRelC(X) :- oRelA(X), oRelB(X), temp(X).
@label("R4") temp(T) :- iRel2(T), f1(T).
@redefines("R4","M-R2").
@output("oRelC").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m1A").
# hasRule("m1A","m1A:0").
# rule("m1A:0").
# hasPositiveHeadAtom("m1A:0","m1A:1").
# relationalAtom("m1A:1").
# hasName("m1A:1","oRelC").
# hasArgument("m1A:1","m1A:2",0).
# term("m1A:2").
# hasSerialization("m1A:2","X").
# hasPositiveBodyAtom("m1A:0","m1A:3").
# relationalAtom("m1A:3").
# hasName("m1A:3","oRelA").
# hasArgument("m1A:3","m1A:4",0).
# term("m1A:4").
# hasSerialization("m1A:4","X").
# hasPositiveBodyAtom("m1A:0","m1A:5").
# relationalAtom("m1A:5").
# hasName("m1A:5","oRelB").
# hasArgument("m1A:5","m1A:6",0).
# term("m1A:6").
# hasSerialization("m1A:6","X").
# hasPositiveBodyAtom("m1A:0","m1A:7").
# relationalAtom("m1A:7").
# hasName("m1A:7","temp").
# hasArgument("m1A:7","m1A:8",0).
# term("m1A:8").
# hasSerialization("m1A:8","X").
# hasAnnotation("m1A:0","m1A:9").
# annotation("m1A:9").
# hasName("m1A:9","label").
# hasArgument("m1A:9","m1A:10",0).
# term("m1A:10").
# hasSerialization("m1A:10","""R3""").
# hasRule("m1A","m1A:11").
# rule("m1A:11").
# hasPositiveHeadAtom("m1A:11","m1A:12").
# relationalAtom("m1A:12").
# hasName("m1A:12","temp").
# hasArgument("m1A:12","m1A:13",0).
# term("m1A:13").
# hasSerialization("m1A:13","T").
# hasPositiveBodyAtom("m1A:11","m1A:14").
# relationalAtom("m1A:14").
# hasName("m1A:14","iRel2").
# hasArgument("m1A:14","m1A:15",0).
# term("m1A:15").
# hasSerialization("m1A:15","T").
# hasPositiveBodyAtom("m1A:11","m1A:16").
# relationalAtom("m1A:16").
# hasName("m1A:16","f1").
# hasArgument("m1A:16","m1A:17",0).
# term("m1A:17").
# hasSerialization("m1A:17","T").
# hasAnnotation("m1A:11","m1A:18").
# annotation("m1A:18").
# hasName("m1A:18","label").
# hasArgument("m1A:18","m1A:19",0).
# term("m1A:19").
# hasSerialization("m1A:19","""R4""").
# hasFact("m1A","m1A:20").
# relationalAtom("m1A:20").
# hasName("m1A:20","iRel2").
# hasArgument("m1A:20","m1A:21",0).
# term("m1A:21").
# hasSerialization("m1A:21","""l1""").
# hasFact("m1A","m1A:22").
# relationalAtom("m1A:22").
# hasName("m1A:22","f1").
# hasArgument("m1A:22","m1A:23",0).
# term("m1A:23").
# hasSerialization("m1A:23","""l2""").
# hasFact("m1A","m1A:24").
# relationalAtom("m1A:24").
# hasName("m1A:24","f2").
# hasArgument("m1A:24","m1A:25",0).
# term("m1A:25").
# hasSerialization("m1A:25","""l1""").
# hasAnnotation("m1A:24","m1A:26").
# annotation("m1A:26").
# hasName("m1A:26","label").
# hasArgument("m1A:26","m1A:27",0).
# term("m1A:27").
# hasSerialization("m1A:27","""F1""").
# hasAnnotation("m1A","m1A:28").
# annotation("m1A:28").
# hasName("m1A:28","module").
# hasArgument("m1A:28","m1A:29",0).
# term("m1A:29").
# hasSerialization("m1A:29","""m1A""").
# hasAnnotation("m1A","m1A:30").
# annotation("m1A:30").
# hasName("m1A:30","inherits").
# hasArgument("m1A:30","m1A:31",0).
# term("m1A:31").
# hasSerialization("m1A:31","""m""").
# hasAnnotation("m1A","m1A:32").
# annotation("m1A:32").
# hasName("m1A:32","non_growable").
# hasArgument("m1A:32","m1A:33",0).
# term("m1A:33").
# hasSerialization("m1A:33","""oRelC""").
# hasAnnotation("m1A","m1A:34").
# annotation("m1A:34").
# hasName("m1A:34","input").
# hasArgument("m1A:34","m1A:35",0).
# term("m1A:35").
# hasSerialization("m1A:35","""iRel2""").
# hasAnnotation("m1A","m1A:36").
# annotation("m1A:36").
# hasName("m1A:36","bind").
# hasArgument("m1A:36","m1A:37",0).
# term("m1A:37").
# hasSerialization("m1A:37","""iRel2""").
# hasArgument("m1A:36","m1A:38",1).
# term("m1A:38").
# hasSerialization("m1A:38","""...""").
# hasAnnotation("m1A","m1A:39").
# annotation("m1A:39").
# hasName("m1A:39","redefines").
# hasArgument("m1A:39","m1A:40",0).
# term("m1A:40").
# hasSerialization("m1A:40","""R4""").
# hasArgument("m1A:39","m1A:41",1).
# term("m1A:41").
# hasSerialization("m1A:41","""M-R2""").
# hasAnnotation("m1A","m1A:42").
# annotation("m1A:42").
# hasName("m1A:42","output").
# hasArgument("m1A:42","m1A:43",0).
# term("m1A:43").
# hasSerialization("m1A:43","""oRelC""").
# </textarea></div></div>

# %%
%%toMeta("m1B").
@module("m1B").
@input("iRel4"). @bind("iRel4","...").
iRel4("l1"). iRel4("l3").
f3("l2"). f3("l3").
@label("F1") f3("l1").
@label("R3") oRelD(X) :- oRelA(X), oRelB(X), f3(X), iRel4(X).
@output("oRelD"). %@delete("oRelD",{0}).
@non_shrinkable("oRelD").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m1B").
# hasRule("m1B","m1B:0").
# rule("m1B:0").
# hasPositiveHeadAtom("m1B:0","m1B:1").
# relationalAtom("m1B:1").
# hasName("m1B:1","oRelD").
# hasArgument("m1B:1","m1B:2",0).
# term("m1B:2").
# hasSerialization("m1B:2","X").
# hasPositiveBodyAtom("m1B:0","m1B:3").
# relationalAtom("m1B:3").
# hasName("m1B:3","oRelA").
# hasArgument("m1B:3","m1B:4",0).
# term("m1B:4").
# hasSerialization("m1B:4","X").
# hasPositiveBodyAtom("m1B:0","m1B:5").
# relationalAtom("m1B:5").
# hasName("m1B:5","oRelB").
# hasArgument("m1B:5","m1B:6",0).
# term("m1B:6").
# hasSerialization("m1B:6","X").
# hasPositiveBodyAtom("m1B:0","m1B:7").
# relationalAtom("m1B:7").
# hasName("m1B:7","f3").
# hasArgument("m1B:7","m1B:8",0).
# term("m1B:8").
# hasSerialization("m1B:8","X").
# hasPositiveBodyAtom("m1B:0","m1B:9").
# relationalAtom("m1B:9").
# hasName("m1B:9","iRel4").
# hasArgument("m1B:9","m1B:10",0).
# term("m1B:10").
# hasSerialization("m1B:10","X").
# hasAnnotation("m1B:0","m1B:11").
# annotation("m1B:11").
# hasName("m1B:11","label").
# hasArgument("m1B:11","m1B:12",0).
# term("m1B:12").
# hasSerialization("m1B:12","""R3""").
# hasFact("m1B","m1B:13").
# relationalAtom("m1B:13").
# hasName("m1B:13","iRel4").
# hasArgument("m1B:13","m1B:14",0).
# term("m1B:14").
# hasSerialization("m1B:14","""l1""").
# hasFact("m1B","m1B:15").
# relationalAtom("m1B:15").
# hasName("m1B:15","iRel4").
# hasArgument("m1B:15","m1B:16",0).
# term("m1B:16").
# hasSerialization("m1B:16","""l3""").
# hasFact("m1B","m1B:17").
# relationalAtom("m1B:17").
# hasName("m1B:17","f3").
# hasArgument("m1B:17","m1B:18",0).
# term("m1B:18").
# hasSerialization("m1B:18","""l2""").
# hasFact("m1B","m1B:19").
# relationalAtom("m1B:19").
# hasName("m1B:19","f3").
# hasArgument("m1B:19","m1B:20",0).
# term("m1B:20").
# hasSerialization("m1B:20","""l3""").
# hasFact("m1B","m1B:21").
# relationalAtom("m1B:21").
# hasName("m1B:21","f3").
# hasArgument("m1B:21","m1B:22",0).
# term("m1B:22").
# hasSerialization("m1B:22","""l1""").
# hasAnnotation("m1B:21","m1B:23").
# annotation("m1B:23").
# hasName("m1B:23","label").
# hasArgument("m1B:23","m1B:24",0).
# term("m1B:24").
# hasSerialization("m1B:24","""F1""").
# hasAnnotation("m1B","m1B:25").
# annotation("m1B:25").
# hasName("m1B:25","module").
# hasArgument("m1B:25","m1B:26",0).
# term("m1B:26").
# hasSerialization("m1B:26","""m1B""").
# hasAnnotation("m1B","m1B:27").
# annotation("m1B:27").
# hasName("m1B:27","input").
# hasArgument("m1B:27","m1B:28",0).
# term("m1B:28").
# hasSerialization("m1B:28","""iRel4""").
# hasAnnotation("m1B","m1B:29").
# annotation("m1B:29").
# hasName("m1B:29","bind").
# hasArgument("m1B:29","m1B:30",0).
# term("m1B:30").
# hasSerialization("m1B:30","""iRel4""").
# hasArgument("m1B:29","m1B:31",1).
# term("m1B:31").
# hasSerialization("m1B:31","""...""").
# hasAnnotation("m1B","m1B:32").
# annotation("m1B:32").
# hasName("m1B:32","output").
# hasArgument("m1B:32","m1B:33",0).
# term("m1B:33").
# hasSerialization("m1B:33","""oRelD""").
# hasAnnotation("m1B","m1B:34").
# annotation("m1B:34").
# hasName("m1B:34","non_shrinkable").
# hasArgument("m1B:34","m1B:35",0).
# term("m1B:35").
# hasSerialization("m1B:35","""oRelD""").
# </textarea></div></div>

# %%
%%toMeta("m1C").
@module("m1C").  @inherits("m").
@no_additional_input.
@input("iRel3"). @bind("iRel3","...").
iRel3("l1","l1"). iRel3("l2","l3").
@label("R3") oRelC(X,Y) :- iRel3(X,Y), f1(Y).
@remove("M-R2").
@output("oRelC").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m1C").
# hasRule("m1C","m1C:0").
# rule("m1C:0").
# hasPositiveHeadAtom("m1C:0","m1C:1").
# relationalAtom("m1C:1").
# hasName("m1C:1","oRelC").
# hasArgument("m1C:1","m1C:2",0).
# term("m1C:2").
# hasSerialization("m1C:2","X").
# hasArgument("m1C:1","m1C:3",1).
# term("m1C:3").
# hasSerialization("m1C:3","Y").
# hasPositiveBodyAtom("m1C:0","m1C:4").
# relationalAtom("m1C:4").
# hasName("m1C:4","iRel3").
# hasArgument("m1C:4","m1C:5",0).
# term("m1C:5").
# hasSerialization("m1C:5","X").
# hasArgument("m1C:4","m1C:6",1).
# term("m1C:6").
# hasSerialization("m1C:6","Y").
# hasPositiveBodyAtom("m1C:0","m1C:7").
# relationalAtom("m1C:7").
# hasName("m1C:7","f1").
# hasArgument("m1C:7","m1C:8",0).
# term("m1C:8").
# hasSerialization("m1C:8","Y").
# hasAnnotation("m1C:0","m1C:9").
# annotation("m1C:9").
# hasName("m1C:9","label").
# hasArgument("m1C:9","m1C:10",0).
# term("m1C:10").
# hasSerialization("m1C:10","""R3""").
# hasFact("m1C","m1C:11").
# relationalAtom("m1C:11").
# hasName("m1C:11","iRel3").
# hasArgument("m1C:11","m1C:12",0).
# term("m1C:12").
# hasSerialization("m1C:12","""l1""").
# hasArgument("m1C:11","m1C:13",1).
# term("m1C:13").
# hasSerialization("m1C:13","""l1""").
# hasFact("m1C","m1C:14").
# relationalAtom("m1C:14").
# hasName("m1C:14","iRel3").
# hasArgument("m1C:14","m1C:15",0).
# term("m1C:15").
# hasSerialization("m1C:15","""l2""").
# hasArgument("m1C:14","m1C:16",1).
# term("m1C:16").
# hasSerialization("m1C:16","""l3""").
# hasAnnotation("m1C","m1C:17").
# annotation("m1C:17").
# hasName("m1C:17","module").
# hasArgument("m1C:17","m1C:18",0).
# term("m1C:18").
# hasSerialization("m1C:18","""m1C""").
# hasAnnotation("m1C","m1C:19").
# annotation("m1C:19").
# hasName("m1C:19","inherits").
# hasArgument("m1C:19","m1C:20",0).
# term("m1C:20").
# hasSerialization("m1C:20","""m""").
# hasAnnotation("m1C","m1C:21").
# annotation("m1C:21").
# hasName("m1C:21","no_additional_input").
# hasAnnotation("m1C","m1C:22").
# annotation("m1C:22").
# hasName("m1C:22","input").
# hasArgument("m1C:22","m1C:23",0).
# term("m1C:23").
# hasSerialization("m1C:23","""iRel3""").
# hasAnnotation("m1C","m1C:24").
# annotation("m1C:24").
# hasName("m1C:24","bind").
# hasArgument("m1C:24","m1C:25",0).
# term("m1C:25").
# hasSerialization("m1C:25","""iRel3""").
# hasArgument("m1C:24","m1C:26",1).
# term("m1C:26").
# hasSerialization("m1C:26","""...""").
# hasAnnotation("m1C","m1C:27").
# annotation("m1C:27").
# hasName("m1C:27","remove").
# hasArgument("m1C:27","m1C:28",0).
# term("m1C:28").
# hasSerialization("m1C:28","""M-R2""").
# hasAnnotation("m1C","m1C:29").
# annotation("m1C:29").
# hasName("m1C:29","output").
# hasArgument("m1C:29","m1C:30",0).
# term("m1C:30").
# hasSerialization("m1C:30","""oRelC""").
# </textarea></div></div>

# %%
%%toMeta("m2").
@module("m2"). @inherits("m1A"). @inherits("m1B"). @inherits("m1C").
@no_additional_output.
f1("l3"). f2("l3"). f2("f1").
@label("R5") oRelE(X) :- f1(X), f2(A), f3(X), iRel1(X), iRel3(A,X).
@redefinesQ("R5","R3","m1B").
@output("oRelE").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m2").
# hasRule("m2","m2:0").
# rule("m2:0").
# hasPositiveHeadAtom("m2:0","m2:1").
# relationalAtom("m2:1").
# hasName("m2:1","oRelE").
# hasArgument("m2:1","m2:2",0).
# term("m2:2").
# hasSerialization("m2:2","X").
# hasPositiveBodyAtom("m2:0","m2:3").
# relationalAtom("m2:3").
# hasName("m2:3","f1").
# hasArgument("m2:3","m2:4",0).
# term("m2:4").
# hasSerialization("m2:4","X").
# hasPositiveBodyAtom("m2:0","m2:5").
# relationalAtom("m2:5").
# hasName("m2:5","f2").
# hasArgument("m2:5","m2:6",0).
# term("m2:6").
# hasSerialization("m2:6","A").
# hasPositiveBodyAtom("m2:0","m2:7").
# relationalAtom("m2:7").
# hasName("m2:7","f3").
# hasArgument("m2:7","m2:8",0).
# term("m2:8").
# hasSerialization("m2:8","X").
# hasPositiveBodyAtom("m2:0","m2:9").
# relationalAtom("m2:9").
# hasName("m2:9","iRel1").
# hasArgument("m2:9","m2:10",0).
# term("m2:10").
# hasSerialization("m2:10","X").
# hasPositiveBodyAtom("m2:0","m2:11").
# relationalAtom("m2:11").
# hasName("m2:11","iRel3").
# hasArgument("m2:11","m2:12",0).
# term("m2:12").
# hasSerialization("m2:12","A").
# hasArgument("m2:11","m2:13",1).
# term("m2:13").
# hasSerialization("m2:13","X").
# hasAnnotation("m2:0","m2:14").
# annotation("m2:14").
# hasName("m2:14","label").
# hasArgument("m2:14","m2:15",0).
# term("m2:15").
# hasSerialization("m2:15","""R5""").
# hasFact("m2","m2:16").
# relationalAtom("m2:16").
# hasName("m2:16","f1").
# hasArgument("m2:16","m2:17",0).
# term("m2:17").
# hasSerialization("m2:17","""l3""").
# hasFact("m2","m2:18").
# relationalAtom("m2:18").
# hasName("m2:18","f2").
# hasArgument("m2:18","m2:19",0).
# term("m2:19").
# hasSerialization("m2:19","""l3""").
# hasFact("m2","m2:20").
# relationalAtom("m2:20").
# hasName("m2:20","f2").
# hasArgument("m2:20","m2:21",0).
# term("m2:21").
# hasSerialization("m2:21","""f1""").
# hasAnnotation("m2","m2:22").
# annotation("m2:22").
# hasName("m2:22","module").
# hasArgument("m2:22","m2:23",0).
# term("m2:23").
# hasSerialization("m2:23","""m2""").
# hasAnnotation("m2","m2:24").
# annotation("m2:24").
# hasName("m2:24","inherits").
# hasArgument("m2:24","m2:25",0).
# term("m2:25").
# hasSerialization("m2:25","""m1A""").
# hasAnnotation("m2","m2:26").
# annotation("m2:26").
# hasName("m2:26","inherits").
# hasArgument("m2:26","m2:27",0).
# term("m2:27").
# hasSerialization("m2:27","""m1B""").
# hasAnnotation("m2","m2:28").
# annotation("m2:28").
# hasName("m2:28","inherits").
# hasArgument("m2:28","m2:29",0).
# term("m2:29").
# hasSerialization("m2:29","""m1C""").
# hasAnnotation("m2","m2:30").
# annotation("m2:30").
# hasName("m2:30","no_additional_output").
# hasAnnotation("m2","m2:31").
# annotation("m2:31").
# hasName("m2:31","redefinesQ").
# hasArgument("m2:31","m2:32",0).
# term("m2:32").
# hasSerialization("m2:32","""R5""").
# hasArgument("m2:31","m2:33",1).
# term("m2:33").
# hasSerialization("m2:33","""R3""").
# hasArgument("m2:31","m2:34",2).
# term("m2:34").
# hasSerialization("m2:34","""m1B""").
# hasAnnotation("m2","m2:35").
# annotation("m2:35").
# hasName("m2:35","output").
# hasArgument("m2:35","m2:36",0).
# term("m2:36").
# hasSerialization("m2:36","""oRelE""").
# </textarea></div></div>

# %%
%%toMeta("m3").
@module("m3"). @inherits("m2").
@label("R6") oRelF(X,Y) :- iRel1(X), iRel2(X), iRel3(X,Y), iRel4(Y).
@removeQ("F1","m1C").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m3").
# hasRule("m3","m3:0").
# rule("m3:0").
# hasPositiveHeadAtom("m3:0","m3:1").
# relationalAtom("m3:1").
# hasName("m3:1","oRelF").
# hasArgument("m3:1","m3:2",0).
# term("m3:2").
# hasSerialization("m3:2","X").
# hasArgument("m3:1","m3:3",1).
# term("m3:3").
# hasSerialization("m3:3","Y").
# hasPositiveBodyAtom("m3:0","m3:4").
# relationalAtom("m3:4").
# hasName("m3:4","iRel1").
# hasArgument("m3:4","m3:5",0).
# term("m3:5").
# hasSerialization("m3:5","X").
# hasPositiveBodyAtom("m3:0","m3:6").
# relationalAtom("m3:6").
# hasName("m3:6","iRel2").
# hasArgument("m3:6","m3:7",0).
# term("m3:7").
# hasSerialization("m3:7","X").
# hasPositiveBodyAtom("m3:0","m3:8").
# relationalAtom("m3:8").
# hasName("m3:8","iRel3").
# hasArgument("m3:8","m3:9",0).
# term("m3:9").
# hasSerialization("m3:9","X").
# hasArgument("m3:8","m3:10",1).
# term("m3:10").
# hasSerialization("m3:10","Y").
# hasPositiveBodyAtom("m3:0","m3:11").
# relationalAtom("m3:11").
# hasName("m3:11","iRel4").
# hasArgument("m3:11","m3:12",0).
# term("m3:12").
# hasSerialization("m3:12","Y").
# hasAnnotation("m3:0","m3:13").
# annotation("m3:13").
# hasName("m3:13","label").
# hasArgument("m3:13","m3:14",0).
# term("m3:14").
# hasSerialization("m3:14","""R6""").
# hasAnnotation("m3","m3:15").
# annotation("m3:15").
# hasName("m3:15","module").
# hasArgument("m3:15","m3:16",0).
# term("m3:16").
# hasSerialization("m3:16","""m3""").
# hasAnnotation("m3","m3:17").
# annotation("m3:17").
# hasName("m3:17","inherits").
# hasArgument("m3:17","m3:18",0).
# term("m3:18").
# hasSerialization("m3:18","""m2""").
# hasAnnotation("m3","m3:19").
# annotation("m3:19").
# hasName("m3:19","removeQ").
# hasArgument("m3:19","m3:20",0).
# term("m3:20").
# hasSerialization("m3:20","""F1""").
# hasArgument("m3:19","m3:21",1).
# term("m3:21").
# hasSerialization("m3:21","""m1C""").
# </textarea></div></div>

# %% [markdown]
# **Restrictions:**
# * M: `non_omitable("iRel1").` `non_redefinable("iRel1").` `non_additional_annotation("iRel1","bind").` `non_shrinkable("oRelA")`
# * M1A: `non_growable("oRelC")`
# * M1B: -
# * M1C: `no_additional_input`
# * M2: `no_additional_output`
# * M3: -

# %% [markdown]
# # Structural Restrictions
# ## Defined Structural Restrictions

# %%
toDerive("m3").

program("m").
hasRule("m","m:0").
rule("m:0").
hasPositiveHeadAtom("m:0","m:1").
relationalAtom("m:1").
hasName("m:1","oRelA").
hasArgument("m:1","m:2",0).
term("m:2").
hasSerialization("m:2","X").
hasPositiveBodyAtom("m:0","m:3").
relationalAtom("m:3").
hasName("m:3","iRel1").
hasArgument("m:3","m:4",0).
term("m:4").
hasSerialization("m:4","X").
hasPositiveBodyAtom("m:0","m:5").
relationalAtom("m:5").
hasName("m:5","f1").
hasArgument("m:5","m:6",0).
term("m:6").
hasSerialization("m:6","X").
hasRule("m","m:7").
rule("m:7").
hasPositiveHeadAtom("m:7","m:8").
relationalAtom("m:8").
hasName("m:8","oRelB").
hasArgument("m:8","m:9",0).
term("m:9").
hasSerialization("m:9","X").
hasPositiveBodyAtom("m:7","m:10").
relationalAtom("m:10").
hasName("m:10","iRel1").
hasArgument("m:10","m:11",0).
term("m:11").
hasSerialization("m:11","X").
hasPositiveBodyAtom("m:7","m:12").
relationalAtom("m:12").
hasName("m:12","f2").
hasArgument("m:12","m:13",0).
term("m:13").
hasSerialization("m:13","X").
hasAnnotation("m:7","m:14").
annotation("m:14").
hasName("m:14","label").
hasArgument("m:14","m:15",0).
term("m:15").
hasSerialization("m:15","""M-R2""").
hasFact("m","m:16").
relationalAtom("m:16").
hasName("m:16","iRel1").
hasArgument("m:16","m:17",0).
term("m:17").
hasSerialization("m:17","""l1""").
hasFact("m","m:18").
relationalAtom("m:18").
hasName("m:18","iRel1").
hasArgument("m:18","m:19",0).
term("m:19").
hasSerialization("m:19","""l2""").
hasFact("m","m:20").
relationalAtom("m:20").
hasName("m:20","f1").
hasArgument("m:20","m:21",0).
term("m:21").
hasSerialization("m:21","""l1""").
hasAnnotation("m","m:22").
annotation("m:22").
hasName("m:22","module").
hasArgument("m:22","m:23",0).
term("m:23").
hasSerialization("m:23","""m""").
hasAnnotation("m","m:24").
annotation("m:24").
hasName("m:24","non_omitable").
hasArgument("m:24","m:25",0).
term("m:25").
hasSerialization("m:25","""iRel1""").
hasAnnotation("m","m:26").
annotation("m:26").
hasName("m:26","non_redefinable").
hasArgument("m:26","m:27",0).
term("m:27").
hasSerialization("m:27","""iRel1""").
hasAnnotation("m","m:28").
annotation("m:28").
hasName("m:28","no_additional_annotation").
hasArgument("m:28","m:29",0).
term("m:29").
hasSerialization("m:29","""iRel1""").
hasArgument("m:28","m:30",1).
term("m:30").
hasSerialization("m:30","""bind""").
hasAnnotation("m","m:31").
annotation("m:31").
hasName("m:31","non_shrinkable").
hasArgument("m:31","m:32",0).
term("m:32").
hasSerialization("m:32","""oRelA""").
hasAnnotation("m","m:33").
annotation("m:33").
hasName("m:33","input").
hasArgument("m:33","m:34",0).
term("m:34").
hasSerialization("m:34","""iRel1""").
hasAnnotation("m","m:35").
annotation("m:35").
hasName("m:35","bind").
hasArgument("m:35","m:36",0).
term("m:36").
hasSerialization("m:36","""iRel1""").
hasArgument("m:35","m:37",1).
term("m:37").
hasSerialization("m:37","""...""").
hasAnnotation("m","m:38").
annotation("m:38").
hasName("m:38","non_omitable_annotation").
hasArgument("m:38","m:39",0).
term("m:39").
hasSerialization("m:39","""iRel1""").
hasArgument("m:38","m:40",1).
term("m:40").
hasSerialization("m:40","""bind""").
hasAnnotation("m","m:41").
annotation("m:41").
hasName("m:41","output").
hasArgument("m:41","m:42",0).
term("m:42").
hasSerialization("m:42","""oRelA""").
hasAnnotation("m","m:43").
annotation("m:43").
hasName("m:43","post").
hasArgument("m:43","m:44",0).
term("m:44").
hasSerialization("m:44","""oRelA""").
hasArgument("m:43","m:45",1).
term("m:45").
hasSerialization("m:45","""orderby(1)""").
hasAnnotation("m","m:46").
annotation("m:46").
hasName("m:46","output").
hasArgument("m:46","m:47",0).
term("m:47").
hasSerialization("m:47","""oRelB""").


program("m1A").
hasRule("m1A","m1A:0").
rule("m1A:0").
hasPositiveHeadAtom("m1A:0","m1A:1").
relationalAtom("m1A:1").
hasName("m1A:1","oRelC").
hasArgument("m1A:1","m1A:2",0).
term("m1A:2").
hasSerialization("m1A:2","X").
hasPositiveBodyAtom("m1A:0","m1A:3").
relationalAtom("m1A:3").
hasName("m1A:3","oRelA").
hasArgument("m1A:3","m1A:4",0).
term("m1A:4").
hasSerialization("m1A:4","X").
hasPositiveBodyAtom("m1A:0","m1A:5").
relationalAtom("m1A:5").
hasName("m1A:5","oRelB").
hasArgument("m1A:5","m1A:6",0).
term("m1A:6").
hasSerialization("m1A:6","X").
hasPositiveBodyAtom("m1A:0","m1A:7").
relationalAtom("m1A:7").
hasName("m1A:7","temp").
hasArgument("m1A:7","m1A:8",0).
term("m1A:8").
hasSerialization("m1A:8","X").
hasAnnotation("m1A:0","m1A:9").
annotation("m1A:9").
hasName("m1A:9","label").
hasArgument("m1A:9","m1A:10",0).
term("m1A:10").
hasSerialization("m1A:10","""R3""").
hasRule("m1A","m1A:11").
rule("m1A:11").
hasPositiveHeadAtom("m1A:11","m1A:12").
relationalAtom("m1A:12").
hasName("m1A:12","temp").
hasArgument("m1A:12","m1A:13",0).
term("m1A:13").
hasSerialization("m1A:13","T").
hasPositiveBodyAtom("m1A:11","m1A:14").
relationalAtom("m1A:14").
hasName("m1A:14","iRel2").
hasArgument("m1A:14","m1A:15",0).
term("m1A:15").
hasSerialization("m1A:15","T").
hasPositiveBodyAtom("m1A:11","m1A:16").
relationalAtom("m1A:16").
hasName("m1A:16","f1").
hasArgument("m1A:16","m1A:17",0).
term("m1A:17").
hasSerialization("m1A:17","T").
hasAnnotation("m1A:11","m1A:18").
annotation("m1A:18").
hasName("m1A:18","label").
hasArgument("m1A:18","m1A:19",0).
term("m1A:19").
hasSerialization("m1A:19","""R4""").
hasFact("m1A","m1A:20").
relationalAtom("m1A:20").
hasName("m1A:20","iRel2").
hasArgument("m1A:20","m1A:21",0).
term("m1A:21").
hasSerialization("m1A:21","""l1""").
hasFact("m1A","m1A:22").
relationalAtom("m1A:22").
hasName("m1A:22","f1").
hasArgument("m1A:22","m1A:23",0).
term("m1A:23").
hasSerialization("m1A:23","""l2""").
hasFact("m1A","m1A:24").
relationalAtom("m1A:24").
hasName("m1A:24","f2").
hasArgument("m1A:24","m1A:25",0).
term("m1A:25").
hasSerialization("m1A:25","""l1""").
hasAnnotation("m1A:24","m1A:26").
annotation("m1A:26").
hasName("m1A:26","label").
hasArgument("m1A:26","m1A:27",0).
term("m1A:27").
hasSerialization("m1A:27","""F1""").
hasAnnotation("m1A","m1A:28").
annotation("m1A:28").
hasName("m1A:28","module").
hasArgument("m1A:28","m1A:29",0).
term("m1A:29").
hasSerialization("m1A:29","""m1A""").
hasAnnotation("m1A","m1A:30").
annotation("m1A:30").
hasName("m1A:30","inherits").
hasArgument("m1A:30","m1A:31",0).
term("m1A:31").
hasSerialization("m1A:31","""m""").
hasAnnotation("m1A","m1A:32").
annotation("m1A:32").
hasName("m1A:32","non_growable").
hasArgument("m1A:32","m1A:33",0).
term("m1A:33").
hasSerialization("m1A:33","""oRelC""").
hasAnnotation("m1A","m1A:34").
annotation("m1A:34").
hasName("m1A:34","input").
hasArgument("m1A:34","m1A:35",0).
term("m1A:35").
hasSerialization("m1A:35","""iRel2""").
hasAnnotation("m1A","m1A:36").
annotation("m1A:36").
hasName("m1A:36","bind").
hasArgument("m1A:36","m1A:37",0).
term("m1A:37").
hasSerialization("m1A:37","""iRel2""").
hasArgument("m1A:36","m1A:38",1).
term("m1A:38").
hasSerialization("m1A:38","""...""").
hasAnnotation("m1A","m1A:39").
annotation("m1A:39").
hasName("m1A:39","redefines").
hasArgument("m1A:39","m1A:40",0).
term("m1A:40").
hasSerialization("m1A:40","""R4""").
hasArgument("m1A:39","m1A:41",1).
term("m1A:41").
hasSerialization("m1A:41","""M-R2""").
hasAnnotation("m1A","m1A:42").
annotation("m1A:42").
hasName("m1A:42","output").
hasArgument("m1A:42","m1A:43",0).
term("m1A:43").
hasSerialization("m1A:43","""oRelC""").

program("m1B").
hasRule("m1B","m1B:0").
rule("m1B:0").
hasPositiveHeadAtom("m1B:0","m1B:1").
relationalAtom("m1B:1").
hasName("m1B:1","oRelD").
hasArgument("m1B:1","m1B:2",0).
term("m1B:2").
hasSerialization("m1B:2","X").
hasPositiveBodyAtom("m1B:0","m1B:3").
relationalAtom("m1B:3").
hasName("m1B:3","oRelA").
hasArgument("m1B:3","m1B:4",0).
term("m1B:4").
hasSerialization("m1B:4","X").
hasPositiveBodyAtom("m1B:0","m1B:5").
relationalAtom("m1B:5").
hasName("m1B:5","oRelB").
hasArgument("m1B:5","m1B:6",0).
term("m1B:6").
hasSerialization("m1B:6","X").
hasPositiveBodyAtom("m1B:0","m1B:7").
relationalAtom("m1B:7").
hasName("m1B:7","f3").
hasArgument("m1B:7","m1B:8",0).
term("m1B:8").
hasSerialization("m1B:8","X").
hasPositiveBodyAtom("m1B:0","m1B:9").
relationalAtom("m1B:9").
hasName("m1B:9","iRel4").
hasArgument("m1B:9","m1B:10",0).
term("m1B:10").
hasSerialization("m1B:10","X").
hasAnnotation("m1B:0","m1B:11").
annotation("m1B:11").
hasName("m1B:11","label").
hasArgument("m1B:11","m1B:12",0).
term("m1B:12").
hasSerialization("m1B:12","""R3""").
hasFact("m1B","m1B:13").
relationalAtom("m1B:13").
hasName("m1B:13","iRel4").
hasArgument("m1B:13","m1B:14",0).
term("m1B:14").
hasSerialization("m1B:14","""l1""").
hasFact("m1B","m1B:15").
relationalAtom("m1B:15").
hasName("m1B:15","iRel4").
hasArgument("m1B:15","m1B:16",0).
term("m1B:16").
hasSerialization("m1B:16","""l3""").
hasFact("m1B","m1B:17").
relationalAtom("m1B:17").
hasName("m1B:17","f3").
hasArgument("m1B:17","m1B:18",0).
term("m1B:18").
hasSerialization("m1B:18","""l2""").
hasFact("m1B","m1B:19").
relationalAtom("m1B:19").
hasName("m1B:19","f3").
hasArgument("m1B:19","m1B:20",0).
term("m1B:20").
hasSerialization("m1B:20","""l3""").
hasFact("m1B","m1B:21").
relationalAtom("m1B:21").
hasName("m1B:21","f3").
hasArgument("m1B:21","m1B:22",0).
term("m1B:22").
hasSerialization("m1B:22","""l1""").
hasAnnotation("m1B:21","m1B:23").
annotation("m1B:23").
hasName("m1B:23","label").
hasArgument("m1B:23","m1B:24",0).
term("m1B:24").
hasSerialization("m1B:24","""F1""").
hasAnnotation("m1B","m1B:25").
annotation("m1B:25").
hasName("m1B:25","module").
hasArgument("m1B:25","m1B:26",0).
term("m1B:26").
hasSerialization("m1B:26","""m1B""").
hasAnnotation("m1B","m1B:27").
annotation("m1B:27").
hasName("m1B:27","input").
hasArgument("m1B:27","m1B:28",0).
term("m1B:28").
hasSerialization("m1B:28","""iRel4""").
hasAnnotation("m1B","m1B:29").
annotation("m1B:29").
hasName("m1B:29","bind").
hasArgument("m1B:29","m1B:30",0).
term("m1B:30").
hasSerialization("m1B:30","""iRel4""").
hasArgument("m1B:29","m1B:31",1).
term("m1B:31").
hasSerialization("m1B:31","""...""").
hasAnnotation("m1B","m1B:32").
annotation("m1B:32").
hasName("m1B:32","output").
hasArgument("m1B:32","m1B:33",0).
term("m1B:33").
hasSerialization("m1B:33","""oRelD""").
hasAnnotation("m1B","m1B:34").
annotation("m1B:34").
hasName("m1B:34","non_shrinkable").
hasArgument("m1B:34","m1B:35",0).
term("m1B:35").
hasSerialization("m1B:35","""oRelD""").

program("m1C").
hasRule("m1C","m1C:0").
rule("m1C:0").
hasPositiveHeadAtom("m1C:0","m1C:1").
relationalAtom("m1C:1").
hasName("m1C:1","oRelC").
hasArgument("m1C:1","m1C:2",0).
term("m1C:2").
hasSerialization("m1C:2","X").
hasArgument("m1C:1","m1C:3",1).
term("m1C:3").
hasSerialization("m1C:3","Y").
hasPositiveBodyAtom("m1C:0","m1C:4").
relationalAtom("m1C:4").
hasName("m1C:4","iRel3").
hasArgument("m1C:4","m1C:5",0).
term("m1C:5").
hasSerialization("m1C:5","X").
hasArgument("m1C:4","m1C:6",1).
term("m1C:6").
hasSerialization("m1C:6","Y").
hasPositiveBodyAtom("m1C:0","m1C:7").
relationalAtom("m1C:7").
hasName("m1C:7","f1").
hasArgument("m1C:7","m1C:8",0).
term("m1C:8").
hasSerialization("m1C:8","Y").
hasAnnotation("m1C:0","m1C:9").
annotation("m1C:9").
hasName("m1C:9","label").
hasArgument("m1C:9","m1C:10",0).
term("m1C:10").
hasSerialization("m1C:10","""R3""").
hasFact("m1C","m1C:11").
relationalAtom("m1C:11").
hasName("m1C:11","iRel3").
hasArgument("m1C:11","m1C:12",0).
term("m1C:12").
hasSerialization("m1C:12","""l1""").
hasArgument("m1C:11","m1C:13",1).
term("m1C:13").
hasSerialization("m1C:13","""l1""").
hasFact("m1C","m1C:14").
relationalAtom("m1C:14").
hasName("m1C:14","iRel3").
hasArgument("m1C:14","m1C:15",0).
term("m1C:15").
hasSerialization("m1C:15","""l2""").
hasArgument("m1C:14","m1C:16",1).
term("m1C:16").
hasSerialization("m1C:16","""l3""").
hasAnnotation("m1C","m1C:17").
annotation("m1C:17").
hasName("m1C:17","module").
hasArgument("m1C:17","m1C:18",0).
term("m1C:18").
hasSerialization("m1C:18","""m1C""").
hasAnnotation("m1C","m1C:19").
annotation("m1C:19").
hasName("m1C:19","inherits").
hasArgument("m1C:19","m1C:20",0).
term("m1C:20").
hasSerialization("m1C:20","""m""").
hasAnnotation("m1C","m1C:21").
annotation("m1C:21").
hasName("m1C:21","no_additional_input").
hasAnnotation("m1C","m1C:22").
annotation("m1C:22").
hasName("m1C:22","input").
hasArgument("m1C:22","m1C:23",0).
term("m1C:23").
hasSerialization("m1C:23","""iRel3""").
hasAnnotation("m1C","m1C:24").
annotation("m1C:24").
hasName("m1C:24","bind").
hasArgument("m1C:24","m1C:25",0).
term("m1C:25").
hasSerialization("m1C:25","""iRel3""").
hasArgument("m1C:24","m1C:26",1).
term("m1C:26").
hasSerialization("m1C:26","""...""").
hasAnnotation("m1C","m1C:27").
annotation("m1C:27").
hasName("m1C:27","remove").
hasArgument("m1C:27","m1C:28",0).
term("m1C:28").
hasSerialization("m1C:28","""M-R2""").
hasAnnotation("m1C","m1C:29").
annotation("m1C:29").
hasName("m1C:29","output").
hasArgument("m1C:29","m1C:30",0).
term("m1C:30").
hasSerialization("m1C:30","""oRelC""").

program("m2").
hasRule("m2","m2:0").
rule("m2:0").
hasPositiveHeadAtom("m2:0","m2:1").
relationalAtom("m2:1").
hasName("m2:1","oRelE").
hasArgument("m2:1","m2:2",0).
term("m2:2").
hasSerialization("m2:2","X").
hasPositiveBodyAtom("m2:0","m2:3").
relationalAtom("m2:3").
hasName("m2:3","f1").
hasArgument("m2:3","m2:4",0).
term("m2:4").
hasSerialization("m2:4","X").
hasPositiveBodyAtom("m2:0","m2:5").
relationalAtom("m2:5").
hasName("m2:5","f2").
hasArgument("m2:5","m2:6",0).
term("m2:6").
hasSerialization("m2:6","A").
hasPositiveBodyAtom("m2:0","m2:7").
relationalAtom("m2:7").
hasName("m2:7","f3").
hasArgument("m2:7","m2:8",0).
term("m2:8").
hasSerialization("m2:8","X").
hasPositiveBodyAtom("m2:0","m2:9").
relationalAtom("m2:9").
hasName("m2:9","iRel1").
hasArgument("m2:9","m2:10",0).
term("m2:10").
hasSerialization("m2:10","X").
hasPositiveBodyAtom("m2:0","m2:11").
relationalAtom("m2:11").
hasName("m2:11","iRel3").
hasArgument("m2:11","m2:12",0).
term("m2:12").
hasSerialization("m2:12","A").
hasArgument("m2:11","m2:13",1).
term("m2:13").
hasSerialization("m2:13","X").
hasAnnotation("m2:0","m2:14").
annotation("m2:14").
hasName("m2:14","label").
hasArgument("m2:14","m2:15",0).
term("m2:15").
hasSerialization("m2:15","""R5""").
hasFact("m2","m2:16").
relationalAtom("m2:16").
hasName("m2:16","f1").
hasArgument("m2:16","m2:17",0).
term("m2:17").
hasSerialization("m2:17","""l3""").
hasFact("m2","m2:18").
relationalAtom("m2:18").
hasName("m2:18","f2").
hasArgument("m2:18","m2:19",0).
term("m2:19").
hasSerialization("m2:19","""l3""").
hasFact("m2","m2:20").
relationalAtom("m2:20").
hasName("m2:20","f2").
hasArgument("m2:20","m2:21",0).
term("m2:21").
hasSerialization("m2:21","""f1""").
hasAnnotation("m2","m2:22").
annotation("m2:22").
hasName("m2:22","module").
hasArgument("m2:22","m2:23",0).
term("m2:23").
hasSerialization("m2:23","""m2""").
hasAnnotation("m2","m2:24").
annotation("m2:24").
hasName("m2:24","inherits").
hasArgument("m2:24","m2:25",0).
term("m2:25").
hasSerialization("m2:25","""m1A""").
hasAnnotation("m2","m2:26").
annotation("m2:26").
hasName("m2:26","inherits").
hasArgument("m2:26","m2:27",0).
term("m2:27").
hasSerialization("m2:27","""m1B""").
hasAnnotation("m2","m2:28").
annotation("m2:28").
hasName("m2:28","inherits").
hasArgument("m2:28","m2:29",0).
term("m2:29").
hasSerialization("m2:29","""m1C""").
hasAnnotation("m2","m2:30").
annotation("m2:30").
hasName("m2:30","no_additional_output").
hasAnnotation("m2","m2:31").
annotation("m2:31").
hasName("m2:31","redefinesQ").
hasArgument("m2:31","m2:32",0).
term("m2:32").
hasSerialization("m2:32","""R5""").
hasArgument("m2:31","m2:33",1).
term("m2:33").
hasSerialization("m2:33","""R3""").
hasArgument("m2:31","m2:34",2).
term("m2:34").
hasSerialization("m2:34","""m1B""").
hasAnnotation("m2","m2:35").
annotation("m2:35").
hasName("m2:35","output").
hasArgument("m2:35","m2:36",0).
term("m2:36").
hasSerialization("m2:36","""oRelE""").

program("m3").
hasRule("m3","m3:0").
rule("m3:0").
hasPositiveHeadAtom("m3:0","m3:1").
relationalAtom("m3:1").
hasName("m3:1","oRelF").
hasArgument("m3:1","m3:2",0).
term("m3:2").
hasSerialization("m3:2","X").
hasArgument("m3:1","m3:3",1).
term("m3:3").
hasSerialization("m3:3","Y").
hasPositiveBodyAtom("m3:0","m3:4").
relationalAtom("m3:4").
hasName("m3:4","iRel1").
hasArgument("m3:4","m3:5",0).
term("m3:5").
hasSerialization("m3:5","X").
hasPositiveBodyAtom("m3:0","m3:6").
relationalAtom("m3:6").
hasName("m3:6","iRel2").
hasArgument("m3:6","m3:7",0).
term("m3:7").
hasSerialization("m3:7","X").
hasPositiveBodyAtom("m3:0","m3:8").
relationalAtom("m3:8").
hasName("m3:8","iRel3").
hasArgument("m3:8","m3:9",0).
term("m3:9").
hasSerialization("m3:9","X").
hasArgument("m3:8","m3:10",1).
term("m3:10").
hasSerialization("m3:10","Y").
hasPositiveBodyAtom("m3:0","m3:11").
relationalAtom("m3:11").
hasName("m3:11","iRel4").
hasArgument("m3:11","m3:12",0).
term("m3:12").
hasSerialization("m3:12","Y").
hasAnnotation("m3:0","m3:13").
annotation("m3:13").
hasName("m3:13","label").
hasArgument("m3:13","m3:14",0).
term("m3:14").
hasSerialization("m3:14","""R6""").
hasAnnotation("m3","m3:15").
annotation("m3:15").
hasName("m3:15","module").
hasArgument("m3:15","m3:16",0).
term("m3:16").
hasSerialization("m3:16","""m3""").
hasAnnotation("m3","m3:17").
annotation("m3:17").
hasName("m3:17","inherits").
hasArgument("m3:17","m3:18",0).
term("m3:18").
hasSerialization("m3:18","""m2""").
hasAnnotation("m3","m3:19").
annotation("m3:19").
hasName("m3:19","removeQ").
hasArgument("m3:19","m3:20",0).
term("m3:20").
hasSerialization("m3:20","""F1""").
hasArgument("m3:19","m3:21",1).
term("m3:21").
hasSerialization("m3:21","""m1C""").

true(#T). false(#F).

% Find module labels for module IDs
moduleLbl(M,L) :- hasAnnotation(M,A), hasName(A,"module"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
resultset(S,M) :- hasAnnotation(S,A), hasName(A,"resultset"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), M = substring(L1,1,string_length(L1)-1).

% Find Id of module to be derived
deriveModule(M) :- toDerive(L), moduleLbl(M,L).

% Determine inheritance relationships in provided meta-representations
inherits(MC,MP) :- hasAnnotation(MC,A), hasName(A,"inherits"), hasArgument(A,Arg,0), hasSerialization(Arg,MP1), moduleLbl(MP,MPL), MPL = substring(MP1,1,string_length(MP1)-1).
tInherits(M,M2) :- inherits(M,M2).
tInherits(M,M2) :- tInherits(M,M1), inherits(M1,M2).

% Predicates in a module
predicate(M,P) :- inputPredicate(M,P).
predicate(M,P) :- outputPredicate(M,P).
predicate(M,P) :- tHasFact(M,F), relationalAtom(F), hasName(F,P).
predicate(M,P) :- mHasRule(M,R), ruleHeadPredicate(R,P).
predicate(M,P) :- mHasRule(M,R), ruleBodyPredicate(R,P).

inputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"input"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"output"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

% Defined restrictions and modification operations
restriction("no_additional_input").
restriction("no_additional_output").
restriction("no_additional_annotation").
restriction("non_omitable").
restriction("non_redefinable").
restriction("non_shrinkable").
restriction("non_growable").
modOp("remove"). modOp("removeQ").
modOp("redefines"). modOp("redefinesQ").
modOp("inherits").

% Inheritance Annotations
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), restriction(N).
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), modOp(N).

% Which statements exist in a module?
hasStmt(M,S) :- hasRule(M,S).
hasStmt(M,S) :- hasFact(M,S).
hasStmt(M,S) :- moduleLbl(M,_), hasAnnotation(M,S).

% Only labeled statements are interesting, others always propagated
stmtLbl(R,L) :- hasRule(M,R), hasAnnotation(R,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(F,L) :- hasFact(M,F), hasAnnotation(F,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(A,L) :- hasAnnotation(M,A), hasAnnotation(A,A2), hasName(A2,"label"), hasArgument(A2,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtML(M,S,L) :- stmtLbl(S,L), hasStmt(M,S).

% Atoms in a rule
hasAtom(R,A):- hasNegativeBodyAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasPositiveBodyAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasNegativeHeadAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasPositiveHeadAtom(R,A), relationalAtom(A).

ruleBodyPredicate(R,P):- tHasRule(M,R), hasNegativeBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleBodyPredicate(R,P):- tHasRule(M,R), hasPositiveBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- tHasRule(M,R), hasNegativeHeadAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- tHasRule(M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P).
predicateDependency(M,P,P2) :- tHasRule(M,R), ruleHeadPredicate(R,P), ruleBodyPredicate(R,P2).

% RESOLVE INHERITANCE
% Unqualified remove and redefine
redefineStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"redefines"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), L = substring(L1,1,string_length(L1)-1).
removeStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"remove"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), L = substring(L1,1,string_length(L1)-1).
% Any statement except inheritance annotations can be removed
redefineStmt(M,S):- redefineStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).
removeStmt(M,S):- removeStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).

% Qualified remove and redefine
redefineStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"redefinesQ"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), hasArgument(A,Arg3,2), hasSerialization(Arg3,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
removeStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"removeQ"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
redefineStmt(M,S) :- redefineStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).
removeStmt(M,S) :- removeStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).

% Module name annotations are not inherited
removeStmt(M,A) :- hasAnnotation(M,A), hasName(A,"module"), not deriveModule(M).

% Modification operation statements
modOpStmt(M,S) :- removeStmt(M,S).
modOpStmt(M,S) :- redefineStmt(M,S).
tModOpStmt(M,M,S) :- modOpStmt(M,S).
tModOpStmt(M,Morg,S) :- inherits(M,M2), tModOpStmt(M2,Morg,S).

% DETERMINE ACTIVE STATEMENTS AND MODULE/STATEMENT ANNOTATIONS FOR MODULES
% Derive for each module its active rules by inheriting
tHasRule(M,R) :- hasRule(M,R).
tHasRule(M,R) :- inherits(M,MP), tHasRule(MP,R).
moduleStmt(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).
mHasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).

% Determine for each module its active facts by inheriting
tHasFact(M,F) :- hasFact(M,F).
tHasFact(M,F) :- inherits(M,MP), tHasFact(MP,F).
moduleStmt(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F).

% Determine for each module its active module and statement annotations
tHasAnnotationM(M,A) :- moduleLbl(M,L), hasAnnotation(M,A), hasName(A,N), not modOp(N).
tHasAnnotationM(M,A) :- inherits(M,MP), tHasAnnotationM(MP,A).
tHasAnnotationS(M,Stmt,A) :- hasStmt(M,Stmt), hasAnnotation(Stmt,A).
tHasAnnotationS(M,Stmt,A) :- inherits(M,MP), tHasAnnotationS(MP,Stmt,A).
moduleStmt(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A).

% Determine Restrictions defined in modules
noAdditionalInput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_input").
noAdditionalOutput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_output").
noAdditionalAnnotation(M,ANN,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_annotation"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), P = substring(L1,1,string_length(L1)-1), ANN = substring(L2,1,string_length(L2)-1).
nonOmitableAnnotation(M,ANN,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_omitable_annotation"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), P = substring(L1,1,string_length(L1)-1), ANN = substring(L2,1,string_length(L2)-1).
nonOmitable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_omitable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonRedefinable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_redefinable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonGrowable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_growable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P  =substring(L1,1,string_length(L1)-1).
nonShrinkable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_shrinkable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).

@output("noAdditionalInput").
@output("noAdditionalOutput").
@output("noAdditionalAnnotation").
@output("nonOmitable").
@output("nonRedefinable").
@output("nonOmitableAnnotation").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">noAdditionalOutput</caption><thead><tr><th>string</th></tr></thead><tbody><tr><td>m2</td></tr></tbody><tbody><tr><td>m3</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">nonOmitable</caption><thead><tr><th>string</th><th>string</th></tr></thead><tbody><tr><td>m</td><td>iRel1</td></tr></tbody><tbody><tr><td>m1A</td><td>iRel1</td></tr></tbody><tbody><tr><td>m1C</td><td>iRel1</td></tr></tbody><tbody><tr><td>m2</td><td>iRel1</td></tr></tbody><tbody><tr><td>m3</td><td>iRel1</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">nonRedefinable</caption><thead><tr><th>string</th><th>string</th></tr></thead><tbody><tr><td>m</td><td>iRel1</td></tr></tbody><tbody><tr><td>m1A</td><td>iRel1</td></tr></tbody><tbody><tr><td>m1C</td><td>iRel1</td></tr></tbody><tbody><tr><td>m2</td><td>iRel1</td></tr></tbody><tbody><tr><td>m3</td><td>iRel1</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">noAdditionalAnnotation</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m</td><td>bind</td><td>iRel1</td></tr></tbody><tbody><tr><td>m1A</td><td>bind</td><td>iRel1</td></tr></tbody><tbody><tr><td>m1C</td><td>bind</td><td>iRel1</td></tr></tbody><tbody><tr><td>m2</td><td>bind</td><td>iRel1</td></tr></tbody><tbody><tr><td>m3</td><td>bind</td><td>iRel1</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">noAdditionalInput</caption><thead><tr><th>string</th></tr></thead><tbody><tr><td>m1C</td></tr></tbody><tbody><tr><td>m2</td></tr></tbody><tbody><tr><td>m3</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">nonOmitableAnnotation</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m</td><td>bind</td><td>iRel1</td></tr></tbody><tbody><tr><td>m1A</td><td>bind</td><td>iRel1</td></tr></tbody><tbody><tr><td>m1C</td><td>bind</td><td>iRel1</td></tr></tbody><tbody><tr><td>m2</td><td>bind</td><td>iRel1</td></tr></tbody><tbody><tr><td>m3</td><td>bind</td><td>iRel1</td></tr></tbody></table></div></div></div>

# %% [markdown]
# **Restrictions:**
# * m: `non_omitable("iRel1").` `no_additional_annotation("iRel1","bind").` `non_redefinable("iRel1").`
# `non_omitable_annotation("iRel1","bind").`
# * m1A see m
# * m1B none
# * m1C `no_additional_input` + m
# * m2: `no_additional_output` + m + m1C
# * m3: all above

# %% [markdown]
# ## Violations Test
#
# > cannot test violations of redefinable yet as @label("X") @output(...) not supported yet!
#
# > cannot test violations of omitable yet for the same reason

# %%
%%toMeta("m")
@module("m").
@non_omitable("iRel1"). @non_redefinable("iRel1"). @no_additional_annotation("iRel1","bind"). @non_shrinkable("oRelA").
@input("iRel1"). 
@bind("iRel1","...").
@label("iRel1") iRel1("l1"). @label("iRel1") iRel1("l2").
f1("l1").
oRelA(X) :- iRel1(X), f1(X).
@label("M-R2") oRelB(X) :- iRel1(X), f2(X).
@output("oRelA"). @post("oRelA","orderby(1)").
@output("oRelB"). @non_redefinable("oRelB").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m").
# hasRule("m","m:0").
# rule("m:0").
# hasPositiveHeadAtom("m:0","m:1").
# relationalAtom("m:1").
# hasName("m:1","oRelA").
# hasArgument("m:1","m:2",0).
# term("m:2").
# hasSerialization("m:2","X").
# hasPositiveBodyAtom("m:0","m:3").
# relationalAtom("m:3").
# hasName("m:3","iRel1").
# hasArgument("m:3","m:4",0).
# term("m:4").
# hasSerialization("m:4","X").
# hasPositiveBodyAtom("m:0","m:5").
# relationalAtom("m:5").
# hasName("m:5","f1").
# hasArgument("m:5","m:6",0).
# term("m:6").
# hasSerialization("m:6","X").
# hasRule("m","m:7").
# rule("m:7").
# hasPositiveHeadAtom("m:7","m:8").
# relationalAtom("m:8").
# hasName("m:8","oRelB").
# hasArgument("m:8","m:9",0).
# term("m:9").
# hasSerialization("m:9","X").
# hasPositiveBodyAtom("m:7","m:10").
# relationalAtom("m:10").
# hasName("m:10","iRel1").
# hasArgument("m:10","m:11",0).
# term("m:11").
# hasSerialization("m:11","X").
# hasPositiveBodyAtom("m:7","m:12").
# relationalAtom("m:12").
# hasName("m:12","f2").
# hasArgument("m:12","m:13",0).
# term("m:13").
# hasSerialization("m:13","X").
# hasAnnotation("m:7","m:14").
# annotation("m:14").
# hasName("m:14","label").
# hasArgument("m:14","m:15",0).
# term("m:15").
# hasSerialization("m:15","""M-R2""").
# hasFact("m","m:16").
# relationalAtom("m:16").
# hasName("m:16","iRel1").
# hasArgument("m:16","m:17",0).
# term("m:17").
# hasSerialization("m:17","""l1""").
# hasAnnotation("m:16","m:18").
# annotation("m:18").
# hasName("m:18","label").
# hasArgument("m:18","m:19",0).
# term("m:19").
# hasSerialization("m:19","""iRel1""").
# hasFact("m","m:20").
# relationalAtom("m:20").
# hasName("m:20","iRel1").
# hasArgument("m:20","m:21",0).
# term("m:21").
# hasSerialization("m:21","""l2""").
# hasAnnotation("m:20","m:22").
# annotation("m:22").
# hasName("m:22","label").
# hasArgument("m:22","m:23",0).
# term("m:23").
# hasSerialization("m:23","""iRel1""").
# hasFact("m","m:24").
# relationalAtom("m:24").
# hasName("m:24","f1").
# hasArgument("m:24","m:25",0).
# term("m:25").
# hasSerialization("m:25","""l1""").
# hasAnnotation("m","m:26").
# annotation("m:26").
# hasName("m:26","module").
# hasArgument("m:26","m:27",0).
# term("m:27").
# hasSerialization("m:27","""m""").
# hasAnnotation("m","m:28").
# annotation("m:28").
# hasName("m:28","non_omitable").
# hasArgument("m:28","m:29",0).
# term("m:29").
# hasSerialization("m:29","""iRel1""").
# hasAnnotation("m","m:30").
# annotation("m:30").
# hasName("m:30","non_redefinable").
# hasArgument("m:30","m:31",0).
# term("m:31").
# hasSerialization("m:31","""iRel1""").
# hasAnnotation("m","m:32").
# annotation("m:32").
# hasName("m:32","no_additional_annotation").
# hasArgument("m:32","m:33",0).
# term("m:33").
# hasSerialization("m:33","""iRel1""").
# hasArgument("m:32","m:34",1).
# term("m:34").
# hasSerialization("m:34","""bind""").
# hasAnnotation("m","m:35").
# annotation("m:35").
# hasName("m:35","non_shrinkable").
# hasArgument("m:35","m:36",0).
# term("m:36").
# hasSerialization("m:36","""oRelA""").
# hasAnnotation("m","m:37").
# annotation("m:37").
# hasName("m:37","input").
# hasArgument("m:37","m:38",0).
# term("m:38").
# hasSerialization("m:38","""iRel1""").
# hasAnnotation("m","m:39").
# annotation("m:39").
# hasName("m:39","bind").
# hasArgument("m:39","m:40",0).
# term("m:40").
# hasSerialization("m:40","""iRel1""").
# hasArgument("m:39","m:41",1).
# term("m:41").
# hasSerialization("m:41","""...""").
# hasAnnotation("m","m:42").
# annotation("m:42").
# hasName("m:42","output").
# hasArgument("m:42","m:43",0).
# term("m:43").
# hasSerialization("m:43","""oRelA""").
# hasAnnotation("m","m:44").
# annotation("m:44").
# hasName("m:44","post").
# hasArgument("m:44","m:45",0).
# term("m:45").
# hasSerialization("m:45","""oRelA""").
# hasArgument("m:44","m:46",1).
# term("m:46").
# hasSerialization("m:46","""orderby(1)""").
# hasAnnotation("m","m:47").
# annotation("m:47").
# hasName("m:47","output").
# hasArgument("m:47","m:48",0).
# term("m:48").
# hasSerialization("m:48","""oRelB""").
# hasAnnotation("m","m:49").
# annotation("m:49").
# hasName("m:49","non_redefinable").
# hasArgument("m:49","m:50",0).
# term("m:50").
# hasSerialization("m:50","""oRelB""").
# </textarea></div></div>

# %%
%%toMeta("m1A").
@module("m1A"). @inherits("m").
@non_growable("oRelC").
@input("iRel2"). @bind("iRel2","..."). @bind("iRel1","...m1A").
@remove("iRel1").
iRel2("l1").
f1("l2").
@label("F1") f2("l1").
@label("R3") oRelC(X) :- oRelA(X), oRelB(X), temp(X).
@label("R4") temp(T) :- iRel2(T), f1(T).
@redefines("R4","M-R2").
@output("oRelC").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m1A").
# hasRule("m1A","m1A:0").
# rule("m1A:0").
# hasPositiveHeadAtom("m1A:0","m1A:1").
# relationalAtom("m1A:1").
# hasName("m1A:1","oRelC").
# hasArgument("m1A:1","m1A:2",0).
# term("m1A:2").
# hasSerialization("m1A:2","X").
# hasPositiveBodyAtom("m1A:0","m1A:3").
# relationalAtom("m1A:3").
# hasName("m1A:3","oRelA").
# hasArgument("m1A:3","m1A:4",0).
# term("m1A:4").
# hasSerialization("m1A:4","X").
# hasPositiveBodyAtom("m1A:0","m1A:5").
# relationalAtom("m1A:5").
# hasName("m1A:5","oRelB").
# hasArgument("m1A:5","m1A:6",0).
# term("m1A:6").
# hasSerialization("m1A:6","X").
# hasPositiveBodyAtom("m1A:0","m1A:7").
# relationalAtom("m1A:7").
# hasName("m1A:7","temp").
# hasArgument("m1A:7","m1A:8",0).
# term("m1A:8").
# hasSerialization("m1A:8","X").
# hasAnnotation("m1A:0","m1A:9").
# annotation("m1A:9").
# hasName("m1A:9","label").
# hasArgument("m1A:9","m1A:10",0).
# term("m1A:10").
# hasSerialization("m1A:10","""R3""").
# hasRule("m1A","m1A:11").
# rule("m1A:11").
# hasPositiveHeadAtom("m1A:11","m1A:12").
# relationalAtom("m1A:12").
# hasName("m1A:12","temp").
# hasArgument("m1A:12","m1A:13",0).
# term("m1A:13").
# hasSerialization("m1A:13","T").
# hasPositiveBodyAtom("m1A:11","m1A:14").
# relationalAtom("m1A:14").
# hasName("m1A:14","iRel2").
# hasArgument("m1A:14","m1A:15",0).
# term("m1A:15").
# hasSerialization("m1A:15","T").
# hasPositiveBodyAtom("m1A:11","m1A:16").
# relationalAtom("m1A:16").
# hasName("m1A:16","f1").
# hasArgument("m1A:16","m1A:17",0).
# term("m1A:17").
# hasSerialization("m1A:17","T").
# hasAnnotation("m1A:11","m1A:18").
# annotation("m1A:18").
# hasName("m1A:18","label").
# hasArgument("m1A:18","m1A:19",0).
# term("m1A:19").
# hasSerialization("m1A:19","""R4""").
# hasFact("m1A","m1A:20").
# relationalAtom("m1A:20").
# hasName("m1A:20","iRel2").
# hasArgument("m1A:20","m1A:21",0).
# term("m1A:21").
# hasSerialization("m1A:21","""l1""").
# hasFact("m1A","m1A:22").
# relationalAtom("m1A:22").
# hasName("m1A:22","f1").
# hasArgument("m1A:22","m1A:23",0).
# term("m1A:23").
# hasSerialization("m1A:23","""l2""").
# hasFact("m1A","m1A:24").
# relationalAtom("m1A:24").
# hasName("m1A:24","f2").
# hasArgument("m1A:24","m1A:25",0).
# term("m1A:25").
# hasSerialization("m1A:25","""l1""").
# hasAnnotation("m1A:24","m1A:26").
# annotation("m1A:26").
# hasName("m1A:26","label").
# hasArgument("m1A:26","m1A:27",0).
# term("m1A:27").
# hasSerialization("m1A:27","""F1""").
# hasAnnotation("m1A","m1A:28").
# annotation("m1A:28").
# hasName("m1A:28","module").
# hasArgument("m1A:28","m1A:29",0).
# term("m1A:29").
# hasSerialization("m1A:29","""m1A""").
# hasAnnotation("m1A","m1A:30").
# annotation("m1A:30").
# hasName("m1A:30","inherits").
# hasArgument("m1A:30","m1A:31",0).
# term("m1A:31").
# hasSerialization("m1A:31","""m""").
# hasAnnotation("m1A","m1A:32").
# annotation("m1A:32").
# hasName("m1A:32","non_growable").
# hasArgument("m1A:32","m1A:33",0).
# term("m1A:33").
# hasSerialization("m1A:33","""oRelC""").
# hasAnnotation("m1A","m1A:34").
# annotation("m1A:34").
# hasName("m1A:34","input").
# hasArgument("m1A:34","m1A:35",0).
# term("m1A:35").
# hasSerialization("m1A:35","""iRel2""").
# hasAnnotation("m1A","m1A:36").
# annotation("m1A:36").
# hasName("m1A:36","bind").
# hasArgument("m1A:36","m1A:37",0).
# term("m1A:37").
# hasSerialization("m1A:37","""iRel2""").
# hasArgument("m1A:36","m1A:38",1).
# term("m1A:38").
# hasSerialization("m1A:38","""...""").
# hasAnnotation("m1A","m1A:39").
# annotation("m1A:39").
# hasName("m1A:39","bind").
# hasArgument("m1A:39","m1A:40",0).
# term("m1A:40").
# hasSerialization("m1A:40","""iRel1""").
# hasArgument("m1A:39","m1A:41",1).
# term("m1A:41").
# hasSerialization("m1A:41","""...m1A""").
# hasAnnotation("m1A","m1A:42").
# annotation("m1A:42").
# hasName("m1A:42","remove").
# hasArgument("m1A:42","m1A:43",0).
# term("m1A:43").
# hasSerialization("m1A:43","""iRel1""").
# hasAnnotation("m1A","m1A:44").
# annotation("m1A:44").
# hasName("m1A:44","redefines").
# hasArgument("m1A:44","m1A:45",0).
# term("m1A:45").
# hasSerialization("m1A:45","""R4""").
# hasArgument("m1A:44","m1A:46",1).
# term("m1A:46").
# hasSerialization("m1A:46","""M-R2""").
# hasAnnotation("m1A","m1A:47").
# annotation("m1A:47").
# hasName("m1A:47","output").
# hasArgument("m1A:47","m1A:48",0).
# term("m1A:48").
# hasSerialization("m1A:48","""oRelC""").
# </textarea></div></div>

# %%
%%toMeta("m1B").
@module("m1B").
@input("iRel4"). @bind("iRel4","...").
iRel4("l1"). iRel4("l3").
f3("l2"). f3("l3").
@label("F1") f3("l1").
@label("R3") oRelD(X) :- oRelA(X), oRelB(X), f3(X), iRel4(X).
@output("oRelD"). %@delete("oRelD",{0}).
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m1B").
# hasRule("m1B","m1B:0").
# rule("m1B:0").
# hasPositiveHeadAtom("m1B:0","m1B:1").
# relationalAtom("m1B:1").
# hasName("m1B:1","oRelD").
# hasArgument("m1B:1","m1B:2",0).
# term("m1B:2").
# hasSerialization("m1B:2","X").
# hasPositiveBodyAtom("m1B:0","m1B:3").
# relationalAtom("m1B:3").
# hasName("m1B:3","oRelA").
# hasArgument("m1B:3","m1B:4",0).
# term("m1B:4").
# hasSerialization("m1B:4","X").
# hasPositiveBodyAtom("m1B:0","m1B:5").
# relationalAtom("m1B:5").
# hasName("m1B:5","oRelB").
# hasArgument("m1B:5","m1B:6",0).
# term("m1B:6").
# hasSerialization("m1B:6","X").
# hasPositiveBodyAtom("m1B:0","m1B:7").
# relationalAtom("m1B:7").
# hasName("m1B:7","f3").
# hasArgument("m1B:7","m1B:8",0).
# term("m1B:8").
# hasSerialization("m1B:8","X").
# hasPositiveBodyAtom("m1B:0","m1B:9").
# relationalAtom("m1B:9").
# hasName("m1B:9","iRel4").
# hasArgument("m1B:9","m1B:10",0).
# term("m1B:10").
# hasSerialization("m1B:10","X").
# hasAnnotation("m1B:0","m1B:11").
# annotation("m1B:11").
# hasName("m1B:11","label").
# hasArgument("m1B:11","m1B:12",0).
# term("m1B:12").
# hasSerialization("m1B:12","""R3""").
# hasFact("m1B","m1B:13").
# relationalAtom("m1B:13").
# hasName("m1B:13","iRel4").
# hasArgument("m1B:13","m1B:14",0).
# term("m1B:14").
# hasSerialization("m1B:14","""l1""").
# hasFact("m1B","m1B:15").
# relationalAtom("m1B:15").
# hasName("m1B:15","iRel4").
# hasArgument("m1B:15","m1B:16",0).
# term("m1B:16").
# hasSerialization("m1B:16","""l3""").
# hasFact("m1B","m1B:17").
# relationalAtom("m1B:17").
# hasName("m1B:17","f3").
# hasArgument("m1B:17","m1B:18",0).
# term("m1B:18").
# hasSerialization("m1B:18","""l2""").
# hasFact("m1B","m1B:19").
# relationalAtom("m1B:19").
# hasName("m1B:19","f3").
# hasArgument("m1B:19","m1B:20",0).
# term("m1B:20").
# hasSerialization("m1B:20","""l3""").
# hasFact("m1B","m1B:21").
# relationalAtom("m1B:21").
# hasName("m1B:21","f3").
# hasArgument("m1B:21","m1B:22",0).
# term("m1B:22").
# hasSerialization("m1B:22","""l1""").
# hasAnnotation("m1B:21","m1B:23").
# annotation("m1B:23").
# hasName("m1B:23","label").
# hasArgument("m1B:23","m1B:24",0).
# term("m1B:24").
# hasSerialization("m1B:24","""F1""").
# hasAnnotation("m1B","m1B:25").
# annotation("m1B:25").
# hasName("m1B:25","module").
# hasArgument("m1B:25","m1B:26",0).
# term("m1B:26").
# hasSerialization("m1B:26","""m1B""").
# hasAnnotation("m1B","m1B:27").
# annotation("m1B:27").
# hasName("m1B:27","input").
# hasArgument("m1B:27","m1B:28",0).
# term("m1B:28").
# hasSerialization("m1B:28","""iRel4""").
# hasAnnotation("m1B","m1B:29").
# annotation("m1B:29").
# hasName("m1B:29","bind").
# hasArgument("m1B:29","m1B:30",0).
# term("m1B:30").
# hasSerialization("m1B:30","""iRel4""").
# hasArgument("m1B:29","m1B:31",1).
# term("m1B:31").
# hasSerialization("m1B:31","""...""").
# hasAnnotation("m1B","m1B:32").
# annotation("m1B:32").
# hasName("m1B:32","output").
# hasArgument("m1B:32","m1B:33",0).
# term("m1B:33").
# hasSerialization("m1B:33","""oRelD""").
# </textarea></div></div>

# %%
%%toMeta("m1C").
@module("m1C").  @inherits("m").
@no_additional_input.
@input("iRel3"). @bind("iRel3","...").
iRel3("l1","l1"). iRel3("l2","l3").
@label("R3") oRelC(X,Y) :- iRel3(X,Y), f1(Y).
@remove("M-R2").
@output("oRelC").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m1C").
# hasRule("m1C","m1C:0").
# rule("m1C:0").
# hasPositiveHeadAtom("m1C:0","m1C:1").
# relationalAtom("m1C:1").
# hasName("m1C:1","oRelC").
# hasArgument("m1C:1","m1C:2",0).
# term("m1C:2").
# hasSerialization("m1C:2","X").
# hasArgument("m1C:1","m1C:3",1).
# term("m1C:3").
# hasSerialization("m1C:3","Y").
# hasPositiveBodyAtom("m1C:0","m1C:4").
# relationalAtom("m1C:4").
# hasName("m1C:4","iRel3").
# hasArgument("m1C:4","m1C:5",0).
# term("m1C:5").
# hasSerialization("m1C:5","X").
# hasArgument("m1C:4","m1C:6",1).
# term("m1C:6").
# hasSerialization("m1C:6","Y").
# hasPositiveBodyAtom("m1C:0","m1C:7").
# relationalAtom("m1C:7").
# hasName("m1C:7","f1").
# hasArgument("m1C:7","m1C:8",0).
# term("m1C:8").
# hasSerialization("m1C:8","Y").
# hasAnnotation("m1C:0","m1C:9").
# annotation("m1C:9").
# hasName("m1C:9","label").
# hasArgument("m1C:9","m1C:10",0).
# term("m1C:10").
# hasSerialization("m1C:10","""R3""").
# hasFact("m1C","m1C:11").
# relationalAtom("m1C:11").
# hasName("m1C:11","iRel3").
# hasArgument("m1C:11","m1C:12",0).
# term("m1C:12").
# hasSerialization("m1C:12","""l1""").
# hasArgument("m1C:11","m1C:13",1).
# term("m1C:13").
# hasSerialization("m1C:13","""l1""").
# hasFact("m1C","m1C:14").
# relationalAtom("m1C:14").
# hasName("m1C:14","iRel3").
# hasArgument("m1C:14","m1C:15",0).
# term("m1C:15").
# hasSerialization("m1C:15","""l2""").
# hasArgument("m1C:14","m1C:16",1).
# term("m1C:16").
# hasSerialization("m1C:16","""l3""").
# hasAnnotation("m1C","m1C:17").
# annotation("m1C:17").
# hasName("m1C:17","module").
# hasArgument("m1C:17","m1C:18",0).
# term("m1C:18").
# hasSerialization("m1C:18","""m1C""").
# hasAnnotation("m1C","m1C:19").
# annotation("m1C:19").
# hasName("m1C:19","inherits").
# hasArgument("m1C:19","m1C:20",0).
# term("m1C:20").
# hasSerialization("m1C:20","""m""").
# hasAnnotation("m1C","m1C:21").
# annotation("m1C:21").
# hasName("m1C:21","no_additional_input").
# hasAnnotation("m1C","m1C:22").
# annotation("m1C:22").
# hasName("m1C:22","input").
# hasArgument("m1C:22","m1C:23",0).
# term("m1C:23").
# hasSerialization("m1C:23","""iRel3""").
# hasAnnotation("m1C","m1C:24").
# annotation("m1C:24").
# hasName("m1C:24","bind").
# hasArgument("m1C:24","m1C:25",0).
# term("m1C:25").
# hasSerialization("m1C:25","""iRel3""").
# hasArgument("m1C:24","m1C:26",1).
# term("m1C:26").
# hasSerialization("m1C:26","""...""").
# hasAnnotation("m1C","m1C:27").
# annotation("m1C:27").
# hasName("m1C:27","remove").
# hasArgument("m1C:27","m1C:28",0).
# term("m1C:28").
# hasSerialization("m1C:28","""M-R2""").
# hasAnnotation("m1C","m1C:29").
# annotation("m1C:29").
# hasName("m1C:29","output").
# hasArgument("m1C:29","m1C:30",0).
# term("m1C:30").
# hasSerialization("m1C:30","""oRelC""").
# </textarea></div></div>

# %%
%%toMeta("m2").
@module("m2"). @inherits("m1A"). @inherits("m1B"). @inherits("m1C").
@input("violatingInput"). @bind("iRel1","...m2").
@no_additional_output.
f1("l3"). f2("l3"). f2("f1").
@input("iRel1").
@label("R5") oRelE(X) :- f1(X), f2(A), f3(X), iRel1(X), iRel3(A,X).
@redefinesQ("R5","R3","m1B").
@output("oRelE").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m2").
# hasRule("m2","m2:0").
# rule("m2:0").
# hasPositiveHeadAtom("m2:0","m2:1").
# relationalAtom("m2:1").
# hasName("m2:1","oRelE").
# hasArgument("m2:1","m2:2",0).
# term("m2:2").
# hasSerialization("m2:2","X").
# hasPositiveBodyAtom("m2:0","m2:3").
# relationalAtom("m2:3").
# hasName("m2:3","f1").
# hasArgument("m2:3","m2:4",0).
# term("m2:4").
# hasSerialization("m2:4","X").
# hasPositiveBodyAtom("m2:0","m2:5").
# relationalAtom("m2:5").
# hasName("m2:5","f2").
# hasArgument("m2:5","m2:6",0).
# term("m2:6").
# hasSerialization("m2:6","A").
# hasPositiveBodyAtom("m2:0","m2:7").
# relationalAtom("m2:7").
# hasName("m2:7","f3").
# hasArgument("m2:7","m2:8",0).
# term("m2:8").
# hasSerialization("m2:8","X").
# hasPositiveBodyAtom("m2:0","m2:9").
# relationalAtom("m2:9").
# hasName("m2:9","iRel1").
# hasArgument("m2:9","m2:10",0).
# term("m2:10").
# hasSerialization("m2:10","X").
# hasPositiveBodyAtom("m2:0","m2:11").
# relationalAtom("m2:11").
# hasName("m2:11","iRel3").
# hasArgument("m2:11","m2:12",0).
# term("m2:12").
# hasSerialization("m2:12","A").
# hasArgument("m2:11","m2:13",1).
# term("m2:13").
# hasSerialization("m2:13","X").
# hasAnnotation("m2:0","m2:14").
# annotation("m2:14").
# hasName("m2:14","label").
# hasArgument("m2:14","m2:15",0).
# term("m2:15").
# hasSerialization("m2:15","""R5""").
# hasFact("m2","m2:16").
# relationalAtom("m2:16").
# hasName("m2:16","f1").
# hasArgument("m2:16","m2:17",0).
# term("m2:17").
# hasSerialization("m2:17","""l3""").
# hasFact("m2","m2:18").
# relationalAtom("m2:18").
# hasName("m2:18","f2").
# hasArgument("m2:18","m2:19",0).
# term("m2:19").
# hasSerialization("m2:19","""l3""").
# hasFact("m2","m2:20").
# relationalAtom("m2:20").
# hasName("m2:20","f2").
# hasArgument("m2:20","m2:21",0).
# term("m2:21").
# hasSerialization("m2:21","""f1""").
# hasAnnotation("m2","m2:22").
# annotation("m2:22").
# hasName("m2:22","module").
# hasArgument("m2:22","m2:23",0).
# term("m2:23").
# hasSerialization("m2:23","""m2""").
# hasAnnotation("m2","m2:24").
# annotation("m2:24").
# hasName("m2:24","inherits").
# hasArgument("m2:24","m2:25",0).
# term("m2:25").
# hasSerialization("m2:25","""m1A""").
# hasAnnotation("m2","m2:26").
# annotation("m2:26").
# hasName("m2:26","inherits").
# hasArgument("m2:26","m2:27",0).
# term("m2:27").
# hasSerialization("m2:27","""m1B""").
# hasAnnotation("m2","m2:28").
# annotation("m2:28").
# hasName("m2:28","inherits").
# hasArgument("m2:28","m2:29",0).
# term("m2:29").
# hasSerialization("m2:29","""m1C""").
# hasAnnotation("m2","m2:30").
# annotation("m2:30").
# hasName("m2:30","input").
# hasArgument("m2:30","m2:31",0).
# term("m2:31").
# hasSerialization("m2:31","""violatingInput""").
# hasAnnotation("m2","m2:32").
# annotation("m2:32").
# hasName("m2:32","bind").
# hasArgument("m2:32","m2:33",0).
# term("m2:33").
# hasSerialization("m2:33","""iRel1""").
# hasArgument("m2:32","m2:34",1).
# term("m2:34").
# hasSerialization("m2:34","""...m2""").
# hasAnnotation("m2","m2:35").
# annotation("m2:35").
# hasName("m2:35","no_additional_output").
# hasAnnotation("m2","m2:36").
# annotation("m2:36").
# hasName("m2:36","input").
# hasArgument("m2:36","m2:37",0).
# term("m2:37").
# hasSerialization("m2:37","""iRel1""").
# hasAnnotation("m2","m2:38").
# annotation("m2:38").
# hasName("m2:38","redefinesQ").
# hasArgument("m2:38","m2:39",0).
# term("m2:39").
# hasSerialization("m2:39","""R5""").
# hasArgument("m2:38","m2:40",1).
# term("m2:40").
# hasSerialization("m2:40","""R3""").
# hasArgument("m2:38","m2:41",2).
# term("m2:41").
# hasSerialization("m2:41","""m1B""").
# hasAnnotation("m2","m2:42").
# annotation("m2:42").
# hasName("m2:42","output").
# hasArgument("m2:42","m2:43",0).
# term("m2:43").
# hasSerialization("m2:43","""oRelE""").
# </textarea></div></div>

# %%
%%toMeta("m3").
@module("m3"). @inherits("m2").
@label("R6") oRelF(X,Y) :- iRel1(X), iRel2(X), iRel3(X,Y), iRel4(Y).
@removeQ("F1","m1C").
@output("oRelF").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m3").
# hasRule("m3","m3:0").
# rule("m3:0").
# hasPositiveHeadAtom("m3:0","m3:1").
# relationalAtom("m3:1").
# hasName("m3:1","oRelF").
# hasArgument("m3:1","m3:2",0).
# term("m3:2").
# hasSerialization("m3:2","X").
# hasArgument("m3:1","m3:3",1).
# term("m3:3").
# hasSerialization("m3:3","Y").
# hasPositiveBodyAtom("m3:0","m3:4").
# relationalAtom("m3:4").
# hasName("m3:4","iRel1").
# hasArgument("m3:4","m3:5",0).
# term("m3:5").
# hasSerialization("m3:5","X").
# hasPositiveBodyAtom("m3:0","m3:6").
# relationalAtom("m3:6").
# hasName("m3:6","iRel2").
# hasArgument("m3:6","m3:7",0).
# term("m3:7").
# hasSerialization("m3:7","X").
# hasPositiveBodyAtom("m3:0","m3:8").
# relationalAtom("m3:8").
# hasName("m3:8","iRel3").
# hasArgument("m3:8","m3:9",0).
# term("m3:9").
# hasSerialization("m3:9","X").
# hasArgument("m3:8","m3:10",1).
# term("m3:10").
# hasSerialization("m3:10","Y").
# hasPositiveBodyAtom("m3:0","m3:11").
# relationalAtom("m3:11").
# hasName("m3:11","iRel4").
# hasArgument("m3:11","m3:12",0).
# term("m3:12").
# hasSerialization("m3:12","Y").
# hasAnnotation("m3:0","m3:13").
# annotation("m3:13").
# hasName("m3:13","label").
# hasArgument("m3:13","m3:14",0).
# term("m3:14").
# hasSerialization("m3:14","""R6""").
# hasAnnotation("m3","m3:15").
# annotation("m3:15").
# hasName("m3:15","module").
# hasArgument("m3:15","m3:16",0).
# term("m3:16").
# hasSerialization("m3:16","""m3""").
# hasAnnotation("m3","m3:17").
# annotation("m3:17").
# hasName("m3:17","inherits").
# hasArgument("m3:17","m3:18",0).
# term("m3:18").
# hasSerialization("m3:18","""m2""").
# hasAnnotation("m3","m3:19").
# annotation("m3:19").
# hasName("m3:19","removeQ").
# hasArgument("m3:19","m3:20",0).
# term("m3:20").
# hasSerialization("m3:20","""F1""").
# hasArgument("m3:19","m3:21",1).
# term("m3:21").
# hasSerialization("m3:21","""m1C""").
# hasAnnotation("m3","m3:22").
# annotation("m3:22").
# hasName("m3:22","output").
# hasArgument("m3:22","m3:23",0).
# term("m3:23").
# hasSerialization("m3:23","""oRelF""").
# </textarea></div></div>

# %%
program("m").
hasRule("m","m:0").
rule("m:0").
hasPositiveHeadAtom("m:0","m:1").
relationalAtom("m:1").
hasName("m:1","oRelA").
hasArgument("m:1","m:2",0).
term("m:2").
hasSerialization("m:2","X").
hasPositiveBodyAtom("m:0","m:3").
relationalAtom("m:3").
hasName("m:3","iRel1").
hasArgument("m:3","m:4",0).
term("m:4").
hasSerialization("m:4","X").
hasPositiveBodyAtom("m:0","m:5").
relationalAtom("m:5").
hasName("m:5","f1").
hasArgument("m:5","m:6",0).
term("m:6").
hasSerialization("m:6","X").
hasRule("m","m:7").
rule("m:7").
hasPositiveHeadAtom("m:7","m:8").
relationalAtom("m:8").
hasName("m:8","oRelB").
hasArgument("m:8","m:9",0).
term("m:9").
hasSerialization("m:9","X").
hasPositiveBodyAtom("m:7","m:10").
relationalAtom("m:10").
hasName("m:10","iRel1").
hasArgument("m:10","m:11",0).
term("m:11").
hasSerialization("m:11","X").
hasPositiveBodyAtom("m:7","m:12").
relationalAtom("m:12").
hasName("m:12","f2").
hasArgument("m:12","m:13",0).
term("m:13").
hasSerialization("m:13","X").
hasAnnotation("m:7","m:14").
annotation("m:14").
hasName("m:14","label").
hasArgument("m:14","m:15",0).
term("m:15").
hasSerialization("m:15","""M-R2""").
hasFact("m","m:16").
relationalAtom("m:16").
hasName("m:16","iRel1").
hasArgument("m:16","m:17",0).
term("m:17").
hasSerialization("m:17","""l1""").
hasAnnotation("m:16","m:18").
annotation("m:18").
hasName("m:18","label").
hasArgument("m:18","m:19",0).
term("m:19").
hasSerialization("m:19","""iRel1""").
hasFact("m","m:20").
relationalAtom("m:20").
hasName("m:20","iRel1").
hasArgument("m:20","m:21",0).
term("m:21").
hasSerialization("m:21","""l2""").
hasAnnotation("m:20","m:22").
annotation("m:22").
hasName("m:22","label").
hasArgument("m:22","m:23",0).
term("m:23").
hasSerialization("m:23","""iRel1""").
hasFact("m","m:24").
relationalAtom("m:24").
hasName("m:24","f1").
hasArgument("m:24","m:25",0).
term("m:25").
hasSerialization("m:25","""l1""").
hasAnnotation("m","m:26").
annotation("m:26").
hasName("m:26","module").
hasArgument("m:26","m:27",0).
term("m:27").
hasSerialization("m:27","""m""").
hasAnnotation("m","m:28").
annotation("m:28").
hasName("m:28","non_omitable").
hasArgument("m:28","m:29",0).
term("m:29").
hasSerialization("m:29","""iRel1""").
hasAnnotation("m","m:30").
annotation("m:30").
hasName("m:30","non_redefinable").
hasArgument("m:30","m:31",0).
term("m:31").
hasSerialization("m:31","""iRel1""").
hasAnnotation("m","m:32").
annotation("m:32").
hasName("m:32","no_additional_annotation").
hasArgument("m:32","m:33",0).
term("m:33").
hasSerialization("m:33","""iRel1""").
hasArgument("m:32","m:34",1).
term("m:34").
hasSerialization("m:34","""bind""").
hasAnnotation("m","m:35").
annotation("m:35").
hasName("m:35","non_shrinkable").
hasArgument("m:35","m:36",0).
term("m:36").
hasSerialization("m:36","""oRelA""").
hasAnnotation("m","m:37").
annotation("m:37").
hasName("m:37","input").
hasArgument("m:37","m:38",0).
term("m:38").
hasSerialization("m:38","""iRel1""").
hasAnnotation("m","m:39").
annotation("m:39").
hasName("m:39","bind").
hasArgument("m:39","m:40",0).
term("m:40").
hasSerialization("m:40","""iRel1""").
hasArgument("m:39","m:41",1).
term("m:41").
hasSerialization("m:41","""...""").
hasAnnotation("m","m:42").
annotation("m:42").
hasName("m:42","output").
hasArgument("m:42","m:43",0).
term("m:43").
hasSerialization("m:43","""oRelA""").
hasAnnotation("m","m:44").
annotation("m:44").
hasName("m:44","post").
hasArgument("m:44","m:45",0).
term("m:45").
hasSerialization("m:45","""oRelA""").
hasArgument("m:44","m:46",1).
term("m:46").
hasSerialization("m:46","""orderby(1)""").
hasAnnotation("m","m:47").
annotation("m:47").
hasName("m:47","output").
hasArgument("m:47","m:48",0).
term("m:48").
hasSerialization("m:48","""oRelB""").
hasAnnotation("m","m:49").
annotation("m:49").
hasName("m:49","non_redefinable").
hasArgument("m:49","m:50",0).
term("m:50").
hasSerialization("m:50","""oRelB""").

program("m1A").
hasRule("m1A","m1A:0").
rule("m1A:0").
hasPositiveHeadAtom("m1A:0","m1A:1").
relationalAtom("m1A:1").
hasName("m1A:1","oRelC").
hasArgument("m1A:1","m1A:2",0).
term("m1A:2").
hasSerialization("m1A:2","X").
hasPositiveBodyAtom("m1A:0","m1A:3").
relationalAtom("m1A:3").
hasName("m1A:3","oRelA").
hasArgument("m1A:3","m1A:4",0).
term("m1A:4").
hasSerialization("m1A:4","X").
hasPositiveBodyAtom("m1A:0","m1A:5").
relationalAtom("m1A:5").
hasName("m1A:5","oRelB").
hasArgument("m1A:5","m1A:6",0).
term("m1A:6").
hasSerialization("m1A:6","X").
hasPositiveBodyAtom("m1A:0","m1A:7").
relationalAtom("m1A:7").
hasName("m1A:7","temp").
hasArgument("m1A:7","m1A:8",0).
term("m1A:8").
hasSerialization("m1A:8","X").
hasAnnotation("m1A:0","m1A:9").
annotation("m1A:9").
hasName("m1A:9","label").
hasArgument("m1A:9","m1A:10",0).
term("m1A:10").
hasSerialization("m1A:10","""R3""").
hasRule("m1A","m1A:11").
rule("m1A:11").
hasPositiveHeadAtom("m1A:11","m1A:12").
relationalAtom("m1A:12").
hasName("m1A:12","temp").
hasArgument("m1A:12","m1A:13",0).
term("m1A:13").
hasSerialization("m1A:13","T").
hasPositiveBodyAtom("m1A:11","m1A:14").
relationalAtom("m1A:14").
hasName("m1A:14","iRel2").
hasArgument("m1A:14","m1A:15",0).
term("m1A:15").
hasSerialization("m1A:15","T").
hasPositiveBodyAtom("m1A:11","m1A:16").
relationalAtom("m1A:16").
hasName("m1A:16","f1").
hasArgument("m1A:16","m1A:17",0).
term("m1A:17").
hasSerialization("m1A:17","T").
hasAnnotation("m1A:11","m1A:18").
annotation("m1A:18").
hasName("m1A:18","label").
hasArgument("m1A:18","m1A:19",0).
term("m1A:19").
hasSerialization("m1A:19","""R4""").
hasFact("m1A","m1A:20").
relationalAtom("m1A:20").
hasName("m1A:20","iRel2").
hasArgument("m1A:20","m1A:21",0).
term("m1A:21").
hasSerialization("m1A:21","""l1""").
hasFact("m1A","m1A:22").
relationalAtom("m1A:22").
hasName("m1A:22","f1").
hasArgument("m1A:22","m1A:23",0).
term("m1A:23").
hasSerialization("m1A:23","""l2""").
hasFact("m1A","m1A:24").
relationalAtom("m1A:24").
hasName("m1A:24","f2").
hasArgument("m1A:24","m1A:25",0).
term("m1A:25").
hasSerialization("m1A:25","""l1""").
hasAnnotation("m1A:24","m1A:26").
annotation("m1A:26").
hasName("m1A:26","label").
hasArgument("m1A:26","m1A:27",0).
term("m1A:27").
hasSerialization("m1A:27","""F1""").
hasAnnotation("m1A","m1A:28").
annotation("m1A:28").
hasName("m1A:28","module").
hasArgument("m1A:28","m1A:29",0).
term("m1A:29").
hasSerialization("m1A:29","""m1A""").
hasAnnotation("m1A","m1A:30").
annotation("m1A:30").
hasName("m1A:30","inherits").
hasArgument("m1A:30","m1A:31",0).
term("m1A:31").
hasSerialization("m1A:31","""m""").
hasAnnotation("m1A","m1A:32").
annotation("m1A:32").
hasName("m1A:32","non_growable").
hasArgument("m1A:32","m1A:33",0).
term("m1A:33").
hasSerialization("m1A:33","""oRelC""").
hasAnnotation("m1A","m1A:34").
annotation("m1A:34").
hasName("m1A:34","input").
hasArgument("m1A:34","m1A:35",0).
term("m1A:35").
hasSerialization("m1A:35","""iRel2""").
hasAnnotation("m1A","m1A:36").
annotation("m1A:36").
hasName("m1A:36","bind").
hasArgument("m1A:36","m1A:37",0).
term("m1A:37").
hasSerialization("m1A:37","""iRel2""").
hasArgument("m1A:36","m1A:38",1).
term("m1A:38").
hasSerialization("m1A:38","""...""").
hasAnnotation("m1A","m1A:39").
annotation("m1A:39").
hasName("m1A:39","bind").
hasArgument("m1A:39","m1A:40",0).
term("m1A:40").
hasSerialization("m1A:40","""iRel1""").
hasArgument("m1A:39","m1A:41",1).
term("m1A:41").
hasSerialization("m1A:41","""...m1A""").
hasAnnotation("m1A","m1A:42").
annotation("m1A:42").
hasName("m1A:42","remove").
hasArgument("m1A:42","m1A:43",0).
term("m1A:43").
hasSerialization("m1A:43","""iRel1""").
hasAnnotation("m1A","m1A:44").
annotation("m1A:44").
hasName("m1A:44","redefines").
hasArgument("m1A:44","m1A:45",0).
term("m1A:45").
hasSerialization("m1A:45","""R4""").
hasArgument("m1A:44","m1A:46",1).
term("m1A:46").
hasSerialization("m1A:46","""M-R2""").
hasAnnotation("m1A","m1A:47").
annotation("m1A:47").
hasName("m1A:47","output").
hasArgument("m1A:47","m1A:48",0).
term("m1A:48").
hasSerialization("m1A:48","""oRelC""").

program("m1B").
hasRule("m1B","m1B:0").
rule("m1B:0").
hasPositiveHeadAtom("m1B:0","m1B:1").
relationalAtom("m1B:1").
hasName("m1B:1","oRelD").
hasArgument("m1B:1","m1B:2",0).
term("m1B:2").
hasSerialization("m1B:2","X").
hasPositiveBodyAtom("m1B:0","m1B:3").
relationalAtom("m1B:3").
hasName("m1B:3","oRelA").
hasArgument("m1B:3","m1B:4",0).
term("m1B:4").
hasSerialization("m1B:4","X").
hasPositiveBodyAtom("m1B:0","m1B:5").
relationalAtom("m1B:5").
hasName("m1B:5","oRelB").
hasArgument("m1B:5","m1B:6",0).
term("m1B:6").
hasSerialization("m1B:6","X").
hasPositiveBodyAtom("m1B:0","m1B:7").
relationalAtom("m1B:7").
hasName("m1B:7","f3").
hasArgument("m1B:7","m1B:8",0).
term("m1B:8").
hasSerialization("m1B:8","X").
hasPositiveBodyAtom("m1B:0","m1B:9").
relationalAtom("m1B:9").
hasName("m1B:9","iRel4").
hasArgument("m1B:9","m1B:10",0).
term("m1B:10").
hasSerialization("m1B:10","X").
hasAnnotation("m1B:0","m1B:11").
annotation("m1B:11").
hasName("m1B:11","label").
hasArgument("m1B:11","m1B:12",0).
term("m1B:12").
hasSerialization("m1B:12","""R3""").
hasFact("m1B","m1B:13").
relationalAtom("m1B:13").
hasName("m1B:13","iRel4").
hasArgument("m1B:13","m1B:14",0).
term("m1B:14").
hasSerialization("m1B:14","""l1""").
hasFact("m1B","m1B:15").
relationalAtom("m1B:15").
hasName("m1B:15","iRel4").
hasArgument("m1B:15","m1B:16",0).
term("m1B:16").
hasSerialization("m1B:16","""l3""").
hasFact("m1B","m1B:17").
relationalAtom("m1B:17").
hasName("m1B:17","f3").
hasArgument("m1B:17","m1B:18",0).
term("m1B:18").
hasSerialization("m1B:18","""l2""").
hasFact("m1B","m1B:19").
relationalAtom("m1B:19").
hasName("m1B:19","f3").
hasArgument("m1B:19","m1B:20",0).
term("m1B:20").
hasSerialization("m1B:20","""l3""").
hasFact("m1B","m1B:21").
relationalAtom("m1B:21").
hasName("m1B:21","f3").
hasArgument("m1B:21","m1B:22",0).
term("m1B:22").
hasSerialization("m1B:22","""l1""").
hasAnnotation("m1B:21","m1B:23").
annotation("m1B:23").
hasName("m1B:23","label").
hasArgument("m1B:23","m1B:24",0).
term("m1B:24").
hasSerialization("m1B:24","""F1""").
hasAnnotation("m1B","m1B:25").
annotation("m1B:25").
hasName("m1B:25","module").
hasArgument("m1B:25","m1B:26",0).
term("m1B:26").
hasSerialization("m1B:26","""m1B""").
hasAnnotation("m1B","m1B:27").
annotation("m1B:27").
hasName("m1B:27","input").
hasArgument("m1B:27","m1B:28",0).
term("m1B:28").
hasSerialization("m1B:28","""iRel4""").
hasAnnotation("m1B","m1B:29").
annotation("m1B:29").
hasName("m1B:29","bind").
hasArgument("m1B:29","m1B:30",0).
term("m1B:30").
hasSerialization("m1B:30","""iRel4""").
hasArgument("m1B:29","m1B:31",1).
term("m1B:31").
hasSerialization("m1B:31","""...""").
hasAnnotation("m1B","m1B:32").
annotation("m1B:32").
hasName("m1B:32","output").
hasArgument("m1B:32","m1B:33",0).
term("m1B:33").
hasSerialization("m1B:33","""oRelD""").

program("m1C").
hasRule("m1C","m1C:0").
rule("m1C:0").
hasPositiveHeadAtom("m1C:0","m1C:1").
relationalAtom("m1C:1").
hasName("m1C:1","oRelC").
hasArgument("m1C:1","m1C:2",0).
term("m1C:2").
hasSerialization("m1C:2","X").
hasArgument("m1C:1","m1C:3",1).
term("m1C:3").
hasSerialization("m1C:3","Y").
hasPositiveBodyAtom("m1C:0","m1C:4").
relationalAtom("m1C:4").
hasName("m1C:4","iRel3").
hasArgument("m1C:4","m1C:5",0).
term("m1C:5").
hasSerialization("m1C:5","X").
hasArgument("m1C:4","m1C:6",1).
term("m1C:6").
hasSerialization("m1C:6","Y").
hasPositiveBodyAtom("m1C:0","m1C:7").
relationalAtom("m1C:7").
hasName("m1C:7","f1").
hasArgument("m1C:7","m1C:8",0).
term("m1C:8").
hasSerialization("m1C:8","Y").
hasAnnotation("m1C:0","m1C:9").
annotation("m1C:9").
hasName("m1C:9","label").
hasArgument("m1C:9","m1C:10",0).
term("m1C:10").
hasSerialization("m1C:10","""R3""").
hasFact("m1C","m1C:11").
relationalAtom("m1C:11").
hasName("m1C:11","iRel3").
hasArgument("m1C:11","m1C:12",0).
term("m1C:12").
hasSerialization("m1C:12","""l1""").
hasArgument("m1C:11","m1C:13",1).
term("m1C:13").
hasSerialization("m1C:13","""l1""").
hasFact("m1C","m1C:14").
relationalAtom("m1C:14").
hasName("m1C:14","iRel3").
hasArgument("m1C:14","m1C:15",0).
term("m1C:15").
hasSerialization("m1C:15","""l2""").
hasArgument("m1C:14","m1C:16",1).
term("m1C:16").
hasSerialization("m1C:16","""l3""").
hasAnnotation("m1C","m1C:17").
annotation("m1C:17").
hasName("m1C:17","module").
hasArgument("m1C:17","m1C:18",0).
term("m1C:18").
hasSerialization("m1C:18","""m1C""").
hasAnnotation("m1C","m1C:19").
annotation("m1C:19").
hasName("m1C:19","inherits").
hasArgument("m1C:19","m1C:20",0).
term("m1C:20").
hasSerialization("m1C:20","""m""").
hasAnnotation("m1C","m1C:21").
annotation("m1C:21").
hasName("m1C:21","no_additional_input").
hasAnnotation("m1C","m1C:22").
annotation("m1C:22").
hasName("m1C:22","input").
hasArgument("m1C:22","m1C:23",0).
term("m1C:23").
hasSerialization("m1C:23","""iRel3""").
hasAnnotation("m1C","m1C:24").
annotation("m1C:24").
hasName("m1C:24","bind").
hasArgument("m1C:24","m1C:25",0).
term("m1C:25").
hasSerialization("m1C:25","""iRel3""").
hasArgument("m1C:24","m1C:26",1).
term("m1C:26").
hasSerialization("m1C:26","""...""").
hasAnnotation("m1C","m1C:27").
annotation("m1C:27").
hasName("m1C:27","remove").
hasArgument("m1C:27","m1C:28",0).
term("m1C:28").
hasSerialization("m1C:28","""M-R2""").
hasAnnotation("m1C","m1C:29").
annotation("m1C:29").
hasName("m1C:29","output").
hasArgument("m1C:29","m1C:30",0).
term("m1C:30").
hasSerialization("m1C:30","""oRelC""").

program("m2").
hasRule("m2","m2:0").
rule("m2:0").
hasPositiveHeadAtom("m2:0","m2:1").
relationalAtom("m2:1").
hasName("m2:1","oRelE").
hasArgument("m2:1","m2:2",0).
term("m2:2").
hasSerialization("m2:2","X").
hasPositiveBodyAtom("m2:0","m2:3").
relationalAtom("m2:3").
hasName("m2:3","f1").
hasArgument("m2:3","m2:4",0).
term("m2:4").
hasSerialization("m2:4","X").
hasPositiveBodyAtom("m2:0","m2:5").
relationalAtom("m2:5").
hasName("m2:5","f2").
hasArgument("m2:5","m2:6",0).
term("m2:6").
hasSerialization("m2:6","A").
hasPositiveBodyAtom("m2:0","m2:7").
relationalAtom("m2:7").
hasName("m2:7","f3").
hasArgument("m2:7","m2:8",0).
term("m2:8").
hasSerialization("m2:8","X").
hasPositiveBodyAtom("m2:0","m2:9").
relationalAtom("m2:9").
hasName("m2:9","iRel1").
hasArgument("m2:9","m2:10",0).
term("m2:10").
hasSerialization("m2:10","X").
hasPositiveBodyAtom("m2:0","m2:11").
relationalAtom("m2:11").
hasName("m2:11","iRel3").
hasArgument("m2:11","m2:12",0).
term("m2:12").
hasSerialization("m2:12","A").
hasArgument("m2:11","m2:13",1).
term("m2:13").
hasSerialization("m2:13","X").
hasAnnotation("m2:0","m2:14").
annotation("m2:14").
hasName("m2:14","label").
hasArgument("m2:14","m2:15",0).
term("m2:15").
hasSerialization("m2:15","""R5""").
hasFact("m2","m2:16").
relationalAtom("m2:16").
hasName("m2:16","f1").
hasArgument("m2:16","m2:17",0).
term("m2:17").
hasSerialization("m2:17","""l3""").
hasFact("m2","m2:18").
relationalAtom("m2:18").
hasName("m2:18","f2").
hasArgument("m2:18","m2:19",0).
term("m2:19").
hasSerialization("m2:19","""l3""").
hasFact("m2","m2:20").
relationalAtom("m2:20").
hasName("m2:20","f2").
hasArgument("m2:20","m2:21",0).
term("m2:21").
hasSerialization("m2:21","""f1""").
hasAnnotation("m2","m2:22").
annotation("m2:22").
hasName("m2:22","module").
hasArgument("m2:22","m2:23",0).
term("m2:23").
hasSerialization("m2:23","""m2""").
hasAnnotation("m2","m2:24").
annotation("m2:24").
hasName("m2:24","inherits").
hasArgument("m2:24","m2:25",0).
term("m2:25").
hasSerialization("m2:25","""m1A""").
hasAnnotation("m2","m2:26").
annotation("m2:26").
hasName("m2:26","inherits").
hasArgument("m2:26","m2:27",0).
term("m2:27").
hasSerialization("m2:27","""m1B""").
hasAnnotation("m2","m2:28").
annotation("m2:28").
hasName("m2:28","inherits").
hasArgument("m2:28","m2:29",0).
term("m2:29").
hasSerialization("m2:29","""m1C""").
hasAnnotation("m2","m2:30").
annotation("m2:30").
hasName("m2:30","input").
hasArgument("m2:30","m2:31",0).
term("m2:31").
hasSerialization("m2:31","""violatingInput""").
hasAnnotation("m2","m2:32").
annotation("m2:32").
hasName("m2:32","bind").
hasArgument("m2:32","m2:33",0).
term("m2:33").
hasSerialization("m2:33","""iRel1""").
hasArgument("m2:32","m2:34",1).
term("m2:34").
hasSerialization("m2:34","""...m2""").
hasAnnotation("m2","m2:35").
annotation("m2:35").
hasName("m2:35","no_additional_output").
hasAnnotation("m2","m2:36").
annotation("m2:36").
hasName("m2:36","input").
hasArgument("m2:36","m2:37",0).
term("m2:37").
hasSerialization("m2:37","""iRel1""").
hasAnnotation("m2","m2:38").
annotation("m2:38").
hasName("m2:38","redefinesQ").
hasArgument("m2:38","m2:39",0).
term("m2:39").
hasSerialization("m2:39","""R5""").
hasArgument("m2:38","m2:40",1).
term("m2:40").
hasSerialization("m2:40","""R3""").
hasArgument("m2:38","m2:41",2).
term("m2:41").
hasSerialization("m2:41","""m1B""").
hasAnnotation("m2","m2:42").
annotation("m2:42").
hasName("m2:42","output").
hasArgument("m2:42","m2:43",0).
term("m2:43").
hasSerialization("m2:43","""oRelE""").

program("m3").
hasRule("m3","m3:0").
rule("m3:0").
hasPositiveHeadAtom("m3:0","m3:1").
relationalAtom("m3:1").
hasName("m3:1","oRelF").
hasArgument("m3:1","m3:2",0).
term("m3:2").
hasSerialization("m3:2","X").
hasArgument("m3:1","m3:3",1).
term("m3:3").
hasSerialization("m3:3","Y").
hasPositiveBodyAtom("m3:0","m3:4").
relationalAtom("m3:4").
hasName("m3:4","iRel1").
hasArgument("m3:4","m3:5",0).
term("m3:5").
hasSerialization("m3:5","X").
hasPositiveBodyAtom("m3:0","m3:6").
relationalAtom("m3:6").
hasName("m3:6","iRel2").
hasArgument("m3:6","m3:7",0).
term("m3:7").
hasSerialization("m3:7","X").
hasPositiveBodyAtom("m3:0","m3:8").
relationalAtom("m3:8").
hasName("m3:8","iRel3").
hasArgument("m3:8","m3:9",0).
term("m3:9").
hasSerialization("m3:9","X").
hasArgument("m3:8","m3:10",1).
term("m3:10").
hasSerialization("m3:10","Y").
hasPositiveBodyAtom("m3:0","m3:11").
relationalAtom("m3:11").
hasName("m3:11","iRel4").
hasArgument("m3:11","m3:12",0).
term("m3:12").
hasSerialization("m3:12","Y").
hasAnnotation("m3:0","m3:13").
annotation("m3:13").
hasName("m3:13","label").
hasArgument("m3:13","m3:14",0).
term("m3:14").
hasSerialization("m3:14","""R6""").
hasAnnotation("m3","m3:15").
annotation("m3:15").
hasName("m3:15","module").
hasArgument("m3:15","m3:16",0).
term("m3:16").
hasSerialization("m3:16","""m3""").
hasAnnotation("m3","m3:17").
annotation("m3:17").
hasName("m3:17","inherits").
hasArgument("m3:17","m3:18",0).
term("m3:18").
hasSerialization("m3:18","""m2""").
hasAnnotation("m3","m3:19").
annotation("m3:19").
hasName("m3:19","removeQ").
hasArgument("m3:19","m3:20",0).
term("m3:20").
hasSerialization("m3:20","""F1""").
hasArgument("m3:19","m3:21",1).
term("m3:21").
hasSerialization("m3:21","""m1C""").
hasAnnotation("m3","m3:22").
annotation("m3:22").
hasName("m3:22","output").
hasArgument("m3:22","m3:23",0).
term("m3:23").
hasSerialization("m3:23","""oRelF""").

true(#T). false(#F).

% Find module labels for module IDs
moduleLbl(M,L) :- hasAnnotation(M,A), hasName(A,"module"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
resultset(S,M) :- hasAnnotation(S,A), hasName(A,"resultset"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), M = substring(L1,1,string_length(L1)-1).

% Find Id of module to be derived
deriveModule(M) :- toDerive(L), moduleLbl(M,L).

% Determine inheritance relationships in provided meta-representations
inherits(MC,MP) :- hasAnnotation(MC,A), hasName(A,"inherits"), hasArgument(A,Arg,0), hasSerialization(Arg,MP1), moduleLbl(MP,MPL), MPL = substring(MP1,1,string_length(MP1)-1).
tInherits(M,M2) :- inherits(M,M2).
tInherits(M,M2) :- tInherits(M,M1), inherits(M1,M2).

% Predicates in a module
predicate(M,P) :- inputPredicate(M,P).
predicate(M,P) :- outputPredicate(M,P).
predicate(M,P) :- tHasFact(M,F), relationalAtom(F), hasName(F,P).
predicate(M,P) :- mHasRule(M,R), ruleHeadPredicate(R,P).
predicate(M,P) :- mHasRule(M,R), ruleBodyPredicate(R,P).

inputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"input"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"output"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

% Defined restrictions and modification operations
restriction("no_additional_input").
restriction("no_additional_output").
restriction("no_additional_annotation").
restriction("non_omitable").
restriction("non_redefinable").
restriction("non_shrinkable").
restriction("non_growable").
modOp("remove"). modOp("removeQ").
modOp("redefines"). modOp("redefinesQ").
modOp("inherits").

% Inheritance Annotations
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), restriction(N).
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), modOp(N).

% Which statements exist in a module?
hasStmt(M,S) :- hasRule(M,S).
hasStmt(M,S) :- hasFact(M,S).
hasStmt(M,S) :- moduleLbl(M,_), hasAnnotation(M,S).

% Only labeled statements are interesting, others always propagated
stmtLbl(R,L) :- hasRule(M,R), hasAnnotation(R,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(F,L) :- hasFact(M,F), hasAnnotation(F,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(A,L) :- hasAnnotation(M,A), hasAnnotation(A,A2), hasName(A2,"label"), hasArgument(A2,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtML(M,S,L) :- stmtLbl(S,L), hasStmt(M,S).

% Atoms in a rule
hasAtom(R,A):- hasNegativeBodyAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasPositiveBodyAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasNegativeHeadAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasPositiveHeadAtom(R,A), relationalAtom(A).

ruleBodyPredicate(R,P):- tHasRule(M,R), hasNegativeBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleBodyPredicate(R,P):- tHasRule(M,R), hasPositiveBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- tHasRule(M,R), hasNegativeHeadAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- tHasRule(M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P).
predicateDependency(M,P,P2) :- tHasRule(M,R), ruleHeadPredicate(R,P), ruleBodyPredicate(R,P2).

% RESOLVE INHERITANCE
% Unqualified remove and redefine
redefineStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"redefines"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), L = substring(L1,1,string_length(L1)-1).
removeStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"remove"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), L = substring(L1,1,string_length(L1)-1).
% Any statement except inheritance annotations can be removed
redefineStmt(M,S):- redefineStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).
removeStmt(M,S):- removeStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).

% Qualified remove and redefine
redefineStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"redefinesQ"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), hasArgument(A,Arg3,2), hasSerialization(Arg3,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
removeStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"removeQ"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
redefineStmt(M,S) :- redefineStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).
removeStmt(M,S) :- removeStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).

% Module name annotations are not inherited
removeStmt(M,A) :- hasAnnotation(M,A), hasName(A,"module"), not deriveModule(M).

% Modification operation statements
modOpStmt(M,S) :- removeStmt(M,S).
modOpStmt(M,S) :- redefineStmt(M,S).
tModOpStmt(M,M,S) :- modOpStmt(M,S).
tModOpStmt(M,Morg,S) :- inherits(M,M2), tModOpStmt(M2,Morg,S).

% DETERMINE ACTIVE STATEMENTS AND MODULE/STATEMENT ANNOTATIONS FOR MODULES
% Derive for each module its active rules by inheriting
tHasRule(M,R) :- hasRule(M,R).
tHasRule(M,R) :- inherits(M,MP), tHasRule(MP,R).
moduleStmt(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).
mHasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).

% Determine for each module its active facts by inheriting
tHasFact(M,F) :- hasFact(M,F).
tHasFact(M,F) :- inherits(M,MP), tHasFact(MP,F).
moduleStmt(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F).

% Determine for each module its active module and statement annotations
tHasAnnotationM(M,A) :- moduleLbl(M,L), hasAnnotation(M,A), hasName(A,N), not modOp(N).
tHasAnnotationM(M,A) :- inherits(M,MP), tHasAnnotationM(MP,A).
tHasAnnotationS(M,Stmt,A) :- hasStmt(M,Stmt), hasAnnotation(Stmt,A).
tHasAnnotationS(M,Stmt,A) :- inherits(M,MP), tHasAnnotationS(MP,Stmt,A).
moduleStmt(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A).

% Determine Restrictions defined in modules
noAdditionalInput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_input").
noAdditionalOutput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_output").
noAdditionalAnnotation(M,ANN,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_annotation"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), P = substring(L1,1,string_length(L1)-1), ANN = substring(L2,1,string_length(L2)-1).
nonOmitable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_omitable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonRedefinable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_redefinable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonGrowable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_growable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P  =substring(L1,1,string_length(L1)-1).
nonShrinkable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_shrinkable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).

% ------------------------------------------------------------------------
% STRUCTURAL RESTRICTIONS
% ------------------------------------------------------------------------
predicateAnnotation(M,"bind",P,ARG):- hasAnnotation(M,A), hasName(A,"bind"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), P = substring(L1,1,string_length(L1)-1), ARG = substring(L2,1,string_length(L2)-1).

% Warning about violated restrictions
w_noAdditionalInput(M2,P0) :- noAdditionalInput(M), inherits(M2,M), inputPredicate(M2,P2), not inputPredicate(M,P2), P0 = P2.
w_noAdditionalOutput(M2,P0) :- noAdditionalOutput(M), inherits(M2,M), outputPredicate(M2,P2), not outputPredicate(M,P2), P0 = P2.
w_noAdditionalAnnotation(M2,ANN,P0) :- noAdditionalAnnotation(M,ANN,P), inherits(M2,M), predicateAnnotation(M2,ANN,P2,ARG), predicateAnnotation(M,ANN,P,ARG2), P = P2,ARG != ARG2, P0 = P2. % if several binds exist this always reports a warning!
w_nonOmitable(M2,P0) :- nonOmitable(M,P), inherits(M2,M), not outputPredicate(M2,P), not inputPredicate(M2,P), P0 = P.
w_nonRedefinable(M2,P0) :- nonRedefinable(M,P), inherits(M2,M), not outputPredicate(M2,P), not inputPredicate(M2,P), P0 = P.

@output("w_noAdditionalInput").
@output("w_noAdditionalOutput").
@output("w_noAdditionalAnnotation").
@output("w_nonOmitable").
@output("w_nonRedefinable").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">w_noAdditionalAnnotation</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m1A</td><td>bind</td><td>iRel1</td></tr></tbody><tbody><tr><td>m2</td><td>bind</td><td>iRel1</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">w_noAdditionalOutput</caption><thead><tr><th>string</th><th>string</th></tr></thead><tbody><tr><td>m3</td><td>oRelF</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">w_noAdditionalInput</caption><thead><tr><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>violatingInput</td></tr></tbody><tbody><tr><td>m2</td><td>iRel2</td></tr></tbody><tbody><tr><td>m2</td><td>iRel4</td></tr></tbody></table></div></div></div>

# %% [markdown]
# **Expected Results**
# * m1A: `bind(iRel1,...)` [`non_omitable(iRel1)` - cannot be tested yet]
# * m2: `input(violatingInput)`, `bind(iRel1)`
# * m3: `output(oRelF)`

# %% [markdown]
# # Behavioral Restrictions
# ## Dynamic Detection

# %%
%%toMeta("rs2")
@resultset("m2").
oRelA("X").
%oRelA("Z").
oRelB("X","B").
oRelA("Y").
oRelB("Z","A").
%oRelB("Z","C").
oRelC("Z").
%oRelTest("test").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("rs2").
# hasFact("rs2","rs2:0").
# relationalAtom("rs2:0").
# hasName("rs2:0","oRelA").
# hasArgument("rs2:0","rs2:1",0).
# term("rs2:1").
# hasSerialization("rs2:1","""X""").
# hasFact("rs2","rs2:2").
# relationalAtom("rs2:2").
# hasName("rs2:2","oRelB").
# hasArgument("rs2:2","rs2:3",0).
# term("rs2:3").
# hasSerialization("rs2:3","""X""").
# hasArgument("rs2:2","rs2:4",1).
# term("rs2:4").
# hasSerialization("rs2:4","""B""").
# hasFact("rs2","rs2:5").
# relationalAtom("rs2:5").
# hasName("rs2:5","oRelA").
# hasArgument("rs2:5","rs2:6",0).
# term("rs2:6").
# hasSerialization("rs2:6","""Y""").
# hasFact("rs2","rs2:7").
# relationalAtom("rs2:7").
# hasName("rs2:7","oRelB").
# hasArgument("rs2:7","rs2:8",0).
# term("rs2:8").
# hasSerialization("rs2:8","""Z""").
# hasArgument("rs2:7","rs2:9",1).
# term("rs2:9").
# hasSerialization("rs2:9","""A""").
# hasFact("rs2","rs2:10").
# relationalAtom("rs2:10").
# hasName("rs2:10","oRelC").
# hasArgument("rs2:10","rs2:11",0).
# term("rs2:11").
# hasSerialization("rs2:11","""Z""").
# hasAnnotation("rs2","rs2:12").
# annotation("rs2:12").
# hasName("rs2:12","resultset").
# hasArgument("rs2:12","rs2:13",0).
# term("rs2:13").
# hasSerialization("rs2:13","""m2""").
# </textarea></div></div>

# %%
program("rs1").
hasFact("rs1","rs1:0").
relationalAtom("rs1:0").
hasName("rs1:0","oRelA").
hasArgument("rs1:0","rs1:1",0).
term("rs1:1").
hasSerialization("rs1:1","""X""").
hasFact("rs1","rs1:2").
relationalAtom("rs1:2").
hasName("rs1:2","oRelB").
hasArgument("rs1:2","rs1:3",0).
term("rs1:3").
hasSerialization("rs1:3","""X""").
hasArgument("rs1:2","rs1:4",1).
term("rs1:4").
hasSerialization("rs1:4","""B""").
hasFact("rs1","rs1:5").
relationalAtom("rs1:5").
hasName("rs1:5","oRelA").
hasArgument("rs1:5","rs1:6",0).
term("rs1:6").
hasSerialization("rs1:6","""Y""").
hasFact("rs1","rs1:7").
relationalAtom("rs1:7").
hasName("rs1:7","oRelB").
hasArgument("rs1:7","rs1:8",0).
term("rs1:8").
hasSerialization("rs1:8","""Z""").
hasArgument("rs1:7","rs1:9",1).
term("rs1:9").
hasSerialization("rs1:9","""A""").
hasFact("rs1","rs1:10").
relationalAtom("rs1:10").
hasName("rs1:10","oRelC").
hasArgument("rs1:10","rs1:11",0).
term("rs1:11").
hasSerialization("rs1:11","""Z""").
hasAnnotation("rs1","rs1:12").
annotation("rs1:12").
hasName("rs1:12","resultset").
hasArgument("rs1:12","rs1:13",0).
term("rs1:13").
hasSerialization("rs1:13","""m1A""").

program("rs2").
hasFact("rs2","rs2:0").
relationalAtom("rs2:0").
hasName("rs2:0","oRelA").
hasArgument("rs2:0","rs2:1",0).
term("rs2:1").
hasSerialization("rs2:1","""X""").
hasFact("rs2","rs2:2").
relationalAtom("rs2:2").
hasName("rs2:2","oRelB").
hasArgument("rs2:2","rs2:3",0).
term("rs2:3").
hasSerialization("rs2:3","""X""").
hasArgument("rs2:2","rs2:4",1).
term("rs2:4").
hasSerialization("rs2:4","""B""").
hasFact("rs2","rs2:5").
relationalAtom("rs2:5").
hasName("rs2:5","oRelA").
hasArgument("rs2:5","rs2:6",0).
term("rs2:6").
hasSerialization("rs2:6","""Y""").
hasFact("rs2","rs2:7").
relationalAtom("rs2:7").
hasName("rs2:7","oRelA").
hasArgument("rs2:7","rs2:8",0).
term("rs2:8").
hasSerialization("rs2:8","""Y2""").
hasFact("rs2","rs2:10").
relationalAtom("rs2:10").
hasName("rs2:10","testing").
hasArgument("rs2:10","rs2:11",0).
term("rs2:11").
hasSerialization("rs2:11","""Z""").
hasAnnotation("rs2","rs2:12").
annotation("rs2:12").
hasName("rs2:12","resultset").
hasArgument("rs2:12","rs2:13",0).
term("rs2:13").
hasSerialization("rs2:13","""m2""").

hasFact("rs2","rs2:14").
relationalAtom("rs2:14").
hasName("rs2:14","oRelC").
hasArgument("rs2:14","rs2:15",0).
term("rs2:15").
hasSerialization("rs2:15","""test""").


tInherits("m2","m1A").
moduleLbl("m2","").
moduleLbl("m1A","").
outputPredicates("m1A","testing").

% ------------------------------------------------------------------------
% BEHAVIORAL MODIFICATION DETECTION
% ------------------------------------------------------------------------
%requires resultsets where an annotation @resultset("<module>") is required where <module> is the module generating the resultset
resultset(RS,M) :- hasAnnotation(RS,A), hasName(A,"resultset"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), M = substring(L1,1,string_length(L1)-1).
factPredicate(M,F,PRED,CONST,POS) :- resultset(M,_), hasFact(M,F), relationalAtom(F), hasName(F,PRED), hasArgument(F,Arg,POS), term(Arg), hasSerialization(Arg,L), CONST = substring(L,1,string_length(L)-1).

factsGrown(C,P,PRED) :- moduleLbl(C,_), moduleLbl(P,_), resultset(RS1,C), resultset(RS2,P), tInherits(C,P), factPredicate(RS1,_,PRED,ARG,POS), not factPredicate(RS2,_,PRED,ARG,POS), factPredicate(RS2,_,PRED,_,_).
factsGrown(C,P,PRED) :- moduleLbl(C,_), moduleLbl(P,_), resultset(RS1,C), resultset(RS2,P), tInherits(C,P), outputPredicates(P,PRED), factPredicate(RS1,_,PRED,ARG,POS), not factPredicate(RS2,_,PRED,ARG,POS), factPredicate(RS2,_,PRED,_,_).
factsShrunk(C,P,PRED) :- moduleLbl(C,_), moduleLbl(P,_), resultset(RS1,C), resultset(RS2,P), tInherits(C,P), factPredicate(RS2,_,PRED,ARG,POS), not factPredicate(RS1,_,PRED,ARG,POS).
factsModified(C,P) :- factsGrown(C,P,_), factsShrunk(C,P,_).
factsIdentical(C,P) :- resultset(_,C), resultset(_,P), tInherits(C,P), moduleLbl(C,_), moduleLbl(P,_), not factsGrown(C,P,_), not factsShrunk(C,P,_).

@output("factsGrown"). @ouput("factsGrown","orderby(1,2,3").
@output("factsShrunk"). @ouput("factsShrunk","orderby(1,2,3)").
@output("factsModified"). @ouput("factsModified","orderby(1,2)").
@output("factsIdentical"). @ouput("factsIdentical","orderby(1,2)").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">factsModified</caption><thead><tr><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>m1A</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">factsGrown</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>m1A</td><td>oRelA</td></tr></tbody><tbody><tr><td>m2</td><td>m1A</td><td>oRelC</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">factsShrunk</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>m1A</td><td>oRelB</td></tr></tbody><tbody><tr><td>m2</td><td>m1A</td><td>oRelC</td></tr></tbody></table></div></div></div>

# %% [markdown]
# **Expected:** `testing` predicate added
# + oRelC, oRelA
# - oRelC, oRelB

# %% [markdown]
# ## Conformance

# %%
toDerive("m3").

program("m").
hasRule("m","m:0").
rule("m:0").
hasPositiveHeadAtom("m:0","m:1").
relationalAtom("m:1").
hasName("m:1","oRelA").
hasArgument("m:1","m:2",0).
term("m:2").
hasSerialization("m:2","X").
hasPositiveBodyAtom("m:0","m:3").
relationalAtom("m:3").
hasName("m:3","iRel1").
hasArgument("m:3","m:4",0).
term("m:4").
hasSerialization("m:4","X").
hasPositiveBodyAtom("m:0","m:5").
relationalAtom("m:5").
hasName("m:5","f1").
hasArgument("m:5","m:6",0).
term("m:6").
hasSerialization("m:6","X").
hasRule("m","m:7").
rule("m:7").
hasPositiveHeadAtom("m:7","m:8").
relationalAtom("m:8").
hasName("m:8","oRelB").
hasArgument("m:8","m:9",0).
term("m:9").
hasSerialization("m:9","X").
hasPositiveBodyAtom("m:7","m:10").
relationalAtom("m:10").
hasName("m:10","iRel1").
hasArgument("m:10","m:11",0).
term("m:11").
hasSerialization("m:11","X").
hasPositiveBodyAtom("m:7","m:12").
relationalAtom("m:12").
hasName("m:12","f2").
hasArgument("m:12","m:13",0).
term("m:13").
hasSerialization("m:13","X").
hasAnnotation("m:7","m:14").
annotation("m:14").
hasName("m:14","label").
hasArgument("m:14","m:15",0).
term("m:15").
hasSerialization("m:15","""M-R2""").
hasFact("m","m:16").
relationalAtom("m:16").
hasName("m:16","iRel1").
hasArgument("m:16","m:17",0).
term("m:17").
hasSerialization("m:17","""l1""").
hasAnnotation("m:16","m:18").
annotation("m:18").
hasName("m:18","label").
hasArgument("m:18","m:19",0).
term("m:19").
hasSerialization("m:19","""iRel1""").
hasFact("m","m:20").
relationalAtom("m:20").
hasName("m:20","iRel1").
hasArgument("m:20","m:21",0).
term("m:21").
hasSerialization("m:21","""l2""").
hasAnnotation("m:20","m:22").
annotation("m:22").
hasName("m:22","label").
hasArgument("m:22","m:23",0).
term("m:23").
hasSerialization("m:23","""iRel1""").
hasFact("m","m:24").
relationalAtom("m:24").
hasName("m:24","f1").
hasArgument("m:24","m:25",0).
term("m:25").
hasSerialization("m:25","""l1""").
hasAnnotation("m","m:26").
annotation("m:26").
hasName("m:26","module").
hasArgument("m:26","m:27",0).
term("m:27").
hasSerialization("m:27","""m""").
hasAnnotation("m","m:28").
annotation("m:28").
hasName("m:28","non_omitable").
hasArgument("m:28","m:29",0).
term("m:29").
hasSerialization("m:29","""iRel1""").
hasAnnotation("m","m:30").
annotation("m:30").
hasName("m:30","non_extensible_predicate").
hasArgument("m:30","m:31",0).
term("m:31").
hasSerialization("m:31","""iRel1""").
hasArgument("m:30","m:32",1).
term("m:32").
hasSerialization("m:32","""bind""").
hasAnnotation("m","m:33").
annotation("m:33").
hasName("m:33","non_shrinkable").
hasArgument("m:33","m:34",0).
term("m:34").
hasSerialization("m:34","""oRelA""").
hasAnnotation("m","m:35").
annotation("m:35").
hasName("m:35","input").
hasArgument("m:35","m:36",0).
term("m:36").
hasSerialization("m:36","""iRel1""").
hasAnnotation("m","m:37").
annotation("m:37").
hasName("m:37","bind").
hasArgument("m:37","m:38",0).
term("m:38").
hasSerialization("m:38","""iRel1""").
hasArgument("m:37","m:39",1).
term("m:39").
hasSerialization("m:39","""...""").
hasAnnotation("m","m:40").
annotation("m:40").
hasName("m:40","output").
hasArgument("m:40","m:41",0).
term("m:41").
hasSerialization("m:41","""oRelA""").
hasAnnotation("m","m:42").
annotation("m:42").
hasName("m:42","post").
hasArgument("m:42","m:43",0).
term("m:43").
hasSerialization("m:43","""oRelA""").
hasArgument("m:42","m:44",1).
term("m:44").
hasSerialization("m:44","""orderby(1)""").
hasAnnotation("m","m:45").
annotation("m:45").
hasName("m:45","output").
hasArgument("m:45","m:46",0).
term("m:46").
hasSerialization("m:46","""oRelB""").
hasAnnotation("m","m:47").
annotation("m:47").
hasName("m:47","non_shrinkable").
hasArgument("m:47","m:48",0).
term("m:48").
hasSerialization("m:48","""oRelB""").


program("m1A").
hasRule("m1A","m1A:0").
rule("m1A:0").
hasPositiveHeadAtom("m1A:0","m1A:1").
relationalAtom("m1A:1").
hasName("m1A:1","oRelC").
hasArgument("m1A:1","m1A:2",0).
term("m1A:2").
hasSerialization("m1A:2","X").
hasPositiveBodyAtom("m1A:0","m1A:3").
relationalAtom("m1A:3").
hasName("m1A:3","oRelA").
hasArgument("m1A:3","m1A:4",0).
term("m1A:4").
hasSerialization("m1A:4","X").
hasPositiveBodyAtom("m1A:0","m1A:5").
relationalAtom("m1A:5").
hasName("m1A:5","oRelB").
hasArgument("m1A:5","m1A:6",0).
term("m1A:6").
hasSerialization("m1A:6","X").
hasPositiveBodyAtom("m1A:0","m1A:7").
relationalAtom("m1A:7").
hasName("m1A:7","temp").
hasArgument("m1A:7","m1A:8",0).
term("m1A:8").
hasSerialization("m1A:8","X").
hasAnnotation("m1A:0","m1A:9").
annotation("m1A:9").
hasName("m1A:9","label").
hasArgument("m1A:9","m1A:10",0).
term("m1A:10").
hasSerialization("m1A:10","""R3""").
hasRule("m1A","m1A:11").
rule("m1A:11").
hasPositiveHeadAtom("m1A:11","m1A:12").
relationalAtom("m1A:12").
hasName("m1A:12","temp").
hasArgument("m1A:12","m1A:13",0).
term("m1A:13").
hasSerialization("m1A:13","T").
hasPositiveBodyAtom("m1A:11","m1A:14").
relationalAtom("m1A:14").
hasName("m1A:14","iRel2").
hasArgument("m1A:14","m1A:15",0).
term("m1A:15").
hasSerialization("m1A:15","T").
hasPositiveBodyAtom("m1A:11","m1A:16").
relationalAtom("m1A:16").
hasName("m1A:16","f1").
hasArgument("m1A:16","m1A:17",0).
term("m1A:17").
hasSerialization("m1A:17","T").
hasAnnotation("m1A:11","m1A:18").
annotation("m1A:18").
hasName("m1A:18","label").
hasArgument("m1A:18","m1A:19",0).
term("m1A:19").
hasSerialization("m1A:19","""R4""").
hasFact("m1A","m1A:20").
relationalAtom("m1A:20").
hasName("m1A:20","iRel2").
hasArgument("m1A:20","m1A:21",0).
term("m1A:21").
hasSerialization("m1A:21","""l1""").
hasFact("m1A","m1A:22").
relationalAtom("m1A:22").
hasName("m1A:22","f1").
hasArgument("m1A:22","m1A:23",0).
term("m1A:23").
hasSerialization("m1A:23","""l2""").
hasFact("m1A","m1A:24").
relationalAtom("m1A:24").
hasName("m1A:24","f2").
hasArgument("m1A:24","m1A:25",0).
term("m1A:25").
hasSerialization("m1A:25","""l1""").
hasAnnotation("m1A:24","m1A:26").
annotation("m1A:26").
hasName("m1A:26","label").
hasArgument("m1A:26","m1A:27",0).
term("m1A:27").
hasSerialization("m1A:27","""F1""").
hasAnnotation("m1A","m1A:28").
annotation("m1A:28").
hasName("m1A:28","module").
hasArgument("m1A:28","m1A:29",0).
term("m1A:29").
hasSerialization("m1A:29","""m1A""").
hasAnnotation("m1A","m1A:30").
annotation("m1A:30").
hasName("m1A:30","inherits").
hasArgument("m1A:30","m1A:31",0).
term("m1A:31").
hasSerialization("m1A:31","""m""").
hasAnnotation("m1A","m1A:32").
annotation("m1A:32").
hasName("m1A:32","non_growable").
hasArgument("m1A:32","m1A:33",0).
term("m1A:33").
hasSerialization("m1A:33","""oRelC""").
hasAnnotation("m1A","m1A:34").
annotation("m1A:34").
hasName("m1A:34","input").
hasArgument("m1A:34","m1A:35",0).
term("m1A:35").
hasSerialization("m1A:35","""iRel2""").
hasAnnotation("m1A","m1A:36").
annotation("m1A:36").
hasName("m1A:36","bind").
hasArgument("m1A:36","m1A:37",0).
term("m1A:37").
hasSerialization("m1A:37","""iRel2""").
hasArgument("m1A:36","m1A:38",1).
term("m1A:38").
hasSerialization("m1A:38","""...""").
hasAnnotation("m1A","m1A:39").
annotation("m1A:39").
hasName("m1A:39","bind").
hasArgument("m1A:39","m1A:40",0).
term("m1A:40").
hasSerialization("m1A:40","""iRel1""").
hasArgument("m1A:39","m1A:41",1).
term("m1A:41").
hasSerialization("m1A:41","""...m1A""").
hasAnnotation("m1A","m1A:42").
annotation("m1A:42").
hasName("m1A:42","remove").
hasArgument("m1A:42","m1A:43",0).
term("m1A:43").
hasSerialization("m1A:43","""iRel1""").
hasAnnotation("m1A","m1A:44").
annotation("m1A:44").
hasName("m1A:44","redefines").
hasArgument("m1A:44","m1A:45",0).
term("m1A:45").
hasSerialization("m1A:45","""R4""").
hasArgument("m1A:44","m1A:46",1).
term("m1A:46").
hasSerialization("m1A:46","""M-R2""").
hasAnnotation("m1A","m1A:47").
annotation("m1A:47").
hasName("m1A:47","output").
hasArgument("m1A:47","m1A:48",0).
term("m1A:48").
hasSerialization("m1A:48","""oRelC""").

program("m1B").
hasRule("m1B","m1B:0").
rule("m1B:0").
hasPositiveHeadAtom("m1B:0","m1B:1").
relationalAtom("m1B:1").
hasName("m1B:1","oRelD").
hasArgument("m1B:1","m1B:2",0).
term("m1B:2").
hasSerialization("m1B:2","X").
hasPositiveBodyAtom("m1B:0","m1B:3").
relationalAtom("m1B:3").
hasName("m1B:3","oRelA").
hasArgument("m1B:3","m1B:4",0).
term("m1B:4").
hasSerialization("m1B:4","X").
hasPositiveBodyAtom("m1B:0","m1B:5").
relationalAtom("m1B:5").
hasName("m1B:5","oRelB").
hasArgument("m1B:5","m1B:6",0).
term("m1B:6").
hasSerialization("m1B:6","X").
hasPositiveBodyAtom("m1B:0","m1B:7").
relationalAtom("m1B:7").
hasName("m1B:7","f3").
hasArgument("m1B:7","m1B:8",0).
term("m1B:8").
hasSerialization("m1B:8","X").
hasPositiveBodyAtom("m1B:0","m1B:9").
relationalAtom("m1B:9").
hasName("m1B:9","iRel4").
hasArgument("m1B:9","m1B:10",0).
term("m1B:10").
hasSerialization("m1B:10","X").
hasAnnotation("m1B:0","m1B:11").
annotation("m1B:11").
hasName("m1B:11","label").
hasArgument("m1B:11","m1B:12",0).
term("m1B:12").
hasSerialization("m1B:12","""R3""").
hasFact("m1B","m1B:13").
relationalAtom("m1B:13").
hasName("m1B:13","iRel4").
hasArgument("m1B:13","m1B:14",0).
term("m1B:14").
hasSerialization("m1B:14","""l1""").
hasFact("m1B","m1B:15").
relationalAtom("m1B:15").
hasName("m1B:15","iRel4").
hasArgument("m1B:15","m1B:16",0).
term("m1B:16").
hasSerialization("m1B:16","""l3""").
hasFact("m1B","m1B:17").
relationalAtom("m1B:17").
hasName("m1B:17","f3").
hasArgument("m1B:17","m1B:18",0).
term("m1B:18").
hasSerialization("m1B:18","""l2""").
hasFact("m1B","m1B:19").
relationalAtom("m1B:19").
hasName("m1B:19","f3").
hasArgument("m1B:19","m1B:20",0).
term("m1B:20").
hasSerialization("m1B:20","""l3""").
hasFact("m1B","m1B:21").
relationalAtom("m1B:21").
hasName("m1B:21","f3").
hasArgument("m1B:21","m1B:22",0).
term("m1B:22").
hasSerialization("m1B:22","""l1""").
hasAnnotation("m1B:21","m1B:23").
annotation("m1B:23").
hasName("m1B:23","label").
hasArgument("m1B:23","m1B:24",0).
term("m1B:24").
hasSerialization("m1B:24","""F1""").
hasAnnotation("m1B","m1B:25").
annotation("m1B:25").
hasName("m1B:25","module").
hasArgument("m1B:25","m1B:26",0).
term("m1B:26").
hasSerialization("m1B:26","""m1B""").
hasAnnotation("m1B","m1B:27").
annotation("m1B:27").
hasName("m1B:27","input").
hasArgument("m1B:27","m1B:28",0).
term("m1B:28").
hasSerialization("m1B:28","""iRel4""").
hasAnnotation("m1B","m1B:29").
annotation("m1B:29").
hasName("m1B:29","bind").
hasArgument("m1B:29","m1B:30",0).
term("m1B:30").
hasSerialization("m1B:30","""iRel4""").
hasArgument("m1B:29","m1B:31",1).
term("m1B:31").
hasSerialization("m1B:31","""...""").
hasAnnotation("m1B","m1B:32").
annotation("m1B:32").
hasName("m1B:32","output").
hasArgument("m1B:32","m1B:33",0).
term("m1B:33").
hasSerialization("m1B:33","""oRelD""").

program("m1C").
hasRule("m1C","m1C:0").
rule("m1C:0").
hasPositiveHeadAtom("m1C:0","m1C:1").
relationalAtom("m1C:1").
hasName("m1C:1","oRelC").
hasArgument("m1C:1","m1C:2",0).
term("m1C:2").
hasSerialization("m1C:2","X").
hasArgument("m1C:1","m1C:3",1).
term("m1C:3").
hasSerialization("m1C:3","Y").
hasPositiveBodyAtom("m1C:0","m1C:4").
relationalAtom("m1C:4").
hasName("m1C:4","iRel3").
hasArgument("m1C:4","m1C:5",0).
term("m1C:5").
hasSerialization("m1C:5","X").
hasArgument("m1C:4","m1C:6",1).
term("m1C:6").
hasSerialization("m1C:6","Y").
hasPositiveBodyAtom("m1C:0","m1C:7").
relationalAtom("m1C:7").
hasName("m1C:7","f1").
hasArgument("m1C:7","m1C:8",0).
term("m1C:8").
hasSerialization("m1C:8","Y").
hasAnnotation("m1C:0","m1C:9").
annotation("m1C:9").
hasName("m1C:9","label").
hasArgument("m1C:9","m1C:10",0).
term("m1C:10").
hasSerialization("m1C:10","""R3""").
hasFact("m1C","m1C:11").
relationalAtom("m1C:11").
hasName("m1C:11","iRel3").
hasArgument("m1C:11","m1C:12",0).
term("m1C:12").
hasSerialization("m1C:12","""l1""").
hasArgument("m1C:11","m1C:13",1).
term("m1C:13").
hasSerialization("m1C:13","""l1""").
hasFact("m1C","m1C:14").
relationalAtom("m1C:14").
hasName("m1C:14","iRel3").
hasArgument("m1C:14","m1C:15",0).
term("m1C:15").
hasSerialization("m1C:15","""l2""").
hasArgument("m1C:14","m1C:16",1).
term("m1C:16").
hasSerialization("m1C:16","""l3""").
hasAnnotation("m1C","m1C:17").
annotation("m1C:17").
hasName("m1C:17","module").
hasArgument("m1C:17","m1C:18",0).
term("m1C:18").
hasSerialization("m1C:18","""m1C""").
hasAnnotation("m1C","m1C:19").
annotation("m1C:19").
hasName("m1C:19","inherits").
hasArgument("m1C:19","m1C:20",0).
term("m1C:20").
hasSerialization("m1C:20","""m""").
hasAnnotation("m1C","m1C:21").
annotation("m1C:21").
hasName("m1C:21","non_extensible_input").
hasAnnotation("m1C","m1C:22").
annotation("m1C:22").
hasName("m1C:22","input").
hasArgument("m1C:22","m1C:23",0).
term("m1C:23").
hasSerialization("m1C:23","""iRel3""").
hasAnnotation("m1C","m1C:24").
annotation("m1C:24").
hasName("m1C:24","bind").
hasArgument("m1C:24","m1C:25",0).
term("m1C:25").
hasSerialization("m1C:25","""iRel3""").
hasArgument("m1C:24","m1C:26",1).
term("m1C:26").
hasSerialization("m1C:26","""...""").
hasAnnotation("m1C","m1C:27").
annotation("m1C:27").
hasName("m1C:27","remove").
hasArgument("m1C:27","m1C:28",0).
term("m1C:28").
hasSerialization("m1C:28","""M-R2""").
hasAnnotation("m1C","m1C:29").
annotation("m1C:29").
hasName("m1C:29","output").
hasArgument("m1C:29","m1C:30",0).
term("m1C:30").
hasSerialization("m1C:30","""oRelC""").

program("m2").
hasRule("m2","m2:0").
rule("m2:0").
hasPositiveHeadAtom("m2:0","m2:1").
relationalAtom("m2:1").
hasName("m2:1","oRelE").
hasArgument("m2:1","m2:2",0).
term("m2:2").
hasSerialization("m2:2","X").
hasPositiveBodyAtom("m2:0","m2:3").
relationalAtom("m2:3").
hasName("m2:3","f1").
hasArgument("m2:3","m2:4",0).
term("m2:4").
hasSerialization("m2:4","X").
hasPositiveBodyAtom("m2:0","m2:5").
relationalAtom("m2:5").
hasName("m2:5","f2").
hasArgument("m2:5","m2:6",0).
term("m2:6").
hasSerialization("m2:6","A").
hasPositiveBodyAtom("m2:0","m2:7").
relationalAtom("m2:7").
hasName("m2:7","f3").
hasArgument("m2:7","m2:8",0).
term("m2:8").
hasSerialization("m2:8","X").
hasPositiveBodyAtom("m2:0","m2:9").
relationalAtom("m2:9").
hasName("m2:9","iRel1").
hasArgument("m2:9","m2:10",0).
term("m2:10").
hasSerialization("m2:10","X").
hasPositiveBodyAtom("m2:0","m2:11").
relationalAtom("m2:11").
hasName("m2:11","iRel3").
hasArgument("m2:11","m2:12",0).
term("m2:12").
hasSerialization("m2:12","A").
hasArgument("m2:11","m2:13",1).
term("m2:13").
hasSerialization("m2:13","X").
hasAnnotation("m2:0","m2:14").
annotation("m2:14").
hasName("m2:14","label").
hasArgument("m2:14","m2:15",0).
term("m2:15").
hasSerialization("m2:15","""R5""").
hasFact("m2","m2:16").
relationalAtom("m2:16").
hasName("m2:16","f1").
hasArgument("m2:16","m2:17",0).
term("m2:17").
hasSerialization("m2:17","""l3""").
hasFact("m2","m2:18").
relationalAtom("m2:18").
hasName("m2:18","f2").
hasArgument("m2:18","m2:19",0).
term("m2:19").
hasSerialization("m2:19","""l3""").
hasFact("m2","m2:20").
relationalAtom("m2:20").
hasName("m2:20","f2").
hasArgument("m2:20","m2:21",0).
term("m2:21").
hasSerialization("m2:21","""f1""").
hasAnnotation("m2","m2:22").
annotation("m2:22").
hasName("m2:22","module").
hasArgument("m2:22","m2:23",0).
term("m2:23").
hasSerialization("m2:23","""m2""").
hasAnnotation("m2","m2:24").
annotation("m2:24").
hasName("m2:24","inherits").
hasArgument("m2:24","m2:25",0).
term("m2:25").
hasSerialization("m2:25","""m1A""").
hasAnnotation("m2","m2:26").
annotation("m2:26").
hasName("m2:26","inherits").
hasArgument("m2:26","m2:27",0).
term("m2:27").
hasSerialization("m2:27","""m1B""").
hasAnnotation("m2","m2:28").
annotation("m2:28").
hasName("m2:28","inherits").
hasArgument("m2:28","m2:29",0).
term("m2:29").
hasSerialization("m2:29","""m1C""").
hasAnnotation("m2","m2:30").
annotation("m2:30").
hasName("m2:30","input").
hasArgument("m2:30","m2:31",0).
term("m2:31").
hasSerialization("m2:31","""violatingInput""").
hasAnnotation("m2","m2:32").
annotation("m2:32").
hasName("m2:32","bind").
hasArgument("m2:32","m2:33",0).
term("m2:33").
hasSerialization("m2:33","""iRel1""").
hasArgument("m2:32","m2:34",1).
term("m2:34").
hasSerialization("m2:34","""...m2""").
hasAnnotation("m2","m2:35").
annotation("m2:35").
hasName("m2:35","non_extensible_output").
hasAnnotation("m2","m2:36").
annotation("m2:36").
hasName("m2:36","input").
hasArgument("m2:36","m2:37",0).
term("m2:37").
hasSerialization("m2:37","""iRel1""").
hasAnnotation("m2","m2:38").
annotation("m2:38").
hasName("m2:38","redefinesQ").
hasArgument("m2:38","m2:39",0).
term("m2:39").
hasSerialization("m2:39","""R5""").
hasArgument("m2:38","m2:40",1).
term("m2:40").
hasSerialization("m2:40","""R3""").
hasArgument("m2:38","m2:41",2).
term("m2:41").
hasSerialization("m2:41","""m1B""").
hasAnnotation("m2","m2:42").
annotation("m2:42").
hasName("m2:42","output").
hasArgument("m2:42","m2:43",0).
term("m2:43").
hasSerialization("m2:43","""oRelE""").

program("m3").
hasRule("m3","m3:0").
rule("m3:0").
hasPositiveHeadAtom("m3:0","m3:1").
relationalAtom("m3:1").
hasName("m3:1","oRelF").
hasArgument("m3:1","m3:2",0).
term("m3:2").
hasSerialization("m3:2","X").
hasArgument("m3:1","m3:3",1).
term("m3:3").
hasSerialization("m3:3","Y").
hasPositiveBodyAtom("m3:0","m3:4").
relationalAtom("m3:4").
hasName("m3:4","iRel1").
hasArgument("m3:4","m3:5",0).
term("m3:5").
hasSerialization("m3:5","X").
hasPositiveBodyAtom("m3:0","m3:6").
relationalAtom("m3:6").
hasName("m3:6","iRel2").
hasArgument("m3:6","m3:7",0).
term("m3:7").
hasSerialization("m3:7","X").
hasPositiveBodyAtom("m3:0","m3:8").
relationalAtom("m3:8").
hasName("m3:8","iRel3").
hasArgument("m3:8","m3:9",0).
term("m3:9").
hasSerialization("m3:9","X").
hasArgument("m3:8","m3:10",1).
term("m3:10").
hasSerialization("m3:10","Y").
hasPositiveBodyAtom("m3:0","m3:11").
relationalAtom("m3:11").
hasName("m3:11","iRel4").
hasArgument("m3:11","m3:12",0).
term("m3:12").
hasSerialization("m3:12","Y").
hasAnnotation("m3:0","m3:13").
annotation("m3:13").
hasName("m3:13","label").
hasArgument("m3:13","m3:14",0).
term("m3:14").
hasSerialization("m3:14","""R6""").
hasAnnotation("m3","m3:15").
annotation("m3:15").
hasName("m3:15","module").
hasArgument("m3:15","m3:16",0).
term("m3:16").
hasSerialization("m3:16","""m3""").
hasAnnotation("m3","m3:17").
annotation("m3:17").
hasName("m3:17","inherits").
hasArgument("m3:17","m3:18",0).
term("m3:18").
hasSerialization("m3:18","""m2""").
hasAnnotation("m3","m3:19").
annotation("m3:19").
hasName("m3:19","removeQ").
hasArgument("m3:19","m3:20",0).
term("m3:20").
hasSerialization("m3:20","""F1""").
hasArgument("m3:19","m3:21",1).
term("m3:21").
hasSerialization("m3:21","""m1C""").
hasAnnotation("m3","m3:22").
annotation("m3:22").
hasName("m3:22","output").
hasArgument("m3:22","m3:23",0).
term("m3:23").
hasSerialization("m3:23","""oRelF""").

true(#T). false(#F).

% Find module labels for module IDs
moduleLbl(M,L) :- hasAnnotation(M,A), hasName(A,"module"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
resultset(S,M) :- hasAnnotation(S,A), hasName(A,"resultset"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), M = substring(L1,1,string_length(L1)-1).

% Find Id of module to be derived
deriveModule(M) :- toDerive(L), moduleLbl(M,L).

% Determine inheritance relationships in provided meta-representations
inherits(MC,MP) :- hasAnnotation(MC,A), hasName(A,"inherits"), hasArgument(A,Arg,0), hasSerialization(Arg,MP1), moduleLbl(MP,MPL), MPL = substring(MP1,1,string_length(MP1)-1).
tInherits(M,M2) :- inherits(M,M2).
tInherits(M,M2) :- tInherits(M,M1), inherits(M1,M2).

% Predicates in a module
predicate(M,P) :- inputPredicate(M,P).
predicate(M,P) :- outputPredicate(M,P).
predicate(M,P) :- tHasFact(M,F), relationalAtom(F), hasName(F,P).
predicate(M,P) :- mHasRule(M,R), ruleHeadPredicate(R,P).
predicate(M,P) :- mHasRule(M,R), ruleBodyPredicate(R,P).

inputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"input"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"output"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

% Defined restrictions and modification operations
restriction("no_additional_input").
restriction("no_additional_output").
restriction("no_additional_annotation").
restriction("non_omitable").
restriction("non_redefinable").
restriction("non_shrinkable").
restriction("non_growable").
modOp("remove"). modOp("removeQ").
modOp("redefines"). modOp("redefinesQ").
modOp("inherits").

% Inheritance Annotations
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), restriction(N).
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), modOp(N).

% Which statements exist in a module?
hasStmt(M,S) :- hasRule(M,S).
hasStmt(M,S) :- hasFact(M,S).
hasStmt(M,S) :- moduleLbl(M,_), hasAnnotation(M,S).

% Only labeled statements are interesting, others always propagated
stmtLbl(R,L) :- hasRule(M,R), hasAnnotation(R,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(F,L) :- hasFact(M,F), hasAnnotation(F,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(A,L) :- hasAnnotation(M,A), hasAnnotation(A,A2), hasName(A2,"label"), hasArgument(A2,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtML(M,S,L) :- stmtLbl(S,L), hasStmt(M,S).

% Atoms in a rule
hasAtom(R,A):- hasNegativeBodyAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasPositiveBodyAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasNegativeHeadAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasPositiveHeadAtom(R,A), relationalAtom(A).

ruleBodyPredicate(R,P):- tHasRule(M,R), hasNegativeBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleBodyPredicate(R,P):- tHasRule(M,R), hasPositiveBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- tHasRule(M,R), hasNegativeHeadAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- tHasRule(M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P).
predicateDependency(M,P,P2) :- tHasRule(M,R), ruleHeadPredicate(R,P), ruleBodyPredicate(R,P2).

% RESOLVE INHERITANCE
% Unqualified remove and redefine
redefineStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"redefines"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), L = substring(L1,1,string_length(L1)-1).
removeStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"remove"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), L = substring(L1,1,string_length(L1)-1).
% Any statement except inheritance annotations can be removed
redefineStmt(M,S):- redefineStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).
removeStmt(M,S):- removeStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).

% Qualified remove and redefine
redefineStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"redefinesQ"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), hasArgument(A,Arg3,2), hasSerialization(Arg3,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
removeStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"removeQ"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
redefineStmt(M,S) :- redefineStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).
removeStmt(M,S) :- removeStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).

% Module name annotations are not inherited
removeStmt(M,A) :- hasAnnotation(M,A), hasName(A,"module"), not deriveModule(M).

% Modification operation statements
modOpStmt(M,S) :- removeStmt(M,S).
modOpStmt(M,S) :- redefineStmt(M,S).
tModOpStmt(M,M,S) :- modOpStmt(M,S).
tModOpStmt(M,Morg,S) :- inherits(M,M2), tModOpStmt(M2,Morg,S).

% DETERMINE ACTIVE STATEMENTS AND MODULE/STATEMENT ANNOTATIONS FOR MODULES
% Derive for each module its active rules by inheriting
tHasRule(M,R) :- hasRule(M,R).
tHasRule(M,R) :- inherits(M,MP), tHasRule(MP,R).
moduleStmt(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).
mHasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).

% Determine for each module its active facts by inheriting
tHasFact(M,F) :- hasFact(M,F).
tHasFact(M,F) :- inherits(M,MP), tHasFact(MP,F).
moduleStmt(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F).

% Determine for each module its active module and statement annotations
tHasAnnotationM(M,A) :- moduleLbl(M,L), hasAnnotation(M,A), hasName(A,N), not modOp(N).
tHasAnnotationM(M,A) :- inherits(M,MP), tHasAnnotationM(MP,A).
tHasAnnotationS(M,Stmt,A) :- hasStmt(M,Stmt), hasAnnotation(Stmt,A).
tHasAnnotationS(M,Stmt,A) :- inherits(M,MP), tHasAnnotationS(MP,Stmt,A).
moduleStmt(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A).

% Determine Restrictions defined in modules
noAdditionalInput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_input").
noAdditionalOutput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_output").
noAdditionalAnnotation(M,ANN,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_annotation"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), P = substring(L1,1,string_length(L1)-1), ANN = substring(L2,1,string_length(L2)-1).
nonOmitable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_omitable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonRedefinable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_redefinable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonGrowable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_growable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P  =substring(L1,1,string_length(L1)-1).
nonShrinkable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_shrinkable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).

% ------------------------------------------------------------------------
% BEHAVIORAL RESTRICTIONS
% ------------------------------------------------------------------------
w_nonGrowable(C,P,PRED) :- resultset(RS1,C), moduleLbl(C,_), resultset(RS2,P), tInherits(C,P), nonGrowable(P,PRED), factsGrown(C,P,PRED).
w_nonShrinkable(C,P,PRED) :- resultset(RS1,C), moduleLbl(C,_), resultset(RS2,P), tInherits(C,P), nonShrinkable(P,PRED), factsShrunk(C,P,PRED).

@output("w_nonGrowable").
@output("w_nonShrinkable").

program("rs1").
hasFact("rs1","rs1:0").
relationalAtom("rs1:0").
hasName("rs1:0","oRelA").
hasArgument("rs1:0","rs1:1",0).
term("rs1:1").
hasSerialization("rs1:1","""X""").
hasFact("rs1","rs1:2").
relationalAtom("rs1:2").
hasName("rs1:2","oRelB").
hasArgument("rs1:2","rs1:3",0).
term("rs1:3").
hasSerialization("rs1:3","""X""").
hasArgument("rs1:2","rs1:4",1).
term("rs1:4").
hasSerialization("rs1:4","""B""").
hasFact("rs1","rs1:5").
relationalAtom("rs1:5").
hasName("rs1:5","oRelA").
hasArgument("rs1:5","rs1:6",0).
term("rs1:6").
hasSerialization("rs1:6","""Y""").
hasFact("rs1","rs1:7").
relationalAtom("rs1:7").
hasName("rs1:7","oRelB").
hasArgument("rs1:7","rs1:8",0).
term("rs1:8").
hasSerialization("rs1:8","""Z""").
hasArgument("rs1:7","rs1:9",1).
term("rs1:9").
hasSerialization("rs1:9","""A""").
hasFact("rs1","rs1:10").
relationalAtom("rs1:10").
hasName("rs1:10","oRelC").
hasArgument("rs1:10","rs1:11",0).
term("rs1:11").
hasSerialization("rs1:11","""Z""").
hasAnnotation("rs1","rs1:12").
annotation("rs1:12").
hasName("rs1:12","resultset").
hasArgument("rs1:12","rs1:13",0).
term("rs1:13").
hasSerialization("rs1:13","""m1A""").

program("rs2").
hasFact("rs2","rs2:0").
relationalAtom("rs2:0").
hasName("rs2:0","oRelA").
hasArgument("rs2:0","rs2:1",0).
term("rs2:1").
hasSerialization("rs2:1","""X""").
hasFact("rs2","rs2:2").
relationalAtom("rs2:2").
hasName("rs2:2","oRelB").
hasArgument("rs2:2","rs2:3",0).
term("rs2:3").
hasSerialization("rs2:3","""X""").
hasArgument("rs2:2","rs2:4",1).
term("rs2:4").
hasSerialization("rs2:4","""B""").
hasFact("rs2","rs2:5").
relationalAtom("rs2:5").
hasName("rs2:5","oRelA").
hasArgument("rs2:5","rs2:6",0).
term("rs2:6").
hasSerialization("rs2:6","""Y""").
hasFact("rs2","rs2:7").
relationalAtom("rs2:7").
hasName("rs2:7","oRelA").
hasArgument("rs2:7","rs2:8",0).
term("rs2:8").
hasSerialization("rs2:8","""Y2""").
hasFact("rs2","rs2:10").
relationalAtom("rs2:10").
hasName("rs2:10","testing").
hasArgument("rs2:10","rs2:11",0).
term("rs2:11").
hasSerialization("rs2:11","""Z""").
hasAnnotation("rs2","rs2:12").
annotation("rs2:12").
hasName("rs2:12","resultset").
hasArgument("rs2:12","rs2:13",0).
term("rs2:13").
hasSerialization("rs2:13","""m2""").

hasFact("rs2","rs2:14").
relationalAtom("rs2:14").
hasName("rs2:14","oRelC").
hasArgument("rs2:14","rs2:15",0).
term("rs2:15").
hasSerialization("rs2:15","""test""").


% ------------------------------------------------------------------------
% BEHAVIORAL MODIFICATION DETECTION
% ------------------------------------------------------------------------
%requires resultsets where an annotation @resultset("<module>") is required where <module> is the module generating the resultset
resultset(RS,M) :- hasAnnotation(RS,A), hasName(A,"resultset"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), M = substring(L1,1,string_length(L1)-1).
factPredicate(M,F,PRED,CONST,POS) :- resultset(M,_), hasFact(M,F), relationalAtom(F), hasName(F,PRED), hasArgument(F,Arg,POS), term(Arg), hasSerialization(Arg,L), CONST = substring(L,1,string_length(L)-1).

factsGrown(C,P,PRED) :- moduleLbl(C,_), moduleLbl(P,_), resultset(RS1,C), resultset(RS2,P), tInherits(C,P), factPredicate(RS1,_,PRED,ARG,POS), not factPredicate(RS2,_,PRED,ARG,POS), factPredicate(RS2,_,PRED,_,_).
factsGrown(C,P,PRED) :- moduleLbl(C,_), moduleLbl(P,_), resultset(RS1,C), resultset(RS2,P), tInherits(C,P), outputPredicates(P,PRED), factPredicate(RS1,_,PRED,ARG,POS), not factPredicate(RS2,_,PRED,ARG,POS), factPredicate(RS2,_,PRED,_,_).
factsShrunk(C,P,PRED) :- moduleLbl(C,_), moduleLbl(P,_), resultset(RS1,C), resultset(RS2,P), tInherits(C,P), factPredicate(RS2,_,PRED,ARG,POS), not factPredicate(RS1,_,PRED,ARG,POS).
factsModified(C,P) :- factsGrown(C,P,_), factsShrunk(C,P,_).
factsIdentical(C,P) :- resultset(_,C), resultset(_,P), tInherits(C,P), moduleLbl(C,_), moduleLbl(P,_), not factsGrown(C,P,_), not factsShrunk(C,P,_).

@output("factsGrown"). @ouput("factsGrown","orderby(1,2,3").
@output("factsShrunk"). @ouput("factsShrunk","orderby(1,2,3)").
@output("factsModified"). @ouput("factsModified","orderby(1,2)").
@output("factsIdentical"). @ouput("factsIdentical","orderby(1,2)").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">w_nonShrinkable</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>m1A</td><td>oRelB</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">factsModified</caption><thead><tr><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>m1A</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">w_nonGrowable</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>m1A</td><td>oRelC</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">factsGrown</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>m1A</td><td>oRelA</td></tr></tbody><tbody><tr><td>m2</td><td>m1A</td><td>oRelC</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">factsShrunk</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>m1A</td><td>oRelB</td></tr></tbody><tbody><tr><td>m2</td><td>m1A</td><td>oRelC</td></tr></tbody></table></div></div></div>

# %% [markdown]
# **Expected:**
# * `nonGrowable("oRelC")`
# * `nonShrinkable("oRelB")`

# %% [markdown]
# ## Static Detection

# %%
toDerive("m3").

program("m").
hasRule("m","m:0").
rule("m:0").
hasPositiveHeadAtom("m:0","m:1").
relationalAtom("m:1").
hasName("m:1","oRelA").
hasArgument("m:1","m:2",0).
term("m:2").
hasSerialization("m:2","X").
hasPositiveBodyAtom("m:0","m:3").
relationalAtom("m:3").
hasName("m:3","iRel1").
hasArgument("m:3","m:4",0).
term("m:4").
hasSerialization("m:4","X").
hasPositiveBodyAtom("m:0","m:5").
relationalAtom("m:5").
hasName("m:5","f1").
hasArgument("m:5","m:6",0).
term("m:6").
hasSerialization("m:6","X").
hasRule("m","m:7").
rule("m:7").
hasPositiveHeadAtom("m:7","m:8").
relationalAtom("m:8").
hasName("m:8","oRelB").
hasArgument("m:8","m:9",0).
term("m:9").
hasSerialization("m:9","X").
hasPositiveBodyAtom("m:7","m:10").
relationalAtom("m:10").
hasName("m:10","iRel1").
hasArgument("m:10","m:11",0).
term("m:11").
hasSerialization("m:11","X").
hasPositiveBodyAtom("m:7","m:12").
relationalAtom("m:12").
hasName("m:12","f2").
hasArgument("m:12","m:13",0).
term("m:13").
hasSerialization("m:13","X").
hasAnnotation("m:7","m:14").
annotation("m:14").
hasName("m:14","label").
hasArgument("m:14","m:15",0).
term("m:15").
hasSerialization("m:15","""M-R2""").
hasFact("m","m:16").
relationalAtom("m:16").
hasName("m:16","iRel1").
hasArgument("m:16","m:17",0).
term("m:17").
hasSerialization("m:17","""l1""").
hasAnnotation("m:16","m:18").
annotation("m:18").
hasName("m:18","label").
hasArgument("m:18","m:19",0).
term("m:19").
hasSerialization("m:19","""iRel1""").
hasFact("m","m:20").
relationalAtom("m:20").
hasName("m:20","iRel1").
hasArgument("m:20","m:21",0).
term("m:21").
hasSerialization("m:21","""l2""").
hasAnnotation("m:20","m:22").
annotation("m:22").
hasName("m:22","label").
hasArgument("m:22","m:23",0).
term("m:23").
hasSerialization("m:23","""iRel1""").
hasFact("m","m:24").
relationalAtom("m:24").
hasName("m:24","f1").
hasArgument("m:24","m:25",0).
term("m:25").
hasSerialization("m:25","""l1""").
hasAnnotation("m","m:26").
annotation("m:26").
hasName("m:26","module").
hasArgument("m:26","m:27",0).
term("m:27").
hasSerialization("m:27","""m""").
hasAnnotation("m","m:28").
annotation("m:28").
hasName("m:28","non_omitable").
hasArgument("m:28","m:29",0).
term("m:29").
hasSerialization("m:29","""iRel1""").
hasAnnotation("m","m:30").
annotation("m:30").
hasName("m:30","non_extensible_predicate").
hasArgument("m:30","m:31",0).
term("m:31").
hasSerialization("m:31","""iRel1""").
hasArgument("m:30","m:32",1).
term("m:32").
hasSerialization("m:32","""bind""").
hasAnnotation("m","m:33").
annotation("m:33").
hasName("m:33","non_shrinkable").
hasArgument("m:33","m:34",0).
term("m:34").
hasSerialization("m:34","""oRelA""").
hasAnnotation("m","m:35").
annotation("m:35").
hasName("m:35","input").
hasArgument("m:35","m:36",0).
term("m:36").
hasSerialization("m:36","""iRel1""").
hasAnnotation("m","m:37").
annotation("m:37").
hasName("m:37","bind").
hasArgument("m:37","m:38",0).
term("m:38").
hasSerialization("m:38","""iRel1""").
hasArgument("m:37","m:39",1).
term("m:39").
hasSerialization("m:39","""...""").
hasAnnotation("m","m:40").
annotation("m:40").
hasName("m:40","output").
hasArgument("m:40","m:41",0).
term("m:41").
hasSerialization("m:41","""oRelA""").
hasAnnotation("m","m:42").
annotation("m:42").
hasName("m:42","post").
hasArgument("m:42","m:43",0).
term("m:43").
hasSerialization("m:43","""oRelA""").
hasArgument("m:42","m:44",1).
term("m:44").
hasSerialization("m:44","""orderby(1)""").
hasAnnotation("m","m:45").
annotation("m:45").
hasName("m:45","output").
hasArgument("m:45","m:46",0).
term("m:46").
hasSerialization("m:46","""oRelB""").
hasAnnotation("m","m:47").
annotation("m:47").
hasName("m:47","non_shrinkable").
hasArgument("m:47","m:48",0).
term("m:48").
hasSerialization("m:48","""oRelB""").


program("m1A").
hasRule("m1A","m1A:0").
rule("m1A:0").
hasPositiveHeadAtom("m1A:0","m1A:1").
relationalAtom("m1A:1").
hasName("m1A:1","oRelC").
hasArgument("m1A:1","m1A:2",0).
term("m1A:2").
hasSerialization("m1A:2","X").
hasPositiveBodyAtom("m1A:0","m1A:3").
relationalAtom("m1A:3").
hasName("m1A:3","oRelA").
hasArgument("m1A:3","m1A:4",0).
term("m1A:4").
hasSerialization("m1A:4","X").
hasPositiveBodyAtom("m1A:0","m1A:5").
relationalAtom("m1A:5").
hasName("m1A:5","oRelB").
hasArgument("m1A:5","m1A:6",0).
term("m1A:6").
hasSerialization("m1A:6","X").
hasPositiveBodyAtom("m1A:0","m1A:7").
relationalAtom("m1A:7").
hasName("m1A:7","temp").
hasArgument("m1A:7","m1A:8",0).
term("m1A:8").
hasSerialization("m1A:8","X").
hasAnnotation("m1A:0","m1A:9").
annotation("m1A:9").
hasName("m1A:9","label").
hasArgument("m1A:9","m1A:10",0).
term("m1A:10").
hasSerialization("m1A:10","""R3""").
hasRule("m1A","m1A:11").
rule("m1A:11").
hasPositiveHeadAtom("m1A:11","m1A:12").
relationalAtom("m1A:12").
hasName("m1A:12","temp").
hasArgument("m1A:12","m1A:13",0).
term("m1A:13").
hasSerialization("m1A:13","T").
hasPositiveBodyAtom("m1A:11","m1A:14").
relationalAtom("m1A:14").
hasName("m1A:14","iRel2").
hasArgument("m1A:14","m1A:15",0).
term("m1A:15").
hasSerialization("m1A:15","T").
hasPositiveBodyAtom("m1A:11","m1A:16").
relationalAtom("m1A:16").
hasName("m1A:16","f1").
hasArgument("m1A:16","m1A:17",0).
term("m1A:17").
hasSerialization("m1A:17","T").
hasAnnotation("m1A:11","m1A:18").
annotation("m1A:18").
hasName("m1A:18","label").
hasArgument("m1A:18","m1A:19",0).
term("m1A:19").
hasSerialization("m1A:19","""R4""").
hasFact("m1A","m1A:20").
relationalAtom("m1A:20").
hasName("m1A:20","iRel2").
hasArgument("m1A:20","m1A:21",0).
term("m1A:21").
hasSerialization("m1A:21","""l1""").
hasFact("m1A","m1A:22").
relationalAtom("m1A:22").
hasName("m1A:22","f1").
hasArgument("m1A:22","m1A:23",0).
term("m1A:23").
hasSerialization("m1A:23","""l2""").
hasFact("m1A","m1A:24").
relationalAtom("m1A:24").
hasName("m1A:24","f2").
hasArgument("m1A:24","m1A:25",0).
term("m1A:25").
hasSerialization("m1A:25","""l1""").
hasAnnotation("m1A:24","m1A:26").
annotation("m1A:26").
hasName("m1A:26","label").
hasArgument("m1A:26","m1A:27",0).
term("m1A:27").
hasSerialization("m1A:27","""F1""").
hasAnnotation("m1A","m1A:28").
annotation("m1A:28").
hasName("m1A:28","module").
hasArgument("m1A:28","m1A:29",0).
term("m1A:29").
hasSerialization("m1A:29","""m1A""").
hasAnnotation("m1A","m1A:30").
annotation("m1A:30").
hasName("m1A:30","inherits").
hasArgument("m1A:30","m1A:31",0).
term("m1A:31").
hasSerialization("m1A:31","""m""").
hasAnnotation("m1A","m1A:32").
annotation("m1A:32").
hasName("m1A:32","non_growable").
hasArgument("m1A:32","m1A:33",0).
term("m1A:33").
hasSerialization("m1A:33","""oRelC""").
hasAnnotation("m1A","m1A:34").
annotation("m1A:34").
hasName("m1A:34","input").
hasArgument("m1A:34","m1A:35",0).
term("m1A:35").
hasSerialization("m1A:35","""iRel2""").
hasAnnotation("m1A","m1A:36").
annotation("m1A:36").
hasName("m1A:36","bind").
hasArgument("m1A:36","m1A:37",0).
term("m1A:37").
hasSerialization("m1A:37","""iRel2""").
hasArgument("m1A:36","m1A:38",1).
term("m1A:38").
hasSerialization("m1A:38","""...""").
hasAnnotation("m1A","m1A:39").
annotation("m1A:39").
hasName("m1A:39","bind").
hasArgument("m1A:39","m1A:40",0).
term("m1A:40").
hasSerialization("m1A:40","""iRel1""").
hasArgument("m1A:39","m1A:41",1).
term("m1A:41").
hasSerialization("m1A:41","""...m1A""").
hasAnnotation("m1A","m1A:42").
annotation("m1A:42").
hasName("m1A:42","remove").
hasArgument("m1A:42","m1A:43",0).
term("m1A:43").
hasSerialization("m1A:43","""iRel1""").
hasAnnotation("m1A","m1A:44").
annotation("m1A:44").
hasName("m1A:44","redefines").
hasArgument("m1A:44","m1A:45",0).
term("m1A:45").
hasSerialization("m1A:45","""R4""").
hasArgument("m1A:44","m1A:46",1).
term("m1A:46").
hasSerialization("m1A:46","""M-R2""").
hasAnnotation("m1A","m1A:47").
annotation("m1A:47").
hasName("m1A:47","output").
hasArgument("m1A:47","m1A:48",0).
term("m1A:48").
hasSerialization("m1A:48","""oRelC""").

program("m1B").
hasRule("m1B","m1B:0").
rule("m1B:0").
hasPositiveHeadAtom("m1B:0","m1B:1").
relationalAtom("m1B:1").
hasName("m1B:1","oRelD").
hasArgument("m1B:1","m1B:2",0).
term("m1B:2").
hasSerialization("m1B:2","X").
hasPositiveBodyAtom("m1B:0","m1B:3").
relationalAtom("m1B:3").
hasName("m1B:3","oRelA").
hasArgument("m1B:3","m1B:4",0).
term("m1B:4").
hasSerialization("m1B:4","X").
hasPositiveBodyAtom("m1B:0","m1B:5").
relationalAtom("m1B:5").
hasName("m1B:5","oRelB").
hasArgument("m1B:5","m1B:6",0).
term("m1B:6").
hasSerialization("m1B:6","X").
hasPositiveBodyAtom("m1B:0","m1B:7").
relationalAtom("m1B:7").
hasName("m1B:7","f3").
hasArgument("m1B:7","m1B:8",0).
term("m1B:8").
hasSerialization("m1B:8","X").
hasPositiveBodyAtom("m1B:0","m1B:9").
relationalAtom("m1B:9").
hasName("m1B:9","iRel4").
hasArgument("m1B:9","m1B:10",0).
term("m1B:10").
hasSerialization("m1B:10","X").
hasAnnotation("m1B:0","m1B:11").
annotation("m1B:11").
hasName("m1B:11","label").
hasArgument("m1B:11","m1B:12",0).
term("m1B:12").
hasSerialization("m1B:12","""R3""").
hasFact("m1B","m1B:13").
relationalAtom("m1B:13").
hasName("m1B:13","iRel4").
hasArgument("m1B:13","m1B:14",0).
term("m1B:14").
hasSerialization("m1B:14","""l1""").
hasFact("m1B","m1B:15").
relationalAtom("m1B:15").
hasName("m1B:15","iRel4").
hasArgument("m1B:15","m1B:16",0).
term("m1B:16").
hasSerialization("m1B:16","""l3""").
hasFact("m1B","m1B:17").
relationalAtom("m1B:17").
hasName("m1B:17","f3").
hasArgument("m1B:17","m1B:18",0).
term("m1B:18").
hasSerialization("m1B:18","""l2""").
hasFact("m1B","m1B:19").
relationalAtom("m1B:19").
hasName("m1B:19","f3").
hasArgument("m1B:19","m1B:20",0).
term("m1B:20").
hasSerialization("m1B:20","""l3""").
hasFact("m1B","m1B:21").
relationalAtom("m1B:21").
hasName("m1B:21","f3").
hasArgument("m1B:21","m1B:22",0).
term("m1B:22").
hasSerialization("m1B:22","""l1""").
hasAnnotation("m1B:21","m1B:23").
annotation("m1B:23").
hasName("m1B:23","label").
hasArgument("m1B:23","m1B:24",0).
term("m1B:24").
hasSerialization("m1B:24","""F1""").
hasAnnotation("m1B","m1B:25").
annotation("m1B:25").
hasName("m1B:25","module").
hasArgument("m1B:25","m1B:26",0).
term("m1B:26").
hasSerialization("m1B:26","""m1B""").
hasAnnotation("m1B","m1B:27").
annotation("m1B:27").
hasName("m1B:27","input").
hasArgument("m1B:27","m1B:28",0).
term("m1B:28").
hasSerialization("m1B:28","""iRel4""").
hasAnnotation("m1B","m1B:29").
annotation("m1B:29").
hasName("m1B:29","bind").
hasArgument("m1B:29","m1B:30",0).
term("m1B:30").
hasSerialization("m1B:30","""iRel4""").
hasArgument("m1B:29","m1B:31",1).
term("m1B:31").
hasSerialization("m1B:31","""...""").
hasAnnotation("m1B","m1B:32").
annotation("m1B:32").
hasName("m1B:32","output").
hasArgument("m1B:32","m1B:33",0).
term("m1B:33").
hasSerialization("m1B:33","""oRelD""").

program("m1C").
hasRule("m1C","m1C:0").
rule("m1C:0").
hasPositiveHeadAtom("m1C:0","m1C:1").
relationalAtom("m1C:1").
hasName("m1C:1","oRelC").
hasArgument("m1C:1","m1C:2",0).
term("m1C:2").
hasSerialization("m1C:2","X").
hasArgument("m1C:1","m1C:3",1).
term("m1C:3").
hasSerialization("m1C:3","Y").
hasPositiveBodyAtom("m1C:0","m1C:4").
relationalAtom("m1C:4").
hasName("m1C:4","iRel3").
hasArgument("m1C:4","m1C:5",0).
term("m1C:5").
hasSerialization("m1C:5","X").
hasArgument("m1C:4","m1C:6",1).
term("m1C:6").
hasSerialization("m1C:6","Y").
hasPositiveBodyAtom("m1C:0","m1C:7").
relationalAtom("m1C:7").
hasName("m1C:7","f1").
hasArgument("m1C:7","m1C:8",0).
term("m1C:8").
hasSerialization("m1C:8","Y").
hasAnnotation("m1C:0","m1C:9").
annotation("m1C:9").
hasName("m1C:9","label").
hasArgument("m1C:9","m1C:10",0).
term("m1C:10").
hasSerialization("m1C:10","""R3""").
hasFact("m1C","m1C:11").
relationalAtom("m1C:11").
hasName("m1C:11","iRel3").
hasArgument("m1C:11","m1C:12",0).
term("m1C:12").
hasSerialization("m1C:12","""l1""").
hasArgument("m1C:11","m1C:13",1).
term("m1C:13").
hasSerialization("m1C:13","""l1""").
hasFact("m1C","m1C:14").
relationalAtom("m1C:14").
hasName("m1C:14","iRel3").
hasArgument("m1C:14","m1C:15",0).
term("m1C:15").
hasSerialization("m1C:15","""l2""").
hasArgument("m1C:14","m1C:16",1).
term("m1C:16").
hasSerialization("m1C:16","""l3""").
hasAnnotation("m1C","m1C:17").
annotation("m1C:17").
hasName("m1C:17","module").
hasArgument("m1C:17","m1C:18",0).
term("m1C:18").
hasSerialization("m1C:18","""m1C""").
hasAnnotation("m1C","m1C:19").
annotation("m1C:19").
hasName("m1C:19","inherits").
hasArgument("m1C:19","m1C:20",0).
term("m1C:20").
hasSerialization("m1C:20","""m""").
hasAnnotation("m1C","m1C:21").
annotation("m1C:21").
hasName("m1C:21","non_extensible_input").
hasAnnotation("m1C","m1C:22").
annotation("m1C:22").
hasName("m1C:22","input").
hasArgument("m1C:22","m1C:23",0).
term("m1C:23").
hasSerialization("m1C:23","""iRel3""").
hasAnnotation("m1C","m1C:24").
annotation("m1C:24").
hasName("m1C:24","bind").
hasArgument("m1C:24","m1C:25",0).
term("m1C:25").
hasSerialization("m1C:25","""iRel3""").
hasArgument("m1C:24","m1C:26",1).
term("m1C:26").
hasSerialization("m1C:26","""...""").
hasAnnotation("m1C","m1C:27").
annotation("m1C:27").
hasName("m1C:27","remove").
hasArgument("m1C:27","m1C:28",0).
term("m1C:28").
hasSerialization("m1C:28","""M-R2""").
hasAnnotation("m1C","m1C:29").
annotation("m1C:29").
hasName("m1C:29","output").
hasArgument("m1C:29","m1C:30",0).
term("m1C:30").
hasSerialization("m1C:30","""oRelC""").

program("m2").
hasRule("m2","m2:0").
rule("m2:0").
hasPositiveHeadAtom("m2:0","m2:1").
relationalAtom("m2:1").
hasName("m2:1","oRelE").
hasArgument("m2:1","m2:2",0).
term("m2:2").
hasSerialization("m2:2","X").
hasPositiveBodyAtom("m2:0","m2:3").
relationalAtom("m2:3").
hasName("m2:3","f1").
hasArgument("m2:3","m2:4",0).
term("m2:4").
hasSerialization("m2:4","X").
hasPositiveBodyAtom("m2:0","m2:5").
relationalAtom("m2:5").
hasName("m2:5","f2").
hasArgument("m2:5","m2:6",0).
term("m2:6").
hasSerialization("m2:6","A").
hasPositiveBodyAtom("m2:0","m2:7").
relationalAtom("m2:7").
hasName("m2:7","f3").
hasArgument("m2:7","m2:8",0).
term("m2:8").
hasSerialization("m2:8","X").
hasPositiveBodyAtom("m2:0","m2:9").
relationalAtom("m2:9").
hasName("m2:9","iRel1").
hasArgument("m2:9","m2:10",0).
term("m2:10").
hasSerialization("m2:10","X").
hasPositiveBodyAtom("m2:0","m2:11").
relationalAtom("m2:11").
hasName("m2:11","iRel3").
hasArgument("m2:11","m2:12",0).
term("m2:12").
hasSerialization("m2:12","A").
hasArgument("m2:11","m2:13",1).
term("m2:13").
hasSerialization("m2:13","X").
hasAnnotation("m2:0","m2:14").
annotation("m2:14").
hasName("m2:14","label").
hasArgument("m2:14","m2:15",0).
term("m2:15").
hasSerialization("m2:15","""R5""").
hasFact("m2","m2:16").
relationalAtom("m2:16").
hasName("m2:16","f1").
hasArgument("m2:16","m2:17",0).
term("m2:17").
hasSerialization("m2:17","""l3""").
hasFact("m2","m2:18").
relationalAtom("m2:18").
hasName("m2:18","f2").
hasArgument("m2:18","m2:19",0).
term("m2:19").
hasSerialization("m2:19","""l3""").
hasFact("m2","m2:20").
relationalAtom("m2:20").
hasName("m2:20","f2").
hasArgument("m2:20","m2:21",0).
term("m2:21").
hasSerialization("m2:21","""f1""").
hasAnnotation("m2","m2:22").
annotation("m2:22").
hasName("m2:22","module").
hasArgument("m2:22","m2:23",0).
term("m2:23").
hasSerialization("m2:23","""m2""").
hasAnnotation("m2","m2:24").
annotation("m2:24").
hasName("m2:24","inherits").
hasArgument("m2:24","m2:25",0).
term("m2:25").
hasSerialization("m2:25","""m1A""").
hasAnnotation("m2","m2:26").
annotation("m2:26").
hasName("m2:26","inherits").
hasArgument("m2:26","m2:27",0).
term("m2:27").
hasSerialization("m2:27","""m1B""").
hasAnnotation("m2","m2:28").
annotation("m2:28").
hasName("m2:28","inherits").
hasArgument("m2:28","m2:29",0).
term("m2:29").
hasSerialization("m2:29","""m1C""").
hasAnnotation("m2","m2:30").
annotation("m2:30").
hasName("m2:30","input").
hasArgument("m2:30","m2:31",0).
term("m2:31").
hasSerialization("m2:31","""violatingInput""").
hasAnnotation("m2","m2:32").
annotation("m2:32").
hasName("m2:32","bind").
hasArgument("m2:32","m2:33",0).
term("m2:33").
hasSerialization("m2:33","""iRel1""").
hasArgument("m2:32","m2:34",1).
term("m2:34").
hasSerialization("m2:34","""...m2""").
hasAnnotation("m2","m2:35").
annotation("m2:35").
hasName("m2:35","non_extensible_output").
hasAnnotation("m2","m2:36").
annotation("m2:36").
hasName("m2:36","input").
hasArgument("m2:36","m2:37",0).
term("m2:37").
hasSerialization("m2:37","""iRel1""").
hasAnnotation("m2","m2:38").
annotation("m2:38").
hasName("m2:38","redefinesQ").
hasArgument("m2:38","m2:39",0).
term("m2:39").
hasSerialization("m2:39","""R5""").
hasArgument("m2:38","m2:40",1).
term("m2:40").
hasSerialization("m2:40","""R3""").
hasArgument("m2:38","m2:41",2).
term("m2:41").
hasSerialization("m2:41","""m1B""").
hasAnnotation("m2","m2:42").
annotation("m2:42").
hasName("m2:42","output").
hasArgument("m2:42","m2:43",0).
term("m2:43").
hasSerialization("m2:43","""oRelE""").

program("m3").
hasRule("m3","m3:0").
rule("m3:0").
hasPositiveHeadAtom("m3:0","m3:1").
relationalAtom("m3:1").
hasName("m3:1","oRelF").
hasArgument("m3:1","m3:2",0).
term("m3:2").
hasSerialization("m3:2","X").
hasArgument("m3:1","m3:3",1).
term("m3:3").
hasSerialization("m3:3","Y").
hasPositiveBodyAtom("m3:0","m3:4").
relationalAtom("m3:4").
hasName("m3:4","iRel1").
hasArgument("m3:4","m3:5",0).
term("m3:5").
hasSerialization("m3:5","X").
hasPositiveBodyAtom("m3:0","m3:6").
relationalAtom("m3:6").
hasName("m3:6","iRel2").
hasArgument("m3:6","m3:7",0).
term("m3:7").
hasSerialization("m3:7","X").
hasPositiveBodyAtom("m3:0","m3:8").
relationalAtom("m3:8").
hasName("m3:8","iRel3").
hasArgument("m3:8","m3:9",0).
term("m3:9").
hasSerialization("m3:9","X").
hasArgument("m3:8","m3:10",1).
term("m3:10").
hasSerialization("m3:10","Y").
hasPositiveBodyAtom("m3:0","m3:11").
relationalAtom("m3:11").
hasName("m3:11","iRel4").
hasArgument("m3:11","m3:12",0).
term("m3:12").
hasSerialization("m3:12","Y").
hasAnnotation("m3:0","m3:13").
annotation("m3:13").
hasName("m3:13","label").
hasArgument("m3:13","m3:14",0).
term("m3:14").
hasSerialization("m3:14","""R6""").
hasAnnotation("m3","m3:15").
annotation("m3:15").
hasName("m3:15","module").
hasArgument("m3:15","m3:16",0).
term("m3:16").
hasSerialization("m3:16","""m3""").
hasAnnotation("m3","m3:17").
annotation("m3:17").
hasName("m3:17","inherits").
hasArgument("m3:17","m3:18",0).
term("m3:18").
hasSerialization("m3:18","""m2""").
hasAnnotation("m3","m3:19").
annotation("m3:19").
hasName("m3:19","removeQ").
hasArgument("m3:19","m3:20",0).
term("m3:20").
hasSerialization("m3:20","""F1""").
hasArgument("m3:19","m3:21",1).
term("m3:21").
hasSerialization("m3:21","""m1C""").
hasAnnotation("m3","m3:22").
annotation("m3:22").
hasName("m3:22","output").
hasArgument("m3:22","m3:23",0).
term("m3:23").
hasSerialization("m3:23","""oRelF""").

true(#T). false(#F).

% Find module labels for module IDs
moduleLbl(M,L) :- hasAnnotation(M,A), hasName(A,"module"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
resultset(S,M) :- hasAnnotation(S,A), hasName(A,"resultset"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), M = substring(L1,1,string_length(L1)-1).

% Find Id of module to be derived
deriveModule(M) :- toDerive(L), moduleLbl(M,L).

% Determine inheritance relationships in provided meta-representations
inherits(MC,MP) :- hasAnnotation(MC,A), hasName(A,"inherits"), hasArgument(A,Arg,0), hasSerialization(Arg,MP1), moduleLbl(MP,MPL), MPL = substring(MP1,1,string_length(MP1)-1).
tInherits(M,M2) :- inherits(M,M2).
tInherits(M,M2) :- tInherits(M,M1), inherits(M1,M2).

% Predicates in a module
predicate(M,P) :- inputPredicate(M,P).
predicate(M,P) :- outputPredicate(M,P).
predicate(M,P) :- tHasFact(M,F), relationalAtom(F), hasName(F,P).
predicate(M,P) :- mHasRule(M,R), ruleHeadPredicate(R,P).
predicate(M,P) :- mHasRule(M,R), ruleBodyPredicate(R,P).

inputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"input"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).
outputPredicate(M,P) :- tHasAnnotationM(M,A), hasName(A,"output"), not tModOpStmt(M,_,A), hasArgument(A,Arg2,0), hasSerialization(Arg2,L1), P = substring(L1,1,string_length(L1)-1).

% Defined restrictions and modification operations
restriction("no_additional_input").
restriction("no_additional_output").
restriction("no_additional_annotation").
restriction("non_omitable").
restriction("non_redefinable").
restriction("non_shrinkable").
restriction("non_growable").
modOp("remove"). modOp("removeQ").
modOp("redefines"). modOp("redefinesQ").
modOp("inherits").

% Inheritance Annotations
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), restriction(N).
inhAnnotation(A) :- hasAnnotation(_,A), hasName(A,N), modOp(N).

% Which statements exist in a module?
hasStmt(M,S) :- hasRule(M,S).
hasStmt(M,S) :- hasFact(M,S).
hasStmt(M,S) :- moduleLbl(M,_), hasAnnotation(M,S).

% Only labeled statements are interesting, others always propagated
stmtLbl(R,L) :- hasRule(M,R), hasAnnotation(R,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(F,L) :- hasFact(M,F), hasAnnotation(F,A), hasName(A,"label"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtLbl(A,L) :- hasAnnotation(M,A), hasAnnotation(A,A2), hasName(A2,"label"), hasArgument(A2,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).
stmtML(M,S,L) :- stmtLbl(S,L), hasStmt(M,S).

% Atoms in a rule
hasAtom(R,A):- hasNegativeBodyAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasPositiveBodyAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasNegativeHeadAtom(R,A), relationalAtom(A).
hasAtom(R,A):- hasPositiveHeadAtom(R,A), relationalAtom(A).

ruleBodyPredicate(R,P):- tHasRule(M,R), hasNegativeBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleBodyPredicate(R,P):- tHasRule(M,R), hasPositiveBodyAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- tHasRule(M,R), hasNegativeHeadAtom(R,A), relationalAtom(A), hasName(A,P).
ruleHeadPredicate(R,P):- tHasRule(M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P).
predicateDependency(M,P,P2) :- tHasRule(M,R), ruleHeadPredicate(R,P), ruleBodyPredicate(R,P2).

% RESOLVE INHERITANCE
% Unqualified remove and redefine
redefineStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"redefines"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), L = substring(L1,1,string_length(L1)-1).
removeStmtLbl(M,L) :- hasAnnotation(M,A), hasName(A,"remove"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), L = substring(L1,1,string_length(L1)-1).
% Any statement except inheritance annotations can be removed
redefineStmt(M,S):- redefineStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).
removeStmt(M,S):- removeStmtLbl(M,L), stmtLbl(S,L), not inhAnnotation(S).

% Qualified remove and redefine
redefineStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"redefinesQ"), hasArgument(A,Arg2,1), hasSerialization(Arg2,L1), hasArgument(A,Arg3,2), hasSerialization(Arg3,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
removeStmtQ(M,L,MQ) :- hasAnnotation(M,A), hasName(A,"removeQ"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), L = substring(L1,1,string_length(L1)-1), MQ = substring(L2,1,string_length(L2)-1).
redefineStmt(M,S) :- redefineStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).
removeStmt(M,S) :- removeStmtQ(M,L,MQ), stmtML(MQ,S,L), not inhAnnotation(S).

% Module name annotations are not inherited
removeStmt(M,A) :- hasAnnotation(M,A), hasName(A,"module"), not deriveModule(M).

% Modification operation statements
modOpStmt(M,S) :- removeStmt(M,S).
modOpStmt(M,S) :- redefineStmt(M,S).
tModOpStmt(M,M,S) :- modOpStmt(M,S).
tModOpStmt(M,Morg,S) :- inherits(M,M2), tModOpStmt(M2,Morg,S).

% DETERMINE ACTIVE STATEMENTS AND MODULE/STATEMENT ANNOTATIONS FOR MODULES
% Derive for each module its active rules by inheriting
tHasRule(M,R) :- hasRule(M,R).
tHasRule(M,R) :- inherits(M,MP), tHasRule(MP,R).
moduleStmt(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).
mHasRule(M,R) :- tHasRule(M,R), not tModOpStmt(M,_,R).

% Determine for each module its active facts by inheriting
tHasFact(M,F) :- hasFact(M,F).
tHasFact(M,F) :- inherits(M,MP), tHasFact(MP,F).
moduleStmt(M,F) :- tHasFact(M,F), not tModOpStmt(M,_,F).

% Determine for each module its active module and statement annotations
tHasAnnotationM(M,A) :- moduleLbl(M,L), hasAnnotation(M,A), hasName(A,N), not modOp(N).
tHasAnnotationM(M,A) :- inherits(M,MP), tHasAnnotationM(MP,A).
tHasAnnotationS(M,Stmt,A) :- hasStmt(M,Stmt), hasAnnotation(Stmt,A).
tHasAnnotationS(M,Stmt,A) :- inherits(M,MP), tHasAnnotationS(MP,Stmt,A).
moduleStmt(M,A) :- tHasAnnotationM(M,A), not tModOpStmt(M,_,A).

% Determine Restrictions defined in modules
noAdditionalInput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_input").
noAdditionalOutput(M) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_output").
noAdditionalAnnotation(M,ANN,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"no_additional_annotation"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), P = substring(L1,1,string_length(L1)-1), ANN = substring(L2,1,string_length(L2)-1).
nonOmitable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_omitable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonRedefinable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_redefinable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).
nonGrowable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_growable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P  =substring(L1,1,string_length(L1)-1).
nonShrinkable(M,P) :- moduleStmt(M,F), tHasAnnotationM(M,A), hasName(A,"non_shrinkable"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), P = substring(L1,1,string_length(L1)-1).

% -----------------------------------------------------------------------------
% PRELIMINARY STATIC DETECTION OF MODIFICATIONS
% -----------------------------------------------------------------------------
redefinesRule(M2,R2,R) :- hasAnnotation(M2,A), hasName(A,"redefines"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), stmtLbl(R2,R2Lbl), stmtLbl(R,RLbl), R2Lbl=substring(L1,1,string_length(L1)-1), RLbl=substring(L2,1,string_length(L2)-1).
redefinesRule(M2,R2,R) :- hasAnnotation(M2,A), hasName(A,"redefinesQ"), hasArgument(A,Arg1,0), hasSerialization(Arg1,L1), hasArgument(A,Arg2,1), hasSerialization(Arg2,L2), hasArgument(A,Arg3,2), hasSerialization(Arg3,L3), stmtLbl(R2,R2Lbl), stmtML(M,R,RLbl), R2Lbl=substring(L1,1,string_length(L1)-1), RLbl=substring(L2,1,string_length(L2)-1), M = substring(L3,1,string_length(L3)-1).

identicalAtom(R1,A1,R2,A2,P) :- redefinesRule(_,R2,R1), hasPositiveBodyAtom(R1,A1), hasName(A1,P), hasPositiveBodyAtom(R2,A2), hasName(A2,P), relationalAtom(A1), relationalAtom(A2), not differingAtom(R1,A1,R2,A2,P).
differingAtom(R1,A1,R2,A2,P) :- redefinesRule(_,R2,R1), hasPositiveBodyAtom(R1,A1), hasPositiveBodyAtom(R2,A2), relationalAtom(A1), relationalAtom(A2), hasName(A1,P), hasName(A2,P), hasArgument(A1,Arg1,Pos), hasArgument(A2,Arg2,Pos), hasSerialization(Arg1,S1), hasSerialization(Arg2,S2), S1!=S2, A1!=A2.

% Added Rules or removed rules imply facts grown or removed respectively
factsGrown(M2,M,P) :- tInherits(M2,M), hasRule(M2,R), not redefinesRule(M2,R,_), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P), outputPredicate(M,P).
factsGrown(M2,M,P) :- inherits(M2,M), hasRule(M,R), not redefinesRule(M2,R,_), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P), tInherits(M2,M3), hasRule(M3,R2), not redefinesRule(M2,R2,_), hasPositiveHeadAtom(R2,A2), relationalAtom(A2), hasName(A2,P), outputPredicate(_,P), M <> M3.
factsShrunk(M2,M,P) :- tInherits(M2,M), removeStmt(M2,R), hasRule(M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P), outputPredicate(M,P).

% Determine modifications to redefined rules
samePosPredicate(M2,M,R2,P) :- redefinesRule(M2,R2,R), hasRule(M,R), hasPositiveBodyAtom(R,A), hasPositiveBodyAtom(R2,A2), identicalAtom(R,A,R2,A2,P).
lessPosPredicate(M2,M,R2,P) :- redefinesRule(M2,R2,R), hasRule(M,R), hasPositiveBodyAtom(R,A), relationalAtom(A), hasName(A,P), not samePosPredicate(M2,M,R2,P).
morePosPredicate(M2,M,R2,P) :- redefinesRule(M2,R2,R), hasRule(M,R), hasPositiveBodyAtom(R2,A2), relationalAtom(A2), hasName(A2,P), not samePosPredicate(M2,M,R2,P).

sameNegPredicate(M2,M,R2,P) :- redefinesRule(M2,R2,R), hasRule(M,R), hasNegativeBodyAtom(R,A), relationalAtom(A), hasName(A,P), hasNegativeBodyAtom(R2,A2), relationalAtom(A2), hasName(A2,P2), P2=P.
lessNegPredicate(M2,M,R2,P) :- redefinesRule(M2,R2,R), hasRule(M,R), hasNegativeBodyAtom(R,A), relationalAtom(A), hasName(A,P), not sameNegPredicate(M2,M,R2,P).
moreNegPredicate(M2,M,R2,P) :- redefinesRule(M2,R2,R), hasRule(M,R), hasNegativeBodyAtom(R2,A2), relationalAtom(A2), hasName(A2,P), not sameNegPredicate(M2,M,R2,P).

someCondition(M,R) :- hasRule(M,R), hasPositiveBodyAtom(R,A), nonRelationalAtom(A).
noCondition(M,R) :- hasRule(M,R), not someCondition(M,R).
sameCondition(M2,M,R2,C) :- redefinesRule(M2,R2,R), hasRule(M,R), hasPositiveBodyAtom(R,A), nonRelationalAtom(A), hasSerialization(A,C), hasPositiveBodyAtom(R2,A2), nonRelationalAtom(A2), hasSerialization(A2,C).
diffCondition(M2,M,R2) :- redefinesRule(M2,R2,R), hasRule(M,R), not noCondition(M,R), hasPositiveBodyAtom(R,A), nonRelationalAtom(A), hasSerialization(A,C), not sameCondition(M2,M,R2,C).
diffCondition(M2,M,R2) :- redefinesRule(M2,R2,R), hasRule(M,R), not noCondition(M,R), hasPositiveBodyAtom(R2,A2), nonRelationalAtom(A2), hasSerialization(A2,C), not sameCondition(M2,M,R2,C).

% Determine facts grown or shrunk for redefined rules
factsGrown(M2,M,P) :- lessPosPredicate(M2,M,R,_), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P), outputPredicate(M2,P).
factsGrown(M2,M,P) :- lessNegPredicate(M2,M,R,_), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P), outputPredicate(M2,P).
factsShrunk(M2,M,P) :- morePosPredicate(M2,M,R,_), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P), outputPredicate(M2,P).
factsShrunk(M2,M,P) :- moreNegPredicate(M2,M,R,_), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P), outputPredicate(M2,P).

factsGrown(M2,M,P) :- diffCondition(M2,M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P), outputPredicate(M2,P).
factsShrunk(M2,M,P) :- diffCondition(M2,M,R), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P), outputPredicate(M2,P).
factsShrunk(M2,M,P) :- redefinesRule(M2,R2,R), noCondition(M,R), someCondition(M2,R2), hasPositiveHeadAtom(R,A), relationalAtom(A), hasName(A,P), outputPredicate(M2,P).

factsGrown(M2,M,P) :- differingAtom(R1,_,R2,_,_), mHasRule(M,R1), mHasRule(M2,R2), hasPositiveHeadAtom(R2,A), relationalAtom(A), hasName(A,P), outputPredicate(M2,P).
factsShrunk(M2,M,P) :- differingAtom(R1,_,R2,_,_), mHasRule(M,R1), mHasRule(M2,R2), hasPositiveHeadAtom(R2,A), relationalAtom(A), hasName(A,P), outputPredicate(M2,P).

% Propagate fact changes along rule dependencies
factsGrown(M2,M,P) :- mHasRule(M,R), hasPositiveHeadAtom(R,A0), hasName(A0,P), hasPositiveBodyAtom(R,A), hasName(A,N), factsGrown(M2,M,N).
factsGrown(M2,M,P) :- mHasRule(M,R), hasPositiveHeadAtom(R,A0), hasName(A0,P), hasNegativeBodyAtom(R,A), hasName(A,N), factsShrunk(M2,M,N).

factsShrunk(M2,M,P) :- mHasRule(M,R), hasPositiveHeadAtom(R,A0), hasName(A0,P), hasPositiveBodyAtom(R,A), hasName(A,N), factsShrunk(M2,M,N).
factsShrunk(M2,M,P) :- mHasRule(M,R), hasPositiveHeadAtom(R,A0), hasName(A0,P), hasNegativeBodyAtom(R,A), hasName(A,N), factsGrown(M2,M,N).

factsModified(M2,M,P) :- factsGrown(M2,M,P), factsShrunk(M2,M,P).
factsIdentical(M2,M) :- moduleLbl(M,_), moduleLbl(M2,_), tInherits(M2,M), not factsGrown(M2,_,_), not factsShrunk(M2,_,_).

grown(M2,M,P) :- factsGrown(M2,M,P), not factsModified(M2,M,P).
shrunk(M2,M,P) :- factsShrunk(M2,M,P), not factsModified(M2,M,P).

@output("grown"). @output("shrunk").
@output("factsModified"). @post("factsModified","orderby(1,2,3)").
@output("factsIdentical").
@output("factsGrown"). @post("factsGrown", "orderby(1,2,3)"). @post("factsGrown","unique"). @post("factsShrunk","unique").
@output("factsShrunk"). @post("factsShrunk", "orderby(1,2,3)").

% ------------------------------------------------------------------------
% BEHAVIORAL RESTRICTIONS
% ------------------------------------------------------------------------
w_nonGrowable(C,P,PRED) :- resultset(RS1,C), moduleLbl(C,_), resultset(RS2,P), tInherits(C,P), nonGrowable(P,PRED), factsGrown(C,P,PRED).
w_nonShrinkable(C,P,PRED) :- resultset(RS1,C), moduleLbl(C,_), resultset(RS2,P), tInherits(C,P), nonShrinkable(P,PRED), factsShrunk(C,P,PRED).

@output("w_nonGrowable").
@output("w_nonShrinkable").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">factsIdentical</caption><thead><tr><th>string</th><th>string</th></tr></thead><tbody><tr><td>m1A</td><td>m</td></tr></tbody><tbody><tr><td>m3</td><td>m</td></tr></tbody><tbody><tr><td>m3</td><td>m1A</td></tr></tbody><tbody><tr><td>m3</td><td>m1B</td></tr></tbody><tbody><tr><td>m3</td><td>m1C</td></tr></tbody><tbody><tr><td>m3</td><td>m2</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">factsModified</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>m1B</td><td>oRelE</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">factsGrown</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>m1A</td><td>oRelC</td></tr></tbody><tbody><tr><td>m2</td><td>m1B</td><td>oRelE</td></tr></tbody><tbody><tr><td>m2</td><td>m1C</td><td>oRelC</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">shrunk</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m1C</td><td>m</td><td>oRelB</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">grown</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2</td><td>m1A</td><td>oRelC</td></tr></tbody><tbody><tr><td>m2</td><td>m1C</td><td>oRelC</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">factsShrunk</caption><thead><tr><th>string</th><th>string</th><th>string</th></tr></thead><tbody><tr><td>m1C</td><td>m</td><td>oRelB</td></tr></tbody><tbody><tr><td>m2</td><td>m1B</td><td>oRelE</td></tr></tbody></table></div></div></div>

# %% [markdown]
# **Expected:**
#
# +/- `oRelE` in m2 (due to redefining m1B.R3) [`temp` in m1A (due to redefining m.M-R2) - is not in the output]
#
# `+` `oRelC` in m2
#
# `-` `oRelB` in m1C
