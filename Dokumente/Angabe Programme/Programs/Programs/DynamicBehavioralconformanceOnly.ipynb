# %% [markdown]
# # Resultsets

# %%
%%tometa("m1")
@resultset("m1").
f1(1).
f1(2).
f2(3).
f2(4).
f3(0).
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m1").
# hasFact("m1","m1:0").
# relationalAtom("m1:0").
# hasName("m1:0","f1").
# hasArgument("m1:0","m1:1",0).
# term("m1:1").
# hasSerialization("m1:1","1").
# hasFact("m1","m1:2").
# relationalAtom("m1:2").
# hasName("m1:2","f1").
# hasArgument("m1:2","m1:3",0).
# term("m1:3").
# hasSerialization("m1:3","2").
# hasFact("m1","m1:4").
# relationalAtom("m1:4").
# hasName("m1:4","f2").
# hasArgument("m1:4","m1:5",0).
# term("m1:5").
# hasSerialization("m1:5","3").
# hasFact("m1","m1:6").
# relationalAtom("m1:6").
# hasName("m1:6","f2").
# hasArgument("m1:6","m1:7",0).
# term("m1:7").
# hasSerialization("m1:7","4").
# hasFact("m1","m1:8").
# relationalAtom("m1:8").
# hasName("m1:8","f3").
# hasArgument("m1:8","m1:9",0).
# term("m1:9").
# hasSerialization("m1:9","0").
# hasAnnotation("m1","m1:10").
# annotation("m1:10").
# hasName("m1:10","resultset").
# hasArgument("m1:10","m1:11",0).
# term("m1:11").
# hasSerialization("m1:11","""M1""").
# </textarea></div></div>

# %%
%%toMeta("m2")
@resultset("m2").
f1(1).
f1(2).
f1(3).
f2(3).
f2(4).
f2(5).
f3(0).
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m2").
# hasFact("m2","m2:0").
# relationalAtom("m2:0").
# hasName("m2:0","f1").
# hasArgument("m2:0","m2:1",0).
# term("m2:1").
# hasSerialization("m2:1","1").
# hasFact("m2","m2:2").
# relationalAtom("m2:2").
# hasName("m2:2","f1").
# hasArgument("m2:2","m2:3",0).
# term("m2:3").
# hasSerialization("m2:3","2").
# hasFact("m2","m2:4").
# relationalAtom("m2:4").
# hasName("m2:4","f1").
# hasArgument("m2:4","m2:5",0).
# term("m2:5").
# hasSerialization("m2:5","3").
# hasFact("m2","m2:6").
# relationalAtom("m2:6").
# hasName("m2:6","f2").
# hasArgument("m2:6","m2:7",0).
# term("m2:7").
# hasSerialization("m2:7","3").
# hasFact("m2","m2:8").
# relationalAtom("m2:8").
# hasName("m2:8","f2").
# hasArgument("m2:8","m2:9",0).
# term("m2:9").
# hasSerialization("m2:9","4").
# hasFact("m2","m2:10").
# relationalAtom("m2:10").
# hasName("m2:10","f2").
# hasArgument("m2:10","m2:11",0).
# term("m2:11").
# hasSerialization("m2:11","5").
# hasFact("m2","m2:12").
# relationalAtom("m2:12").
# hasName("m2:12","f3").
# hasArgument("m2:12","m2:13",0).
# term("m2:13").
# hasSerialization("m2:13","0").
# hasAnnotation("m2","m2:14").
# annotation("m2:14").
# hasName("m2:14","resultset").
# hasArgument("m2:14","m2:15",0).
# term("m2:15").
# hasSerialization("m2:15","""M2""").
# </textarea></div></div>

# %%
%%toMeta("m3")
@resultset("m2").
f1(1).
f1(3).
f2(3).
f2(4).
f3(0).
f3(1).
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m3").
# hasFact("m3","m3:0").
# relationalAtom("m3:0").
# hasName("m3:0","f1").
# hasArgument("m3:0","m3:1",0).
# term("m3:1").
# hasSerialization("m3:1","1").
# hasFact("m3","m3:2").
# relationalAtom("m3:2").
# hasName("m3:2","f1").
# hasArgument("m3:2","m3:3",0).
# term("m3:3").
# hasSerialization("m3:3","3").
# hasFact("m3","m3:4").
# relationalAtom("m3:4").
# hasName("m3:4","f2").
# hasArgument("m3:4","m3:5",0).
# term("m3:5").
# hasSerialization("m3:5","3").
# hasFact("m3","m3:6").
# relationalAtom("m3:6").
# hasName("m3:6","f2").
# hasArgument("m3:6","m3:7",0).
# term("m3:7").
# hasSerialization("m3:7","4").
# hasFact("m3","m3:8").
# relationalAtom("m3:8").
# hasName("m3:8","f3").
# hasArgument("m3:8","m3:9",0).
# term("m3:9").
# hasSerialization("m3:9","0").
# hasFact("m3","m3:10").
# relationalAtom("m3:10").
# hasName("m3:10","f3").
# hasArgument("m3:10","m3:11",0).
# term("m3:11").
# hasSerialization("m3:11","1").
# hasAnnotation("m3","m3:12").
# annotation("m3:12").
# hasName("m3:12","resultset").
# hasArgument("m3:12","m3:13",0).
# term("m3:13").
# hasSerialization("m3:13","""m2""").
# </textarea></div></div>

# %%
%%toMeta("m1Org")
@module("m1").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m1Org").
# hasAnnotation("m1Org","m1Org:0").
# annotation("m1Org:0").
# hasName("m1Org:0","module").
# hasArgument("m1Org:0","m1Org:1",0).
# term("m1Org:1").
# hasSerialization("m1Org:1","""m1""").
# </textarea></div></div>

# %%
%%toMeta("m2Org")
@module("m2"). @inherits("m1").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m2Org").
# hasAnnotation("m2Org","m2Org:0").
# annotation("m2Org:0").
# hasName("m2Org:0","module").
# hasArgument("m2Org:0","m2Org:1",0).
# term("m2Org:1").
# hasSerialization("m2Org:1","""m2""").
# hasAnnotation("m2Org","m2Org:2").
# annotation("m2Org:2").
# hasName("m2Org:2","inherits").
# hasArgument("m2Org:2","m2Org:3",0).
# term("m2Org:3").
# hasSerialization("m2Org:3","""m1""").
# </textarea></div></div>

# %%
%%toMeta("m3Org")
@module("m3"). @inherits("m1").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block"><div class="vadalog-output-header">metaProgram</div><div class="vadalog-output-header"><textarea rows="10" class="vadalog-meta-program-textarea">
# program("m3Org").
# hasAnnotation("m3Org","m3Org:0").
# annotation("m3Org:0").
# hasName("m3Org:0","module").
# hasArgument("m3Org:0","m3Org:1",0).
# term("m3Org:1").
# hasSerialization("m3Org:1","""m3""").
# hasAnnotation("m3Org","m3Org:2").
# annotation("m3Org:2").
# hasName("m3Org:2","inherits").
# hasArgument("m3Org:2","m3Org:3",0).
# term("m3Org:3").
# hasSerialization("m3Org:3","""m1""").
# </textarea></div></div>

# %% [markdown]
# # Test several input resultsets

# %%
program("m1Org").
hasAnnotation("m1Org","m1Org:0").
annotation("m1Org:0").
hasName("m1Org:0","module").
hasArgument("m1Org:0","m1Org:1",0).
term("m1Org:1").
hasSerialization("m1Org:1","""m1""").

program("m2Org").
hasAnnotation("m2Org","m2Org:0").
annotation("m2Org:0").
hasName("m2Org:0","module").
hasArgument("m2Org:0","m2Org:1",0).
term("m2Org:1").
hasSerialization("m2Org:1","""m2""").
hasAnnotation("m2Org","m2Org:2").
annotation("m2Org:2").
hasName("m2Org:2","inherits").
hasArgument("m2Org:2","m2Org:3",0).
term("m2Org:3").
hasSerialization("m2Org:3","""m1""").

program("m3Org").
hasAnnotation("m3Org","m3Org:0").
annotation("m3Org:0").
hasName("m3Org:0","module").
hasArgument("m3Org:0","m3Org:1",0).
term("m3Org:1").
hasSerialization("m3Org:1","""m3""").
hasAnnotation("m3Org","m3Org:2").
annotation("m3Org:2").
hasName("m3Org:2","inherits").
hasArgument("m3Org:2","m3Org:3",0).
term("m3Org:3").
hasSerialization("m3Org:3","""m1""").




program("m1").
hasFact("m1","m1:0").
relationalAtom("m1:0").
hasName("m1:0","f1").
hasArgument("m1:0","m1:1",0).
term("m1:1").
hasSerialization("m1:1","1").
hasFact("m1","m1:2").
relationalAtom("m1:2").
hasName("m1:2","f1").
hasArgument("m1:2","m1:3",0).
term("m1:3").
hasSerialization("m1:3","2").
hasFact("m1","m1:4").
relationalAtom("m1:4").
hasName("m1:4","f2").
hasArgument("m1:4","m1:5",0).
term("m1:5").
hasSerialization("m1:5","3").
hasFact("m1","m1:6").
relationalAtom("m1:6").
hasName("m1:6","f2").
hasArgument("m1:6","m1:7",0).
term("m1:7").
hasSerialization("m1:7","4").
hasFact("m1","m1:8").
relationalAtom("m1:8").
hasName("m1:8","f3").
hasArgument("m1:8","m1:9",0).
term("m1:9").
hasSerialization("m1:9","0").
hasAnnotation("m1","m1:10").
annotation("m1:10").
hasName("m1:10","resultset").
hasArgument("m1:10","m1:11",0).
term("m1:11").
hasSerialization("m1:11","""m1""").

program("m2").
hasFact("m2","m2:0").
relationalAtom("m2:0").
hasName("m2:0","f1").
hasArgument("m2:0","m2:1",0).
term("m2:1").
hasSerialization("m2:1","1").
hasFact("m2","m2:2").
relationalAtom("m2:2").
hasName("m2:2","f1").
hasArgument("m2:2","m2:3",0).
term("m2:3").
hasSerialization("m2:3","2").
hasFact("m2","m2:4").
relationalAtom("m2:4").
hasName("m2:4","f1").
hasArgument("m2:4","m2:5",0).
term("m2:5").
hasSerialization("m2:5","3").
hasFact("m2","m2:6").
relationalAtom("m2:6").
hasName("m2:6","f2").
hasArgument("m2:6","m2:7",0).
term("m2:7").
hasSerialization("m2:7","3").
hasFact("m2","m2:8").
relationalAtom("m2:8").
hasName("m2:8","f2").
hasArgument("m2:8","m2:9",0).
term("m2:9").
hasSerialization("m2:9","4").
hasFact("m2","m2:10").
relationalAtom("m2:10").
hasName("m2:10","f2").
hasArgument("m2:10","m2:11",0).
term("m2:11").
hasSerialization("m2:11","5").
hasFact("m2","m2:12").
relationalAtom("m2:12").
hasName("m2:12","f3").
hasArgument("m2:12","m2:13",0).
term("m2:13").
hasSerialization("m2:13","0").
hasAnnotation("m2","m2:14").
annotation("m2:14").
hasName("m2:14","resultset").
hasArgument("m2:14","m2:15",0).
term("m2:15").
hasSerialization("m2:15","""m2""").

program("m3").
hasFact("m3","m3:0").
relationalAtom("m3:0").
hasName("m3:0","f1").
hasArgument("m3:0","m3:1",0).
term("m3:1").
hasSerialization("m3:1","1").
hasFact("m3","m3:2").
relationalAtom("m3:2").
hasName("m3:2","f1").
hasArgument("m3:2","m3:3",0).
term("m3:3").
hasSerialization("m3:3","3").
hasFact("m3","m3:4").
relationalAtom("m3:4").
hasName("m3:4","f2").
hasArgument("m3:4","m3:5",0).
term("m3:5").
hasSerialization("m3:5","3").
hasFact("m3","m3:6").
relationalAtom("m3:6").
hasName("m3:6","f2").
hasArgument("m3:6","m3:7",0).
term("m3:7").
hasSerialization("m3:7","4").
hasFact("m3","m3:8").
relationalAtom("m3:8").
hasName("m3:8","f3").
hasArgument("m3:8","m3:9",0).
term("m3:9").
hasSerialization("m3:9","0").
hasFact("m3","m3:10").
relationalAtom("m3:10").
hasName("m3:10","f3").
hasArgument("m3:10","m3:11",0).
term("m3:11").
hasSerialization("m3:11","1").
hasAnnotation("m3","m3:12").
annotation("m3:12").
hasName("m3:12","resultset").
hasArgument("m3:12","m3:13",0).
term("m3:13").
hasSerialization("m3:13","""m2""").


% ------------------------------------------------------------------------
% BEHAVIORAL MODIFICATION DETECTION
%
% ------------------------------------------------------------------------
% Find module labels for module IDs
moduleLbl(M,L) :- hasAnnotation(M,A), hasName(A,"module"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), L = substring(L1,1,string_length(L1)-1).

% Determine inheritance relationships in provided meta-representations
inherits(MC,MP) :- hasAnnotation(MC,A), hasName(A,"inherits"), hasArgument(A,Arg,0), hasSerialization(Arg,MP1), moduleLbl(MP,MPL), MPL = substring(MP1,1,string_length(MP1)-1).
tInherits(M,M2) :- inherits(M,M2).
tInherits(M,M2) :- tInherits(M,M1), inherits(M1,M2).

%requires resultsets where an annotation @resultset("<module>") is required where <module> is the module generating the resultset
resultset(RS,M) :- hasAnnotation(RS,A), hasName(A,"resultset"), hasArgument(A,Arg,0), hasSerialization(Arg,L1), moduleLbl(M,L), L = substring(L1,1,string_length(L1)-1).

%Currently only either numbers or strings in facts are possible, currently no means to check for type of serialization!!
%FOR strings only
%factPredicate(M,F,PRED,CONST,POS) :- resultset(M,_), hasFact(M,F), relationalAtom(F), hasName(F,PRED), hasArgument(F,Arg,POS), term(Arg), hasSerialization(Arg,L), CONST = substring(L,1,string_length(L)-1).
%FOR numbers only
factPredicate(M,F,PRED,L,POS) :- resultset(M,_), hasFact(M,F), relationalAtom(F), hasName(F,PRED), hasArgument(F,Arg,POS), term(Arg), hasSerialization(Arg,L).

factsGrown(C,P,PRED) :- moduleLbl(C,_), moduleLbl(P,_), resultset(RS1,C), resultset(RS2,P), tInherits(C,P), factPredicate(RS1,_,PRED,ARG,POS), not factPredicate(RS2,_,PRED,ARG,POS), factPredicate(RS2,_,PRED,_,_).
factsGrown(C,P,PRED) :- moduleLbl(C,_), moduleLbl(P,_), resultset(RS1,C), resultset(RS2,P), tInherits(C,P), factPredicate(RS1,_,PRED,ARG,POS), not factPredicate(RS2,_,PRED,ARG,POS), factPredicate(RS2,_,PRED,_,_).
factsShrunk(C,P,PRED) :- moduleLbl(C,_), moduleLbl(P,_), resultset(RS1,C), resultset(RS2,P), tInherits(C,P), factPredicate(RS2,_,PRED,ARG,POS), not factPredicate(RS1,_,PRED,ARG,POS).
factsModified(M2,M,P) :- factsGrown(M2,M,P), factsShrunk(M2,M,P).
factsIdentical(C,P) :- resultset(_,C), resultset(_,P), tInherits(C,P), moduleLbl(C,_), moduleLbl(P,_), not factsGrown(C,P,_), not factsShrunk(C,P,_).

grown(M2,M,P) :- factsGrown(M2,M,P), not factsModified(M2,M,P).
shrunk(M2,M,P) :- factsShrunk(M2,M,P), not factsModified(M2,M,P).

@output("factsGrown"). @ouput("factsGrown","orderby(1,2,3").
@output("factsShrunk"). @ouput("factsShrunk","orderby(1,2,3)").
@output("factsModified"). @ouput("factsModified","orderby(1,2)").
@output("factsIdentical"). @ouput("factsIdentical","orderby(1,2)").
@output("grown").
@output("shrunk").


%@output("resultset"). @output("tInherits"). @output("test"). @output("inherits"). @output("moduleLbl").
@output("factPredicate"). @output("moduleLbl").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">factsIdentical</caption><thead><tr><th>string</th><th>string</th></tr></thead><tbody><tr><td>m2Org</td><td>m1Org</td></tr></tbody></table></div></div><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">moduleLbl</caption><thead><tr><th>string</th><th>string</th></tr></thead><tbody><tr><td>m1Org</td><td>m1</td></tr></tbody><tbody><tr><td>m2Org</td><td>m2</td></tr></tbody><tbody><tr><td>m3Org</td><td>m3</td></tr></tbody></table></div></div></div>

# %% [markdown]
# **m1 - m2**
# f1+
# f2+
# f3=
#
# **m1 - m3**
# f1+-
# f2=
# f3+
